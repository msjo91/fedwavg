# %%
# %matplotlib inline

dataset = 'svhn'
clsimb = [2, 3, 4] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_scaffold'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 3

# %%
import copy
import json
import logging
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/train_32x32.mat
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/test_32x32.mat

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
def average_weights(w):
    w_avg = copy.deepcopy(w[0])
        
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
    return w_avg

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, other_models):
    epoch_losses = []
    
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    
    # SCAFFOLD
    global_model, c_global_model, c_local_model = other_models[0], other_models[1], other_models[2]
    c_global_state, c_local_state = c_global_model.state_dict(), c_local_model.state_dict()
    cnt = 0
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())
            
            # SCAFFOLD
            local_state = model.state_dict()
            for  k in local_state:
                local_state[k] = local_state[k] - (lr * (c_global_state[k] - c_local_state[k]))
            model.load_state_dict(local_state)
            cnt += 1

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    # SCAFFOLD        
    new_c_local_state = c_local_model.state_dict()
    c_delta_state = copy.deepcopy(new_c_local_state)
    local_state, global_state = model.state_dict(), global_model.state_dict()
    for k in local_state:
        new_c_local_state[k] = new_c_local_state[k] + ((global_state[k] - local_state[k]) / (lr * cnt) - c_global_state[k])
        c_delta_state[k] = new_c_local_state[k] - c_local_state[k]
    c_local_model.load_state_dict(new_c_local_state)
    
    local_weights = model.state_dict()

    return local_weights, epoch_losses, c_delta_state

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0

logger.info(f'\nAlgorithm: Scaffold\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

# SCAFFOLD
c_fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
c_fed_model.to(device)

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    # SCAFFOLD
    other_models = [fed_model, c_fed_model, copy.deepcopy(c_fed_model)]
    delta_state = copy.deepcopy(fed_model.state_dict())
    for k in delta_state:
        delta_state[k] = 0.0
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls, c_delta_state = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, other_models)

        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
        # SCAFFOLD
        for k in c_delta_state:
            delta_state[k] = delta_state[k] + c_delta_state[k]
        
    fed_weights = average_weights(local_weights)
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    # SCAFFOLD
    c_global_state = c_fed_model.state_dict()
    for k in delta_state:
        c_global_state[k] = c_global_state[k] + (delta_state[k] / sum(clsimb))
    c_fed_model.load_state_dict(c_global_state)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 13:44:24,797 - INFO -
# Algorithm: Scaffold
# Client Split: [2, 3, 4]
# Dataset: svhn
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 13:44:24,882 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 13:44:43,533 - INFO -   |-- [Party 1] Average Train Loss:   0.3858 Train Accuracy: global   0.00% local  91.46% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:44:43,535 - INFO -   |--    Epoch Losses (10): [0.9066, 0.5942, 0.5375, 0.4407, 0.3663, 0.2697, 0.2295, 0.1889, 0.1603, 0.1646]
# 2021-09-01 13:45:01,744 - INFO -   |-- [Party 2] Average Train Loss:   0.3929 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:45:01,749 - INFO -   |--    Epoch Losses (10): [0.8913, 0.5767, 0.5389, 0.4882, 0.38, 0.2903, 0.2503, 0.2137, 0.1593, 0.1403]
# 2021-09-01 13:45:18,561 - INFO -   |-- [Party 3] Average Train Loss:   0.4703 Train Accuracy: global   0.00% local  94.41% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:45:18,565 - INFO -   |--    Epoch Losses (10): [1.0232, 0.6822, 0.6685, 0.63, 0.5073, 0.3327, 0.2374, 0.2193, 0.2134, 0.1884]
# 2021-09-01 13:45:38,282 - INFO -   |-- [Party 4] Average Train Loss:   0.6854 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:45:38,286 - INFO -   |--    Epoch Losses (10): [1.0763, 0.6986, 0.6856, 0.682, 0.6799, 0.6841, 0.676, 0.6475, 0.5909, 0.4329]
# 2021-09-01 13:45:57,464 - INFO -   |-- [Party 5] Average Train Loss:   0.6644 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:45:57,468 - INFO -   |--    Epoch Losses (10): [1.1341, 0.6846, 0.6931, 0.6972, 0.693, 0.6913, 0.6643, 0.6038, 0.4453, 0.3371]
# 2021-09-01 13:46:16,993 - INFO -   |-- [Party 6] Average Train Loss:   0.6401 Train Accuracy: global  48.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:46:16,996 - INFO -   |--    Epoch Losses (10): [1.0739, 0.6981, 0.6986, 0.689, 0.6872, 0.6662, 0.6257, 0.5317, 0.4165, 0.3139]
# 2021-09-01 13:46:36,538 - INFO -   |-- [Party 7] Average Train Loss:   0.5992 Train Accuracy: global  48.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:46:36,542 - INFO -   |--    Epoch Losses (10): [1.0577, 0.7066, 0.7054, 0.6892, 0.6727, 0.6229, 0.5429, 0.4002, 0.3147, 0.2796]
# 2021-09-01 13:46:53,273 - INFO -   |-- [Party 8] Average Train Loss:   0.5914 Train Accuracy: global  48.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:46:53,278 - INFO -   |--    Epoch Losses (10): [0.9661, 0.7139, 0.6973, 0.6923, 0.6935, 0.6488, 0.5557, 0.4294, 0.2861, 0.2305]
# 2021-09-01 13:47:10,508 - INFO -   |-- [Party 9] Average Train Loss:   0.5753 Train Accuracy: global  48.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:47:10,512 - INFO -   |--    Epoch Losses (10): [0.9848, 0.7122, 0.7065, 0.7054, 0.6716, 0.6222, 0.4815, 0.3505, 0.2796, 0.2389]
# 2021-09-01 13:47:25,344 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 13:47:25,349 - INFO -     |---- Train Accuracy: 21.55%
# 2021-09-01 13:47:25,351 - INFO -     |---- Test Accuracy: 9.59%
# 2021-09-01 13:47:25,352 - INFO -     |---- Test Loss: 2.5304
# 2021-09-01 13:47:25,353 - INFO -     |---- Elapsed time: 0:03:00.472630
# 2021-09-01 13:47:25,355 - INFO -
# Test Acc: Max 9.5905% (1 round) | Last 9.5905% | Avg 9.5905% (1 round)
#
# 2021-09-01 13:47:25,359 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 13:47:43,590 - INFO -   |-- [Party 1] Average Train Loss:   0.3104 Train Accuracy: global   0.00% local  97.14% ... 1948 forgettables out of 2130 (91.46%) ... total data used 2130
# 2021-09-01 13:47:43,594 - INFO -   |--    Epoch Losses (10): [1.017, 0.537, 0.4266, 0.2882, 0.1925, 0.1606, 0.1287, 0.1437, 0.1096, 0.1]
# 2021-09-01 13:48:01,741 - INFO -   |-- [Party 2] Average Train Loss:   0.3401 Train Accuracy: global   0.00% local  97.04% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:48:01,745 - INFO -   |--    Epoch Losses (10): [1.0395, 0.5532, 0.4676, 0.3753, 0.2664, 0.1898, 0.1524, 0.1319, 0.1239, 0.1012]
# 2021-09-01 13:48:20,101 - INFO -   |-- [Party 3] Average Train Loss:   0.3676 Train Accuracy: global   0.00% local   0.00% ... 2011 forgettables out of 2130 (94.41%) ... total data used 2130
# 2021-09-01 13:48:20,104 - INFO -   |--    Epoch Losses (10): [1.1453, 0.643, 0.4637, 0.3051, 0.2654, 0.2127, 0.1846, 0.1633, 0.1566, 0.1358]
# 2021-09-01 13:48:38,458 - INFO -   |-- [Party 4] Average Train Loss:   0.4671 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:48:38,460 - INFO -   |--    Epoch Losses (10): [1.1978, 0.6819, 0.6539, 0.5344, 0.4289, 0.3051, 0.2691, 0.2258, 0.1984, 0.1754]
# 2021-09-01 13:48:55,864 - INFO -   |-- [Party 5] Average Train Loss:   0.4871 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:48:55,868 - INFO -   |--    Epoch Losses (10): [1.2002, 0.6982, 0.6862, 0.6393, 0.4662, 0.3331, 0.2647, 0.2209, 0.1857, 0.1768]
# 2021-09-01 13:49:12,781 - INFO -   |-- [Party 6] Average Train Loss:   0.4156 Train Accuracy: global  48.50% local  51.50% ... 1097 forgettables out of 2130 (51.50%) ... total data used 2130
# 2021-09-01 13:49:12,783 - INFO -   |--    Epoch Losses (10): [0.7983, 0.6621, 0.6137, 0.548, 0.4047, 0.3038, 0.2386, 0.2245, 0.1941, 0.1685]
# 2021-09-01 13:49:30,180 - INFO -   |-- [Party 7] Average Train Loss:   0.4418 Train Accuracy: global  48.50% local  51.50% ... 1097 forgettables out of 2130 (51.50%) ... total data used 2130
# 2021-09-01 13:49:30,181 - INFO -   |--    Epoch Losses (10): [0.807, 0.6927, 0.6581, 0.5992, 0.4673, 0.336, 0.2595, 0.2344, 0.1977, 0.1658]
# 2021-09-01 13:49:48,857 - INFO -   |-- [Party 8] Average Train Loss:   0.3296 Train Accuracy: global  48.50% local  51.50% ... 1097 forgettables out of 2130 (51.50%) ... total data used 2130
# 2021-09-01 13:49:48,863 - INFO -   |--    Epoch Losses (10): [0.772, 0.622, 0.4672, 0.3048, 0.2344, 0.215, 0.2109, 0.1718, 0.1573, 0.1406]
# 2021-09-01 13:50:06,093 - INFO -   |-- [Party 9] Average Train Loss:   0.3737 Train Accuracy: global  48.50% local  51.50% ... 1097 forgettables out of 2130 (51.50%) ... total data used 2130
# 2021-09-01 13:50:06,097 - INFO -   |--    Epoch Losses (10): [0.784, 0.6601, 0.5594, 0.4167, 0.3149, 0.2512, 0.213, 0.1864, 0.1829, 0.1686]
# 2021-09-01 13:50:20,542 - INFO -     |---- Number of Forgettables: 8347 (43.54%)
# 2021-09-01 13:50:20,546 - INFO -     |---- Train Accuracy: 22.89%
# 2021-09-01 13:50:20,547 - INFO -     |---- Test Accuracy: 10.49%
# 2021-09-01 13:50:20,547 - INFO -     |---- Test Loss: nan
# 2021-09-01 13:50:20,548 - INFO -     |---- Elapsed time: 0:05:55.667325
# 2021-09-01 13:50:20,549 - INFO -
# Test Acc: Max 10.4864% (2 round) | Last 10.4864% | Avg 10.0385% (2 round)
#
# 2021-09-01 13:50:20,555 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 13:50:39,369 - INFO -   |-- [Party 1] Average Train Loss:   0.3666 Train Accuracy: global   0.00% local  97.46% ... 2069 forgettables out of 2130 (97.14%) ... total data used 2130
# 2021-09-01 13:50:39,373 - INFO -   |--    Epoch Losses (10): [1.6925, 0.4926, 0.37, 0.2545, 0.2069, 0.1577, 0.1449, 0.121, 0.1258, 0.0995]
# 2021-09-01 13:50:57,317 - INFO -   |-- [Party 2] Average Train Loss:   0.4049 Train Accuracy: global   0.00% local  96.43% ... 2067 forgettables out of 2130 (97.04%) ... total data used 2130
# 2021-09-01 13:50:57,321 - INFO -   |--    Epoch Losses (10): [1.8226, 0.5234, 0.3921, 0.3398, 0.2357, 0.1916, 0.1468, 0.1324, 0.141, 0.1231]
# 2021-09-01 13:51:16,942 - INFO -   |-- [Party 3] Average Train Loss:   0.3993 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:51:16,945 - INFO -   |--    Epoch Losses (10): [1.8629, 0.5041, 0.3072, 0.2797, 0.2333, 0.1847, 0.1701, 0.1652, 0.153, 0.133]
# 2021-09-01 13:51:36,440 - INFO -   |-- [Party 4] Average Train Loss:   0.5674 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:51:36,444 - INFO -   |--    Epoch Losses (10): [1.9975, 0.7161, 0.673, 0.5493, 0.3819, 0.3534, 0.2889, 0.272, 0.238, 0.204]
# 2021-09-01 13:51:55,158 - INFO -   |-- [Party 5] Average Train Loss:   0.4838 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:51:55,162 - INFO -   |--    Epoch Losses (10): [2.0739, 0.6466, 0.4354, 0.3367, 0.285, 0.2475, 0.228, 0.1985, 0.2113, 0.1748]
# 2021-09-01 13:52:14,666 - INFO -   |-- [Party 6] Average Train Loss:   0.1956 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:52:14,670 - INFO -   |--    Epoch Losses (10): [0.4589, 0.2414, 0.2156, 0.1851, 0.1498, 0.1492, 0.1721, 0.1438, 0.1246, 0.1156]
# 2021-09-01 13:52:33,941 - INFO -   |-- [Party 7] Average Train Loss:   0.2174 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:52:33,945 - INFO -   |--    Epoch Losses (10): [0.4615, 0.2844, 0.2437, 0.2203, 0.1989, 0.1622, 0.1749, 0.1596, 0.1498, 0.1187]
# 2021-09-01 13:52:51,920 - INFO -   |-- [Party 8] Average Train Loss:   0.2056 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:52:51,924 - INFO -   |--    Epoch Losses (10): [0.4604, 0.2733, 0.2103, 0.188, 0.1786, 0.186, 0.147, 0.1393, 0.1433, 0.1303]
# 2021-09-01 13:53:11,527 - INFO -   |-- [Party 9] Average Train Loss:   0.2255 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:53:11,530 - INFO -   |--    Epoch Losses (10): [0.5134, 0.2954, 0.2325, 0.2244, 0.1852, 0.1945, 0.1802, 0.1645, 0.1333, 0.1315]
# 2021-09-01 13:53:25,645 - INFO -     |---- Number of Forgettables: 4136 (21.58%)
# 2021-09-01 13:53:25,648 - INFO -     |---- Train Accuracy: 22.89%
# 2021-09-01 13:53:25,649 - INFO -     |---- Test Accuracy: 10.49%
# 2021-09-01 13:53:25,650 - INFO -     |---- Test Loss: nan
# 2021-09-01 13:53:25,651 - INFO -     |---- Elapsed time: 0:09:00.770313
# 2021-09-01 13:53:25,652 - INFO -
# Test Acc: Max 10.4864% (2 round) | Last 10.4864% | Avg 10.1878% (2 round)
#
# 2021-09-01 13:53:25,655 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 13:53:43,319 - INFO -   |-- [Party 1] Average Train Loss:   0.4901 Train Accuracy: global   0.00% local  96.57% ... 2076 forgettables out of 2130 (97.46%) ... total data used 2130
# 2021-09-01 13:53:43,320 - INFO -   |--    Epoch Losses (10): [2.9538, 0.562, 0.3477, 0.242, 0.1715, 0.1507, 0.1394, 0.1309, 0.1074, 0.0956]
# 2021-09-01 13:54:01,264 - INFO -   |-- [Party 2] Average Train Loss:   0.7118 Train Accuracy: global   0.00% local   0.00% ... 2054 forgettables out of 2130 (96.43%) ... total data used 2130
# 2021-09-01 13:54:01,268 - INFO -   |--    Epoch Losses (10): [3.2928, 0.7651, 0.6386, 0.6024, 0.514, 0.3983, 0.2984, 0.2389, 0.2023, 0.1672]
# 2021-09-01 13:54:20,468 - INFO -   |-- [Party 3] Average Train Loss:   0.5314 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:54:20,470 - INFO -   |--    Epoch Losses (10): [3.1392, 0.6177, 0.3146, 0.2495, 0.2124, 0.1841, 0.1824, 0.1445, 0.1421, 0.1279]
# 2021-09-01 13:54:39,031 - INFO -   |-- [Party 4] Average Train Loss:   1.0123 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:54:39,035 - INFO -   |--    Epoch Losses (10): [3.4617, 0.919, 0.7517, 0.7291, 0.7288, 0.7263, 0.7232, 0.7181, 0.6982, 0.6671]
# 2021-09-01 13:54:55,934 - INFO -   |-- [Party 5] Average Train Loss:   0.6991 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:54:55,937 - INFO -   |--    Epoch Losses (10): [3.4566, 1.0407, 0.5814, 0.409, 0.3122, 0.2906, 0.2727, 0.2431, 0.2011, 0.1837]
# 2021-09-01 13:55:13,289 - INFO -   |-- [Party 6] Average Train Loss:   0.1538 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:55:13,293 - INFO -   |--    Epoch Losses (10): [0.2924, 0.2027, 0.1821, 0.1597, 0.1417, 0.1348, 0.1266, 0.1061, 0.1055, 0.0861]
# 2021-09-01 13:55:32,674 - INFO -   |-- [Party 7] Average Train Loss:   0.1683 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:55:32,679 - INFO -   |--    Epoch Losses (10): [0.2945, 0.2121, 0.1946, 0.188, 0.169, 0.1622, 0.1279, 0.121, 0.1222, 0.091]
# 2021-09-01 13:55:52,154 - INFO -   |-- [Party 8] Average Train Loss:   0.1832 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:55:52,158 - INFO -   |--    Epoch Losses (10): [0.3332, 0.2164, 0.2022, 0.179, 0.1637, 0.1651, 0.1623, 0.1481, 0.136, 0.1258]
# 2021-09-01 13:56:11,006 - INFO -   |-- [Party 9] Average Train Loss:   0.1828 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:56:11,010 - INFO -   |--    Epoch Losses (10): [0.3195, 0.2354, 0.1859, 0.2039, 0.188, 0.1797, 0.1404, 0.1304, 0.1223, 0.1226]
# 2021-09-01 13:56:25,117 - INFO -     |---- Number of Forgettables: 4130 (21.54%)
# 2021-09-01 13:56:25,121 - INFO -     |---- Train Accuracy: 36.67%
# 2021-09-01 13:56:25,122 - INFO -     |---- Test Accuracy: 17.35%
# 2021-09-01 13:56:25,123 - INFO -     |---- Test Loss: 6.1589
# 2021-09-01 13:56:25,124 - INFO -     |---- Elapsed time: 0:12:00.243070
# 2021-09-01 13:56:25,125 - INFO -
# Test Acc: Max 17.3531% (4 round) | Last 17.3531% | Avg 11.9791% (4 round)
#
# 2021-09-01 13:56:25,127 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 13:56:44,689 - INFO -   |-- [Party 1] Average Train Loss:   0.9154 Train Accuracy: global   0.00% local  93.85% ... 2057 forgettables out of 2130 (96.57%) ... total data used 2130
# 2021-09-01 13:56:44,693 - INFO -   |--    Epoch Losses (10): [4.7858, 1.0982, 0.6712, 0.6028, 0.559, 0.4433, 0.3283, 0.2522, 0.2189, 0.1942]
# 2021-09-01 13:57:03,885 - INFO -   |-- [Party 2] Average Train Loss:   1.2895 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:57:03,889 - INFO -   |--    Epoch Losses (10): [5.1809, 1.7266, 1.0958, 0.8158, 0.7252, 0.6962, 0.6809, 0.6731, 0.6595, 0.6406]
# 2021-09-01 13:57:22,056 - INFO -   |-- [Party 3] Average Train Loss:   0.9500 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:57:22,057 - INFO -   |--    Epoch Losses (10): [4.8477, 1.3466, 0.8397, 0.7163, 0.5954, 0.3821, 0.257, 0.1865, 0.1685, 0.1604]
# 2021-09-01 13:57:40,775 - INFO -   |-- [Party 4] Average Train Loss:   1.4116 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:57:40,778 - INFO -   |--    Epoch Losses (10): [5.1201, 1.871, 1.3135, 1.0007, 0.8704, 0.8221, 0.7975, 0.7846, 0.7743, 0.7615]
# 2021-09-01 13:57:57,673 - INFO -   |-- [Party 5] Average Train Loss:   1.3864 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:57:57,677 - INFO -   |--    Epoch Losses (10): [5.2201, 2.0983, 1.6447, 1.2102, 0.9284, 0.8109, 0.7251, 0.5474, 0.392, 0.2867]
# 2021-09-01 13:58:15,687 - INFO -   |-- [Party 6] Average Train Loss:   0.1351 Train Accuracy: global  81.88% local  51.50% ...   35 forgettables out of 2130 ( 1.64%) ... total data used 2130
# 2021-09-01 13:58:15,691 - INFO -   |--    Epoch Losses (10): [0.2385, 0.17, 0.1711, 0.1328, 0.1263, 0.1238, 0.116, 0.1054, 0.0848, 0.0825]
# 2021-09-01 13:58:34,404 - INFO -   |-- [Party 7] Average Train Loss:   0.1470 Train Accuracy: global  83.99% local  51.50% ...   35 forgettables out of 2130 ( 1.64%) ... total data used 2130
# 2021-09-01 13:58:34,408 - INFO -   |--    Epoch Losses (10): [0.2234, 0.1998, 0.1817, 0.154, 0.1384, 0.1412, 0.112, 0.106, 0.1009, 0.1126]
# 2021-09-01 13:58:52,055 - INFO -   |-- [Party 8] Average Train Loss:   0.1482 Train Accuracy: global  82.86% local  51.50% ...   23 forgettables out of 2130 ( 1.08%) ... total data used 2130
# 2021-09-01 13:58:52,057 - INFO -   |--    Epoch Losses (10): [0.2246, 0.175, 0.1628, 0.1533, 0.1271, 0.152, 0.1431, 0.1207, 0.1166, 0.1065]
# 2021-09-01 13:59:10,792 - INFO -   |-- [Party 9] Average Train Loss:   0.1512 Train Accuracy: global  82.68% local  51.50% ...   43 forgettables out of 2130 ( 2.02%) ... total data used 2130
# 2021-09-01 13:59:10,796 - INFO -   |--    Epoch Losses (10): [0.2421, 0.1899, 0.1768, 0.1423, 0.1284, 0.1516, 0.1298, 0.1288, 0.1174, 0.1051]
# 2021-09-01 13:59:24,918 - INFO -     |---- Number of Forgettables: 2193 (11.44%)
# 2021-09-01 13:59:24,920 - INFO -     |---- Train Accuracy: 40.04%
# 2021-09-01 13:59:24,921 - INFO -     |---- Test Accuracy: 18.24%
# 2021-09-01 13:59:24,922 - INFO -     |---- Test Loss: 7.0365
# 2021-09-01 13:59:24,922 - INFO -     |---- Elapsed time: 0:15:00.041538
# 2021-09-01 13:59:24,923 - INFO -
# Test Acc: Max 18.2370% (5 round) | Last 18.2370% | Avg 13.2307% (4 round)
#
# 2021-09-01 13:59:24,926 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 13:59:43,772 - INFO -   |-- [Party 1] Average Train Loss:   1.4168 Train Accuracy: global   0.00% local  73.33% ... 1999 forgettables out of 2130 (93.85%) ... total data used 2130
# 2021-09-01 13:59:43,776 - INFO -   |--    Epoch Losses (10): [5.894, 2.122, 1.4435, 0.9584, 0.7209, 0.6447, 0.6133, 0.6003, 0.5919, 0.5788]
# 2021-09-01 14:00:02,505 - INFO -   |-- [Party 2] Average Train Loss:   2.1131 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:00:02,509 - INFO -   |--    Epoch Losses (10): [6.4222, 2.566, 2.2362, 2.05, 1.8517, 1.6221, 1.3798, 1.1609, 0.9852, 0.8569]
# 2021-09-01 14:00:20,622 - INFO -   |-- [Party 3] Average Train Loss:   1.4119 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:00:20,624 - INFO -   |--    Epoch Losses (10): [6.0217, 2.216, 1.6032, 1.1065, 0.8444, 0.7407, 0.6687, 0.4726, 0.2629, 0.1819]
# 2021-09-01 14:00:39,973 - INFO -   |-- [Party 4] Average Train Loss:   2.0865 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:00:39,977 - INFO -   |--    Epoch Losses (10): [6.161, 2.5452, 2.2551, 2.0679, 1.8266, 1.5618, 1.3338, 1.1538, 1.0244, 0.9356]
# 2021-09-01 14:00:57,570 - INFO -   |-- [Party 5] Average Train Loss:   1.9772 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:00:57,571 - INFO -   |--    Epoch Losses (10): [6.3612, 2.6833, 2.3468, 2.0621, 1.6762, 1.2768, 0.9813, 0.8387, 0.7856, 0.7601]
# 2021-09-01 14:01:17,191 - INFO -   |-- [Party 6] Average Train Loss:   0.1164 Train Accuracy: global  89.48% local  51.50% ...   39 forgettables out of 2130 ( 1.83%) ... total data used 2130
# 2021-09-01 14:01:17,195 - INFO -   |--    Epoch Losses (10): [0.2052, 0.1725, 0.1293, 0.1064, 0.1051, 0.1012, 0.0921, 0.0791, 0.0946, 0.0785]
# 2021-09-01 14:01:34,619 - INFO -   |-- [Party 7] Average Train Loss:   0.1282 Train Accuracy: global  90.33% local  51.50% ...   48 forgettables out of 2130 ( 2.25%) ... total data used 2130
# 2021-09-01 14:01:34,623 - INFO -   |--    Epoch Losses (10): [0.2143, 0.1519, 0.1347, 0.1323, 0.1198, 0.1144, 0.1118, 0.097, 0.1035, 0.1021]
# 2021-09-01 14:01:51,941 - INFO -   |-- [Party 8] Average Train Loss:   0.1366 Train Accuracy: global  90.85% local  51.50% ...   35 forgettables out of 2130 ( 1.64%) ... total data used 2130
# 2021-09-01 14:01:51,945 - INFO -   |--    Epoch Losses (10): [0.198, 0.1777, 0.146, 0.1355, 0.1364, 0.1383, 0.1138, 0.0997, 0.1133, 0.1076]
# 2021-09-01 14:02:11,443 - INFO -   |-- [Party 9] Average Train Loss:   0.1318 Train Accuracy: global  90.28% local  51.50% ...   45 forgettables out of 2130 ( 2.11%) ... total data used 2130
# 2021-09-01 14:02:11,447 - INFO -   |--    Epoch Losses (10): [0.2045, 0.167, 0.1415, 0.137, 0.1315, 0.1104, 0.1155, 0.0989, 0.1023, 0.1097]
# 2021-09-01 14:02:25,889 - INFO -     |---- Number of Forgettables: 2166 (11.30%)
# 2021-09-01 14:02:25,892 - INFO -     |---- Train Accuracy: 41.27%
# 2021-09-01 14:02:25,893 - INFO -     |---- Test Accuracy: 18.60%
# 2021-09-01 14:02:25,894 - INFO -     |---- Test Loss: 6.7431
# 2021-09-01 14:02:25,895 - INFO -     |---- Elapsed time: 0:18:01.014184
# 2021-09-01 14:02:25,896 - INFO -
# Test Acc: Max 18.5978% (6 round) | Last 18.5978% | Avg 14.1252% (4 round)
#
# 2021-09-01 14:02:25,902 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 14:02:44,573 - INFO -   |-- [Party 1] Average Train Loss:   1.9308 Train Accuracy: global   0.00% local  73.33% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 14:02:44,577 - INFO -   |--    Epoch Losses (10): [7.0323, 2.6313, 2.2221, 1.9506, 1.563, 1.1314, 0.8291, 0.6913, 0.6381, 0.619]
# 2021-09-01 14:03:03,746 - INFO -   |-- [Party 2] Average Train Loss:   2.8894 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:03:03,750 - INFO -   |--    Epoch Losses (10): [7.4846, 3.0144, 2.5861, 2.4396, 2.3743, 2.3325, 2.2911, 2.2328, 2.1357, 2.003]
# 2021-09-01 14:03:23,221 - INFO -   |-- [Party 3] Average Train Loss:   1.9335 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:03:23,225 - INFO -   |--    Epoch Losses (10): [7.2561, 2.7572, 2.2203, 1.8851, 1.5251, 1.1322, 0.8546, 0.7297, 0.6039, 0.3711]
# 2021-09-01 14:03:40,300 - INFO -   |-- [Party 4] Average Train Loss:   2.7915 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:03:40,304 - INFO -   |--    Epoch Losses (10): [7.5692, 3.0841, 2.6155, 2.4574, 2.3835, 2.3192, 2.2147, 2.0302, 1.7678, 1.4732]
# 2021-09-01 14:03:58,179 - INFO -   |-- [Party 5] Average Train Loss:   2.7734 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:03:58,182 - INFO -   |--    Epoch Losses (10): [7.6206, 3.2607, 2.8335, 2.6363, 2.4674, 2.2655, 2.0281, 1.7782, 1.5302, 1.3133]
# 2021-09-01 14:04:15,869 - INFO -   |-- [Party 6] Average Train Loss:   0.1051 Train Accuracy: global  93.00% local  51.50% ...   68 forgettables out of 2130 ( 3.19%) ... total data used 2130
# 2021-09-01 14:04:15,871 - INFO -   |--    Epoch Losses (10): [0.1747, 0.1374, 0.116, 0.1054, 0.1055, 0.0904, 0.0914, 0.081, 0.0693, 0.0802]
# 2021-09-01 14:04:34,610 - INFO -   |-- [Party 7] Average Train Loss:   0.1086 Train Accuracy: global  92.86% local  51.50% ...   76 forgettables out of 2130 ( 3.57%) ... total data used 2130
# 2021-09-01 14:04:34,612 - INFO -   |--    Epoch Losses (10): [0.1688, 0.1344, 0.1255, 0.1136, 0.1174, 0.0888, 0.0898, 0.0841, 0.0824, 0.0816]
# 2021-09-01 14:04:52,024 - INFO -   |-- [Party 8] Average Train Loss:   0.1062 Train Accuracy: global  92.44% local  51.50% ...   75 forgettables out of 2130 ( 3.52%) ... total data used 2130
# 2021-09-01 14:04:52,026 - INFO -   |--    Epoch Losses (10): [0.1559, 0.1333, 0.1162, 0.1092, 0.107, 0.0919, 0.0957, 0.0916, 0.0771, 0.0844]
# 2021-09-01 14:05:11,451 - INFO -   |-- [Party 9] Average Train Loss:   0.1084 Train Accuracy: global  93.00% local  51.50% ...   75 forgettables out of 2130 ( 3.52%) ... total data used 2130
# 2021-09-01 14:05:11,454 - INFO -   |--    Epoch Losses (10): [0.1598, 0.1216, 0.1137, 0.1093, 0.111, 0.1014, 0.1163, 0.0929, 0.0805, 0.0776]
# 2021-09-01 14:05:25,649 - INFO -     |---- Number of Forgettables: 1856 (9.68%)
# 2021-09-01 14:05:25,650 - INFO -     |---- Train Accuracy: 37.27%
# 2021-09-01 14:05:25,651 - INFO -     |---- Test Accuracy: 16.74%
# 2021-09-01 14:05:25,652 - INFO -     |---- Test Loss: 6.9741
# 2021-09-01 14:05:25,653 - INFO -     |---- Elapsed time: 0:21:00.772017
# 2021-09-01 14:05:25,654 - INFO -
# Test Acc: Max 16.7398% (6 round) | Last 16.7398% | Avg 14.4987% (4 round)
#
# 2021-09-01 14:05:25,656 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 14:05:43,815 - INFO -   |-- [Party 1] Average Train Loss:   2.4656 Train Accuracy: global   0.00% local  73.33% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 14:05:43,819 - INFO -   |--    Epoch Losses (10): [8.1676, 3.014, 2.3972, 2.2197, 2.0834, 1.9008, 1.6394, 1.3288, 1.0526, 0.8526]
# 2021-09-01 14:06:01,080 - INFO -   |-- [Party 2] Average Train Loss:   3.2737 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:06:01,083 - INFO -   |--    Epoch Losses (10): [8.8838, 3.7194, 2.9386, 2.6481, 2.5238, 2.4631, 2.4231, 2.4014, 2.376, 2.3598]
# 2021-09-01 14:06:19,246 - INFO -   |-- [Party 3] Average Train Loss:   2.4456 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:06:19,248 - INFO -   |--    Epoch Losses (10): [8.5738, 3.4654, 2.6472, 2.251, 1.9602, 1.6576, 1.3197, 1.0099, 0.8262, 0.7447]
# 2021-09-01 14:06:36,312 - INFO -   |-- [Party 4] Average Train Loss:   3.3496 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:06:36,316 - INFO -   |--    Epoch Losses (10): [9.2623, 3.9974, 3.1451, 2.7848, 2.5902, 2.4914, 2.4343, 2.3796, 2.2672, 2.1434]
# 2021-09-01 14:06:53,361 - INFO -   |-- [Party 5] Average Train Loss:   3.6938 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:06:53,365 - INFO -   |--    Epoch Losses (10): [9.073, 4.2292, 3.5808, 3.2691, 3.069, 2.9231, 2.8175, 2.7883, 2.6419, 2.546]
# 2021-09-01 14:07:10,410 - INFO -   |-- [Party 6] Average Train Loss:   0.0939 Train Accuracy: global  84.60% local  51.50% ...  313 forgettables out of 2130 (14.69%) ... total data used 2130
# 2021-09-01 14:07:10,413 - INFO -   |--    Epoch Losses (10): [0.1406, 0.1145, 0.1104, 0.0987, 0.0843, 0.0801, 0.0813, 0.078, 0.0759, 0.0752]
# 2021-09-01 14:07:29,745 - INFO -   |-- [Party 7] Average Train Loss:   0.0901 Train Accuracy: global  82.96% local  51.50% ...  351 forgettables out of 2130 (16.48%) ... total data used 2130
# 2021-09-01 14:07:29,749 - INFO -   |--    Epoch Losses (10): [0.1429, 0.1069, 0.1, 0.0908, 0.0846, 0.0924, 0.0792, 0.0646, 0.0742, 0.0658]
# 2021-09-01 14:07:48,207 - INFO -   |-- [Party 8] Average Train Loss:   0.1004 Train Accuracy: global  83.85% local  51.50% ...  327 forgettables out of 2130 (15.35%) ... total data used 2130
# 2021-09-01 14:07:48,211 - INFO -   |--    Epoch Losses (10): [0.1364, 0.1298, 0.1048, 0.105, 0.0997, 0.0865, 0.0873, 0.0948, 0.0914, 0.068]
# 2021-09-01 14:08:05,028 - INFO -   |-- [Party 9] Average Train Loss:   0.0856 Train Accuracy: global  85.07% local  51.50% ...  312 forgettables out of 2130 (14.65%) ... total data used 2130
# 2021-09-01 14:08:05,032 - INFO -   |--    Epoch Losses (10): [0.1308, 0.0935, 0.0945, 0.0906, 0.0829, 0.0897, 0.0828, 0.0698, 0.057, 0.0643]
# 2021-09-01 14:08:19,273 - INFO -     |---- Number of Forgettables: 2865 (14.95%)
# 2021-09-01 14:08:19,277 - INFO -     |---- Train Accuracy: 22.89%
# 2021-09-01 14:08:19,278 - INFO -     |---- Test Accuracy: 10.49%
# 2021-09-01 14:08:19,281 - INFO -     |---- Test Loss: nan
# 2021-09-01 14:08:19,282 - INFO -     |---- Elapsed time: 0:23:54.401218
# 2021-09-01 14:08:19,284 - INFO -
# Test Acc: Max 10.4864% (6 round) | Last 10.4864% | Avg 13.9972% (4 round)
#
# 2021-09-01 14:08:19,291 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 14:08:38,757 - INFO -   |-- [Party 1] Average Train Loss:   2.9629 Train Accuracy: global   0.00% local  58.22% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 14:08:38,759 - INFO -   |--    Epoch Losses (10): [9.5145, 3.7392, 2.6503, 2.3403, 2.208, 2.1146, 2.0071, 1.8712, 1.6974, 1.4864]
# 2021-09-01 14:08:56,296 - INFO -   |-- [Party 2] Average Train Loss:   3.6940 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:08:56,298 - INFO -   |--    Epoch Losses (10): [10.2972, 4.75, 3.5418, 3.0188, 2.7563, 2.6164, 2.5381, 2.4937, 2.4671, 2.4606]
# 2021-09-01 14:09:13,372 - INFO -   |-- [Party 3] Average Train Loss:   3.0528 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:09:13,376 - INFO -   |--    Epoch Losses (10): [10.0346, 4.5851, 3.4676, 2.837, 2.4182, 2.0647, 1.7432, 1.402, 1.0922, 0.8838]
# 2021-09-01 14:09:31,402 - INFO -   |-- [Party 4] Average Train Loss:   4.0615 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:09:31,405 - INFO -   |--    Epoch Losses (10): [10.6106, 5.3886, 4.2511, 3.6994, 3.2522, 2.9405, 2.7362, 2.6064, 2.6623, 2.4683]
# 2021-09-01 14:09:51,259 - INFO -   |-- [Party 5] Average Train Loss:   4.9425 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:09:51,263 - INFO -   |--    Epoch Losses (10): [10.6126, 5.7602, 5.0556, 4.6465, 4.3445, 4.1032, 3.9298, 3.8126, 3.6283, 3.5314]
# 2021-09-01 14:10:09,235 - INFO -   |-- [Party 6] Average Train Loss:   0.0871 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:10:09,237 - INFO -   |--    Epoch Losses (10): [0.1287, 0.1032, 0.0866, 0.0872, 0.0887, 0.0696, 0.0834, 0.0834, 0.066, 0.0748]
# 2021-09-01 14:10:27,417 - INFO -   |-- [Party 7] Average Train Loss:   0.0778 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:10:27,420 - INFO -   |--    Epoch Losses (10): [0.1178, 0.0974, 0.0846, 0.068, 0.0626, 0.0661, 0.078, 0.0756, 0.0583, 0.0693]
# 2021-09-01 14:10:44,791 - INFO -   |-- [Party 8] Average Train Loss:   0.0915 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:10:44,795 - INFO -   |--    Epoch Losses (10): [0.1272, 0.1158, 0.1025, 0.0912, 0.0826, 0.0724, 0.0815, 0.0901, 0.0776, 0.0739]
# 2021-09-01 14:11:03,888 - INFO -   |-- [Party 9] Average Train Loss:   0.0735 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:11:03,892 - INFO -   |--    Epoch Losses (10): [0.0981, 0.0882, 0.0702, 0.0855, 0.0839, 0.0731, 0.0659, 0.0543, 0.0511, 0.0645]
# 2021-09-01 14:11:18,035 - INFO -     |---- Number of Forgettables: 1562 (8.15%)
# 2021-09-01 14:11:18,036 - INFO -     |---- Train Accuracy: 22.89%
# 2021-09-01 14:11:18,037 - INFO -     |---- Test Accuracy: 10.49%
# 2021-09-01 14:11:18,037 - INFO -     |---- Test Loss: nan
# 2021-09-01 14:11:18,038 - INFO -     |---- Elapsed time: 0:26:53.157582
# 2021-09-01 14:11:18,039 - INFO -
# Test Acc: Max 10.4864% (6 round) | Last 10.4864% | Avg 13.6071% (4 round)
#
# 2021-09-01 14:11:18,042 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 14:11:36,545 - INFO -   |-- [Party 1] Average Train Loss:   3.3539 Train Accuracy: global   0.00% local   0.00% ... 1240 forgettables out of 2130 (58.22%) ... total data used 2130
# 2021-09-01 14:11:36,549 - INFO -   |--    Epoch Losses (10): [10.7609, 4.6535, 3.1078, 2.6013, 2.3348, 2.2038, 2.1177, 2.0316, 1.9273, 1.7999]
# 2021-09-01 14:11:54,703 - INFO -   |-- [Party 2] Average Train Loss:   4.3527 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:11:54,707 - INFO -   |--    Epoch Losses (10): [11.5474, 6.0896, 4.8346, 3.9381, 3.3677, 3.0488, 2.8246, 2.6932, 2.6163, 2.5671]
# 2021-09-01 14:12:12,901 - INFO -   |-- [Party 3] Average Train Loss:   3.8693 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:12:12,905 - INFO -   |--    Epoch Losses (10): [11.4485, 5.9273, 4.4943, 3.7189, 3.1501, 2.7268, 2.3946, 1.9889, 1.6082, 1.2354]
# 2021-09-01 14:12:32,382 - INFO -   |-- [Party 4] Average Train Loss:   5.1590 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:12:32,386 - INFO -   |--    Epoch Losses (10): [11.7385, 6.9314, 5.8308, 5.2639, 4.6512, 4.1303, 3.6644, 3.3495, 3.1059, 2.9245]
# 2021-09-01 14:12:51,436 - INFO -   |-- [Party 5] Average Train Loss:   6.7223 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:12:51,438 - INFO -   |--    Epoch Losses (10): [11.9406, 7.66, 6.8795, 6.5545, 6.1741, 5.939, 5.7193, 5.5293, 5.4793, 5.3474]
# 2021-09-01 14:13:08,962 - INFO -   |-- [Party 6] Average Train Loss:   0.0789 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:13:08,966 - INFO -   |--    Epoch Losses (10): [0.1153, 0.0912, 0.0878, 0.0805, 0.0803, 0.0738, 0.0706, 0.0676, 0.0633, 0.0583]
# 2021-09-01 14:13:26,271 - INFO -   |-- [Party 7] Average Train Loss:   0.0724 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:13:26,275 - INFO -   |--    Epoch Losses (10): [0.11, 0.0877, 0.0729, 0.0818, 0.0651, 0.0718, 0.0614, 0.0625, 0.0574, 0.0535]
# 2021-09-01 14:13:44,660 - INFO -   |-- [Party 8] Average Train Loss:   0.0880 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:13:44,664 - INFO -   |--    Epoch Losses (10): [0.1195, 0.0992, 0.0963, 0.0902, 0.0828, 0.0855, 0.0754, 0.0806, 0.0874, 0.0631]
# 2021-09-01 14:14:01,928 - INFO -   |-- [Party 9] Average Train Loss:   0.0705 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:14:01,932 - INFO -   |--    Epoch Losses (10): [0.1077, 0.0766, 0.0652, 0.0639, 0.0624, 0.0574, 0.0802, 0.0719, 0.0531, 0.0663]
# 2021-09-01 14:14:15,634 - INFO -     |---- Number of Forgettables: 1240 (6.47%)
# 2021-09-01 14:14:15,636 - INFO -     |---- Train Accuracy: 22.89%
# 2021-09-01 14:14:15,637 - INFO -     |---- Test Accuracy: 10.49%
# 2021-09-01 14:14:15,638 - INFO -     |---- Test Loss: nan
# 2021-09-01 14:14:15,639 - INFO -     |---- Elapsed time: 0:29:50.758467
# 2021-09-01 14:14:15,640 - INFO -
# Test Acc: Max 10.4864% (6 round) | Last 10.4864% | Avg 13.2951% (4 round)
#
# 2021-09-01 14:14:15,648 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 14:14:34,089 - INFO -   |-- [Party 1] Average Train Loss:   3.7111 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:14:34,093 - INFO -   |--    Epoch Losses (10): [11.5071, 5.6711, 3.8003, 2.8997, 2.5203, 2.328, 2.21, 2.1305, 2.0601, 1.9835]
# 2021-09-01 14:14:52,558 - INFO -   |-- [Party 2] Average Train Loss:   4.8642 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:14:52,562 - INFO -   |--    Epoch Losses (10): [12.1006, 7.4133, 5.5942, 4.4293, 3.8062, 3.3728, 3.1491, 3.0261, 2.915, 2.8351]
# 2021-09-01 14:15:10,960 - INFO -   |-- [Party 3] Average Train Loss:   4.7106 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:15:10,964 - INFO -   |--    Epoch Losses (10): [11.9081, 7.3259, 5.8056, 4.7971, 4.0869, 3.529, 3.0107, 2.7307, 2.2026, 1.7092]
# 2021-09-01 14:15:28,435 - INFO -   |-- [Party 4] Average Train Loss:   6.3810 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:15:28,437 - INFO -   |--    Epoch Losses (10): [12.5138, 8.5765, 7.4361, 6.5672, 5.8577, 5.5566, 4.9705, 4.5167, 4.0653, 3.7495]
# 2021-09-01 14:15:47,407 - INFO -   |-- [Party 5] Average Train Loss:   8.7153 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:15:47,410 - INFO -   |--    Epoch Losses (10): [12.7669, 9.4285, 8.8052, 8.4614, 8.2686, 8.0739, 7.89, 7.7737, 8.0, 7.6853]
# 2021-09-01 14:16:04,570 - INFO -   |-- [Party 6] Average Train Loss:   0.0841 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:16:04,573 - INFO -   |--    Epoch Losses (10): [0.1254, 0.0968, 0.0826, 0.0747, 0.0752, 0.0732, 0.0724, 0.0938, 0.0717, 0.0748]
# 2021-09-01 14:16:21,697 - INFO -   |-- [Party 7] Average Train Loss:   0.0790 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:16:21,701 - INFO -   |--    Epoch Losses (10): [0.1078, 0.0927, 0.0789, 0.0712, 0.0776, 0.072, 0.0695, 0.0689, 0.0767, 0.0751]
# 2021-09-01 14:16:41,553 - INFO -   |-- [Party 8] Average Train Loss:   0.0903 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:16:41,557 - INFO -   |--    Epoch Losses (10): [0.1257, 0.0978, 0.0856, 0.0859, 0.092, 0.0874, 0.0881, 0.0764, 0.0845, 0.0801]
# 2021-09-01 14:16:59,580 - INFO -   |-- [Party 9] Average Train Loss:   0.0807 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:16:59,584 - INFO -   |--    Epoch Losses (10): [0.114, 0.0796, 0.0681, 0.0645, 0.0801, 0.0921, 0.0649, 0.0772, 0.0764, 0.0904]
# 2021-09-01 14:17:13,618 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 14:17:13,621 - INFO -     |---- Train Accuracy: 22.89%
# 2021-09-01 14:17:13,623 - INFO -     |---- Test Accuracy: 10.49%
# 2021-09-01 14:17:13,624 - INFO -     |---- Test Loss: nan
# 2021-09-01 14:17:13,624 - INFO -     |---- Elapsed time: 0:32:48.743690
# 2021-09-01 14:17:13,626 - INFO -
# Test Acc: Max 10.4864% (6 round) | Last 10.4864% | Avg 13.0397% (4 round)
#
# 2021-09-01 14:17:13,629 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 14:17:31,430 - INFO -   |-- [Party 1] Average Train Loss:   3.9389 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:17:31,433 - INFO -   |--    Epoch Losses (10): [11.9062, 6.4988, 4.1523, 3.1161, 2.6807, 2.3974, 2.2585, 2.1804, 2.1263, 2.0725]
# 2021-09-01 14:17:49,386 - INFO -   |-- [Party 2] Average Train Loss:   5.3904 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:17:49,390 - INFO -   |--    Epoch Losses (10): [12.8081, 8.4735, 6.481, 5.097, 4.2682, 3.8356, 3.5189, 3.2755, 3.1276, 3.019]
# 2021-09-01 14:18:07,112 - INFO -   |-- [Party 3] Average Train Loss:   5.5340 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:18:07,115 - INFO -   |--    Epoch Losses (10): [12.4818, 8.5853, 6.965, 5.9042, 5.0867, 4.3907, 3.8239, 3.239, 2.705, 2.1584]
# 2021-09-01 14:18:24,103 - INFO -   |-- [Party 4] Average Train Loss:   7.5734 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:18:24,107 - INFO -   |--    Epoch Losses (10): [13.3512, 10.0973, 8.929, 8.0364, 7.4077, 6.7589, 6.1406, 5.5613, 4.9082, 4.5437]
# 2021-09-01 14:18:41,854 - INFO -   |-- [Party 5] Average Train Loss:  10.4929 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:18:41,857 - INFO -   |--    Epoch Losses (10): [13.6312, 11.1073, 10.5893, 10.3247, 10.1279, 10.0062, 9.9004, 9.7816, 9.7302, 9.7299]
# 2021-09-01 14:19:01,985 - INFO -   |-- [Party 6] Average Train Loss:   0.0989 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:19:01,989 - INFO -   |--    Epoch Losses (10): [0.155, 0.1084, 0.098, 0.0984, 0.0908, 0.0942, 0.0842, 0.0831, 0.088, 0.0894]
# 2021-09-01 14:19:21,397 - INFO -   |-- [Party 7] Average Train Loss:   0.1098 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:19:21,401 - INFO -   |--    Epoch Losses (10): [0.1472, 0.1223, 0.1087, 0.0981, 0.1116, 0.0908, 0.1129, 0.0981, 0.1063, 0.1018]
# 2021-09-01 14:19:38,787 - INFO -   |-- [Party 8] Average Train Loss:   0.1271 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:19:38,789 - INFO -   |--    Epoch Losses (10): [0.1722, 0.124, 0.1286, 0.126, 0.1115, 0.1071, 0.1144, 0.1351, 0.13, 0.1221]
# 2021-09-01 14:19:57,660 - INFO -   |-- [Party 9] Average Train Loss:   0.1194 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:19:57,664 - INFO -   |--    Epoch Losses (10): [0.1552, 0.1157, 0.1042, 0.1254, 0.122, 0.1146, 0.1022, 0.1296, 0.1131, 0.1117]
# 2021-09-01 14:20:11,779 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 14:20:11,781 - INFO -     |---- Train Accuracy: 22.89%
# 2021-09-01 14:20:11,782 - INFO -     |---- Test Accuracy: 10.49%
# 2021-09-01 14:20:11,783 - INFO -     |---- Test Loss: nan
# 2021-09-01 14:20:11,784 - INFO -     |---- Elapsed time: 0:35:46.903093
# 2021-09-01 14:20:11,785 - INFO -
# Test Acc: Max 10.4864% (6 round) | Last 10.4864% | Avg 12.8269% (4 round)
#
# 2021-09-01 14:20:11,787 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 14:20:30,646 - INFO -   |-- [Party 1] Average Train Loss:   4.2658 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:20:30,648 - INFO -   |--    Epoch Losses (10): [12.4425, 7.6861, 5.0321, 3.4969, 2.7432, 2.4284, 2.3079, 2.2239, 2.1704, 2.1267]
# 2021-09-01 14:20:47,920 - INFO -   |-- [Party 2] Average Train Loss:   6.1107 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:20:47,923 - INFO -   |--    Epoch Losses (10): [13.5819, 9.5153, 7.7434, 6.2237, 5.2237, 4.6086, 4.0335, 3.5853, 3.3771, 3.2143]
# 2021-09-01 14:21:08,221 - INFO -   |-- [Party 3] Average Train Loss:   6.3592 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:21:08,224 - INFO -   |--    Epoch Losses (10): [13.2995, 10.0484, 8.3236, 6.922, 5.8702, 5.1192, 4.4255, 3.8103, 3.2197, 2.5535]
# 2021-09-01 14:21:26,114 - INFO -   |-- [Party 4] Average Train Loss:   8.8362 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:21:26,118 - INFO -   |--    Epoch Losses (10): [13.8752, 11.6037, 10.4826, 9.5667, 8.7429, 8.3138, 7.4633, 6.7725, 6.1121, 5.4292]
# 2021-09-01 14:21:44,093 - INFO -   |-- [Party 5] Average Train Loss:  12.2416 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:21:44,096 - INFO -   |--    Epoch Losses (10): [14.2992, 12.7382, 12.3713, 12.2126, 12.1174, 11.908, 11.7905, 11.7052, 11.6656, 11.6076]
# 2021-09-01 14:22:03,570 - INFO -   |-- [Party 6] Average Train Loss:   0.4865 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:22:03,574 - INFO -   |--    Epoch Losses (10): [0.8079, 0.7052, 0.6705, 0.6149, 0.5292, 0.4187, 0.3402, 0.2938, 0.2654, 0.2192]
# 2021-09-01 14:22:22,351 - INFO -   |-- [Party 7] Average Train Loss:   0.5863 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:22:22,355 - INFO -   |--    Epoch Losses (10): [0.8177, 0.705, 0.6979, 0.684, 0.6477, 0.6109, 0.5305, 0.4594, 0.3869, 0.3228]
# 2021-09-01 14:22:40,840 - INFO -   |-- [Party 8] Average Train Loss:   0.6603 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:22:40,844 - INFO -   |--    Epoch Losses (10): [0.7893, 0.7071, 0.7014, 0.7047, 0.7124, 0.6862, 0.6697, 0.6068, 0.5617, 0.4641]
# 2021-09-01 14:22:58,071 - INFO -   |-- [Party 9] Average Train Loss:   0.7167 Train Accuracy: global  51.50% local  51.50% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:22:58,075 - INFO -   |--    Epoch Losses (10): [0.8311, 0.7086, 0.6957, 0.7056, 0.7, 0.7065, 0.6951, 0.7033, 0.7116, 0.7093]
# 2021-09-01 14:23:12,068 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 14:23:12,072 - INFO -     |---- Train Accuracy: 21.55%
# 2021-09-01 14:23:12,073 - INFO -     |---- Test Accuracy: 9.59%
# 2021-09-01 14:23:12,074 - INFO -     |---- Test Loss: 13.5138
# 2021-09-01 14:23:12,075 - INFO -     |---- Elapsed time: 0:38:47.194536
# 2021-09-01 14:23:12,077 - INFO -
# Test Acc: Max 9.5905% (6 round) | Last 9.5905% | Avg 12.5780% (4 round)
#
# 2021-09-01 14:23:12,079 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 14:23:31,846 - INFO -   |-- [Party 1] Average Train Loss:   4.5235 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:23:31,849 - INFO -   |--    Epoch Losses (10): [13.8197, 8.2582, 5.1947, 3.6222, 2.9149, 2.4907, 2.326, 2.2471, 2.2, 2.1611]
# 2021-09-01 14:23:49,237 - INFO -   |-- [Party 2] Average Train Loss:   6.8017 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:23:49,240 - INFO -   |--    Epoch Losses (10): [14.9183, 10.8036, 8.9885, 7.1584, 5.7782, 4.8124, 4.3091, 3.8903, 3.5754, 3.7824]
# 2021-09-01 14:24:06,989 - INFO -   |-- [Party 3] Average Train Loss:   7.5580 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:24:06,993 - INFO -   |--    Epoch Losses (10): [14.9926, 11.419, 9.5827, 8.1846, 7.0413, 6.1917, 5.4547, 4.8282, 4.2842, 3.6007]
# 2021-09-01 14:24:26,166 - INFO -   |-- [Party 4] Average Train Loss:  10.3815 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:24:26,169 - INFO -   |--    Epoch Losses (10): [15.6127, 13.1933, 12.0873, 11.3123, 10.4892, 9.7082, 8.9463, 8.1884, 7.473, 6.8043]
# 2021-09-01 14:24:45,213 - INFO -   |-- [Party 5] Average Train Loss:  14.0558 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 14:24:45,216 - INFO -   |--    Epoch Losses (10): [16.1456, 14.5511, 14.2002, 13.9121, 13.7977, 13.722, 13.6174, 13.5565, 13.573, 13.4826]
# 2021-09-01 14:25:02,177 - INFO -   |-- [Party 6] Average Train Loss:   0.6618 Train Accuracy: global  48.50% local  51.50% ... 1097 forgettables out of 2130 (51.50%) ... total data used 2130
# 2021-09-01 14:25:02,181 - INFO -   |--    Epoch Losses (10): [0.7585, 0.6991, 0.7113, 0.7025, 0.6951, 0.6963, 0.6738, 0.6329, 0.5881, 0.4599]
# ...
# 2021-09-01 23:23:41,525 - INFO -   |-- [Party 6] Average Train Loss:   0.1511 Train Accuracy: global  93.80% local  51.50% ...  126 forgettables out of 2130 ( 5.92%) ... total data used 2130
# 2021-09-01 23:23:41,529 - INFO -   |--    Epoch Losses (10): [0.2636, 0.1754, 0.1854, 0.1508, 0.1583, 0.1284, 0.1307, 0.1127, 0.1176, 0.0881]
# 2021-09-01 23:24:00,424 - INFO -   |-- [Party 7] Average Train Loss:   0.0991 Train Accuracy: global  93.15% local  51.50% ...  138 forgettables out of 2130 ( 6.48%) ... total data used 2130
# 2021-09-01 23:24:00,425 - INFO -   |--    Epoch Losses (10): [0.2312, 0.1507, 0.1151, 0.1012, 0.0872, 0.0656, 0.0866, 0.0663, 0.0446, 0.0428]
# 2021-09-01 23:24:18,872 - INFO -   |-- [Party 8] Average Train Loss:   0.1335 Train Accuracy: global  93.24% local  51.50% ...    7 forgettables out of 2130 ( 0.33%) ... total data used 2130
# 2021-09-01 23:24:18,875 - INFO -   |--    Epoch Losses (10): [0.3182, 0.1844, 0.1509, 0.1385, 0.1059, 0.1038, 0.0994, 0.0667, 0.0661, 0.1013]
# 2021-09-01 23:24:37,647 - INFO -   |-- [Party 9] Average Train Loss:   0.0041 Train Accuracy: global  96.24% local  51.50% ...   80 forgettables out of 2130 ( 3.76%) ... total data used 2130
# 2021-09-01 23:24:37,649 - INFO -   |--    Epoch Losses (10): [0.0, 0.0001, 0.0, 0.002, 0.0031, 0.0146, 0.0018, 0.0012, 0.0056, 0.0121]
# 2021-09-01 23:24:50,992 - INFO -     |---- Number of Forgettables: 351 (1.83%)
# 2021-09-01 23:24:50,993 - INFO -     |---- Train Accuracy: 41.71%
# 2021-09-01 23:24:50,994 - INFO -     |---- Test Accuracy: 18.21%
# 2021-09-01 23:24:50,995 - INFO -     |---- Test Loss: 4.3307
# 2021-09-01 23:24:50,996 - INFO -     |---- Elapsed time: 9:40:26.115561
# 2021-09-01 23:24:50,998 - INFO -
# Test Acc: Max 18.2130% (180 round) | Last 18.2130% | Avg 14.9496% (4 round)
#
# 2021-09-01 23:24:51,002 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 23:25:07,359 - INFO -   |-- [Party 1] Average Train Loss:  12.7717 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:25:07,360 - INFO -   |--    Epoch Losses (10): [55.3699, 30.5766, 15.7511, 7.6686, 4.4131, 3.2892, 2.8515, 2.6571, 2.5962, 2.5437]
# 2021-09-01 23:25:23,475 - INFO -   |-- [Party 2] Average Train Loss:  19.7064 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:25:23,479 - INFO -   |--    Epoch Losses (10): [59.3547, 41.9116, 29.3984, 20.3429, 13.9337, 9.7554, 7.1336, 5.8438, 5.0148, 4.3747]
# 2021-09-01 23:25:39,768 - INFO -   |-- [Party 3] Average Train Loss:  18.9623 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:25:39,769 - INFO -   |--    Epoch Losses (10): [58.7738, 41.6327, 30.1031, 21.4306, 13.8343, 8.0671, 5.4655, 3.9131, 3.3768, 3.0257]
# 2021-09-01 23:25:56,123 - INFO -   |-- [Party 4] Average Train Loss:  21.0309 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:25:56,124 - INFO -   |--    Epoch Losses (10): [59.7496, 44.5763, 33.8145, 24.7003, 15.9988, 9.9553, 7.0449, 5.3118, 4.6836, 4.474]
# 2021-09-01 23:26:12,305 - INFO -   |-- [Party 5] Average Train Loss:  19.9391 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:26:12,308 - INFO -   |--    Epoch Losses (10): [60.4296, 45.3217, 33.1979, 21.9357, 12.9129, 7.9896, 5.6415, 4.4435, 3.91, 3.6089]
# 2021-09-01 23:26:28,473 - INFO -   |-- [Party 6] Average Train Loss:   0.1450 Train Accuracy: global  93.15% local  51.50% ...  138 forgettables out of 2130 ( 6.48%) ... total data used 2130
# 2021-09-01 23:26:28,474 - INFO -   |--    Epoch Losses (10): [0.2847, 0.189, 0.1814, 0.1256, 0.1333, 0.119, 0.1096, 0.099, 0.1062, 0.1019]
# 2021-09-01 23:26:45,263 - INFO -   |-- [Party 7] Average Train Loss:   0.0953 Train Accuracy: global  93.00% local  51.50% ...  144 forgettables out of 2130 ( 6.76%) ... total data used 2130
# 2021-09-01 23:26:45,265 - INFO -   |--    Epoch Losses (10): [0.2248, 0.1424, 0.1023, 0.0883, 0.076, 0.0701, 0.0687, 0.0526, 0.0565, 0.071]
# 2021-09-01 23:27:02,600 - INFO -   |-- [Party 8] Average Train Loss:   0.1244 Train Accuracy: global  92.91% local  51.50% ...  143 forgettables out of 2130 ( 6.71%) ... total data used 2130
# 2021-09-01 23:27:02,602 - INFO -   |--    Epoch Losses (10): [0.2626, 0.1994, 0.1376, 0.13, 0.1098, 0.0991, 0.0934, 0.0757, 0.0651, 0.0715]
# 2021-09-01 23:27:20,416 - INFO -   |-- [Party 9] Average Train Loss:   0.0048 Train Accuracy: global  95.82% local  51.50% ...   89 forgettables out of 2130 ( 4.18%) ... total data used 2130
# 2021-09-01 23:27:20,418 - INFO -   |--    Epoch Losses (10): [0.0001, 0.0001, 0.0, 0.0029, 0.0, 0.0008, 0.0, 0.0152, 0.0011, 0.0277]
# 2021-09-01 23:27:33,707 - INFO -     |---- Number of Forgettables: 514 (2.68%)
# 2021-09-01 23:27:33,708 - INFO -     |---- Train Accuracy: 41.71%
# 2021-09-01 23:27:33,709 - INFO -     |---- Test Accuracy: 18.38%
# 2021-09-01 23:27:33,710 - INFO -     |---- Test Loss: 4.5887
# 2021-09-01 23:27:33,712 - INFO -     |---- Elapsed time: 9:43:08.830863
# 2021-09-01 23:27:33,713 - INFO -
# Test Acc: Max 18.3813% (180 round) | Last 18.3813% | Avg 14.9670% (4 round)
#
# 2021-09-01 23:27:33,717 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 23:27:50,146 - INFO -   |-- [Party 1] Average Train Loss:  12.6455 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:27:50,149 - INFO -   |--    Epoch Losses (10): [54.8352, 30.1172, 15.0051, 7.8203, 4.5086, 3.3572, 2.912, 2.708, 2.6283, 2.5634]
# 2021-09-01 23:28:06,307 - INFO -   |-- [Party 2] Average Train Loss:  18.6875 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:28:06,309 - INFO -   |--    Epoch Losses (10): [59.044, 41.7096, 28.5276, 18.3888, 11.5095, 7.9404, 5.9933, 5.0912, 4.4633, 4.2074]
# 2021-09-01 23:28:23,517 - INFO -   |-- [Party 3] Average Train Loss:  17.8717 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:28:23,518 - INFO -   |--    Epoch Losses (10): [57.1619, 38.778, 27.2959, 18.473, 12.0472, 8.1349, 5.5085, 4.5171, 3.5999, 3.2009]
# 2021-09-01 23:28:40,104 - INFO -   |-- [Party 4] Average Train Loss:  20.0472 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:28:40,106 - INFO -   |--    Epoch Losses (10): [59.8873, 44.3961, 32.8967, 21.7848, 13.5303, 8.5522, 6.0175, 4.9341, 4.3307, 4.1419]
# 2021-09-01 23:29:01,629 - INFO -   |-- [Party 5] Average Train Loss:  19.5861 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:29:01,632 - INFO -   |--    Epoch Losses (10): [60.1013, 43.9486, 31.9047, 21.6409, 13.1882, 8.2334, 5.492, 4.106, 3.7869, 3.4593]
# 2021-09-01 23:29:21,302 - INFO -   |-- [Party 6] Average Train Loss:   0.1486 Train Accuracy: global  93.71% local  51.50% ...  124 forgettables out of 2130 ( 5.82%) ... total data used 2130
# 2021-09-01 23:29:21,304 - INFO -   |--    Epoch Losses (10): [0.2625, 0.198, 0.1642, 0.15, 0.1545, 0.1327, 0.0982, 0.1259, 0.1138, 0.0863]
# 2021-09-01 23:29:40,051 - INFO -   |-- [Party 7] Average Train Loss:   0.0988 Train Accuracy: global  92.96% local  51.50% ...  147 forgettables out of 2130 ( 6.90%) ... total data used 2130
# 2021-09-01 23:29:40,055 - INFO -   |--    Epoch Losses (10): [0.2105, 0.152, 0.1141, 0.0883, 0.0821, 0.091, 0.0636, 0.0447, 0.0795, 0.0618]
# 2021-09-01 23:29:59,545 - INFO -   |-- [Party 8] Average Train Loss:   0.1224 Train Accuracy: global  92.54% local  51.50% ...  151 forgettables out of 2130 ( 7.09%) ... total data used 2130
# 2021-09-01 23:29:59,547 - INFO -   |--    Epoch Losses (10): [0.2527, 0.2006, 0.1359, 0.1377, 0.1189, 0.087, 0.0944, 0.0721, 0.0659, 0.0583]
# 2021-09-01 23:30:15,695 - INFO -   |-- [Party 9] Average Train Loss:   0.0033 Train Accuracy: global  96.38% local  51.50% ...   77 forgettables out of 2130 ( 3.62%) ... total data used 2130
# 2021-09-01 23:30:15,697 - INFO -   |--    Epoch Losses (10): [0.0046, 0.0, 0.0004, 0.0, 0.0007, 0.0066, 0.003, 0.0079, 0.0033, 0.0066]
# 2021-09-01 23:30:29,077 - INFO -     |---- Number of Forgettables: 499 (2.60%)
# 2021-09-01 23:30:29,079 - INFO -     |---- Train Accuracy: 41.81%
# 2021-09-01 23:30:29,080 - INFO -     |---- Test Accuracy: 18.36%
# 2021-09-01 23:30:29,081 - INFO -     |---- Test Loss: 3.9902
# 2021-09-01 23:30:29,083 - INFO -     |---- Elapsed time: 9:46:04.201871
# 2021-09-01 23:30:29,086 - INFO -
# Test Acc: Max 18.3633% (180 round) | Last 18.3633% | Avg 14.9841% (4 round)
#
# 2021-09-01 23:30:29,088 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 23:30:45,336 - INFO -   |-- [Party 1] Average Train Loss:  12.5520 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:30:45,340 - INFO -   |--    Epoch Losses (10): [54.9249, 30.5724, 14.9068, 7.094, 4.2005, 3.2318, 2.8172, 2.6579, 2.5825, 2.5319]
# 2021-09-01 23:31:01,468 - INFO -   |-- [Party 2] Average Train Loss:  19.8693 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:31:01,469 - INFO -   |--    Epoch Losses (10): [58.4813, 41.9162, 29.6624, 21.0523, 15.0792, 10.4039, 7.5157, 5.7707, 4.7318, 4.0798]
# 2021-09-01 23:31:18,185 - INFO -   |-- [Party 3] Average Train Loss:  19.1003 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:31:18,187 - INFO -   |--    Epoch Losses (10): [58.2363, 40.8233, 29.8756, 20.8083, 13.8607, 8.4209, 6.0726, 5.0869, 4.1764, 3.6424]
# 2021-09-01 23:31:34,351 - INFO -   |-- [Party 4] Average Train Loss:  19.2404 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:31:34,355 - INFO -   |--    Epoch Losses (10): [59.4539, 43.4168, 30.5911, 20.3093, 12.536, 7.7845, 5.4681, 4.6459, 4.2339, 3.9644]
# 2021-09-01 23:31:50,601 - INFO -   |-- [Party 5] Average Train Loss:  19.7170 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:31:50,602 - INFO -   |--    Epoch Losses (10): [59.4634, 43.5255, 31.5878, 21.7731, 14.0624, 8.9174, 5.9329, 4.4756, 3.8957, 3.5358]
# 2021-09-01 23:32:09,225 - INFO -   |-- [Party 6] Average Train Loss:   0.1490 Train Accuracy: global  93.00% local  51.50% ...  143 forgettables out of 2130 ( 6.71%) ... total data used 2130
# 2021-09-01 23:32:09,226 - INFO -   |--    Epoch Losses (10): [0.2513, 0.1847, 0.1554, 0.1551, 0.159, 0.1301, 0.1325, 0.1022, 0.1031, 0.1171]
# 2021-09-01 23:32:27,332 - INFO -   |-- [Party 7] Average Train Loss:   0.0923 Train Accuracy: global  93.00% local  51.50% ...  142 forgettables out of 2130 ( 6.67%) ... total data used 2130
# 2021-09-01 23:32:27,335 - INFO -   |--    Epoch Losses (10): [0.2297, 0.13, 0.0833, 0.0948, 0.0867, 0.0594, 0.0642, 0.0649, 0.0638, 0.0458]
# 2021-09-01 23:32:46,249 - INFO -   |-- [Party 8] Average Train Loss:   0.1304 Train Accuracy: global  92.39% local  48.50% ...  156 forgettables out of 2130 ( 7.32%) ... total data used 2130
# 2021-09-01 23:32:46,251 - INFO -   |--    Epoch Losses (10): [0.2781, 0.1959, 0.1659, 0.13, 0.1116, 0.1273, 0.0899, 0.0755, 0.0756, 0.0542]
# 2021-09-01 23:33:04,183 - INFO -   |-- [Party 9] Average Train Loss:   0.0027 Train Accuracy: global  96.57% local  99.91% ...   73 forgettables out of 2130 ( 3.43%) ... total data used 2130
# 2021-09-01 23:33:04,185 - INFO -   |--    Epoch Losses (10): [0.0, 0.0, 0.0001, 0.0, 0.0002, 0.0046, 0.0053, 0.0011, 0.0079, 0.0081]
# 2021-09-01 23:33:17,550 - INFO -     |---- Number of Forgettables: 514 (2.68%)
# 2021-09-01 23:33:17,553 - INFO -     |---- Train Accuracy: 41.82%
# 2021-09-01 23:33:17,554 - INFO -     |---- Test Accuracy: 18.39%
# 2021-09-01 23:33:17,555 - INFO -     |---- Test Loss: 4.0808
# 2021-09-01 23:33:17,556 - INFO -     |---- Elapsed time: 9:48:52.675220
# 2021-09-01 23:33:17,558 - INFO -
# Test Acc: Max 18.3934% (180 round) | Last 18.3934% | Avg 15.0013% (4 round)
#
# 2021-09-01 23:33:17,560 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 23:33:36,219 - INFO -   |-- [Party 1] Average Train Loss:  12.2747 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:33:36,220 - INFO -   |--    Epoch Losses (10): [54.5299, 30.6351, 14.271, 6.1837, 3.7134, 2.9416, 2.7253, 2.6289, 2.5809, 2.5367]
# 2021-09-01 23:33:52,435 - INFO -   |-- [Party 2] Average Train Loss:  19.1224 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:33:52,436 - INFO -   |--    Epoch Losses (10): [57.9952, 40.6974, 27.918, 19.7606, 13.9248, 9.8069, 6.9176, 5.5637, 4.6849, 3.9549]
# 2021-09-01 23:34:09,824 - INFO -   |-- [Party 3] Average Train Loss:  20.3125 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:34:09,828 - INFO -   |--    Epoch Losses (10): [58.8376, 42.4995, 31.4694, 22.6574, 15.7989, 10.301, 7.3633, 5.5466, 4.5792, 4.0722]
# 2021-09-01 23:34:28,531 - INFO -   |-- [Party 4] Average Train Loss:  20.3130 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:34:28,533 - INFO -   |--    Epoch Losses (10): [59.9436, 45.1057, 33.4982, 22.4437, 14.364, 8.795, 5.9609, 4.8224, 4.2113, 3.9854]
# 2021-09-01 23:34:46,110 - INFO -   |-- [Party 5] Average Train Loss:  20.2390 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 23:34:46,111 - INFO -   |--    Epoch Losses (10): [59.6237, 43.7685, 32.3111, 22.7795, 15.2136, 10.3196, 6.6936, 4.5903, 3.7056, 3.3843]
# 2021-09-01 23:35:05,664 - INFO -   |-- [Party 6] Average Train Loss:   0.1575 Train Accuracy: global  93.52% local  48.50% ...  132 forgettables out of 2130 ( 6.20%) ... total data used 2130
# 2021-09-01 23:35:05,667 - INFO -   |--    Epoch Losses (10): [0.2972, 0.1941, 0.1904, 0.1676, 0.1271, 0.1257, 0.1095, 0.1252, 0.1121, 0.1264]
# 2021-09-01 23:35:22,604 - INFO -   |-- [Party 7] Average Train Loss:   0.0855 Train Accuracy: global  93.24% local  51.50% ...  143 forgettables out of 2130 ( 6.71%) ... total data used 2130
# 2021-09-01 23:35:22,606 - INFO -   |--    Epoch Losses (10): [0.2084, 0.1177, 0.074, 0.0948, 0.0857, 0.0728, 0.0351, 0.058, 0.0612, 0.0473]
# 2021-09-01 23:35:40,541 - INFO -   |-- [Party 8] Average Train Loss:   0.1257 Train Accuracy: global  92.96% local  51.50% ...    8 forgettables out of 2130 ( 0.38%) ... total data used 2130
# 2021-09-01 23:35:40,542 - INFO -   |--    Epoch Losses (10): [0.2987, 0.1711, 0.1728, 0.1202, 0.1011, 0.1043, 0.0685, 0.0949, 0.059, 0.0667]
# 2021-09-01 23:35:56,906 - INFO -   |-- [Party 9] Average Train Loss:   0.0012 Train Accuracy: global  96.57% local  51.50% ...   73 forgettables out of 2130 ( 3.43%) ... total data used 2130
# 2021-09-01 23:35:56,908 - INFO -   |--    Epoch Losses (10): [0.0001, 0.0, 0.0001, 0.0025, 0.0011, 0.0001, 0.0002, 0.0039, 0.0001, 0.0035]
# 2021-09-01 23:36:10,067 - INFO -     |---- Number of Forgettables: 356 (1.86%)
# 2021-09-01 23:36:10,068 - INFO -     |---- Train Accuracy: 41.89%
# 2021-09-01 23:36:10,069 - INFO -     |---- Test Accuracy: 18.50%
# 2021-09-01 23:36:10,070 - INFO -     |---- Test Loss: 3.5379
# 2021-09-01 23:36:10,071 - INFO -     |---- Elapsed time: 9:51:45.189732
# 2021-09-01 23:36:10,072 - INFO -
# Test Acc: Max 18.5016% (180 round) | Last 18.5016% | Avg 15.0188% (4 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

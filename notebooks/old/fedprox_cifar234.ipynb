# %%
# %matplotlib inline

dataset = 'cifar10'
clsimb = [2, 3, 4] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_fedprox'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 1

# %%
import copy
import json
import logging
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Files already downloaded and verified

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
def average_weights(w):
    w_avg = copy.deepcopy(w[0])
        
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
    return w_avg

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, global_model, mu=0.01):
    epoch_losses = []
    
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    
    global_params = list(global_model.parameters())
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            prox_reg = 0.0
            for i, param in enumerate(model.parameters()):
                prox_reg += ((mu / 2) * torch.norm((param - global_params[i])) ** 2)
            loss += prox_reg
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    local_weights = model.state_dict()

    return local_weights, epoch_losses

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0

logger.info(f'\nAlgorithm: FedProx\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, fed_model, mu=0.01)

        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
    fed_weights = average_weights(local_weights)
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 13:25:29,479 - INFO -
# Algorithm: FedProx
# Client Split: [2, 3, 4]
# Dataset: cifar10
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 13:25:29,483 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 13:25:42,185 - INFO -   |-- [Party 1] Average Train Loss:   0.6005 Train Accuracy: global   0.00% local  90.76% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:25:42,188 - INFO -   |--    Epoch Losses (10): [1.0634, 0.8102, 0.7103, 0.609, 0.5662, 0.5039, 0.4629, 0.4176, 0.4384, 0.4227]
# 2021-09-01 13:25:52,752 - INFO -   |-- [Party 2] Average Train Loss:   0.5456 Train Accuracy: global   0.00% local  63.24% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:25:52,758 - INFO -   |--    Epoch Losses (10): [1.0542, 0.7577, 0.667, 0.5456, 0.4701, 0.4251, 0.3541, 0.3844, 0.3807, 0.4171]
# 2021-09-01 13:26:03,450 - INFO -   |-- [Party 3] Average Train Loss:   0.7854 Train Accuracy: global   0.00% local  67.02% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:03,452 - INFO -   |--    Epoch Losses (10): [1.2586, 0.9883, 0.9119, 0.7789, 0.7147, 0.6857, 0.6553, 0.6165, 0.6264, 0.6179]
# 2021-09-01 13:26:14,376 - INFO -   |-- [Party 4] Average Train Loss:   0.7474 Train Accuracy: global   0.00% local  77.45% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:14,380 - INFO -   |--    Epoch Losses (10): [1.1893, 0.9449, 0.864, 0.763, 0.6702, 0.6498, 0.5974, 0.622, 0.5999, 0.5739]
# 2021-09-01 13:26:24,588 - INFO -   |-- [Party 5] Average Train Loss:   0.7805 Train Accuracy: global   0.00% local  64.78% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:24,591 - INFO -   |--    Epoch Losses (10): [1.2502, 0.9428, 0.9119, 0.8056, 0.6846, 0.673, 0.6128, 0.6389, 0.6215, 0.664]
# 2021-09-01 13:26:34,590 - INFO -   |-- [Party 6] Average Train Loss:   0.6407 Train Accuracy: global  50.00% local  87.04% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:34,594 - INFO -   |--    Epoch Losses (10): [1.1169, 0.8721, 0.7245, 0.653, 0.5564, 0.5579, 0.4968, 0.4809, 0.5035, 0.4449]
# 2021-09-01 13:26:45,117 - INFO -   |-- [Party 7] Average Train Loss:   0.5940 Train Accuracy: global  50.00% local  89.01% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:45,121 - INFO -   |--    Epoch Losses (10): [1.08, 0.8319, 0.7288, 0.6, 0.4883, 0.5081, 0.4617, 0.4087, 0.4222, 0.4104]
# 2021-09-01 13:26:55,442 - INFO -   |-- [Party 8] Average Train Loss:   0.6058 Train Accuracy: global  50.00% local  83.89% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:55,443 - INFO -   |--    Epoch Losses (10): [1.0609, 0.8752, 0.7414, 0.5952, 0.5508, 0.5165, 0.4538, 0.432, 0.4308, 0.4017]
# 2021-09-01 13:27:05,660 - INFO -   |-- [Party 9] Average Train Loss:   0.6197 Train Accuracy: global  50.00% local  86.13% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:27:05,664 - INFO -   |--    Epoch Losses (10): [1.0808, 0.8803, 0.7665, 0.6371, 0.5646, 0.4876, 0.479, 0.4427, 0.4113, 0.4472]
# 2021-09-01 13:27:12,671 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 13:27:12,675 - INFO -     |---- Train Accuracy: 22.25%
# 2021-09-01 13:27:12,677 - INFO -     |---- Test Accuracy: 16.67%
# 2021-09-01 13:27:12,678 - INFO -     |---- Test Loss: 2.1224
# 2021-09-01 13:27:12,679 - INFO -     |---- Elapsed time: 0:01:43.196640
# 2021-09-01 13:27:12,680 - INFO -
# Test Acc: Max 16.6667% (1 round) | Last 16.6667% | Avg 16.6667% (1 round)
#
# 2021-09-01 13:27:12,683 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 13:27:22,859 - INFO -   |-- [Party 1] Average Train Loss:   0.5114 Train Accuracy: global   0.00% local  90.41% ... 1296 forgettables out of 1428 (90.76%) ... total data used 1428
# 2021-09-01 13:27:22,863 - INFO -   |--    Epoch Losses (10): [0.9603, 0.7366, 0.6358, 0.507, 0.4116, 0.3739, 0.3997, 0.4036, 0.3733, 0.3123]
# 2021-09-01 13:27:33,816 - INFO -   |-- [Party 2] Average Train Loss:   0.5036 Train Accuracy: global   0.00% local  86.06% ...  903 forgettables out of 1428 (63.24%) ... total data used 1428
# 2021-09-01 13:27:33,820 - INFO -   |--    Epoch Losses (10): [0.9544, 0.7642, 0.6249, 0.5037, 0.4304, 0.4093, 0.3645, 0.3504, 0.3139, 0.3198]
# 2021-09-01 13:27:44,698 - INFO -   |-- [Party 3] Average Train Loss:   0.6960 Train Accuracy: global   0.00% local  77.24% ...  957 forgettables out of 1428 (67.02%) ... total data used 1428
# 2021-09-01 13:27:44,702 - INFO -   |--    Epoch Losses (10): [0.9862, 0.9342, 0.789, 0.7018, 0.6386, 0.6258, 0.5953, 0.5543, 0.5573, 0.5778]
# 2021-09-01 13:27:55,774 - INFO -   |-- [Party 4] Average Train Loss:   0.6374 Train Accuracy: global   0.00% local  75.42% ... 1106 forgettables out of 1428 (77.45%) ... total data used 1428
# 2021-09-01 13:27:55,778 - INFO -   |--    Epoch Losses (10): [0.9554, 0.8303, 0.7741, 0.6186, 0.5648, 0.5154, 0.4974, 0.5139, 0.5241, 0.5805]
# 2021-09-01 13:28:06,466 - INFO -   |-- [Party 5] Average Train Loss:   0.6673 Train Accuracy: global   0.00% local  61.41% ...  925 forgettables out of 1428 (64.78%) ... total data used 1428
# 2021-09-01 13:28:06,470 - INFO -   |--    Epoch Losses (10): [0.9893, 0.8843, 0.7722, 0.6642, 0.5567, 0.5667, 0.5591, 0.5839, 0.5638, 0.5332]
# 2021-09-01 13:28:17,185 - INFO -   |-- [Party 6] Average Train Loss:   0.4515 Train Accuracy: global  50.07% local  88.38% ...  585 forgettables out of 1428 (40.97%) ... total data used 1428
# 2021-09-01 13:28:17,189 - INFO -   |--    Epoch Losses (10): [0.6319, 0.6026, 0.4804, 0.4342, 0.4295, 0.4429, 0.4064, 0.3853, 0.3377, 0.3641]
# 2021-09-01 13:28:27,489 - INFO -   |-- [Party 7] Average Train Loss:   0.4492 Train Accuracy: global  50.00% local  78.57% ...  595 forgettables out of 1428 (41.67%) ... total data used 1428
# 2021-09-01 13:28:27,492 - INFO -   |--    Epoch Losses (10): [0.6089, 0.5564, 0.4442, 0.3902, 0.3818, 0.4054, 0.4031, 0.4362, 0.421, 0.4446]
# 2021-09-01 13:28:37,706 - INFO -   |-- [Party 8] Average Train Loss:   0.4496 Train Accuracy: global  50.07% local  89.78% ...  501 forgettables out of 1428 (35.08%) ... total data used 1428
# 2021-09-01 13:28:37,708 - INFO -   |--    Epoch Losses (10): [0.6632, 0.6179, 0.4927, 0.423, 0.3688, 0.3622, 0.416, 0.4049, 0.364, 0.3835]
# 2021-09-01 13:28:48,439 - INFO -   |-- [Party 9] Average Train Loss:   0.4759 Train Accuracy: global  50.00% local  79.83% ...  559 forgettables out of 1428 (39.15%) ... total data used 1428
# 2021-09-01 13:28:48,443 - INFO -   |--    Epoch Losses (10): [0.6502, 0.6075, 0.4927, 0.4392, 0.4158, 0.4262, 0.4096, 0.4209, 0.4365, 0.4606]
# 2021-09-01 13:28:54,992 - INFO -     |---- Number of Forgettables: 7427 (57.79%)
# 2021-09-01 13:28:54,993 - INFO -     |---- Train Accuracy: 32.01%
# 2021-09-01 13:28:54,994 - INFO -     |---- Test Accuracy: 23.45%
# 2021-09-01 13:28:54,995 - INFO -     |---- Test Loss: 2.1065
# 2021-09-01 13:28:54,996 - INFO -     |---- Elapsed time: 0:03:25.513788
# 2021-09-01 13:28:54,997 - INFO -
# Test Acc: Max 23.4500% (2 round) | Last 23.4500% | Avg 20.0583% (2 round)
#
# 2021-09-01 13:28:55,000 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 13:29:05,379 - INFO -   |-- [Party 1] Average Train Loss:   0.4375 Train Accuracy: global   0.00% local  90.48% ... 1291 forgettables out of 1428 (90.41%) ... total data used 1428
# 2021-09-01 13:29:05,381 - INFO -   |--    Epoch Losses (10): [0.8472, 0.6366, 0.5041, 0.431, 0.3506, 0.3466, 0.3263, 0.3144, 0.3202, 0.2983]
# 2021-09-01 13:29:15,423 - INFO -   |-- [Party 2] Average Train Loss:   0.4090 Train Accuracy: global   0.00% local  92.79% ... 1229 forgettables out of 1428 (86.06%) ... total data used 1428
# 2021-09-01 13:29:15,427 - INFO -   |--    Epoch Losses (10): [0.8723, 0.6251, 0.5054, 0.3738, 0.3125, 0.2833, 0.2688, 0.2789, 0.2807, 0.2887]
# 2021-09-01 13:29:25,594 - INFO -   |-- [Party 3] Average Train Loss:   0.6060 Train Accuracy: global   0.00% local  83.26% ... 1103 forgettables out of 1428 (77.24%) ... total data used 1428
# 2021-09-01 13:29:25,595 - INFO -   |--    Epoch Losses (10): [0.8803, 0.7663, 0.658, 0.5835, 0.5736, 0.5388, 0.4945, 0.5042, 0.506, 0.5545]
# 2021-09-01 13:29:35,650 - INFO -   |-- [Party 4] Average Train Loss:   0.5622 Train Accuracy: global   0.00% local  60.99% ... 1077 forgettables out of 1428 (75.42%) ... total data used 1428
# 2021-09-01 13:29:35,652 - INFO -   |--    Epoch Losses (10): [0.811, 0.7171, 0.6402, 0.5301, 0.5057, 0.4376, 0.4693, 0.5186, 0.5254, 0.4671]
# 2021-09-01 13:29:45,770 - INFO -   |-- [Party 5] Average Train Loss:   0.5649 Train Accuracy: global   0.00% local  83.75% ...  877 forgettables out of 1428 (61.41%) ... total data used 1428
# 2021-09-01 13:29:45,772 - INFO -   |--    Epoch Losses (10): [0.8715, 0.7828, 0.6376, 0.5391, 0.5092, 0.4797, 0.4616, 0.4377, 0.4529, 0.477]
# 2021-09-01 13:29:56,503 - INFO -   |-- [Party 6] Average Train Loss:   0.3535 Train Accuracy: global  72.69% local  85.22% ...  355 forgettables out of 1428 (24.86%) ... total data used 1428
# 2021-09-01 13:29:56,504 - INFO -   |--    Epoch Losses (10): [0.5044, 0.4676, 0.3431, 0.3108, 0.3334, 0.3181, 0.2922, 0.29, 0.3275, 0.3476]
# 2021-09-01 13:30:06,567 - INFO -   |-- [Party 7] Average Train Loss:   0.3276 Train Accuracy: global  71.22% local  72.90% ...  396 forgettables out of 1428 (27.73%) ... total data used 1428
# 2021-09-01 13:30:06,570 - INFO -   |--    Epoch Losses (10): [0.5069, 0.4192, 0.3227, 0.2967, 0.3002, 0.303, 0.2929, 0.313, 0.284, 0.238]
# 2021-09-01 13:30:17,524 - INFO -   |-- [Party 8] Average Train Loss:   0.3260 Train Accuracy: global  71.64% local  89.22% ...  364 forgettables out of 1428 (25.49%) ... total data used 1428
# 2021-09-01 13:30:17,528 - INFO -   |--    Epoch Losses (10): [0.4924, 0.4429, 0.3492, 0.3062, 0.284, 0.2804, 0.2755, 0.2751, 0.2744, 0.2804]
# 2021-09-01 13:30:27,757 - INFO -   |-- [Party 9] Average Train Loss:   0.3780 Train Accuracy: global  70.45% local  90.97% ...  163 forgettables out of 1428 (11.41%) ... total data used 1428
# 2021-09-01 13:30:27,760 - INFO -   |--    Epoch Losses (10): [0.5594, 0.5029, 0.3688, 0.3163, 0.3173, 0.3223, 0.3017, 0.3307, 0.3674, 0.3934]
# 2021-09-01 13:30:34,670 - INFO -     |---- Number of Forgettables: 6855 (53.34%)
# 2021-09-01 13:30:34,674 - INFO -     |---- Train Accuracy: 38.83%
# 2021-09-01 13:30:34,675 - INFO -     |---- Test Accuracy: 29.45%
# 2021-09-01 13:30:34,676 - INFO -     |---- Test Loss: 1.9499
# 2021-09-01 13:30:34,677 - INFO -     |---- Elapsed time: 0:05:05.194687
# 2021-09-01 13:30:34,678 - INFO -
# Test Acc: Max 29.4500% (3 round) | Last 29.4500% | Avg 23.1889% (2 round)
#
# 2021-09-01 13:30:34,681 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 13:30:45,432 - INFO -   |-- [Party 1] Average Train Loss:   0.3709 Train Accuracy: global   0.00% local  94.61% ... 1292 forgettables out of 1428 (90.48%) ... total data used 1428
# 2021-09-01 13:30:45,434 - INFO -   |--    Epoch Losses (10): [0.8156, 0.5613, 0.4366, 0.3236, 0.3002, 0.2615, 0.2518, 0.2703, 0.2611, 0.2266]
# 2021-09-01 13:30:56,210 - INFO -   |-- [Party 2] Average Train Loss:   0.3927 Train Accuracy: global   0.00% local  88.59% ... 1325 forgettables out of 1428 (92.79%) ... total data used 1428
# 2021-09-01 13:30:56,214 - INFO -   |--    Epoch Losses (10): [0.7995, 0.5571, 0.4392, 0.4025, 0.3163, 0.2832, 0.3023, 0.3013, 0.278, 0.2472]
# 2021-09-01 13:31:06,282 - INFO -   |-- [Party 3] Average Train Loss:   0.5450 Train Accuracy: global   0.00% local  69.05% ... 1189 forgettables out of 1428 (83.26%) ... total data used 1428
# 2021-09-01 13:31:06,284 - INFO -   |--    Epoch Losses (10): [0.8543, 0.7517, 0.58, 0.4892, 0.4964, 0.4624, 0.4451, 0.4426, 0.4543, 0.4739]
# 2021-09-01 13:31:16,535 - INFO -   |-- [Party 4] Average Train Loss:   0.4682 Train Accuracy: global   0.00% local  82.56% ...  871 forgettables out of 1428 (60.99%) ... total data used 1428
# 2021-09-01 13:31:16,538 - INFO -   |--    Epoch Losses (10): [0.7548, 0.6351, 0.4987, 0.4792, 0.4111, 0.3788, 0.3778, 0.4218, 0.3933, 0.3311]
# 2021-09-01 13:31:27,047 - INFO -   |-- [Party 5] Average Train Loss:   0.5156 Train Accuracy: global   0.00% local  86.69% ... 1196 forgettables out of 1428 (83.75%) ... total data used 1428
# 2021-09-01 13:31:27,048 - INFO -   |--    Epoch Losses (10): [0.7997, 0.6798, 0.5576, 0.535, 0.4705, 0.4556, 0.4185, 0.4223, 0.393, 0.4238]
# 2021-09-01 13:31:38,296 - INFO -   |-- [Party 6] Average Train Loss:   0.3134 Train Accuracy: global  87.25% local  88.59% ...  121 forgettables out of 1428 ( 8.47%) ... total data used 1428
# 2021-09-01 13:31:38,300 - INFO -   |--    Epoch Losses (10): [0.4167, 0.3744, 0.3495, 0.3515, 0.3095, 0.2547, 0.2822, 0.2562, 0.2497, 0.2893]
# 2021-09-01 13:31:48,331 - INFO -   |-- [Party 7] Average Train Loss:   0.2998 Train Accuracy: global  87.39% local  94.05% ...   43 forgettables out of 1428 ( 3.01%) ... total data used 1428
# 2021-09-01 13:31:48,333 - INFO -   |--    Epoch Losses (10): [0.3928, 0.3623, 0.2937, 0.2421, 0.2192, 0.2756, 0.3049, 0.3126, 0.3157, 0.2793]
# 2021-09-01 13:31:59,286 - INFO -   |-- [Party 8] Average Train Loss:   0.2868 Train Accuracy: global  87.54% local  81.09% ...   91 forgettables out of 1428 ( 6.37%) ... total data used 1428
# 2021-09-01 13:31:59,289 - INFO -   |--    Epoch Losses (10): [0.4143, 0.3692, 0.2538, 0.2641, 0.2853, 0.2732, 0.2461, 0.2691, 0.2538, 0.2387]
# 2021-09-01 13:32:09,507 - INFO -   |-- [Party 9] Average Train Loss:   0.3113 Train Accuracy: global  86.41% local  93.28% ...  119 forgettables out of 1428 ( 8.33%) ... total data used 1428
# 2021-09-01 13:32:09,508 - INFO -   |--    Epoch Losses (10): [0.4404, 0.3752, 0.3192, 0.3003, 0.2831, 0.3037, 0.2976, 0.2789, 0.271, 0.244]
# 2021-09-01 13:32:16,006 - INFO -     |---- Number of Forgettables: 6247 (48.61%)
# 2021-09-01 13:32:16,009 - INFO -     |---- Train Accuracy: 40.37%
# 2021-09-01 13:32:16,010 - INFO -     |---- Test Accuracy: 30.12%
# 2021-09-01 13:32:16,011 - INFO -     |---- Test Loss: 1.8842
# 2021-09-01 13:32:16,012 - INFO -     |---- Elapsed time: 0:06:46.529936
# 2021-09-01 13:32:16,013 - INFO -
# Test Acc: Max 30.1167% (4 round) | Last 30.1167% | Avg 24.9208% (3 round)
#
# 2021-09-01 13:32:16,016 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 13:32:26,115 - INFO -   |-- [Party 1] Average Train Loss:   0.3734 Train Accuracy: global   0.00% local  83.82% ... 1351 forgettables out of 1428 (94.61%) ... total data used 1428
# 2021-09-01 13:32:26,117 - INFO -   |--    Epoch Losses (10): [0.8269, 0.5346, 0.3979, 0.3513, 0.2701, 0.2423, 0.3096, 0.2425, 0.2856, 0.2735]
# 2021-09-01 13:32:36,945 - INFO -   |-- [Party 2] Average Train Loss:   0.3175 Train Accuracy: global   0.00% local  93.91% ... 1265 forgettables out of 1428 (88.59%) ... total data used 1428
# 2021-09-01 13:32:36,946 - INFO -   |--    Epoch Losses (10): [0.8048, 0.5211, 0.3869, 0.3053, 0.2285, 0.2096, 0.1809, 0.174, 0.1745, 0.1889]
# 2021-09-01 13:32:47,816 - INFO -   |-- [Party 3] Average Train Loss:   0.5036 Train Accuracy: global   0.00% local  71.08% ...  986 forgettables out of 1428 (69.05%) ... total data used 1428
# 2021-09-01 13:32:47,819 - INFO -   |--    Epoch Losses (10): [0.8313, 0.6897, 0.5223, 0.4718, 0.4418, 0.4128, 0.4093, 0.4089, 0.4069, 0.4407]
# 2021-09-01 13:32:58,828 - INFO -   |-- [Party 4] Average Train Loss:   0.4388 Train Accuracy: global   0.00% local  76.40% ... 1179 forgettables out of 1428 (82.56%) ... total data used 1428
# 2021-09-01 13:32:58,831 - INFO -   |--    Epoch Losses (10): [0.7461, 0.581, 0.4559, 0.3978, 0.3828, 0.3803, 0.3913, 0.3704, 0.3545, 0.3283]
# 2021-09-01 13:33:09,037 - INFO -   |-- [Party 5] Average Train Loss:   0.4781 Train Accuracy: global   0.00% local  86.62% ... 1238 forgettables out of 1428 (86.69%) ... total data used 1428
# 2021-09-01 13:33:09,039 - INFO -   |--    Epoch Losses (10): [0.7537, 0.5944, 0.5251, 0.4917, 0.4413, 0.4215, 0.3988, 0.3669, 0.4008, 0.3867]
# 2021-09-01 13:33:19,472 - INFO -   |-- [Party 6] Average Train Loss:   0.2793 Train Accuracy: global  89.64% local  92.65% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 13:33:19,475 - INFO -   |--    Epoch Losses (10): [0.3903, 0.3562, 0.2575, 0.2524, 0.2234, 0.2447, 0.2201, 0.2421, 0.2826, 0.3242]
# 2021-09-01 13:33:29,770 - INFO -   |-- [Party 7] Average Train Loss:   0.2592 Train Accuracy: global  91.81% local  89.36% ...   57 forgettables out of 1428 ( 3.99%) ... total data used 1428
# 2021-09-01 13:33:29,771 - INFO -   |--    Epoch Losses (10): [0.4047, 0.3184, 0.2609, 0.2274, 0.2291, 0.2145, 0.2101, 0.2387, 0.2709, 0.2173]
# 2021-09-01 13:33:40,827 - INFO -   |-- [Party 8] Average Train Loss:   0.2838 Train Accuracy: global  89.99% local  85.64% ...   57 forgettables out of 1428 ( 3.99%) ... total data used 1428
# 2021-09-01 13:33:40,829 - INFO -   |--    Epoch Losses (10): [0.405, 0.3471, 0.2735, 0.2484, 0.3214, 0.3299, 0.2829, 0.2338, 0.2104, 0.186]
# 2021-09-01 13:33:50,866 - INFO -   |-- [Party 9] Average Train Loss:   0.2746 Train Accuracy: global  90.97% local  90.90% ...   79 forgettables out of 1428 ( 5.53%) ... total data used 1428
# 2021-09-01 13:33:50,867 - INFO -   |--    Epoch Losses (10): [0.3752, 0.3553, 0.2701, 0.2246, 0.2155, 0.2127, 0.2654, 0.2569, 0.2936, 0.2762]
# 2021-09-01 13:33:57,593 - INFO -     |---- Number of Forgettables: 6287 (48.92%)
# 2021-09-01 13:33:57,597 - INFO -     |---- Train Accuracy: 41.15%
# 2021-09-01 13:33:57,598 - INFO -     |---- Test Accuracy: 30.63%
# 2021-09-01 13:33:57,599 - INFO -     |---- Test Loss: 1.8313
# 2021-09-01 13:33:57,600 - INFO -     |---- Elapsed time: 0:08:28.117790
# 2021-09-01 13:33:57,601 - INFO -
# Test Acc: Max 30.6333% (5 round) | Last 30.6333% | Avg 26.0633% (3 round)
#
# 2021-09-01 13:33:57,605 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 13:34:08,021 - INFO -   |-- [Party 1] Average Train Loss:   0.3118 Train Accuracy: global   0.00% local  95.31% ... 1197 forgettables out of 1428 (83.82%) ... total data used 1428
# 2021-09-01 13:34:08,022 - INFO -   |--    Epoch Losses (10): [0.813, 0.4706, 0.3644, 0.2505, 0.2007, 0.1891, 0.1945, 0.1928, 0.2071, 0.2348]
# 2021-09-01 13:34:18,177 - INFO -   |-- [Party 2] Average Train Loss:   0.3328 Train Accuracy: global   0.00% local  92.72% ... 1341 forgettables out of 1428 (93.91%) ... total data used 1428
# 2021-09-01 13:34:18,178 - INFO -   |--    Epoch Losses (10): [0.7895, 0.4736, 0.3683, 0.3122, 0.2593, 0.2298, 0.2689, 0.2125, 0.1894, 0.2241]
# 2021-09-01 13:34:28,313 - INFO -   |-- [Party 3] Average Train Loss:   0.4600 Train Accuracy: global   0.00% local  54.97% ... 1015 forgettables out of 1428 (71.08%) ... total data used 1428
# 2021-09-01 13:34:28,316 - INFO -   |--    Epoch Losses (10): [0.7441, 0.622, 0.5018, 0.4225, 0.3714, 0.3832, 0.4122, 0.3863, 0.3875, 0.3693]
# 2021-09-01 13:34:38,559 - INFO -   |-- [Party 4] Average Train Loss:   0.4033 Train Accuracy: global   0.00% local  86.90% ... 1091 forgettables out of 1428 (76.40%) ... total data used 1428
# 2021-09-01 13:34:38,561 - INFO -   |--    Epoch Losses (10): [0.6836, 0.5538, 0.437, 0.3593, 0.3221, 0.3081, 0.3259, 0.3535, 0.3485, 0.3417]
# 2021-09-01 13:34:49,110 - INFO -   |-- [Party 5] Average Train Loss:   0.4524 Train Accuracy: global   0.00% local  70.80% ... 1237 forgettables out of 1428 (86.62%) ... total data used 1428
# 2021-09-01 13:34:49,111 - INFO -   |--    Epoch Losses (10): [0.7188, 0.5821, 0.4649, 0.425, 0.3689, 0.4115, 0.397, 0.3754, 0.3923, 0.3885]
# 2021-09-01 13:34:59,486 - INFO -   |-- [Party 6] Average Train Loss:   0.2753 Train Accuracy: global  92.02% local  95.24% ...   71 forgettables out of 1428 ( 4.97%) ... total data used 1428
# 2021-09-01 13:34:59,488 - INFO -   |--    Epoch Losses (10): [0.372, 0.3402, 0.3038, 0.2739, 0.2873, 0.2818, 0.2473, 0.2111, 0.1996, 0.2359]
# 2021-09-01 13:35:10,847 - INFO -   |-- [Party 7] Average Train Loss:   0.2302 Train Accuracy: global  93.91% local  94.54% ...   46 forgettables out of 1428 ( 3.22%) ... total data used 1428
# 2021-09-01 13:35:10,848 - INFO -   |--    Epoch Losses (10): [0.3121, 0.2734, 0.2213, 0.2012, 0.2089, 0.2262, 0.2444, 0.2287, 0.197, 0.1884]
# 2021-09-01 13:35:20,992 - INFO -   |-- [Party 8] Average Train Loss:   0.2432 Train Accuracy: global  92.16% local  89.22% ...   68 forgettables out of 1428 ( 4.76%) ... total data used 1428
# 2021-09-01 13:35:20,994 - INFO -   |--    Epoch Losses (10): [0.3491, 0.2723, 0.2142, 0.2175, 0.1998, 0.2045, 0.2031, 0.1982, 0.3085, 0.2645]
# 2021-09-01 13:35:32,025 - INFO -   |-- [Party 9] Average Train Loss:   0.2646 Train Accuracy: global  92.02% local  96.36% ...   70 forgettables out of 1428 ( 4.90%) ... total data used 1428
# 2021-09-01 13:35:32,029 - INFO -   |--    Epoch Losses (10): [0.3195, 0.2906, 0.278, 0.2153, 0.2206, 0.2324, 0.277, 0.3037, 0.2705, 0.2383]
# 2021-09-01 13:35:38,710 - INFO -     |---- Number of Forgettables: 6136 (47.74%)
# 2021-09-01 13:35:38,714 - INFO -     |---- Train Accuracy: 41.29%
# 2021-09-01 13:35:38,715 - INFO -     |---- Test Accuracy: 30.67%
# 2021-09-01 13:35:38,716 - INFO -     |---- Test Loss: 1.8819
# 2021-09-01 13:35:38,716 - INFO -     |---- Elapsed time: 0:10:09.234214
# 2021-09-01 13:35:38,718 - INFO -
# Test Acc: Max 30.6667% (6 round) | Last 30.6667% | Avg 26.8306% (3 round)
#
# 2021-09-01 13:35:38,721 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 13:35:49,293 - INFO -   |-- [Party 1] Average Train Loss:   0.3196 Train Accuracy: global   0.00% local  80.81% ... 1361 forgettables out of 1428 (95.31%) ... total data used 1428
# 2021-09-01 13:35:49,296 - INFO -   |--    Epoch Losses (10): [0.8453, 0.4901, 0.3441, 0.2506, 0.1907, 0.1686, 0.1667, 0.2878, 0.2416, 0.211]
# 2021-09-01 13:36:00,743 - INFO -   |-- [Party 2] Average Train Loss:   0.3163 Train Accuracy: global   0.00% local  95.80% ... 1324 forgettables out of 1428 (92.72%) ... total data used 1428
# 2021-09-01 13:36:00,746 - INFO -   |--    Epoch Losses (10): [0.8238, 0.4935, 0.3462, 0.2436, 0.2056, 0.2321, 0.1947, 0.2107, 0.2156, 0.1976]
# 2021-09-01 13:36:11,595 - INFO -   |-- [Party 3] Average Train Loss:   0.4322 Train Accuracy: global   0.00% local  89.08% ...  785 forgettables out of 1428 (54.97%) ... total data used 1428
# 2021-09-01 13:36:11,599 - INFO -   |--    Epoch Losses (10): [0.7509, 0.574, 0.4897, 0.4156, 0.3813, 0.3244, 0.3559, 0.3484, 0.3487, 0.3327]
# 2021-09-01 13:36:23,123 - INFO -   |-- [Party 4] Average Train Loss:   0.3810 Train Accuracy: global   0.00% local  91.67% ... 1241 forgettables out of 1428 (86.90%) ... total data used 1428
# 2021-09-01 13:36:23,125 - INFO -   |--    Epoch Losses (10): [0.6762, 0.5141, 0.4089, 0.3802, 0.3349, 0.3543, 0.3064, 0.267, 0.2844, 0.2836]
# 2021-09-01 13:36:34,123 - INFO -   |-- [Party 5] Average Train Loss:   0.4280 Train Accuracy: global   0.00% local  90.83% ... 1011 forgettables out of 1428 (70.80%) ... total data used 1428
# 2021-09-01 13:36:34,125 - INFO -   |--    Epoch Losses (10): [0.7285, 0.5951, 0.454, 0.3732, 0.3413, 0.3256, 0.3483, 0.3829, 0.3786, 0.3525]
# 2021-09-01 13:36:44,559 - INFO -   |-- [Party 6] Average Train Loss:   0.2344 Train Accuracy: global  92.58% local  91.18% ...   69 forgettables out of 1428 ( 4.83%) ... total data used 1428
# 2021-09-01 13:36:44,561 - INFO -   |--    Epoch Losses (10): [0.3437, 0.3248, 0.2472, 0.2062, 0.175, 0.1918, 0.2228, 0.2203, 0.1925, 0.2203]
# 2021-09-01 13:36:54,540 - INFO -   |-- [Party 7] Average Train Loss:   0.2242 Train Accuracy: global  93.49% local  91.04% ...   62 forgettables out of 1428 ( 4.34%) ... total data used 1428
# 2021-09-01 13:36:54,541 - INFO -   |--    Epoch Losses (10): [0.2806, 0.2812, 0.2241, 0.2202, 0.1927, 0.1541, 0.1818, 0.2411, 0.2534, 0.2125]
# 2021-09-01 13:37:05,072 - INFO -   |-- [Party 8] Average Train Loss:   0.2421 Train Accuracy: global  92.72% local  89.92% ...   69 forgettables out of 1428 ( 4.83%) ... total data used 1428
# 2021-09-01 13:37:05,075 - INFO -   |--    Epoch Losses (10): [0.3272, 0.2818, 0.2357, 0.25, 0.2139, 0.1976, 0.1704, 0.2363, 0.2228, 0.2853]
# 2021-09-01 13:37:16,060 - INFO -   |-- [Party 9] Average Train Loss:   0.2159 Train Accuracy: global  92.86% local  88.03% ...   70 forgettables out of 1428 ( 4.90%) ... total data used 1428
# 2021-09-01 13:37:16,063 - INFO -   |--    Epoch Losses (10): [0.3269, 0.2836, 0.2281, 0.2035, 0.1785, 0.1685, 0.2101, 0.2101, 0.1795, 0.1705]
# 2021-09-01 13:37:22,468 - INFO -     |---- Number of Forgettables: 5992 (46.62%)
# 2021-09-01 13:37:22,470 - INFO -     |---- Train Accuracy: 41.59%
# 2021-09-01 13:37:22,471 - INFO -     |---- Test Accuracy: 30.85%
# 2021-09-01 13:37:22,472 - INFO -     |---- Test Loss: 1.8593
# 2021-09-01 13:37:22,472 - INFO -     |---- Elapsed time: 0:11:52.990134
# 2021-09-01 13:37:22,473 - INFO -
# Test Acc: Max 30.8500% (7 round) | Last 30.8500% | Avg 27.4048% (3 round)
#
# 2021-09-01 13:37:22,476 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 13:37:33,041 - INFO -   |-- [Party 1] Average Train Loss:   0.3301 Train Accuracy: global   0.00% local  91.18% ... 1154 forgettables out of 1428 (80.81%) ... total data used 1428
# 2021-09-01 13:37:33,045 - INFO -   |--    Epoch Losses (10): [0.8045, 0.4869, 0.3284, 0.284, 0.2409, 0.2031, 0.2261, 0.2804, 0.2346, 0.2122]
# 2021-09-01 13:37:44,507 - INFO -   |-- [Party 2] Average Train Loss:   0.2859 Train Accuracy: global   0.00% local  79.76% ... 1368 forgettables out of 1428 (95.80%) ... total data used 1428
# 2021-09-01 13:37:44,509 - INFO -   |--    Epoch Losses (10): [0.7757, 0.4616, 0.3086, 0.2375, 0.1758, 0.1697, 0.1528, 0.1669, 0.2131, 0.1978]
# 2021-09-01 13:37:54,587 - INFO -   |-- [Party 3] Average Train Loss:   0.4298 Train Accuracy: global   0.07% local  87.68% ... 1271 forgettables out of 1428 (89.01%) ... total data used 1428
# 2021-09-01 13:37:54,591 - INFO -   |--    Epoch Losses (10): [0.7131, 0.5486, 0.4372, 0.3733, 0.36, 0.3761, 0.3623, 0.3971, 0.3773, 0.3534]
# 2021-09-01 13:38:04,699 - INFO -   |-- [Party 4] Average Train Loss:   0.3622 Train Accuracy: global   0.14% local  74.44% ... 1307 forgettables out of 1428 (91.53%) ... total data used 1428
# 2021-09-01 13:38:04,702 - INFO -   |--    Epoch Losses (10): [0.6469, 0.4937, 0.3664, 0.3195, 0.2857, 0.2671, 0.3301, 0.3132, 0.2933, 0.3061]
# 2021-09-01 13:38:14,889 - INFO -   |-- [Party 5] Average Train Loss:   0.4039 Train Accuracy: global   0.28% local  90.41% ... 1293 forgettables out of 1428 (90.55%) ... total data used 1428
# 2021-09-01 13:38:14,891 - INFO -   |--    Epoch Losses (10): [0.6786, 0.5342, 0.4169, 0.3886, 0.3332, 0.3201, 0.3157, 0.3504, 0.3579, 0.3431]
# 2021-09-01 13:38:25,119 - INFO -   |-- [Party 6] Average Train Loss:   0.2299 Train Accuracy: global  93.70% local  95.03% ...   53 forgettables out of 1428 ( 3.71%) ... total data used 1428
# 2021-09-01 13:38:25,121 - INFO -   |--    Epoch Losses (10): [0.3518, 0.2906, 0.198, 0.1771, 0.1662, 0.1622, 0.2178, 0.2309, 0.2564, 0.2479]
# 2021-09-01 13:38:35,455 - INFO -   |-- [Party 7] Average Train Loss:   0.2250 Train Accuracy: global  94.96% local  94.47% ...   35 forgettables out of 1428 ( 2.45%) ... total data used 1428
# 2021-09-01 13:38:35,457 - INFO -   |--    Epoch Losses (10): [0.2943, 0.2511, 0.2517, 0.2697, 0.2458, 0.168, 0.1478, 0.1861, 0.2099, 0.2255]
# 2021-09-01 13:38:46,174 - INFO -   |-- [Party 8] Average Train Loss:   0.1902 Train Accuracy: global  93.14% local  68.35% ...   57 forgettables out of 1428 ( 3.99%) ... total data used 1428
# 2021-09-01 13:38:46,176 - INFO -   |--    Epoch Losses (10): [0.3005, 0.2108, 0.1646, 0.1656, 0.1902, 0.1877, 0.1895, 0.1983, 0.1472, 0.1475]
# 2021-09-01 13:38:56,950 - INFO -   |-- [Party 9] Average Train Loss:   0.1906 Train Accuracy: global  92.30% local  95.73% ...   64 forgettables out of 1428 ( 4.48%) ... total data used 1428
# 2021-09-01 13:38:56,954 - INFO -   |--    Epoch Losses (10): [0.2983, 0.233, 0.1679, 0.1634, 0.1812, 0.2018, 0.191, 0.1541, 0.1353, 0.1801]
# 2021-09-01 13:39:03,557 - INFO -     |---- Number of Forgettables: 6602 (51.37%)
# 2021-09-01 13:39:03,561 - INFO -     |---- Train Accuracy: 41.67%
# 2021-09-01 13:39:03,562 - INFO -     |---- Test Accuracy: 30.90%
# 2021-09-01 13:39:03,563 - INFO -     |---- Test Loss: 1.9077
# 2021-09-01 13:39:03,563 - INFO -     |---- Elapsed time: 0:13:34.081198
# 2021-09-01 13:39:03,565 - INFO -
# Test Acc: Max 30.9000% (8 round) | Last 30.9000% | Avg 27.8417% (3 round)
#
# 2021-09-01 13:39:03,568 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 13:39:13,773 - INFO -   |-- [Party 1] Average Train Loss:   0.2840 Train Accuracy: global   0.00% local  98.04% ... 1302 forgettables out of 1428 (91.18%) ... total data used 1428
# 2021-09-01 13:39:13,777 - INFO -   |--    Epoch Losses (10): [0.7773, 0.4841, 0.3163, 0.2333, 0.1838, 0.187, 0.1749, 0.1838, 0.1637, 0.1363]
# 2021-09-01 13:39:23,896 - INFO -   |-- [Party 2] Average Train Loss:   0.2765 Train Accuracy: global   0.00% local  97.41% ... 1139 forgettables out of 1428 (79.76%) ... total data used 1428
# 2021-09-01 13:39:23,898 - INFO -   |--    Epoch Losses (10): [0.7519, 0.4559, 0.3175, 0.2335, 0.2058, 0.1625, 0.1632, 0.1459, 0.1624, 0.166]
# 2021-09-01 13:39:34,493 - INFO -   |-- [Party 3] Average Train Loss:   0.4089 Train Accuracy: global   0.21% local  89.29% ... 1249 forgettables out of 1428 (87.46%) ... total data used 1428
# 2021-09-01 13:39:34,497 - INFO -   |--    Epoch Losses (10): [0.7019, 0.5415, 0.428, 0.4288, 0.3587, 0.315, 0.325, 0.3278, 0.3391, 0.3237]
# 2021-09-01 13:39:44,953 - INFO -   |-- [Party 4] Average Train Loss:   0.3650 Train Accuracy: global   0.28% local  90.27% ... 1060 forgettables out of 1428 (74.23%) ... total data used 1428
# 2021-09-01 13:39:44,954 - INFO -   |--    Epoch Losses (10): [0.6195, 0.5267, 0.4106, 0.3073, 0.253, 0.2601, 0.2824, 0.2889, 0.3929, 0.3084]
# 2021-09-01 13:39:55,059 - INFO -   |-- [Party 5] Average Train Loss:   0.3936 Train Accuracy: global   0.42% local  92.72% ... 1285 forgettables out of 1428 (89.99%) ... total data used 1428
# 2021-09-01 13:39:55,063 - INFO -   |--    Epoch Losses (10): [0.6918, 0.5346, 0.5025, 0.3579, 0.3169, 0.3518, 0.372, 0.3005, 0.2708, 0.2376]
# 2021-09-01 13:40:05,121 - INFO -   |-- [Party 6] Average Train Loss:   0.1920 Train Accuracy: global  93.84% local  81.16% ...   42 forgettables out of 1428 ( 2.94%) ... total data used 1428
# 2021-09-01 13:40:05,122 - INFO -   |--    Epoch Losses (10): [0.2905, 0.2288, 0.1797, 0.1682, 0.1666, 0.1667, 0.1709, 0.1621, 0.2128, 0.1738]
# 2021-09-01 13:40:15,551 - INFO -   |-- [Party 7] Average Train Loss:   0.1901 Train Accuracy: global  94.05% local  91.46% ...   63 forgettables out of 1428 ( 4.41%) ... total data used 1428
# 2021-09-01 13:40:15,552 - INFO -   |--    Epoch Losses (10): [0.2898, 0.2288, 0.1789, 0.1926, 0.1806, 0.1715, 0.161, 0.1378, 0.1712, 0.1892]
# 2021-09-01 13:40:25,638 - INFO -   |-- [Party 8] Average Train Loss:   0.2061 Train Accuracy: global  92.72% local  88.87% ...   32 forgettables out of 1428 ( 2.24%) ... total data used 1428
# 2021-09-01 13:40:25,639 - INFO -   |--    Epoch Losses (10): [0.3, 0.2571, 0.1944, 0.2061, 0.1754, 0.2099, 0.19, 0.1814, 0.1741, 0.1725]
# 2021-09-01 13:40:35,866 - INFO -   |-- [Party 9] Average Train Loss:   0.1844 Train Accuracy: global  92.51% local  96.92% ...   88 forgettables out of 1428 ( 6.16%) ... total data used 1428
# 2021-09-01 13:40:35,868 - INFO -   |--    Epoch Losses (10): [0.2911, 0.235, 0.1782, 0.1898, 0.1855, 0.1371, 0.1729, 0.1279, 0.1715, 0.155]
# 2021-09-01 13:40:42,428 - INFO -     |---- Number of Forgettables: 6260 (48.71%)
# 2021-09-01 13:40:42,432 - INFO -     |---- Train Accuracy: 42.00%
# 2021-09-01 13:40:42,433 - INFO -     |---- Test Accuracy: 31.00%
# 2021-09-01 13:40:42,434 - INFO -     |---- Test Loss: 1.9005
# 2021-09-01 13:40:42,435 - INFO -     |---- Elapsed time: 0:15:12.952688
# 2021-09-01 13:40:42,436 - INFO -
# Test Acc: Max 31.0000% (9 round) | Last 31.0000% | Avg 28.1926% (3 round)
#
# 2021-09-01 13:40:42,439 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 13:40:54,141 - INFO -   |-- [Party 1] Average Train Loss:   0.2652 Train Accuracy: global   0.00% local  95.10% ... 1400 forgettables out of 1428 (98.04%) ... total data used 1428
# 2021-09-01 13:40:54,142 - INFO -   |--    Epoch Losses (10): [0.7541, 0.4007, 0.3041, 0.2144, 0.1671, 0.1571, 0.1538, 0.1459, 0.159, 0.1958]
# 2021-09-01 13:41:05,306 - INFO -   |-- [Party 2] Average Train Loss:   0.2760 Train Accuracy: global   0.00% local  90.13% ... 1391 forgettables out of 1428 (97.41%) ... total data used 1428
# 2021-09-01 13:41:05,309 - INFO -   |--    Epoch Losses (10): [0.7961, 0.4361, 0.3159, 0.2288, 0.1844, 0.1746, 0.1763, 0.1517, 0.1513, 0.1447]
# 2021-09-01 13:41:15,647 - INFO -   |-- [Party 3] Average Train Loss:   0.3763 Train Accuracy: global   0.07% local  90.34% ... 1274 forgettables out of 1428 (89.22%) ... total data used 1428
# 2021-09-01 13:41:15,649 - INFO -   |--    Epoch Losses (10): [0.6632, 0.523, 0.389, 0.3448, 0.3088, 0.3358, 0.2926, 0.3038, 0.3014, 0.3009]
# 2021-09-01 13:41:25,947 - INFO -   |-- [Party 4] Average Train Loss:   0.3277 Train Accuracy: global   0.21% local  92.72% ... 1286 forgettables out of 1428 (90.06%) ... total data used 1428
# 2021-09-01 13:41:25,949 - INFO -   |--    Epoch Losses (10): [0.605, 0.4295, 0.3475, 0.3182, 0.2773, 0.2566, 0.2499, 0.2781, 0.2514, 0.2635]
# 2021-09-01 13:41:36,924 - INFO -   |-- [Party 5] Average Train Loss:   0.3679 Train Accuracy: global   0.42% local  91.74% ... 1318 forgettables out of 1428 (92.30%) ... total data used 1428
# 2021-09-01 13:41:36,926 - INFO -   |--    Epoch Losses (10): [0.6139, 0.4427, 0.3845, 0.3327, 0.3889, 0.3347, 0.3126, 0.2692, 0.287, 0.3133]
# 2021-09-01 13:41:46,883 - INFO -   |-- [Party 6] Average Train Loss:   0.2063 Train Accuracy: global  94.05% local  92.58% ...   55 forgettables out of 1428 ( 3.85%) ... total data used 1428
# 2021-09-01 13:41:46,884 - INFO -   |--    Epoch Losses (10): [0.2947, 0.298, 0.2385, 0.1571, 0.1796, 0.1462, 0.1469, 0.1688, 0.1921, 0.2409]
# 2021-09-01 13:41:57,920 - INFO -   |-- [Party 7] Average Train Loss:   0.1806 Train Accuracy: global  95.03% local  97.41% ...   38 forgettables out of 1428 ( 2.66%) ... total data used 1428
# 2021-09-01 13:41:57,925 - INFO -   |--    Epoch Losses (10): [0.2699, 0.2179, 0.1716, 0.1794, 0.1939, 0.1622, 0.1499, 0.1503, 0.1371, 0.1737]
# 2021-09-01 13:42:09,157 - INFO -   |-- [Party 8] Average Train Loss:   0.2016 Train Accuracy: global  93.91% local  97.48% ...   52 forgettables out of 1428 ( 3.64%) ... total data used 1428
# 2021-09-01 13:42:09,161 - INFO -   |--    Epoch Losses (10): [0.3062, 0.2522, 0.218, 0.1761, 0.1806, 0.2184, 0.1899, 0.1703, 0.1566, 0.1473]
# 2021-09-01 13:42:20,408 - INFO -   |-- [Party 9] Average Train Loss:   0.1850 Train Accuracy: global  94.19% local  95.66% ...   61 forgettables out of 1428 ( 4.27%) ... total data used 1428
# 2021-09-01 13:42:20,412 - INFO -   |--    Epoch Losses (10): [0.2839, 0.228, 0.1584, 0.1749, 0.2066, 0.1656, 0.1558, 0.1616, 0.1445, 0.1708]
# 2021-09-01 13:42:26,932 - INFO -     |---- Number of Forgettables: 6875 (53.49%)
# 2021-09-01 13:42:26,934 - INFO -     |---- Train Accuracy: 42.14%
# 2021-09-01 13:42:26,935 - INFO -     |---- Test Accuracy: 31.07%
# 2021-09-01 13:42:26,936 - INFO -     |---- Test Loss: 1.9129
# 2021-09-01 13:42:26,936 - INFO -     |---- Elapsed time: 0:16:57.454164
# 2021-09-01 13:42:26,938 - INFO -
# Test Acc: Max 31.0667% (10 round) | Last 31.0667% | Avg 28.4800% (3 round)
#
# 2021-09-01 13:42:26,940 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 13:42:37,289 - INFO -   |-- [Party 1] Average Train Loss:   0.2728 Train Accuracy: global   0.00% local  96.36% ... 1358 forgettables out of 1428 (95.10%) ... total data used 1428
# 2021-09-01 13:42:37,290 - INFO -   |--    Epoch Losses (10): [0.757, 0.4051, 0.3308, 0.2594, 0.1994, 0.1604, 0.1636, 0.1662, 0.1508, 0.1347]
# 2021-09-01 13:42:47,431 - INFO -   |-- [Party 2] Average Train Loss:   0.2784 Train Accuracy: global   0.00% local  97.69% ... 1287 forgettables out of 1428 (90.13%) ... total data used 1428
# 2021-09-01 13:42:47,434 - INFO -   |--    Epoch Losses (10): [0.7873, 0.4094, 0.2787, 0.244, 0.186, 0.1478, 0.1587, 0.1712, 0.2125, 0.188]
# 2021-09-01 13:42:57,812 - INFO -   |-- [Party 3] Average Train Loss:   0.3786 Train Accuracy: global   0.21% local  90.83% ... 1287 forgettables out of 1428 (90.13%) ... total data used 1428
# 2021-09-01 13:42:57,813 - INFO -   |--    Epoch Losses (10): [0.6531, 0.4773, 0.4031, 0.3604, 0.3671, 0.3474, 0.3084, 0.2895, 0.3001, 0.2799]
# 2021-09-01 13:43:08,011 - INFO -   |-- [Party 4] Average Train Loss:   0.3406 Train Accuracy: global   0.56% local  88.10% ... 1316 forgettables out of 1428 (92.16%) ... total data used 1428
# 2021-09-01 13:43:08,015 - INFO -   |--    Epoch Losses (10): [0.6047, 0.4514, 0.3546, 0.296, 0.246, 0.2524, 0.3167, 0.3391, 0.2671, 0.278]
# 2021-09-01 13:43:18,615 - INFO -   |-- [Party 5] Average Train Loss:   0.3454 Train Accuracy: global   0.63% local  89.78% ... 1301 forgettables out of 1428 (91.11%) ... total data used 1428
# 2021-09-01 13:43:18,619 - INFO -   |--    Epoch Losses (10): [0.624, 0.4318, 0.3386, 0.3352, 0.2873, 0.3099, 0.2929, 0.2673, 0.2421, 0.3252]
# 2021-09-01 13:43:28,813 - INFO -   |-- [Party 6] Average Train Loss:   0.1773 Train Accuracy: global  94.19% local  97.41% ...   47 forgettables out of 1428 ( 3.29%) ... total data used 1428
# 2021-09-01 13:43:28,817 - INFO -   |--    Epoch Losses (10): [0.2833, 0.2524, 0.1856, 0.1914, 0.1965, 0.1634, 0.1466, 0.1202, 0.1261, 0.1078]
# 2021-09-01 13:43:39,140 - INFO -   |-- [Party 7] Average Train Loss:   0.1697 Train Accuracy: global  95.38% local  97.06% ...   52 forgettables out of 1428 ( 3.64%) ... total data used 1428
# 2021-09-01 13:43:39,144 - INFO -   |--    Epoch Losses (10): [0.2578, 0.2275, 0.1813, 0.1516, 0.1279, 0.1598, 0.1829, 0.1549, 0.12, 0.1333]
# 2021-09-01 13:43:50,259 - INFO -   |-- [Party 8] Average Train Loss:   0.1834 Train Accuracy: global  93.70% local  95.52% ...   71 forgettables out of 1428 ( 4.97%) ... total data used 1428
# 2021-09-01 13:43:50,263 - INFO -   |--    Epoch Losses (10): [0.2875, 0.2437, 0.1862, 0.1477, 0.141, 0.1395, 0.1783, 0.1767, 0.1453, 0.1878]
# 2021-09-01 13:44:02,040 - INFO -   |-- [Party 9] Average Train Loss:   0.1819 Train Accuracy: global  94.19% local  97.76% ...   55 forgettables out of 1428 ( 3.85%) ... total data used 1428
# 2021-09-01 13:44:02,044 - INFO -   |--    Epoch Losses (10): [0.263, 0.2105, 0.1689, 0.1297, 0.1394, 0.1497, 0.1856, 0.22, 0.1865, 0.1659]
# 2021-09-01 13:44:08,653 - INFO -     |---- Number of Forgettables: 6774 (52.71%)
# 2021-09-01 13:44:08,655 - INFO -     |---- Train Accuracy: 42.48%
# 2021-09-01 13:44:08,656 - INFO -     |---- Test Accuracy: 31.20%
# 2021-09-01 13:44:08,656 - INFO -     |---- Test Loss: 1.9035
# 2021-09-01 13:44:08,656 - INFO -     |---- Elapsed time: 0:18:39.174180
# 2021-09-01 13:44:08,657 - INFO -
# Test Acc: Max 31.2000% (11 round) | Last 31.2000% | Avg 28.7273% (3 round)
#
# 2021-09-01 13:44:08,660 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 13:44:19,904 - INFO -   |-- [Party 1] Average Train Loss:   0.2578 Train Accuracy: global   0.00% local  96.15% ... 1376 forgettables out of 1428 (96.36%) ... total data used 1428
# 2021-09-01 13:44:19,907 - INFO -   |--    Epoch Losses (10): [0.7534, 0.4175, 0.3184, 0.2204, 0.1627, 0.1249, 0.1448, 0.13, 0.1472, 0.1583]
# 2021-09-01 13:44:29,986 - INFO -   |-- [Party 2] Average Train Loss:   0.2635 Train Accuracy: global   0.00% local  97.13% ... 1395 forgettables out of 1428 (97.69%) ... total data used 1428
# 2021-09-01 13:44:29,988 - INFO -   |--    Epoch Losses (10): [0.7445, 0.428, 0.2983, 0.2158, 0.1749, 0.1405, 0.1517, 0.1868, 0.1685, 0.1257]
# 2021-09-01 13:44:41,265 - INFO -   |-- [Party 3] Average Train Loss:   0.3834 Train Accuracy: global   0.14% local  92.09% ... 1295 forgettables out of 1428 (90.69%) ... total data used 1428
# 2021-09-01 13:44:41,266 - INFO -   |--    Epoch Losses (10): [0.6817, 0.4937, 0.3997, 0.3357, 0.3274, 0.3304, 0.3353, 0.3128, 0.3095, 0.3082]
# 2021-09-01 13:44:51,676 - INFO -   |-- [Party 4] Average Train Loss:   0.3084 Train Accuracy: global   0.49% local  95.10% ... 1251 forgettables out of 1428 (87.61%) ... total data used 1428
# 2021-09-01 13:44:51,678 - INFO -   |--    Epoch Losses (10): [0.6071, 0.4197, 0.3307, 0.2825, 0.2686, 0.2757, 0.2407, 0.2453, 0.2037, 0.2103]
# 2021-09-01 13:45:01,883 - INFO -   |-- [Party 5] Average Train Loss:   0.3443 Train Accuracy: global   0.49% local  58.19% ... 1275 forgettables out of 1428 (89.29%) ... total data used 1428
# 2021-09-01 13:45:01,886 - INFO -   |--    Epoch Losses (10): [0.6206, 0.4409, 0.361, 0.3461, 0.3179, 0.2692, 0.2842, 0.2707, 0.2819, 0.2506]
# 2021-09-01 13:45:13,301 - INFO -   |-- [Party 6] Average Train Loss:   0.1956 Train Accuracy: global  94.82% local  97.13% ...   56 forgettables out of 1428 ( 3.92%) ... total data used 1428
# 2021-09-01 13:45:13,305 - INFO -   |--    Epoch Losses (10): [0.2524, 0.2401, 0.2085, 0.1923, 0.1564, 0.1418, 0.1619, 0.2117, 0.2071, 0.1842]
# 2021-09-01 13:45:24,242 - INFO -   |-- [Party 7] Average Train Loss:   0.1533 Train Accuracy: global  95.73% local  96.50% ...   42 forgettables out of 1428 ( 2.94%) ... total data used 1428
# 2021-09-01 13:45:24,244 - INFO -   |--    Epoch Losses (10): [0.2523, 0.2089, 0.1693, 0.1369, 0.1124, 0.1307, 0.1461, 0.136, 0.1116, 0.1283]
# 2021-09-01 13:45:34,592 - INFO -   |-- [Party 8] Average Train Loss:   0.1742 Train Accuracy: global  94.40% local  95.87% ...   64 forgettables out of 1428 ( 4.48%) ... total data used 1428
# 2021-09-01 13:45:34,594 - INFO -   |--    Epoch Losses (10): [0.3186, 0.2671, 0.1841, 0.1466, 0.1488, 0.1345, 0.1075, 0.1297, 0.1183, 0.187]
# 2021-09-01 13:45:46,163 - INFO -   |-- [Party 9] Average Train Loss:   0.1909 Train Accuracy: global  94.40% local  67.51% ...   67 forgettables out of 1428 ( 4.69%) ... total data used 1428
# 2021-09-01 13:45:46,167 - INFO -   |--    Epoch Losses (10): [0.2775, 0.2062, 0.181, 0.1859, 0.1596, 0.1257, 0.1497, 0.1864, 0.2261, 0.2106]
# 2021-09-01 13:45:52,712 - INFO -     |---- Number of Forgettables: 6821 (53.07%)
# 2021-09-01 13:45:52,715 - INFO -     |---- Train Accuracy: 41.65%
# 2021-09-01 13:45:52,716 - INFO -     |---- Test Accuracy: 30.87%
# 2021-09-01 13:45:52,717 - INFO -     |---- Test Loss: 2.0063
# 2021-09-01 13:45:52,718 - INFO -     |---- Elapsed time: 0:20:23.235686
# 2021-09-01 13:45:52,719 - INFO -
# Test Acc: Max 30.8667% (11 round) | Last 30.8667% | Avg 28.9056% (3 round)
#
# 2021-09-01 13:45:52,722 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 13:46:04,137 - INFO -   |-- [Party 1] Average Train Loss:   0.2481 Train Accuracy: global   0.00% local  97.41% ... 1373 forgettables out of 1428 (96.15%) ... total data used 1428
# 2021-09-01 13:46:04,141 - INFO -   |--    Epoch Losses (10): [0.7552, 0.4103, 0.2792, 0.1887, 0.1437, 0.1244, 0.1382, 0.1421, 0.1242, 0.1754]
# 2021-09-01 13:46:14,874 - INFO -   |-- [Party 2] Average Train Loss:   0.2610 Train Accuracy: global   0.00% local  95.45% ... 1387 forgettables out of 1428 (97.13%) ... total data used 1428
# 2021-09-01 13:46:14,878 - INFO -   |--    Epoch Losses (10): [0.7031, 0.3994, 0.2907, 0.213, 0.2001, 0.1845, 0.1667, 0.1551, 0.1424, 0.1546]
# 2021-09-01 13:46:25,801 - INFO -   |-- [Party 3] Average Train Loss:   0.3792 Train Accuracy: global   0.28% local  93.35% ... 1311 forgettables out of 1428 (91.81%) ... total data used 1428
# 2021-09-01 13:46:25,805 - INFO -   |--    Epoch Losses (10): [0.6454, 0.4677, 0.3651, 0.3214, 0.3594, 0.3575, 0.334, 0.3204, 0.3324, 0.2882]
# 2021-09-01 13:46:36,108 - INFO -   |-- [Party 4] Average Train Loss:   0.3021 Train Accuracy: global   0.42% local  91.95% ... 1352 forgettables out of 1428 (94.68%) ... total data used 1428
# 2021-09-01 13:46:36,109 - INFO -   |--    Epoch Losses (10): [0.5741, 0.3964, 0.3403, 0.2621, 0.2167, 0.2077, 0.2402, 0.2664, 0.2807, 0.2362]
# 2021-09-01 13:46:46,970 - INFO -   |-- [Party 5] Average Train Loss:   0.3264 Train Accuracy: global   0.42% local  91.18% ...  826 forgettables out of 1428 (57.84%) ... total data used 1428
# 2021-09-01 13:46:46,973 - INFO -   |--    Epoch Losses (10): [0.6247, 0.4783, 0.3477, 0.2858, 0.2284, 0.2511, 0.2724, 0.2276, 0.267, 0.2813]
# 2021-09-01 13:46:57,051 - INFO -   |-- [Party 6] Average Train Loss:   0.1799 Train Accuracy: global  93.00% local  89.01% ...   85 forgettables out of 1428 ( 5.95%) ... total data used 1428
# 2021-09-01 13:46:57,053 - INFO -   |--    Epoch Losses (10): [0.2745, 0.2254, 0.1634, 0.1607, 0.1458, 0.1552, 0.1485, 0.1719, 0.1686, 0.1852]
# 2021-09-01 13:47:07,108 - INFO -   |-- [Party 7] Average Train Loss:   0.1578 Train Accuracy: global  93.35% local  95.52% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 13:47:07,111 - INFO -   |--    Epoch Losses (10): [0.2524, 0.2192, 0.2052, 0.133, 0.1341, 0.1288, 0.1192, 0.1347, 0.1259, 0.1252]
# 2021-09-01 13:47:17,078 - INFO -   |-- [Party 8] Average Train Loss:   0.1699 Train Accuracy: global  92.23% local  64.64% ...   94 forgettables out of 1428 ( 6.58%) ... total data used 1428
# 2021-09-01 13:47:17,080 - INFO -   |--    Epoch Losses (10): [0.2915, 0.2576, 0.1734, 0.1467, 0.1165, 0.105, 0.1189, 0.1497, 0.1511, 0.1887]
# 2021-09-01 13:47:27,937 - INFO -   |-- [Party 9] Average Train Loss:   0.1454 Train Accuracy: global  92.30% local  97.69% ...   22 forgettables out of 1428 ( 1.54%) ... total data used 1428
# 2021-09-01 13:47:27,938 - INFO -   |--    Epoch Losses (10): [0.2424, 0.2202, 0.1697, 0.152, 0.1154, 0.1215, 0.1151, 0.12, 0.1027, 0.0948]
# 2021-09-01 13:47:34,636 - INFO -     |---- Number of Forgettables: 6525 (50.77%)
# 2021-09-01 13:47:34,640 - INFO -     |---- Train Accuracy: 42.02%
# 2021-09-01 13:47:34,641 - INFO -     |---- Test Accuracy: 31.33%
# 2021-09-01 13:47:34,642 - INFO -     |---- Test Loss: 1.9452
# 2021-09-01 13:47:34,642 - INFO -     |---- Elapsed time: 0:22:05.160126
# 2021-09-01 13:47:34,643 - INFO -
# Test Acc: Max 31.3333% (13 round) | Last 31.3333% | Avg 29.0923% (3 round)
#
# 2021-09-01 13:47:34,646 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 13:47:45,910 - INFO -   |-- [Party 1] Average Train Loss:   0.2558 Train Accuracy: global   0.00% local  98.11% ... 1391 forgettables out of 1428 (97.41%) ... total data used 1428
# 2021-09-01 13:47:45,914 - INFO -   |--    Epoch Losses (10): [0.752, 0.3861, 0.2739, 0.2022, 0.1556, 0.1577, 0.1862, 0.1496, 0.1435, 0.1509]
# 2021-09-01 13:47:55,985 - INFO -   |-- [Party 2] Average Train Loss:   0.2374 Train Accuracy: global   0.00% local  98.46% ... 1363 forgettables out of 1428 (95.45%) ... total data used 1428
# 2021-09-01 13:47:55,986 - INFO -   |--    Epoch Losses (10): [0.7412, 0.3849, 0.2822, 0.2109, 0.1826, 0.1682, 0.1223, 0.0903, 0.0887, 0.1027]
# 2021-09-01 13:48:07,117 - INFO -   |-- [Party 3] Average Train Loss:   0.3517 Train Accuracy: global   0.28% local  75.14% ... 1329 forgettables out of 1428 (93.07%) ... total data used 1428
# 2021-09-01 13:48:07,121 - INFO -   |--    Epoch Losses (10): [0.6306, 0.4674, 0.3646, 0.3079, 0.2816, 0.2797, 0.2823, 0.3055, 0.3119, 0.2857]
# 2021-09-01 13:48:17,555 - INFO -   |-- [Party 4] Average Train Loss:   0.2802 Train Accuracy: global   0.42% local  96.01% ... 1307 forgettables out of 1428 (91.53%) ... total data used 1428
# 2021-09-01 13:48:17,558 - INFO -   |--    Epoch Losses (10): [0.5441, 0.3967, 0.2888, 0.2675, 0.2439, 0.2378, 0.2359, 0.2067, 0.1914, 0.1892]
# 2021-09-01 13:48:28,573 - INFO -   |-- [Party 5] Average Train Loss:   0.2976 Train Accuracy: global   0.21% local  83.12% ... 1299 forgettables out of 1428 (90.97%) ... total data used 1428
# 2021-09-01 13:48:28,577 - INFO -   |--    Epoch Losses (10): [0.5761, 0.4104, 0.3246, 0.2629, 0.2712, 0.2367, 0.2237, 0.2382, 0.218, 0.214]
# 2021-09-01 13:48:39,040 - INFO -   |-- [Party 6] Average Train Loss:   0.1620 Train Accuracy: global  94.40% local  96.36% ...   31 forgettables out of 1428 ( 2.17%) ... total data used 1428
# 2021-09-01 13:48:39,042 - INFO -   |--    Epoch Losses (10): [0.2678, 0.2491, 0.2044, 0.1463, 0.1178, 0.1131, 0.1169, 0.1119, 0.1164, 0.1764]
# ...
# 2021-09-01 19:05:14,219 - INFO -   |--    Epoch Losses (10): [0.1008, 0.101, 0.086, 0.0561, 0.0382, 0.0298, 0.0239, 0.0197, 0.0318, 0.0411]
# 2021-09-01 19:05:24,078 - INFO -   |-- [Party 6] Average Train Loss:   0.0690 Train Accuracy: global  94.26% local  99.79% ...   78 forgettables out of 1428 ( 5.46%) ... total data used 1428
# 2021-09-01 19:05:24,079 - INFO -   |--    Epoch Losses (10): [0.0842, 0.0705, 0.0538, 0.0492, 0.0502, 0.0557, 0.1048, 0.1007, 0.0658, 0.0551]
# 2021-09-01 19:05:33,880 - INFO -   |-- [Party 7] Average Train Loss:   0.0408 Train Accuracy: global  93.42% local  99.93% ...   92 forgettables out of 1428 ( 6.44%) ... total data used 1428
# 2021-09-01 19:05:33,883 - INFO -   |--    Epoch Losses (10): [0.0871, 0.0627, 0.0354, 0.025, 0.0322, 0.0339, 0.0334, 0.0338, 0.0341, 0.0305]
# 2021-09-01 19:05:43,731 - INFO -   |-- [Party 8] Average Train Loss:   0.0760 Train Accuracy: global  93.84% local 100.00% ...   88 forgettables out of 1428 ( 6.16%) ... total data used 1428
# 2021-09-01 19:05:43,733 - INFO -   |--    Epoch Losses (10): [0.0703, 0.049, 0.0441, 0.0818, 0.1058, 0.1238, 0.1156, 0.0784, 0.0525, 0.0383]
# 2021-09-01 19:05:54,732 - INFO -   |-- [Party 9] Average Train Loss:   0.0587 Train Accuracy: global  94.19% local  99.93% ...   82 forgettables out of 1428 ( 5.74%) ... total data used 1428
# 2021-09-01 19:05:54,736 - INFO -   |--    Epoch Losses (10): [0.0702, 0.0566, 0.044, 0.0369, 0.0486, 0.095, 0.0938, 0.063, 0.0446, 0.0342]
# 2021-09-01 19:06:01,082 - INFO -     |---- Number of Forgettables: 6165 (47.97%)
# 2021-09-01 19:06:01,083 - INFO -     |---- Train Accuracy: 51.62%
# 2021-09-01 19:06:01,084 - INFO -     |---- Test Accuracy: 41.30%
# 2021-09-01 19:06:01,085 - INFO -     |---- Test Loss: 1.6066
# 2021-09-01 19:06:01,086 - INFO -     |---- Elapsed time: 5:40:31.604233
# 2021-09-01 19:06:01,088 - INFO -
# Test Acc: Max 41.3000% (178 round) | Last 41.3000% | Avg 39.4469% (44 round)
#
# 2021-09-01 19:06:01,091 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 19:06:10,990 - INFO -   |-- [Party 1] Average Train Loss:   0.0813 Train Accuracy: global  19.12% local  99.23% ... 1155 forgettables out of 1428 (80.88%) ... total data used 1428
# 2021-09-01 19:06:10,992 - INFO -   |--    Epoch Losses (10): [0.293, 0.1899, 0.1123, 0.0728, 0.0471, 0.0322, 0.0229, 0.0162, 0.0126, 0.0143]
# 2021-09-01 19:06:20,673 - INFO -   |-- [Party 2] Average Train Loss:   0.1042 Train Accuracy: global  19.47% local 100.00% ... 1150 forgettables out of 1428 (80.53%) ... total data used 1428
# 2021-09-01 19:06:20,676 - INFO -   |--    Epoch Losses (10): [0.3209, 0.2027, 0.1253, 0.0873, 0.0847, 0.0751, 0.0527, 0.0392, 0.0297, 0.024]
# 2021-09-01 19:06:30,473 - INFO -   |-- [Party 3] Average Train Loss:   0.1291 Train Accuracy: global  15.83% local  99.09% ... 1192 forgettables out of 1428 (83.47%) ... total data used 1428
# 2021-09-01 19:06:30,475 - INFO -   |--    Epoch Losses (10): [0.1225, 0.1207, 0.0869, 0.0678, 0.1317, 0.2029, 0.1697, 0.1309, 0.1462, 0.1116]
# 2021-09-01 19:06:40,251 - INFO -   |-- [Party 4] Average Train Loss:   0.0649 Train Accuracy: global  14.29% local 100.00% ... 1207 forgettables out of 1428 (84.52%) ... total data used 1428
# 2021-09-01 19:06:40,253 - INFO -   |--    Epoch Losses (10): [0.0988, 0.0838, 0.0543, 0.0534, 0.057, 0.0597, 0.0671, 0.0723, 0.0576, 0.0449]
# 2021-09-01 19:06:50,105 - INFO -   |-- [Party 5] Average Train Loss:   0.0600 Train Accuracy: global  14.64% local  98.74% ... 1202 forgettables out of 1428 (84.17%) ... total data used 1428
# 2021-09-01 19:06:50,107 - INFO -   |--    Epoch Losses (10): [0.0926, 0.0802, 0.0592, 0.0574, 0.0538, 0.0659, 0.0607, 0.0503, 0.0393, 0.0404]
# 2021-09-01 19:06:59,937 - INFO -   |-- [Party 6] Average Train Loss:   0.0329 Train Accuracy: global  94.89% local 100.00% ...   72 forgettables out of 1428 ( 5.04%) ... total data used 1428
# 2021-09-01 19:06:59,939 - INFO -   |--    Epoch Losses (10): [0.089, 0.0727, 0.0508, 0.0374, 0.0246, 0.0161, 0.0133, 0.0101, 0.0077, 0.0068]
# 2021-09-01 19:07:09,634 - INFO -   |-- [Party 7] Average Train Loss:   0.0656 Train Accuracy: global  94.89% local 100.00% ...   73 forgettables out of 1428 ( 5.11%) ... total data used 1428
# 2021-09-01 19:07:09,638 - INFO -   |--    Epoch Losses (10): [0.0733, 0.0615, 0.0522, 0.0443, 0.0645, 0.0841, 0.0903, 0.081, 0.0588, 0.0466]
# 2021-09-01 19:07:19,468 - INFO -   |-- [Party 8] Average Train Loss:   0.0725 Train Accuracy: global  95.24% local  99.93% ...   68 forgettables out of 1428 ( 4.76%) ... total data used 1428
# 2021-09-01 19:07:19,469 - INFO -   |--    Epoch Losses (10): [0.0855, 0.0863, 0.0749, 0.0537, 0.0606, 0.1107, 0.1023, 0.0692, 0.0465, 0.0357]
# 2021-09-01 19:07:29,302 - INFO -   |-- [Party 9] Average Train Loss:   0.0600 Train Accuracy: global  96.01% local 100.00% ...   57 forgettables out of 1428 ( 3.99%) ... total data used 1428
# 2021-09-01 19:07:29,304 - INFO -   |--    Epoch Losses (10): [0.1143, 0.1166, 0.1201, 0.0712, 0.049, 0.0353, 0.0281, 0.025, 0.0218, 0.0183]
# 2021-09-01 19:07:35,616 - INFO -     |---- Number of Forgettables: 6176 (48.05%)
# 2021-09-01 19:07:35,617 - INFO -     |---- Train Accuracy: 53.36%
# 2021-09-01 19:07:35,618 - INFO -     |---- Test Accuracy: 42.80%
# 2021-09-01 19:07:35,619 - INFO -     |---- Test Loss: 1.5376
# 2021-09-01 19:07:35,620 - INFO -     |---- Elapsed time: 5:42:06.137743
# 2021-09-01 19:07:35,621 - INFO -
# Test Acc: Max 42.8000% (178 round) | Last 42.8000% | Avg 39.4640% (44 round)
#
# 2021-09-01 19:07:35,624 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 19:07:45,413 - INFO -   |-- [Party 1] Average Train Loss:   0.0886 Train Accuracy: global  21.36% local 100.00% ... 1113 forgettables out of 1428 (77.94%) ... total data used 1428
# 2021-09-01 19:07:45,415 - INFO -   |--    Epoch Losses (10): [0.3124, 0.2063, 0.1319, 0.0821, 0.052, 0.0347, 0.0236, 0.0177, 0.0134, 0.0114]
# 2021-09-01 19:07:55,437 - INFO -   |-- [Party 2] Average Train Loss:   0.0908 Train Accuracy: global  21.22% local 100.00% ... 1125 forgettables out of 1428 (78.78%) ... total data used 1428
# 2021-09-01 19:07:55,440 - INFO -   |--    Epoch Losses (10): [0.3156, 0.2059, 0.1245, 0.0718, 0.0461, 0.0336, 0.0276, 0.03, 0.0254, 0.0279]
# 2021-09-01 19:08:06,545 - INFO -   |-- [Party 3] Average Train Loss:   0.0761 Train Accuracy: global  32.14% local  99.86% ...  957 forgettables out of 1428 (67.02%) ... total data used 1428
# 2021-09-01 19:08:06,547 - INFO -   |--    Epoch Losses (10): [0.0917, 0.1119, 0.0801, 0.0616, 0.0584, 0.0537, 0.0579, 0.0846, 0.0893, 0.0719]
# 2021-09-01 19:08:17,368 - INFO -   |-- [Party 4] Average Train Loss:   0.0841 Train Accuracy: global  31.16% local  98.88% ...  983 forgettables out of 1428 (68.84%) ... total data used 1428
# 2021-09-01 19:08:17,369 - INFO -   |--    Epoch Losses (10): [0.1032, 0.0903, 0.0664, 0.0526, 0.083, 0.1019, 0.0927, 0.077, 0.0924, 0.082]
# 2021-09-01 19:08:28,309 - INFO -   |-- [Party 5] Average Train Loss:   0.0680 Train Accuracy: global  31.72% local  99.79% ...  960 forgettables out of 1428 (67.23%) ... total data used 1428
# 2021-09-01 19:08:28,311 - INFO -   |--    Epoch Losses (10): [0.1113, 0.1176, 0.0955, 0.0796, 0.0666, 0.0512, 0.0413, 0.0325, 0.0334, 0.0515]
# 2021-09-01 19:08:38,017 - INFO -   |-- [Party 6] Average Train Loss:   0.0844 Train Accuracy: global  86.76% local  99.86% ...  189 forgettables out of 1428 (13.24%) ... total data used 1428
# 2021-09-01 19:08:38,018 - INFO -   |--    Epoch Losses (10): [0.0759, 0.0953, 0.1037, 0.115, 0.0958, 0.094, 0.0723, 0.0776, 0.0638, 0.0506]
# 2021-09-01 19:08:47,809 - INFO -   |-- [Party 7] Average Train Loss:   0.0858 Train Accuracy: global  85.78% local  99.86% ...  203 forgettables out of 1428 (14.22%) ... total data used 1428
# 2021-09-01 19:08:47,812 - INFO -   |--    Epoch Losses (10): [0.0881, 0.0715, 0.0472, 0.0344, 0.0582, 0.0823, 0.1428, 0.1394, 0.1072, 0.0865]
# 2021-09-01 19:08:57,445 - INFO -   |-- [Party 8] Average Train Loss:   0.0495 Train Accuracy: global  84.80% local  99.72% ...  216 forgettables out of 1428 (15.13%) ... total data used 1428
# 2021-09-01 19:08:57,447 - INFO -   |--    Epoch Losses (10): [0.0855, 0.0692, 0.073, 0.0581, 0.0448, 0.0319, 0.0243, 0.0232, 0.0385, 0.0468]
# 2021-09-01 19:09:07,396 - INFO -   |-- [Party 9] Average Train Loss:   0.0481 Train Accuracy: global  83.89% local 100.00% ...  230 forgettables out of 1428 (16.11%) ... total data used 1428
# 2021-09-01 19:09:07,398 - INFO -   |--    Epoch Losses (10): [0.0903, 0.0844, 0.0776, 0.0646, 0.0534, 0.0354, 0.0261, 0.0199, 0.0165, 0.0126]
# 2021-09-01 19:09:13,714 - INFO -     |---- Number of Forgettables: 5976 (46.50%)
# 2021-09-01 19:09:13,715 - INFO -     |---- Train Accuracy: 53.44%
# 2021-09-01 19:09:13,716 - INFO -     |---- Test Accuracy: 42.87%
# 2021-09-01 19:09:13,717 - INFO -     |---- Test Loss: 1.5582
# 2021-09-01 19:09:13,718 - INFO -     |---- Elapsed time: 5:43:44.235548
# 2021-09-01 19:09:13,719 - INFO -
# Test Acc: Max 42.8667% (178 round) | Last 42.8667% | Avg 39.4811% (44 round)
#
# 2021-09-01 19:09:13,721 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 19:09:23,612 - INFO -   |-- [Party 1] Average Train Loss:   0.0978 Train Accuracy: global  19.61% local  99.93% ... 1148 forgettables out of 1428 (80.39%) ... total data used 1428
# 2021-09-01 19:09:23,613 - INFO -   |--    Epoch Losses (10): [0.3022, 0.1951, 0.1179, 0.0711, 0.043, 0.0305, 0.05, 0.0636, 0.0596, 0.0447]
# 2021-09-01 19:09:33,208 - INFO -   |-- [Party 2] Average Train Loss:   0.1143 Train Accuracy: global  18.35% local 100.00% ... 1166 forgettables out of 1428 (81.65%) ... total data used 1428
# 2021-09-01 19:09:33,211 - INFO -   |--    Epoch Losses (10): [0.3226, 0.2186, 0.1389, 0.0869, 0.067, 0.0951, 0.0831, 0.0572, 0.043, 0.0311]
# 2021-09-01 19:09:43,563 - INFO -   |-- [Party 3] Average Train Loss:   0.0955 Train Accuracy: global  26.89% local  99.93% ... 1043 forgettables out of 1428 (73.04%) ... total data used 1428
# 2021-09-01 19:09:43,565 - INFO -   |--    Epoch Losses (10): [0.1139, 0.1234, 0.0949, 0.076, 0.1005, 0.093, 0.0816, 0.1124, 0.0926, 0.0665]
# 2021-09-01 19:09:53,308 - INFO -   |-- [Party 4] Average Train Loss:   0.1109 Train Accuracy: global  26.96% local  98.81% ... 1030 forgettables out of 1428 (72.13%) ... total data used 1428
# 2021-09-01 19:09:53,312 - INFO -   |--    Epoch Losses (10): [0.0963, 0.0868, 0.0589, 0.0512, 0.0897, 0.159, 0.1426, 0.1074, 0.0994, 0.2173]
# 2021-09-01 19:10:04,161 - INFO -   |-- [Party 5] Average Train Loss:   0.0787 Train Accuracy: global  27.31% local  99.93% ... 1037 forgettables out of 1428 (72.62%) ... total data used 1428
# 2021-09-01 19:10:04,165 - INFO -   |--    Epoch Losses (10): [0.1212, 0.1234, 0.1061, 0.1059, 0.0963, 0.0763, 0.0525, 0.0405, 0.0332, 0.0315]
# 2021-09-01 19:10:13,863 - INFO -   |-- [Party 6] Average Train Loss:   0.0699 Train Accuracy: global  91.53% local 100.00% ...  120 forgettables out of 1428 ( 8.40%) ... total data used 1428
# 2021-09-01 19:10:13,865 - INFO -   |--    Epoch Losses (10): [0.0814, 0.1036, 0.113, 0.1226, 0.093, 0.0583, 0.0439, 0.0334, 0.0276, 0.0224]
# 2021-09-01 19:10:23,724 - INFO -   |-- [Party 7] Average Train Loss:   0.0630 Train Accuracy: global  89.50% local 100.00% ...  149 forgettables out of 1428 (10.43%) ... total data used 1428
# 2021-09-01 19:10:23,726 - INFO -   |--    Epoch Losses (10): [0.0749, 0.0584, 0.0383, 0.0631, 0.0899, 0.0944, 0.0793, 0.0598, 0.0415, 0.0302]
# 2021-09-01 19:10:34,532 - INFO -   |-- [Party 8] Average Train Loss:   0.0473 Train Accuracy: global  90.76% local 100.00% ...  130 forgettables out of 1428 ( 9.10%) ... total data used 1428
# 2021-09-01 19:10:34,534 - INFO -   |--    Epoch Losses (10): [0.092, 0.0708, 0.0531, 0.0565, 0.0523, 0.046, 0.0374, 0.0294, 0.0211, 0.0146]
# 2021-09-01 19:10:45,740 - INFO -   |-- [Party 9] Average Train Loss:   0.0338 Train Accuracy: global  91.04% local 100.00% ...  128 forgettables out of 1428 ( 8.96%) ... total data used 1428
# 2021-09-01 19:10:45,744 - INFO -   |--    Epoch Losses (10): [0.0667, 0.0562, 0.0511, 0.0499, 0.0357, 0.0266, 0.0191, 0.014, 0.0102, 0.0086]
# 2021-09-01 19:10:52,130 - INFO -     |---- Number of Forgettables: 5951 (46.30%)
# 2021-09-01 19:10:52,132 - INFO -     |---- Train Accuracy: 53.60%
# 2021-09-01 19:10:52,133 - INFO -     |---- Test Accuracy: 42.87%
# 2021-09-01 19:10:52,134 - INFO -     |---- Test Loss: 1.5061
# 2021-09-01 19:10:52,134 - INFO -     |---- Elapsed time: 5:45:22.652255
# 2021-09-01 19:10:52,136 - INFO -
# Test Acc: Max 42.8667% (178 round) | Last 42.8667% | Avg 39.4982% (44 round)
#
# 2021-09-01 19:10:52,138 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 19:11:01,873 - INFO -   |-- [Party 1] Average Train Loss:   0.1150 Train Accuracy: global  24.51% local  99.65% ... 1078 forgettables out of 1428 (75.49%) ... total data used 1428
# 2021-09-01 19:11:01,875 - INFO -   |--    Epoch Losses (10): [0.2889, 0.1995, 0.1272, 0.0789, 0.0515, 0.0361, 0.026, 0.0514, 0.1577, 0.1328]
# 2021-09-01 19:11:11,690 - INFO -   |-- [Party 2] Average Train Loss:   0.0884 Train Accuracy: global  22.20% local 100.00% ... 1111 forgettables out of 1428 (77.80%) ... total data used 1428
# 2021-09-01 19:11:11,693 - INFO -   |--    Epoch Losses (10): [0.2845, 0.1877, 0.1111, 0.0626, 0.0406, 0.045, 0.0572, 0.0412, 0.0317, 0.0228]
# 2021-09-01 19:11:22,235 - INFO -   |-- [Party 3] Average Train Loss:   0.0848 Train Accuracy: global  37.54% local  99.72% ...  891 forgettables out of 1428 (62.39%) ... total data used 1428
# 2021-09-01 19:11:22,236 - INFO -   |--    Epoch Losses (10): [0.1235, 0.1163, 0.0777, 0.0634, 0.0652, 0.0893, 0.082, 0.0788, 0.0726, 0.079]
# 2021-09-01 19:11:32,979 - INFO -   |-- [Party 4] Average Train Loss:   0.0423 Train Accuracy: global  37.68% local 100.00% ...  879 forgettables out of 1428 (61.55%) ... total data used 1428
# 2021-09-01 19:11:32,980 - INFO -   |--    Epoch Losses (10): [0.086, 0.0919, 0.0669, 0.0512, 0.0378, 0.0282, 0.021, 0.0169, 0.013, 0.0098]
# 2021-09-01 19:11:42,810 - INFO -   |-- [Party 5] Average Train Loss:   0.0553 Train Accuracy: global  38.73% local 100.00% ...  874 forgettables out of 1428 (61.20%) ... total data used 1428
# 2021-09-01 19:11:42,812 - INFO -   |--    Epoch Losses (10): [0.1078, 0.1023, 0.0603, 0.0474, 0.0383, 0.0345, 0.0483, 0.0434, 0.0397, 0.0314]
# 2021-09-01 19:11:52,457 - INFO -   |-- [Party 6] Average Train Loss:   0.0546 Train Accuracy: global  79.97% local  99.93% ...  286 forgettables out of 1428 (20.03%) ... total data used 1428
# 2021-09-01 19:11:52,458 - INFO -   |--    Epoch Losses (10): [0.0711, 0.0552, 0.0434, 0.0437, 0.0368, 0.0324, 0.0365, 0.0836, 0.0818, 0.0619]
# 2021-09-01 19:12:02,218 - INFO -   |-- [Party 7] Average Train Loss:   0.0467 Train Accuracy: global  80.11% local 100.00% ...  284 forgettables out of 1428 (19.89%) ... total data used 1428
# 2021-09-01 19:12:02,220 - INFO -   |--    Epoch Losses (10): [0.0856, 0.0868, 0.0865, 0.0651, 0.0413, 0.0279, 0.0196, 0.0201, 0.0194, 0.015]
# 2021-09-01 19:12:12,504 - INFO -   |-- [Party 8] Average Train Loss:   0.0739 Train Accuracy: global  80.74% local  99.79% ...  275 forgettables out of 1428 (19.26%) ... total data used 1428
# 2021-09-01 19:12:12,505 - INFO -   |--    Epoch Losses (10): [0.1049, 0.1136, 0.1083, 0.0752, 0.0532, 0.0614, 0.0744, 0.0594, 0.0451, 0.044]
# 2021-09-01 19:12:22,305 - INFO -   |-- [Party 9] Average Train Loss:   0.0332 Train Accuracy: global  79.90% local 100.00% ...  287 forgettables out of 1428 (20.10%) ... total data used 1428
# 2021-09-01 19:12:22,307 - INFO -   |--    Epoch Losses (10): [0.0819, 0.0651, 0.0494, 0.033, 0.0279, 0.0219, 0.0207, 0.0139, 0.0103, 0.0077]
# 2021-09-01 19:12:28,630 - INFO -     |---- Number of Forgettables: 5965 (46.41%)
# 2021-09-01 19:12:28,632 - INFO -     |---- Train Accuracy: 54.17%
# 2021-09-01 19:12:28,633 - INFO -     |---- Test Accuracy: 44.00%
# 2021-09-01 19:12:28,634 - INFO -     |---- Test Loss: 1.4489
# 2021-09-01 19:12:28,634 - INFO -     |---- Elapsed time: 5:46:59.152098
# 2021-09-01 19:12:28,635 - INFO -
# Test Acc: Max 44.0000% (178 round) | Last 44.0000% | Avg 39.5207% (44 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

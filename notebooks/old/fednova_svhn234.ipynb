# %%
# %matplotlib inline

dataset = 'svhn'
clsimb = [2, 3, 4] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_fednova'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 3

# %%
import copy
import json
import logging
import math
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/train_32x32.mat
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/test_32x32.mat

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
# def average_weights(w):
#     w_avg = copy.deepcopy(w[0])
        
#     for key in w_avg.keys():
#         for i in range(1, len(w)):
#             w_avg[key] += w[i][key]
#         w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
#     return w_avg

# %%
# FedNova
def nova_update(w, a_list, d_list, n_list, n_client, device):
    coeff = 0.0
    n_round = sum(n_list)
    d_round = copy.deepcopy(w)
    for k in d_round:
        d_round[k] = 0.0
    for i in range(n_client):
        d_w = d_list[i]
        for k in d_w:
            d_round[k] = d_round[k] + (d_w[k] * n_list[i] / n_round)
        coeff += (a_list[i] * n_list[i] / n_round)
    for k in w:
        w[k] = w[k] - (coeff * d_round[k]).cpu()
    return w

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, global_state, momentum):
    epoch_losses = []
    
    # FedNova
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
    tau = 0
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())
            
            # FedNova
            tau += 1

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    # FedNova
    a_i = (tau - momentum * (1 - math.pow(momentum, tau)) / (1 - momentum)) / (1 - momentum)
    local_weights = model.state_dict()
    norm_grad = copy.deepcopy(global_state)
    for k in norm_grad:
        norm_grad[k] = torch.true_divide(global_state[k] - local_weights[k], a_i)
    
    local_weights = model.state_dict()

    return local_weights, epoch_losses, a_i, norm_grad

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0
momentum = 0

logger.info(f'\nAlgorithm: FedNova\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    # FedNova
    a_list, d_list, n_list = [], [], []
    global_state = fed_model.state_dict()
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls, a_i, norm_grad = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, global_state, momentum)

        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
        # FedNova
        a_list.append(a_i)
        d_list.append(norm_grad)
        n_list.append(len(trainloader))
        
    # FedNova
    fed_weights = nova_update(fed_weights, a_list, d_list, n_list, sum(clsimb), device)
    
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 16:21:10,632 - INFO -
# Algorithm: FedNova
# Client Split: [2, 3, 4]
# Dataset: svhn
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 16:21:10,636 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 16:21:23,302 - INFO -   |-- [Party 1] Average Train Loss:   0.9170 Train Accuracy: global   0.00% local  73.33% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:21:23,304 - INFO -   |--    Epoch Losses (10): [1.9304, 1.2286, 0.9669, 0.8472, 0.778, 0.7306, 0.701, 0.6783, 0.6612, 0.648]
# 2021-09-01 16:21:33,663 - INFO -   |-- [Party 2] Average Train Loss:   0.9121 Train Accuracy: global   0.00% local  73.24% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:21:33,669 - INFO -   |--    Epoch Losses (10): [1.9297, 1.2189, 0.956, 0.8354, 0.7735, 0.7267, 0.6974, 0.6757, 0.6596, 0.6485]
# 2021-09-01 16:21:44,040 - INFO -   |-- [Party 3] Average Train Loss:   1.0313 Train Accuracy: global   0.00% local  60.38% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:21:44,043 - INFO -   |--    Epoch Losses (10): [2.0783, 1.3877, 1.0939, 0.9529, 0.8763, 0.8326, 0.8026, 0.7775, 0.7585, 0.753]
# 2021-09-01 16:21:54,635 - INFO -   |-- [Party 4] Average Train Loss:   1.0305 Train Accuracy: global   0.00% local  60.85% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:21:54,637 - INFO -   |--    Epoch Losses (10): [2.0784, 1.3823, 1.0938, 0.956, 0.8787, 0.8308, 0.7997, 0.775, 0.7622, 0.7477]
# 2021-09-01 16:22:05,035 - INFO -   |-- [Party 5] Average Train Loss:   1.0314 Train Accuracy: global   0.00% local  60.33% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:05,036 - INFO -   |--    Epoch Losses (10): [2.0793, 1.3845, 1.0936, 0.9527, 0.8828, 0.8314, 0.7977, 0.7782, 0.7631, 0.7509]
# 2021-09-01 16:22:15,898 - INFO -   |-- [Party 6] Average Train Loss:   0.9926 Train Accuracy: global  48.50% local  54.37% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:15,902 - INFO -   |--    Epoch Losses (10): [1.7996, 1.2881, 1.0538, 0.9398, 0.8789, 0.8375, 0.806, 0.7877, 0.7746, 0.76]
# 2021-09-01 16:22:26,340 - INFO -   |-- [Party 7] Average Train Loss:   0.9933 Train Accuracy: global  48.50% local  56.06% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:26,341 - INFO -   |--    Epoch Losses (10): [1.7973, 1.2926, 1.0583, 0.9398, 0.8768, 0.8369, 0.8117, 0.7875, 0.7699, 0.7627]
# 2021-09-01 16:22:37,730 - INFO -   |-- [Party 8] Average Train Loss:   0.9926 Train Accuracy: global  48.50% local  55.26% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:37,733 - INFO -   |--    Epoch Losses (10): [1.7955, 1.2902, 1.0575, 0.9453, 0.8793, 0.8343, 0.8064, 0.788, 0.7695, 0.7606]
# 2021-09-01 16:22:48,795 - INFO -   |-- [Party 9] Average Train Loss:   0.9938 Train Accuracy: global  48.50% local  55.16% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:48,798 - INFO -   |--    Epoch Losses (10): [1.7939, 1.2874, 1.0562, 0.9385, 0.8809, 0.8395, 0.8116, 0.7892, 0.7743, 0.7661]
# 2021-09-01 16:22:58,371 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 16:22:58,375 - INFO -     |---- Train Accuracy: 22.76%
# 2021-09-01 16:22:58,377 - INFO -     |---- Test Accuracy: 10.48%
# 2021-09-01 16:22:58,378 - INFO -     |---- Test Loss: 2.1382
# 2021-09-01 16:22:58,379 - INFO -     |---- Elapsed time: 0:01:47.744339
# 2021-09-01 16:22:58,381 - INFO -
# Test Acc: Max 10.4804% (1 round) | Last 10.4804% | Avg 10.4804% (1 round)
#
# 2021-09-01 16:22:58,385 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 16:23:09,122 - INFO -   |-- [Party 1] Average Train Loss:   0.8873 Train Accuracy: global   0.00% local  73.33% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 16:23:09,124 - INFO -   |--    Epoch Losses (10): [1.8619, 1.1572, 0.9251, 0.8185, 0.7546, 0.7129, 0.6872, 0.6682, 0.6499, 0.6377]
# 2021-09-01 16:23:20,393 - INFO -   |-- [Party 2] Average Train Loss:   0.8842 Train Accuracy: global   0.00% local  73.05% ... 1560 forgettables out of 2130 (73.24%) ... total data used 2130
# 2021-09-01 16:23:20,397 - INFO -   |--    Epoch Losses (10): [1.8633, 1.1585, 0.9217, 0.8134, 0.7513, 0.7116, 0.6829, 0.6587, 0.6466, 0.6345]
# 2021-09-01 16:23:30,872 - INFO -   |-- [Party 3] Average Train Loss:   0.9308 Train Accuracy: global   0.00% local  60.66% ... 1286 forgettables out of 2130 (60.38%) ... total data used 2130
# 2021-09-01 16:23:30,874 - INFO -   |--    Epoch Losses (10): [1.6593, 1.1621, 0.9753, 0.88, 0.8294, 0.7965, 0.7729, 0.7569, 0.742, 0.7335]
# 2021-09-01 16:23:41,777 - INFO -   |-- [Party 4] Average Train Loss:   0.9302 Train Accuracy: global   0.00% local  60.85% ... 1296 forgettables out of 2130 (60.85%) ... total data used 2130
# 2021-09-01 16:23:41,780 - INFO -   |--    Epoch Losses (10): [1.6571, 1.1639, 0.9749, 0.882, 0.8292, 0.7956, 0.7696, 0.7536, 0.7446, 0.7319]
# 2021-09-01 16:23:52,709 - INFO -   |-- [Party 5] Average Train Loss:   0.9331 Train Accuracy: global   0.00% local  60.94% ... 1285 forgettables out of 2130 (60.33%) ... total data used 2130
# 2021-09-01 16:23:52,711 - INFO -   |--    Epoch Losses (10): [1.6578, 1.1682, 0.9722, 0.8851, 0.8292, 0.7963, 0.7791, 0.7572, 0.747, 0.7392]
# 2021-09-01 16:24:03,476 - INFO -   |-- [Party 6] Average Train Loss:   0.8824 Train Accuracy: global  52.11% local  54.79% ...  537 forgettables out of 2130 (25.21%) ... total data used 2130
# 2021-09-01 16:24:03,479 - INFO -   |--    Epoch Losses (10): [1.3083, 1.0494, 0.9292, 0.8652, 0.826, 0.8018, 0.7788, 0.7627, 0.7544, 0.7479]
# 2021-09-01 16:24:14,337 - INFO -   |-- [Party 7] Average Train Loss:   0.8809 Train Accuracy: global  52.02% local  56.67% ...  552 forgettables out of 2130 (25.92%) ... total data used 2130
# 2021-09-01 16:24:14,340 - INFO -   |--    Epoch Losses (10): [1.3066, 1.0441, 0.9277, 0.863, 0.8275, 0.7962, 0.779, 0.7643, 0.7556, 0.7446]
# 2021-09-01 16:24:25,757 - INFO -   |-- [Party 8] Average Train Loss:   0.8803 Train Accuracy: global  51.36% local  59.01% ...  566 forgettables out of 2130 (26.57%) ... total data used 2130
# 2021-09-01 16:24:25,760 - INFO -   |--    Epoch Losses (10): [1.3104, 1.0437, 0.9279, 0.8644, 0.8246, 0.7986, 0.7769, 0.7656, 0.7503, 0.7407]
# 2021-09-01 16:24:36,578 - INFO -   |-- [Party 9] Average Train Loss:   0.8835 Train Accuracy: global  51.03% local  56.67% ...  544 forgettables out of 2130 (25.54%) ... total data used 2130
# 2021-09-01 16:24:36,580 - INFO -   |--    Epoch Losses (10): [1.3097, 1.0494, 0.9299, 0.8668, 0.8258, 0.7999, 0.7825, 0.767, 0.758, 0.7461]
# 2021-09-01 16:24:45,534 - INFO -     |---- Number of Forgettables: 9188 (47.93%)
# 2021-09-01 16:24:45,536 - INFO -     |---- Train Accuracy: 24.04%
# 2021-09-01 16:24:45,537 - INFO -     |---- Test Accuracy: 10.73%
# 2021-09-01 16:24:45,538 - INFO -     |---- Test Loss: 2.0612
# 2021-09-01 16:24:45,538 - INFO -     |---- Elapsed time: 0:03:34.903556
# 2021-09-01 16:24:45,539 - INFO -
# Test Acc: Max 10.7270% (2 round) | Last 10.7270% | Avg 10.6037% (2 round)
#
# 2021-09-01 16:24:45,542 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 16:24:56,138 - INFO -   |-- [Party 1] Average Train Loss:   0.8703 Train Accuracy: global   0.00% local  73.33% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 16:24:56,141 - INFO -   |--    Epoch Losses (10): [1.8353, 1.1291, 0.9001, 0.7954, 0.7406, 0.7023, 0.6747, 0.653, 0.6412, 0.6318]
# 2021-09-01 16:25:06,944 - INFO -   |-- [Party 2] Average Train Loss:   0.8655 Train Accuracy: global   0.00% local  73.19% ... 1556 forgettables out of 2130 (73.05%) ... total data used 2130
# 2021-09-01 16:25:06,948 - INFO -   |--    Epoch Losses (10): [1.8372, 1.124, 0.8923, 0.7923, 0.7324, 0.6955, 0.6685, 0.6501, 0.6356, 0.6268]
# 2021-09-01 16:25:18,196 - INFO -   |-- [Party 3] Average Train Loss:   0.8988 Train Accuracy: global   0.00% local  60.89% ... 1292 forgettables out of 2130 (60.66%) ... total data used 2130
# 2021-09-01 16:25:18,197 - INFO -   |--    Epoch Losses (10): [1.5368, 1.0967, 0.9327, 0.8538, 0.8107, 0.7805, 0.7629, 0.7465, 0.7386, 0.7292]
# 2021-09-01 16:25:29,606 - INFO -   |-- [Party 4] Average Train Loss:   0.8978 Train Accuracy: global   0.00% local  60.89% ... 1296 forgettables out of 2130 (60.85%) ... total data used 2130
# 2021-09-01 16:25:29,607 - INFO -   |--    Epoch Losses (10): [1.5389, 1.0946, 0.9331, 0.856, 0.8089, 0.7815, 0.7599, 0.7473, 0.7312, 0.7264]
# 2021-09-01 16:25:40,855 - INFO -   |-- [Party 5] Average Train Loss:   0.8993 Train Accuracy: global   0.00% local  60.47% ... 1298 forgettables out of 2130 (60.94%) ... total data used 2130
# 2021-09-01 16:25:40,859 - INFO -   |--    Epoch Losses (10): [1.5375, 1.0938, 0.9348, 0.8562, 0.8096, 0.7812, 0.7655, 0.748, 0.7363, 0.7299]
# 2021-09-01 16:25:52,295 - INFO -   |-- [Party 6] Average Train Loss:   0.8549 Train Accuracy: global  55.54% local  59.34% ...  362 forgettables out of 2130 (17.00%) ... total data used 2130
# 2021-09-01 16:25:52,299 - INFO -   |--    Epoch Losses (10): [1.229, 0.9957, 0.8955, 0.84, 0.8034, 0.7861, 0.7652, 0.7539, 0.7423, 0.7378]
# 2021-09-01 16:26:03,446 - INFO -   |-- [Party 7] Average Train Loss:   0.8549 Train Accuracy: global  53.38% local  59.67% ...  429 forgettables out of 2130 (20.14%) ... total data used 2130
# 2021-09-01 16:26:03,449 - INFO -   |--    Epoch Losses (10): [1.23, 0.9993, 0.895, 0.8368, 0.8049, 0.7819, 0.7638, 0.7532, 0.7459, 0.7379]
# 2021-09-01 16:26:14,709 - INFO -   |-- [Party 8] Average Train Loss:   0.8532 Train Accuracy: global  55.12% local  57.70% ...  430 forgettables out of 2130 (20.19%) ... total data used 2130
# 2021-09-01 16:26:14,711 - INFO -   |--    Epoch Losses (10): [1.228, 0.9979, 0.895, 0.8395, 0.8043, 0.7794, 0.7647, 0.7503, 0.7396, 0.733]
# 2021-09-01 16:26:26,179 - INFO -   |-- [Party 9] Average Train Loss:   0.8566 Train Accuracy: global  54.04% local  58.64% ...  428 forgettables out of 2130 (20.09%) ... total data used 2130
# 2021-09-01 16:26:26,181 - INFO -   |--    Epoch Losses (10): [1.2326, 0.9975, 0.8963, 0.8442, 0.8083, 0.7847, 0.7679, 0.7536, 0.743, 0.7383]
# 2021-09-01 16:26:35,299 - INFO -     |---- Number of Forgettables: 8653 (45.14%)
# 2021-09-01 16:26:35,303 - INFO -     |---- Train Accuracy: 24.53%
# 2021-09-01 16:26:35,304 - INFO -     |---- Test Accuracy: 10.88%
# 2021-09-01 16:26:35,305 - INFO -     |---- Test Loss: 2.0219
# 2021-09-01 16:26:35,305 - INFO -     |---- Elapsed time: 0:05:24.670541
# 2021-09-01 16:26:35,307 - INFO -
# Test Acc: Max 10.8833% (3 round) | Last 10.8833% | Avg 10.6969% (2 round)
#
# 2021-09-01 16:26:35,309 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 16:26:46,678 - INFO -   |-- [Party 1] Average Train Loss:   0.8534 Train Accuracy: global   0.00% local  73.33% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 16:26:46,681 - INFO -   |--    Epoch Losses (10): [1.8043, 1.0991, 0.8782, 0.7835, 0.7212, 0.6858, 0.6601, 0.6464, 0.6333, 0.6224]
# 2021-09-01 16:26:58,178 - INFO -   |-- [Party 2] Average Train Loss:   0.8499 Train Accuracy: global   0.00% local  73.38% ... 1559 forgettables out of 2130 (73.19%) ... total data used 2130
# 2021-09-01 16:26:58,181 - INFO -   |--    Epoch Losses (10): [1.806, 1.0899, 0.8737, 0.7807, 0.719, 0.6852, 0.6614, 0.6421, 0.6247, 0.6157]
# 2021-09-01 16:27:09,021 - INFO -   |-- [Party 3] Average Train Loss:   0.8822 Train Accuracy: global   0.00% local  61.41% ... 1297 forgettables out of 2130 (60.89%) ... total data used 2130
# 2021-09-01 16:27:09,025 - INFO -   |--    Epoch Losses (10): [1.487, 1.0671, 0.9105, 0.8397, 0.7986, 0.7719, 0.7503, 0.7427, 0.7308, 0.7237]
# 2021-09-01 16:27:20,055 - INFO -   |-- [Party 4] Average Train Loss:   0.8813 Train Accuracy: global   0.05% local  60.80% ... 1296 forgettables out of 2130 (60.85%) ... total data used 2130
# 2021-09-01 16:27:20,059 - INFO -   |--    Epoch Losses (10): [1.4872, 1.0583, 0.9115, 0.8395, 0.7957, 0.7717, 0.7524, 0.7408, 0.7324, 0.7232]
# 2021-09-01 16:27:31,164 - INFO -   |-- [Party 5] Average Train Loss:   0.8836 Train Accuracy: global   0.00% local  60.70% ... 1288 forgettables out of 2130 (60.47%) ... total data used 2130
# 2021-09-01 16:27:31,166 - INFO -   |--    Epoch Losses (10): [1.4891, 1.0655, 0.9137, 0.8404, 0.8004, 0.775, 0.7534, 0.7409, 0.7333, 0.7246]
# 2021-09-01 16:27:42,279 - INFO -   |-- [Party 6] Average Train Loss:   0.8426 Train Accuracy: global  54.88% local  58.87% ...  399 forgettables out of 2130 (18.73%) ... total data used 2130
# 2021-09-01 16:27:42,282 - INFO -   |--    Epoch Losses (10): [1.2021, 0.9747, 0.8772, 0.8293, 0.7946, 0.7767, 0.7597, 0.743, 0.7398, 0.7288]
# 2021-09-01 16:27:53,011 - INFO -   |-- [Party 7] Average Train Loss:   0.8421 Train Accuracy: global  55.92% local  59.67% ...  404 forgettables out of 2130 (18.97%) ... total data used 2130
# 2021-09-01 16:27:53,013 - INFO -   |--    Epoch Losses (10): [1.2057, 0.9739, 0.8804, 0.8274, 0.7924, 0.7752, 0.7593, 0.7439, 0.7348, 0.7284]
# 2021-09-01 16:28:04,267 - INFO -   |-- [Party 8] Average Train Loss:   0.8387 Train Accuracy: global  57.14% local  59.58% ...  327 forgettables out of 2130 (15.35%) ... total data used 2130
# 2021-09-01 16:28:04,271 - INFO -   |--    Epoch Losses (10): [1.2018, 0.9722, 0.8749, 0.8243, 0.7898, 0.769, 0.7546, 0.7437, 0.7315, 0.7248]
# 2021-09-01 16:28:14,812 - INFO -   |-- [Party 9] Average Train Loss:   0.8430 Train Accuracy: global  53.47% local  57.93% ...  421 forgettables out of 2130 (19.77%) ... total data used 2130
# 2021-09-01 16:28:14,816 - INFO -   |--    Epoch Losses (10): [1.2039, 0.9802, 0.8781, 0.8281, 0.7971, 0.775, 0.7557, 0.7459, 0.7371, 0.7291]
# 2021-09-01 16:28:24,104 - INFO -     |---- Number of Forgettables: 8553 (44.62%)
# 2021-09-01 16:28:24,106 - INFO -     |---- Train Accuracy: 25.27%
# 2021-09-01 16:28:24,106 - INFO -     |---- Test Accuracy: 11.21%
# 2021-09-01 16:28:24,107 - INFO -     |---- Test Loss: 1.9956
# 2021-09-01 16:28:24,107 - INFO -     |---- Elapsed time: 0:07:13.472296
# 2021-09-01 16:28:24,108 - INFO -
# Test Acc: Max 11.2080% (4 round) | Last 11.2080% | Avg 10.8247% (3 round)
#
# 2021-09-01 16:28:24,110 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 16:28:35,254 - INFO -   |-- [Party 1] Average Train Loss:   0.8396 Train Accuracy: global   0.00% local  73.33% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 16:28:35,258 - INFO -   |--    Epoch Losses (10): [1.7665, 1.0657, 0.8635, 0.7702, 0.7127, 0.6807, 0.6572, 0.6417, 0.6223, 0.6158]
# 2021-09-01 16:28:46,535 - INFO -   |-- [Party 2] Average Train Loss:   0.8334 Train Accuracy: global   0.00% local  73.29% ... 1563 forgettables out of 2130 (73.38%) ... total data used 2130
# 2021-09-01 16:28:46,538 - INFO -   |--    Epoch Losses (10): [1.7666, 1.0582, 0.8559, 0.7611, 0.7063, 0.6735, 0.6504, 0.6314, 0.6197, 0.6109]
# 2021-09-01 16:28:57,404 - INFO -   |-- [Party 3] Average Train Loss:   0.8726 Train Accuracy: global   0.05% local  61.36% ... 1307 forgettables out of 2130 (61.36%) ... total data used 2130
# 2021-09-01 16:28:57,407 - INFO -   |--    Epoch Losses (10): [1.4638, 1.045, 0.9003, 0.8351, 0.7924, 0.7647, 0.7497, 0.7325, 0.7253, 0.7171]
# 2021-09-01 16:29:07,807 - INFO -   |-- [Party 4] Average Train Loss:   0.8706 Train Accuracy: global   0.05% local  60.99% ... 1294 forgettables out of 2130 (60.75%) ... total data used 2130
# 2021-09-01 16:29:07,810 - INFO -   |--    Epoch Losses (10): [1.4623, 1.0412, 0.8978, 0.8298, 0.7908, 0.7634, 0.749, 0.7341, 0.7236, 0.7136]
# 2021-09-01 16:29:19,049 - INFO -   |-- [Party 5] Average Train Loss:   0.8746 Train Accuracy: global   0.09% local  60.75% ... 1291 forgettables out of 2130 (60.61%) ... total data used 2130
# 2021-09-01 16:29:19,050 - INFO -   |--    Epoch Losses (10): [1.4667, 1.0475, 0.9029, 0.8311, 0.7936, 0.7685, 0.7507, 0.7358, 0.7286, 0.7201]
# 2021-09-01 16:29:29,583 - INFO -   |-- [Party 6] Average Train Loss:   0.8320 Train Accuracy: global  55.87% local  59.62% ...  340 forgettables out of 2130 (15.96%) ... total data used 2130
# 2021-09-01 16:29:29,587 - INFO -   |--    Epoch Losses (10): [1.1852, 0.9599, 0.868, 0.8183, 0.7853, 0.7656, 0.7513, 0.7371, 0.7281, 0.7213]
# 2021-09-01 16:29:40,097 - INFO -   |-- [Party 7] Average Train Loss:   0.8311 Train Accuracy: global  57.28% local  61.88% ...  380 forgettables out of 2130 (17.84%) ... total data used 2130
# 2021-09-01 16:29:40,101 - INFO -   |--    Epoch Losses (10): [1.1897, 0.9627, 0.8677, 0.8158, 0.7837, 0.7632, 0.7467, 0.736, 0.7242, 0.7217]
# 2021-09-01 16:29:51,456 - INFO -   |-- [Party 8] Average Train Loss:   0.8285 Train Accuracy: global  57.46% local  62.54% ...  345 forgettables out of 2130 (16.20%) ... total data used 2130
# 2021-09-01 16:29:51,459 - INFO -   |--    Epoch Losses (10): [1.1874, 0.9575, 0.8637, 0.8067, 0.7869, 0.7617, 0.7455, 0.7342, 0.7238, 0.7175]
# 2021-09-01 16:30:02,482 - INFO -   |-- [Party 9] Average Train Loss:   0.8328 Train Accuracy: global  55.63% local  60.89% ...  354 forgettables out of 2130 (16.62%) ... total data used 2130
# 2021-09-01 16:30:02,483 - INFO -   |--    Epoch Losses (10): [1.1916, 0.9639, 0.8685, 0.8187, 0.7839, 0.7633, 0.7494, 0.7412, 0.7248, 0.7226]
# 2021-09-01 16:30:11,614 - INFO -     |---- Number of Forgettables: 8436 (44.01%)
# 2021-09-01 16:30:11,616 - INFO -     |---- Train Accuracy: 25.83%
# 2021-09-01 16:30:11,617 - INFO -     |---- Test Accuracy: 11.60%
# 2021-09-01 16:30:11,617 - INFO -     |---- Test Loss: 1.9797
# 2021-09-01 16:30:11,618 - INFO -     |---- Elapsed time: 0:09:00.982644
# 2021-09-01 16:30:11,618 - INFO -
# Test Acc: Max 11.6048% (5 round) | Last 11.6048% | Avg 10.9807% (4 round)
#
# 2021-09-01 16:30:11,620 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 16:30:22,459 - INFO -   |-- [Party 1] Average Train Loss:   0.8265 Train Accuracy: global   0.00% local  73.47% ... 1562 forgettables out of 2130 (73.33%) ... total data used 2130
# 2021-09-01 16:30:22,463 - INFO -   |--    Epoch Losses (10): [1.7443, 1.0502, 0.8428, 0.7563, 0.7023, 0.6684, 0.6485, 0.6277, 0.6186, 0.6064]
# 2021-09-01 16:30:33,351 - INFO -   |-- [Party 2] Average Train Loss:   0.8202 Train Accuracy: global   0.00% local  73.29% ... 1561 forgettables out of 2130 (73.29%) ... total data used 2130
# 2021-09-01 16:30:33,352 - INFO -   |--    Epoch Losses (10): [1.735, 1.0398, 0.8388, 0.747, 0.6955, 0.6629, 0.6417, 0.628, 0.6105, 0.6024]
# 2021-09-01 16:30:44,231 - INFO -   |-- [Party 3] Average Train Loss:   0.8647 Train Accuracy: global   0.09% local  61.03% ... 1305 forgettables out of 2130 (61.27%) ... total data used 2130
# 2021-09-01 16:30:44,235 - INFO -   |--    Epoch Losses (10): [1.4485, 1.0299, 0.8873, 0.8237, 0.7865, 0.7591, 0.7445, 0.7318, 0.722, 0.7135]
# 2021-09-01 16:30:55,357 - INFO -   |-- [Party 4] Average Train Loss:   0.8632 Train Accuracy: global   0.05% local  61.27% ... 1298 forgettables out of 2130 (60.94%) ... total data used 2130
# 2021-09-01 16:30:55,361 - INFO -   |--    Epoch Losses (10): [1.4477, 1.0309, 0.8894, 0.823, 0.7795, 0.7592, 0.7409, 0.7289, 0.72, 0.7121]
# 2021-09-01 16:31:05,732 - INFO -   |-- [Party 5] Average Train Loss:   0.8666 Train Accuracy: global   0.05% local  60.70% ... 1293 forgettables out of 2130 (60.70%) ... total data used 2130
# 2021-09-01 16:31:05,736 - INFO -   |--    Epoch Losses (10): [1.4497, 1.0327, 0.8915, 0.8254, 0.7841, 0.761, 0.7475, 0.7349, 0.7253, 0.7139]
# 2021-09-01 16:31:16,137 - INFO -   |-- [Party 6] Average Train Loss:   0.8223 Train Accuracy: global  58.12% local  61.88% ...  319 forgettables out of 2130 (14.98%) ... total data used 2130
# 2021-09-01 16:31:16,140 - INFO -   |--    Epoch Losses (10): [1.1761, 0.948, 0.8565, 0.8077, 0.7767, 0.7576, 0.7441, 0.728, 0.7206, 0.708]
# 2021-09-01 16:31:27,121 - INFO -   |-- [Party 7] Average Train Loss:   0.8204 Train Accuracy: global  58.12% local  64.18% ...  329 forgettables out of 2130 (15.45%) ... total data used 2130
# 2021-09-01 16:31:27,124 - INFO -   |--    Epoch Losses (10): [1.1715, 0.9494, 0.8564, 0.8036, 0.7747, 0.7533, 0.7385, 0.7282, 0.7183, 0.7105]
# 2021-09-01 16:31:38,240 - INFO -   |-- [Party 8] Average Train Loss:   0.8186 Train Accuracy: global  59.25% local  64.37% ...  325 forgettables out of 2130 (15.26%) ... total data used 2130
# 2021-09-01 16:31:38,242 - INFO -   |--    Epoch Losses (10): [1.1749, 0.9503, 0.8501, 0.8028, 0.7732, 0.7534, 0.7346, 0.7257, 0.714, 0.7072]
# 2021-09-01 16:31:49,456 - INFO -   |-- [Party 9] Average Train Loss:   0.8224 Train Accuracy: global  59.15% local  62.63% ...  324 forgettables out of 2130 (15.21%) ... total data used 2130
# 2021-09-01 16:31:49,459 - INFO -   |--    Epoch Losses (10): [1.1784, 0.951, 0.856, 0.8063, 0.7765, 0.7537, 0.7419, 0.7255, 0.7224, 0.7126]
# 2021-09-01 16:31:58,616 - INFO -     |---- Number of Forgettables: 8316 (43.38%)
# 2021-09-01 16:31:58,620 - INFO -     |---- Train Accuracy: 26.80%
# 2021-09-01 16:31:58,621 - INFO -     |---- Test Accuracy: 12.01%
# 2021-09-01 16:31:58,622 - INFO -     |---- Test Loss: 1.9654
# 2021-09-01 16:31:58,623 - INFO -     |---- Elapsed time: 0:10:47.988549
# 2021-09-01 16:31:58,626 - INFO -
# Test Acc: Max 12.0137% (6 round) | Last 12.0137% | Avg 11.1529% (4 round)
#
# 2021-09-01 16:31:58,632 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 16:32:09,905 - INFO -   |-- [Party 1] Average Train Loss:   0.8141 Train Accuracy: global   0.00% local  73.43% ... 1565 forgettables out of 2130 (73.47%) ... total data used 2130
# 2021-09-01 16:32:09,908 - INFO -   |--    Epoch Losses (10): [1.7161, 1.0302, 0.8325, 0.7447, 0.6919, 0.6594, 0.6382, 0.6188, 0.6107, 0.5992]
# 2021-09-01 16:32:20,989 - INFO -   |-- [Party 2] Average Train Loss:   0.8085 Train Accuracy: global   0.00% local  73.38% ... 1561 forgettables out of 2130 (73.29%) ... total data used 2130
# 2021-09-01 16:32:20,993 - INFO -   |--    Epoch Losses (10): [1.715, 1.0251, 0.8251, 0.7403, 0.6852, 0.6518, 0.6312, 0.6171, 0.5998, 0.5943]
# 2021-09-01 16:32:31,375 - INFO -   |-- [Party 3] Average Train Loss:   0.8584 Train Accuracy: global   0.05% local  61.46% ... 1299 forgettables out of 2130 (60.99%) ... total data used 2130
# 2021-09-01 16:32:31,378 - INFO -   |--    Epoch Losses (10): [1.4383, 1.021, 0.8796, 0.818, 0.7789, 0.7554, 0.7385, 0.7263, 0.7176, 0.7099]
# 2021-09-01 16:32:42,016 - INFO -   |-- [Party 4] Average Train Loss:   0.8567 Train Accuracy: global   0.05% local  60.94% ... 1304 forgettables out of 2130 (61.22%) ... total data used 2130
# 2021-09-01 16:32:42,020 - INFO -   |--    Epoch Losses (10): [1.4371, 1.0199, 0.8786, 0.8121, 0.7762, 0.7528, 0.7375, 0.7265, 0.7183, 0.7081]
# 2021-09-01 16:32:52,773 - INFO -   |-- [Party 5] Average Train Loss:   0.8606 Train Accuracy: global   0.19% local  60.89% ... 1289 forgettables out of 2130 (60.52%) ... total data used 2130
# 2021-09-01 16:32:52,777 - INFO -   |--    Epoch Losses (10): [1.4407, 1.0249, 0.8815, 0.8155, 0.7809, 0.756, 0.7411, 0.7304, 0.7231, 0.7117]
# 2021-09-01 16:33:03,864 - INFO -   |-- [Party 6] Average Train Loss:   0.8143 Train Accuracy: global  61.60% local  63.62% ...  297 forgettables out of 2130 (13.94%) ... total data used 2130
# 2021-09-01 16:33:03,869 - INFO -   |--    Epoch Losses (10): [1.1627, 0.9384, 0.8462, 0.7968, 0.7671, 0.7502, 0.7333, 0.7248, 0.7163, 0.7074]
# 2021-09-01 16:33:15,043 - INFO -   |-- [Party 7] Average Train Loss:   0.8099 Train Accuracy: global  61.64% local  65.16% ...  338 forgettables out of 2130 (15.87%) ... total data used 2130
# 2021-09-01 16:33:15,046 - INFO -   |--    Epoch Losses (10): [1.1642, 0.9352, 0.845, 0.7983, 0.7639, 0.7455, 0.7267, 0.7161, 0.7062, 0.6982]
# 2021-09-01 16:33:26,403 - INFO -   |-- [Party 8] Average Train Loss:   0.8070 Train Accuracy: global  61.92% local  63.80% ...  303 forgettables out of 2130 (14.23%) ... total data used 2130
# 2021-09-01 16:33:26,406 - INFO -   |--    Epoch Losses (10): [1.1607, 0.9374, 0.8409, 0.7898, 0.7635, 0.74, 0.7255, 0.7143, 0.705, 0.6932]
# 2021-09-01 16:33:37,693 - INFO -   |-- [Party 9] Average Train Loss:   0.8128 Train Accuracy: global  59.01% local  63.43% ...  341 forgettables out of 2130 (16.01%) ... total data used 2130
# 2021-09-01 16:33:37,694 - INFO -   |--    Epoch Losses (10): [1.1637, 0.9426, 0.8448, 0.7996, 0.7656, 0.7441, 0.7328, 0.7204, 0.7105, 0.7041]
# 2021-09-01 16:33:46,760 - INFO -     |---- Number of Forgettables: 8297 (43.28%)
# 2021-09-01 16:33:46,762 - INFO -     |---- Train Accuracy: 27.60%
# 2021-09-01 16:33:46,763 - INFO -     |---- Test Accuracy: 12.38%
# 2021-09-01 16:33:46,763 - INFO -     |---- Test Loss: 1.9551
# 2021-09-01 16:33:46,764 - INFO -     |---- Elapsed time: 0:12:36.128836
# 2021-09-01 16:33:46,765 - INFO -
# Test Acc: Max 12.3805% (7 round) | Last 12.3805% | Avg 11.3282% (5 round)
#
# 2021-09-01 16:33:46,767 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 16:33:57,218 - INFO -   |-- [Party 1] Average Train Loss:   0.8017 Train Accuracy: global   0.00% local  73.52% ... 1564 forgettables out of 2130 (73.43%) ... total data used 2130
# 2021-09-01 16:33:57,220 - INFO -   |--    Epoch Losses (10): [1.6991, 1.0113, 0.8198, 0.733, 0.6829, 0.6522, 0.6255, 0.6131, 0.596, 0.5846]
# 2021-09-01 16:34:08,234 - INFO -   |-- [Party 2] Average Train Loss:   0.7953 Train Accuracy: global   0.00% local  73.99% ... 1563 forgettables out of 2130 (73.38%) ... total data used 2130
# 2021-09-01 16:34:08,237 - INFO -   |--    Epoch Losses (10): [1.6935, 1.0055, 0.8103, 0.7286, 0.6776, 0.6399, 0.623, 0.6032, 0.591, 0.5803]
# 2021-09-01 16:34:18,978 - INFO -   |-- [Party 3] Average Train Loss:   0.8522 Train Accuracy: global   0.05% local  61.31% ... 1308 forgettables out of 2130 (61.41%) ... total data used 2130
# 2021-09-01 16:34:18,982 - INFO -   |--    Epoch Losses (10): [1.4236, 1.0117, 0.8764, 0.8136, 0.7742, 0.7492, 0.7332, 0.7209, 0.7122, 0.7072]
# 2021-09-01 16:34:29,539 - INFO -   |-- [Party 4] Average Train Loss:   0.8509 Train Accuracy: global   0.05% local  61.27% ... 1297 forgettables out of 2130 (60.89%) ... total data used 2130
# 2021-09-01 16:34:29,540 - INFO -   |--    Epoch Losses (10): [1.4285, 1.0088, 0.871, 0.8103, 0.7736, 0.748, 0.7325, 0.7209, 0.7105, 0.7054]
# 2021-09-01 16:34:40,931 - INFO -   |-- [Party 5] Average Train Loss:   0.8547 Train Accuracy: global   0.09% local  61.17% ... 1295 forgettables out of 2130 (60.80%) ... total data used 2130
# 2021-09-01 16:34:40,935 - INFO -   |--    Epoch Losses (10): [1.4272, 1.0119, 0.8777, 0.8138, 0.7771, 0.7532, 0.738, 0.7256, 0.7134, 0.7096]
# 2021-09-01 16:34:51,368 - INFO -   |-- [Party 6] Average Train Loss:   0.8018 Train Accuracy: global  63.71% local  64.51% ...  249 forgettables out of 2130 (11.69%) ... total data used 2130
# 2021-09-01 16:34:51,369 - INFO -   |--    Epoch Losses (10): [1.1514, 0.922, 0.8346, 0.7867, 0.7567, 0.739, 0.7232, 0.7112, 0.7006, 0.6931]
# 2021-09-01 16:35:02,550 - INFO -   |-- [Party 7] Average Train Loss:   0.7978 Train Accuracy: global  61.22% local  66.53% ...  350 forgettables out of 2130 (16.43%) ... total data used 2130
# 2021-09-01 16:35:02,551 - INFO -   |--    Epoch Losses (10): [1.1469, 0.925, 0.8267, 0.7847, 0.7519, 0.7352, 0.7163, 0.7059, 0.6983, 0.6869]
# 2021-09-01 16:35:13,503 - INFO -   |-- [Party 8] Average Train Loss:   0.7935 Train Accuracy: global  62.30% local  65.07% ...  285 forgettables out of 2130 (13.38%) ... total data used 2130
# 2021-09-01 16:35:13,504 - INFO -   |--    Epoch Losses (10): [1.1456, 0.9213, 0.8289, 0.7769, 0.7481, 0.7291, 0.7122, 0.7009, 0.6919, 0.6801]
# 2021-09-01 16:35:24,750 - INFO -   |-- [Party 9] Average Train Loss:   0.8002 Train Accuracy: global  63.43% local  65.02% ...  287 forgettables out of 2130 (13.47%) ... total data used 2130
# 2021-09-01 16:35:24,753 - INFO -   |--    Epoch Losses (10): [1.1515, 0.9215, 0.833, 0.7887, 0.7562, 0.7329, 0.7207, 0.7079, 0.699, 0.6902]
# 2021-09-01 16:35:33,882 - INFO -     |---- Number of Forgettables: 8198 (42.76%)
# 2021-09-01 16:35:33,886 - INFO -     |---- Train Accuracy: 28.23%
# 2021-09-01 16:35:33,887 - INFO -     |---- Test Accuracy: 12.63%
# 2021-09-01 16:35:33,888 - INFO -     |---- Test Loss: 1.9450
# 2021-09-01 16:35:33,889 - INFO -     |---- Elapsed time: 0:14:23.253662
# 2021-09-01 16:35:33,890 - INFO -
# Test Acc: Max 12.6270% (8 round) | Last 12.6270% | Avg 11.4906% (5 round)
#
# 2021-09-01 16:35:33,893 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 16:35:45,408 - INFO -   |-- [Party 1] Average Train Loss:   0.7871 Train Accuracy: global   0.00% local  73.85% ... 1566 forgettables out of 2130 (73.52%) ... total data used 2130
# 2021-09-01 16:35:45,411 - INFO -   |--    Epoch Losses (10): [1.6792, 0.9928, 0.8045, 0.718, 0.6725, 0.6391, 0.6149, 0.6004, 0.582, 0.567]
# 2021-09-01 16:35:56,924 - INFO -   |-- [Party 2] Average Train Loss:   0.7818 Train Accuracy: global   0.00% local  74.04% ... 1576 forgettables out of 2130 (73.99%) ... total data used 2130
# 2021-09-01 16:35:56,928 - INFO -   |--    Epoch Losses (10): [1.6766, 0.9882, 0.8003, 0.7132, 0.6623, 0.6322, 0.6104, 0.5864, 0.5807, 0.568]
# 2021-09-01 16:36:08,198 - INFO -   |-- [Party 3] Average Train Loss:   0.8446 Train Accuracy: global   0.05% local  61.46% ... 1305 forgettables out of 2130 (61.27%) ... total data used 2130
# 2021-09-01 16:36:08,200 - INFO -   |--    Epoch Losses (10): [1.4159, 0.9999, 0.8648, 0.8021, 0.7661, 0.7466, 0.7276, 0.7164, 0.7077, 0.6986]
# 2021-09-01 16:36:18,900 - INFO -   |-- [Party 4] Average Train Loss:   0.8455 Train Accuracy: global   0.05% local  61.46% ... 1304 forgettables out of 2130 (61.22%) ... total data used 2130
# 2021-09-01 16:36:18,903 - INFO -   |--    Epoch Losses (10): [1.4154, 1.0018, 0.8667, 0.8032, 0.7685, 0.7469, 0.7268, 0.7181, 0.7064, 0.7015]
# 2021-09-01 16:36:29,615 - INFO -   |-- [Party 5] Average Train Loss:   0.8477 Train Accuracy: global   0.05% local  61.36% ... 1302 forgettables out of 2130 (61.13%) ... total data used 2130
# 2021-09-01 16:36:29,619 - INFO -   |--    Epoch Losses (10): [1.4182, 1.003, 0.8691, 0.8062, 0.7687, 0.747, 0.7328, 0.7206, 0.7075, 0.7042]
# 2021-09-01 16:36:40,900 - INFO -   |-- [Party 6] Average Train Loss:   0.7893 Train Accuracy: global  64.55% local  67.61% ...  233 forgettables out of 2130 (10.94%) ... total data used 2130
# 2021-09-01 16:36:40,902 - INFO -   |--    Epoch Losses (10): [1.1383, 0.9123, 0.8197, 0.773, 0.7429, 0.7255, 0.7104, 0.7014, 0.6898, 0.6799]
# 2021-09-01 16:36:52,108 - INFO -   |-- [Party 7] Average Train Loss:   0.7833 Train Accuracy: global  64.93% local  67.65% ...  287 forgettables out of 2130 (13.47%) ... total data used 2130
# 2021-09-01 16:36:52,111 - INFO -   |--    Epoch Losses (10): [1.1329, 0.9116, 0.8149, 0.7686, 0.7387, 0.7172, 0.7031, 0.6917, 0.6832, 0.671]
# 2021-09-01 16:37:02,760 - INFO -   |-- [Party 8] Average Train Loss:   0.7779 Train Accuracy: global  66.57% local  68.78% ...  219 forgettables out of 2130 (10.28%) ... total data used 2130
# 2021-09-01 16:37:02,762 - INFO -   |--    Epoch Losses (10): [1.1285, 0.9048, 0.8117, 0.762, 0.7337, 0.7153, 0.699, 0.684, 0.6712, 0.6685]
# 2021-09-01 16:37:13,612 - INFO -   |-- [Party 9] Average Train Loss:   0.7875 Train Accuracy: global  61.78% local  66.29% ...  325 forgettables out of 2130 (15.26%) ... total data used 2130
# 2021-09-01 16:37:13,613 - INFO -   |--    Epoch Losses (10): [1.1341, 0.9085, 0.8215, 0.7763, 0.7417, 0.7222, 0.709, 0.6963, 0.6855, 0.6805]
# 2021-09-01 16:37:22,417 - INFO -     |---- Number of Forgettables: 8117 (42.34%)
# 2021-09-01 16:37:22,418 - INFO -     |---- Train Accuracy: 29.00%
# 2021-09-01 16:37:22,419 - INFO -     |---- Test Accuracy: 12.99%
# 2021-09-01 16:37:22,420 - INFO -     |---- Test Loss: 1.9345
# 2021-09-01 16:37:22,420 - INFO -     |---- Elapsed time: 0:16:11.785384
# 2021-09-01 16:37:22,421 - INFO -
# Test Acc: Max 12.9938% (9 round) | Last 12.9938% | Avg 11.6576% (6 round)
#
# 2021-09-01 16:37:22,424 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 16:37:33,756 - INFO -   |-- [Party 1] Average Train Loss:   0.7690 Train Accuracy: global   0.00% local  74.37% ... 1573 forgettables out of 2130 (73.85%) ... total data used 2130
# 2021-09-01 16:37:33,760 - INFO -   |--    Epoch Losses (10): [1.6602, 0.9774, 0.7855, 0.7003, 0.6579, 0.6194, 0.5976, 0.5804, 0.5639, 0.5471]
# 2021-09-01 16:37:44,339 - INFO -   |-- [Party 2] Average Train Loss:   0.7637 Train Accuracy: global   0.00% local  76.43% ... 1577 forgettables out of 2130 (74.04%) ... total data used 2130
# 2021-09-01 16:37:44,340 - INFO -   |--    Epoch Losses (10): [1.6496, 0.9665, 0.7805, 0.697, 0.6513, 0.615, 0.5911, 0.5744, 0.5636, 0.5477]
# 2021-09-01 16:37:54,833 - INFO -   |-- [Party 3] Average Train Loss:   0.8390 Train Accuracy: global   0.14% local  63.24% ... 1306 forgettables out of 2130 (61.31%) ... total data used 2130
# 2021-09-01 16:37:54,834 - INFO -   |--    Epoch Losses (10): [1.4061, 0.995, 0.8579, 0.7965, 0.7589, 0.7408, 0.7232, 0.7126, 0.7053, 0.6936]
# 2021-09-01 16:38:05,716 - INFO -   |-- [Party 4] Average Train Loss:   0.8392 Train Accuracy: global   0.05% local  61.74% ... 1308 forgettables out of 2130 (61.41%) ... total data used 2130
# 2021-09-01 16:38:05,718 - INFO -   |--    Epoch Losses (10): [1.4068, 0.9916, 0.8574, 0.796, 0.7644, 0.7409, 0.7226, 0.7125, 0.7043, 0.695]
# 2021-09-01 16:38:16,834 - INFO -   |-- [Party 5] Average Train Loss:   0.8418 Train Accuracy: global   0.00% local  61.78% ... 1307 forgettables out of 2130 (61.36%) ... total data used 2130
# 2021-09-01 16:38:16,837 - INFO -   |--    Epoch Losses (10): [1.4079, 0.9965, 0.8648, 0.7981, 0.7674, 0.7424, 0.7263, 0.713, 0.7062, 0.6956]
# 2021-09-01 16:38:27,163 - INFO -   |-- [Party 6] Average Train Loss:   0.7721 Train Accuracy: global  64.41% local  65.82% ...  254 forgettables out of 2130 (11.92%) ... total data used 2130
# 2021-09-01 16:38:27,165 - INFO -   |--    Epoch Losses (10): [1.1197, 0.8938, 0.8031, 0.7577, 0.7291, 0.7039, 0.6954, 0.6838, 0.6719, 0.663]
# 2021-09-01 16:38:38,299 - INFO -   |-- [Party 7] Average Train Loss:   0.7661 Train Accuracy: global  65.96% local  70.14% ...  241 forgettables out of 2130 (11.31%) ... total data used 2130
# 2021-09-01 16:38:38,300 - INFO -   |--    Epoch Losses (10): [1.1193, 0.8902, 0.7994, 0.7505, 0.7237, 0.7006, 0.6883, 0.6736, 0.6609, 0.6542]
# 2021-09-01 16:38:49,435 - INFO -   |-- [Party 8] Average Train Loss:   0.7613 Train Accuracy: global  66.43% local  68.08% ...  260 forgettables out of 2130 (12.21%) ... total data used 2130
# 2021-09-01 16:38:49,436 - INFO -   |--    Epoch Losses (10): [1.1164, 0.8869, 0.7943, 0.7492, 0.7193, 0.6969, 0.6815, 0.6678, 0.6568, 0.6444]
# 2021-09-01 16:39:00,261 - INFO -   |-- [Party 9] Average Train Loss:   0.7713 Train Accuracy: global  64.41% local  67.89% ...  259 forgettables out of 2130 (12.16%) ... total data used 2130
# 2021-09-01 16:39:00,262 - INFO -   |--    Epoch Losses (10): [1.122, 0.8971, 0.8002, 0.7577, 0.7237, 0.7067, 0.6914, 0.6802, 0.6718, 0.6626]
# 2021-09-01 16:39:09,224 - INFO -     |---- Number of Forgettables: 8085 (42.18%)
# 2021-09-01 16:39:09,227 - INFO -     |---- Train Accuracy: 29.43%
# 2021-09-01 16:39:09,228 - INFO -     |---- Test Accuracy: 13.32%
# 2021-09-01 16:39:09,229 - INFO -     |---- Test Loss: 1.9246
# 2021-09-01 16:39:09,230 - INFO -     |---- Elapsed time: 0:17:58.595072
# 2021-09-01 16:39:09,231 - INFO -
# Test Acc: Max 13.3185% (10 round) | Last 13.3185% | Avg 11.8237% (6 round)
#
# 2021-09-01 16:39:09,235 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 16:39:19,659 - INFO -   |-- [Party 1] Average Train Loss:   0.7469 Train Accuracy: global   0.00% local  76.81% ... 1584 forgettables out of 2130 (74.37%) ... total data used 2130
# 2021-09-01 16:39:19,661 - INFO -   |--    Epoch Losses (10): [1.6366, 0.9539, 0.7671, 0.6826, 0.6332, 0.598, 0.5737, 0.5551, 0.5405, 0.5286]
# 2021-09-01 16:39:30,597 - INFO -   |-- [Party 2] Average Train Loss:   0.7403 Train Accuracy: global   0.00% local  76.62% ... 1628 forgettables out of 2130 (76.43%) ... total data used 2130
# 2021-09-01 16:39:30,599 - INFO -   |--    Epoch Losses (10): [1.6314, 0.9463, 0.7579, 0.6753, 0.627, 0.5922, 0.5687, 0.5505, 0.5341, 0.5195]
# 2021-09-01 16:39:41,411 - INFO -   |-- [Party 3] Average Train Loss:   0.8317 Train Accuracy: global   0.09% local  63.47% ... 1345 forgettables out of 2130 (63.15%) ... total data used 2130
# 2021-09-01 16:39:41,414 - INFO -   |--    Epoch Losses (10): [1.3978, 0.9847, 0.849, 0.7889, 0.7566, 0.7327, 0.7173, 0.7039, 0.6973, 0.6886]
# 2021-09-01 16:39:52,676 - INFO -   |-- [Party 4] Average Train Loss:   0.8321 Train Accuracy: global   0.09% local  62.86% ... 1313 forgettables out of 2130 (61.64%) ... total data used 2130
# 2021-09-01 16:39:52,678 - INFO -   |--    Epoch Losses (10): [1.3966, 0.9875, 0.8498, 0.7902, 0.7534, 0.733, 0.7166, 0.7079, 0.6961, 0.6894]
# 2021-09-01 16:40:03,811 - INFO -   |-- [Party 5] Average Train Loss:   0.8332 Train Accuracy: global   0.00% local  61.50% ... 1316 forgettables out of 2130 (61.78%) ... total data used 2130
# 2021-09-01 16:40:03,815 - INFO -   |--    Epoch Losses (10): [1.3943, 0.9828, 0.8508, 0.7928, 0.7559, 0.7386, 0.718, 0.7094, 0.698, 0.6912]
# 2021-09-01 16:40:15,073 - INFO -   |-- [Party 6] Average Train Loss:   0.7557 Train Accuracy: global  66.71% local  67.51% ...  230 forgettables out of 2130 (10.80%) ... total data used 2130
# 2021-09-01 16:40:15,077 - INFO -   |--    Epoch Losses (10): [1.1011, 0.8773, 0.7898, 0.744, 0.7116, 0.6948, 0.6767, 0.6672, 0.6546, 0.6404]
# 2021-09-01 16:40:26,616 - INFO -   |-- [Party 7] Average Train Loss:   0.7466 Train Accuracy: global  67.28% local  65.16% ...  228 forgettables out of 2130 (10.70%) ... total data used 2130
# 2021-09-01 16:40:26,619 - INFO -   |--    Epoch Losses (10): [1.0994, 0.8732, 0.78, 0.7312, 0.7041, 0.6802, 0.6663, 0.6523, 0.6436, 0.6356]
# 2021-09-01 16:40:37,924 - INFO -   |-- [Party 8] Average Train Loss:   0.7390 Train Accuracy: global  66.67% local  70.47% ...  197 forgettables out of 2130 ( 9.25%) ... total data used 2130
# 2021-09-01 16:40:37,925 - INFO -   |--    Epoch Losses (10): [1.0936, 0.8637, 0.7747, 0.7257, 0.6966, 0.6728, 0.6572, 0.6471, 0.6378, 0.6204]
# 2021-09-01 16:40:49,043 - INFO -   |-- [Party 9] Average Train Loss:   0.7530 Train Accuracy: global  65.54% local  69.86% ...  258 forgettables out of 2130 (12.11%) ... total data used 2130
# 2021-09-01 16:40:49,044 - INFO -   |--    Epoch Losses (10): [1.1019, 0.8783, 0.786, 0.7371, 0.7049, 0.6895, 0.6773, 0.6595, 0.6535, 0.6425]
# 2021-09-01 16:40:57,947 - INFO -     |---- Number of Forgettables: 8099 (42.25%)
# 2021-09-01 16:40:57,949 - INFO -     |---- Train Accuracy: 30.04%
# 2021-09-01 16:40:57,950 - INFO -     |---- Test Accuracy: 13.42%
# 2021-09-01 16:40:57,951 - INFO -     |---- Test Loss: 1.9131
# 2021-09-01 16:40:57,951 - INFO -     |---- Elapsed time: 0:19:47.316466
# 2021-09-01 16:40:57,952 - INFO -
# Test Acc: Max 13.4207% (11 round) | Last 13.4207% | Avg 11.9689% (6 round)
#
# 2021-09-01 16:40:57,954 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 16:41:09,237 - INFO -   |-- [Party 1] Average Train Loss:   0.7176 Train Accuracy: global   0.00% local  80.00% ... 1636 forgettables out of 2130 (76.81%) ... total data used 2130
# 2021-09-01 16:41:09,238 - INFO -   |--    Epoch Losses (10): [1.6095, 0.9224, 0.743, 0.6564, 0.6042, 0.571, 0.5465, 0.5247, 0.5054, 0.4932]
# 2021-09-01 16:41:19,639 - INFO -   |-- [Party 2] Average Train Loss:   0.7157 Train Accuracy: global   0.00% local  77.61% ... 1632 forgettables out of 2130 (76.62%) ... total data used 2130
# 2021-09-01 16:41:19,643 - INFO -   |--    Epoch Losses (10): [1.6058, 0.9231, 0.7393, 0.6484, 0.5959, 0.5675, 0.5469, 0.5255, 0.5068, 0.4977]
# 2021-09-01 16:41:30,051 - INFO -   |-- [Party 3] Average Train Loss:   0.8205 Train Accuracy: global   0.00% local  64.74% ... 1352 forgettables out of 2130 (63.47%) ... total data used 2130
# 2021-09-01 16:41:30,054 - INFO -   |--    Epoch Losses (10): [1.3852, 0.9712, 0.8398, 0.778, 0.7448, 0.7235, 0.7071, 0.6935, 0.6847, 0.6777]
# 2021-09-01 16:41:40,825 - INFO -   |-- [Party 4] Average Train Loss:   0.8237 Train Accuracy: global   0.05% local  64.51% ... 1338 forgettables out of 2130 (62.82%) ... total data used 2130
# 2021-09-01 16:41:40,826 - INFO -   |--    Epoch Losses (10): [1.388, 0.9728, 0.841, 0.7848, 0.744, 0.7278, 0.7098, 0.6958, 0.6915, 0.6815]
# 2021-09-01 16:41:51,611 - INFO -   |-- [Party 5] Average Train Loss:   0.8250 Train Accuracy: global   0.00% local  63.52% ... 1310 forgettables out of 2130 (61.50%) ... total data used 2130
# 2021-09-01 16:41:51,614 - INFO -   |--    Epoch Losses (10): [1.3876, 0.975, 0.845, 0.7847, 0.7484, 0.7291, 0.7115, 0.7005, 0.6874, 0.6811]
# 2021-09-01 16:42:02,534 - INFO -   |-- [Party 6] Average Train Loss:   0.7362 Train Accuracy: global  67.79% local  70.47% ...  199 forgettables out of 2130 ( 9.34%) ... total data used 2130
# 2021-09-01 16:42:02,537 - INFO -   |--    Epoch Losses (10): [1.0816, 0.8545, 0.7651, 0.724, 0.6943, 0.6655, 0.66, 0.6457, 0.636, 0.6355]
# 2021-09-01 16:42:12,985 - INFO -   |-- [Party 7] Average Train Loss:   0.7266 Train Accuracy: global  68.26% local  72.39% ...  315 forgettables out of 2130 (14.79%) ... total data used 2130
# 2021-09-01 16:42:12,987 - INFO -   |--    Epoch Losses (10): [1.0763, 0.8507, 0.7626, 0.71, 0.6821, 0.6614, 0.6479, 0.6349, 0.6225, 0.6173]
# 2021-09-01 16:42:23,767 - INFO -   |-- [Party 8] Average Train Loss:   0.7182 Train Accuracy: global  69.67% local  72.07% ...  229 forgettables out of 2130 (10.75%) ... total data used 2130
# 2021-09-01 16:42:23,771 - INFO -   |--    Epoch Losses (10): [1.0715, 0.8458, 0.7512, 0.7013, 0.6747, 0.6483, 0.6428, 0.6219, 0.6168, 0.6075]
# 2021-09-01 16:42:34,989 - INFO -   |-- [Party 9] Average Train Loss:   0.7337 Train Accuracy: global  67.37% local  70.61% ...  206 forgettables out of 2130 ( 9.67%) ... total data used 2130
# 2021-09-01 16:42:34,991 - INFO -   |--    Epoch Losses (10): [1.0789, 0.8517, 0.7624, 0.7233, 0.6901, 0.6746, 0.6615, 0.6415, 0.6317, 0.6217]
# 2021-09-01 16:42:43,992 - INFO -     |---- Number of Forgettables: 8217 (42.86%)
# 2021-09-01 16:42:43,996 - INFO -     |---- Train Accuracy: 30.91%
# 2021-09-01 16:42:43,996 - INFO -     |---- Test Accuracy: 13.75%
# 2021-09-01 16:42:43,998 - INFO -     |---- Test Loss: 1.9093
# 2021-09-01 16:42:43,998 - INFO -     |---- Elapsed time: 0:21:33.363540
# 2021-09-01 16:42:43,999 - INFO -
# Test Acc: Max 13.7454% (12 round) | Last 13.7454% | Avg 12.1169% (7 round)
#
# 2021-09-01 16:42:44,002 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 16:42:55,027 - INFO -   |-- [Party 1] Average Train Loss:   0.6891 Train Accuracy: global   0.00% local  80.61% ... 1704 forgettables out of 2130 (80.00%) ... total data used 2130
# 2021-09-01 16:42:55,029 - INFO -   |--    Epoch Losses (10): [1.578, 0.8958, 0.7166, 0.6271, 0.5721, 0.5436, 0.5131, 0.4977, 0.4797, 0.4676]
# 2021-09-01 16:43:05,917 - INFO -   |-- [Party 2] Average Train Loss:   0.6909 Train Accuracy: global   0.00% local  81.13% ... 1653 forgettables out of 2130 (77.61%) ... total data used 2130
# 2021-09-01 16:43:05,919 - INFO -   |--    Epoch Losses (10): [1.5793, 0.8922, 0.7071, 0.6223, 0.5729, 0.5455, 0.5242, 0.5016, 0.4948, 0.4689]
# 2021-09-01 16:43:17,287 - INFO -   |-- [Party 3] Average Train Loss:   0.8081 Train Accuracy: global   0.05% local  65.73% ... 1378 forgettables out of 2130 (64.69%) ... total data used 2130
# 2021-09-01 16:43:17,288 - INFO -   |--    Epoch Losses (10): [1.3715, 0.9551, 0.8313, 0.7663, 0.7342, 0.7056, 0.6989, 0.6832, 0.6713, 0.6638]
# 2021-09-01 16:43:28,410 - INFO -   |-- [Party 4] Average Train Loss:   0.8139 Train Accuracy: global   0.14% local  66.34% ... 1371 forgettables out of 2130 (64.37%) ... total data used 2130
# 2021-09-01 16:43:28,411 - INFO -   |--    Epoch Losses (10): [1.3725, 0.9619, 0.8332, 0.7741, 0.7372, 0.7165, 0.7024, 0.6867, 0.6809, 0.6736]
# 2021-09-01 16:43:39,106 - INFO -   |-- [Party 5] Average Train Loss:   0.8137 Train Accuracy: global   0.00% local  65.77% ... 1353 forgettables out of 2130 (63.52%) ... total data used 2130
# 2021-09-01 16:43:39,110 - INFO -   |--    Epoch Losses (10): [1.3749, 0.9617, 0.8357, 0.7718, 0.7375, 0.7162, 0.7039, 0.6905, 0.6785, 0.6665]
# 2021-09-01 16:43:49,835 - INFO -   |-- [Party 6] Average Train Loss:   0.7198 Train Accuracy: global  68.54% local  72.35% ...  259 forgettables out of 2130 (12.16%) ... total data used 2130
# 2021-09-01 16:43:49,837 - INFO -   |--    Epoch Losses (10): [1.0629, 0.837, 0.7478, 0.7048, 0.6763, 0.6594, 0.6406, 0.6312, 0.6226, 0.6157]
# 2021-09-01 16:44:00,645 - INFO -   |-- [Party 7] Average Train Loss:   0.7071 Train Accuracy: global  70.85% local  72.21% ...  220 forgettables out of 2130 (10.33%) ... total data used 2130
# 2021-09-01 16:44:00,646 - INFO -   |--    Epoch Losses (10): [1.0536, 0.8289, 0.7353, 0.6936, 0.6659, 0.6431, 0.6273, 0.6213, 0.6068, 0.595]
# 2021-09-01 16:44:11,579 - INFO -   |-- [Party 8] Average Train Loss:   0.6976 Train Accuracy: global  70.47% local  72.68% ...  183 forgettables out of 2130 ( 8.59%) ... total data used 2130
# 2021-09-01 16:44:11,581 - INFO -   |--    Epoch Losses (10): [1.0466, 0.8192, 0.7315, 0.6832, 0.655, 0.6369, 0.617, 0.6033, 0.5941, 0.5889]
# 2021-09-01 16:44:22,634 - INFO -   |-- [Party 9] Average Train Loss:   0.7151 Train Accuracy: global  68.26% local  71.27% ...  217 forgettables out of 2130 (10.19%) ... total data used 2130
# 2021-09-01 16:44:22,636 - INFO -   |--    Epoch Losses (10): [1.0617, 0.8321, 0.7463, 0.7032, 0.6755, 0.6545, 0.6375, 0.6199, 0.6146, 0.6055]
# 2021-09-01 16:44:31,639 - INFO -     |---- Number of Forgettables: 8338 (43.50%)
# 2021-09-01 16:44:31,642 - INFO -     |---- Train Accuracy: 30.99%
# 2021-09-01 16:44:31,643 - INFO -     |---- Test Accuracy: 13.85%
# 2021-09-01 16:44:31,644 - INFO -     |---- Test Loss: 1.9005
# 2021-09-01 16:44:31,645 - INFO -     |---- Elapsed time: 0:23:21.009696
# 2021-09-01 16:44:31,646 - INFO -
# Test Acc: Max 13.8476% (13 round) | Last 13.8476% | Avg 12.2501% (7 round)
#
# 2021-09-01 16:44:31,648 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 16:44:42,076 - INFO -   |-- [Party 1] Average Train Loss:   0.6632 Train Accuracy: global   0.00% local  80.85% ... 1717 forgettables out of 2130 (80.61%) ... total data used 2130
# 2021-09-01 16:44:42,078 - INFO -   |--    Epoch Losses (10): [1.5539, 0.8685, 0.6785, 0.5943, 0.5441, 0.5157, 0.4941, 0.4766, 0.4603, 0.446]
# 2021-09-01 16:44:52,742 - INFO -   |-- [Party 2] Average Train Loss:   0.6712 Train Accuracy: global   0.00% local  80.61% ... 1728 forgettables out of 2130 (81.13%) ... total data used 2130
# 2021-09-01 16:44:52,746 - INFO -   |--    Epoch Losses (10): [1.5478, 0.8665, 0.6796, 0.6064, 0.5578, 0.5234, 0.5032, 0.4907, 0.4733, 0.4634]
# 2021-09-01 16:45:04,012 - INFO -   |-- [Party 3] Average Train Loss:   0.7982 Train Accuracy: global   0.09% local  67.32% ... 1398 forgettables out of 2130 (65.63%) ... total data used 2130
# 2021-09-01 16:45:04,014 - INFO -   |--    Epoch Losses (10): [1.3614, 0.9451, 0.8158, 0.7604, 0.7218, 0.6996, 0.6843, 0.676, 0.6615, 0.6557]
# 2021-09-01 16:45:15,219 - INFO -   |-- [Party 4] Average Train Loss:   0.8032 Train Accuracy: global   0.14% local  66.38% ... 1411 forgettables out of 2130 (66.24%) ... total data used 2130
# 2021-09-01 16:45:15,221 - INFO -   |--    Epoch Losses (10): [1.366, 0.9536, 0.8223, 0.7598, 0.7301, 0.7061, 0.6936, 0.6774, 0.6635, 0.6592]
# 2021-09-01 16:45:26,293 - INFO -   |-- [Party 5] Average Train Loss:   0.8030 Train Accuracy: global   0.14% local  67.09% ... 1398 forgettables out of 2130 (65.63%) ... total data used 2130
# 2021-09-01 16:45:26,297 - INFO -   |--    Epoch Losses (10): [1.3661, 0.9491, 0.8241, 0.7649, 0.7279, 0.7048, 0.6904, 0.6784, 0.6657, 0.6589]
# 2021-09-01 16:45:37,438 - INFO -   |-- [Party 6] Average Train Loss:   0.7022 Train Accuracy: global  68.92% local  73.66% ...  218 forgettables out of 2130 (10.23%) ... total data used 2130
# 2021-09-01 16:45:37,442 - INFO -   |--    Epoch Losses (10): [1.0404, 0.8167, 0.7292, 0.691, 0.6566, 0.6451, 0.624, 0.6161, 0.6078, 0.5947]
# ...
# 2021-09-01 22:07:17,995 - INFO -   |--    Epoch Losses (10): [0.091, 0.0472, 0.0468, 0.0447, 0.0415, 0.0425, 0.0435, 0.041, 0.036, 0.0405]
# 2021-09-01 22:07:27,883 - INFO -   |-- [Party 6] Average Train Loss:   0.0419 Train Accuracy: global  87.56% local  98.22% ...  260 forgettables out of 2130 (12.21%) ... total data used 2130
# 2021-09-01 22:07:27,885 - INFO -   |--    Epoch Losses (10): [0.0692, 0.0534, 0.0494, 0.0381, 0.0347, 0.0308, 0.0388, 0.0379, 0.0366, 0.0301]
# 2021-09-01 22:07:38,666 - INFO -   |-- [Party 7] Average Train Loss:   0.0368 Train Accuracy: global  87.89% local  99.34% ...  249 forgettables out of 2130 (11.69%) ... total data used 2130
# 2021-09-01 22:07:38,667 - INFO -   |--    Epoch Losses (10): [0.0684, 0.0401, 0.0337, 0.0417, 0.0338, 0.0343, 0.0254, 0.0318, 0.0268, 0.0318]
# 2021-09-01 22:07:48,547 - INFO -   |-- [Party 8] Average Train Loss:   0.0370 Train Accuracy: global  87.89% local  99.30% ...  249 forgettables out of 2130 (11.69%) ... total data used 2130
# 2021-09-01 22:07:48,550 - INFO -   |--    Epoch Losses (10): [0.0658, 0.0489, 0.0351, 0.0354, 0.0332, 0.0338, 0.0283, 0.0315, 0.0312, 0.0263]
# 2021-09-01 22:08:00,455 - INFO -   |-- [Party 9] Average Train Loss:   0.0412 Train Accuracy: global  86.57% local  99.34% ...  268 forgettables out of 2130 (12.58%) ... total data used 2130
# 2021-09-01 22:08:00,457 - INFO -   |--    Epoch Losses (10): [0.0804, 0.0399, 0.0482, 0.0422, 0.046, 0.036, 0.0359, 0.0249, 0.0285, 0.0296]
# 2021-09-01 22:08:08,749 - INFO -     |---- Number of Forgettables: 7794 (40.66%)
# 2021-09-01 22:08:08,750 - INFO -     |---- Train Accuracy: 62.28%
# 2021-09-01 22:08:08,751 - INFO -     |---- Test Accuracy: 41.21%
# 2021-09-01 22:08:08,752 - INFO -     |---- Test Loss: 1.3054
# 2021-09-01 22:08:08,753 - INFO -     |---- Elapsed time: 5:46:58.118110
# 2021-09-01 22:08:08,754 - INFO -
# Test Acc: Max 41.2122% (188 round) | Last 41.2122% | Avg 31.0621% (51 round)
#
# 2021-09-01 22:08:08,757 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 22:08:19,105 - INFO -   |-- [Party 1] Average Train Loss:   0.0463 Train Accuracy: global  16.71% local  99.39% ... 1762 forgettables out of 2130 (82.72%) ... total data used 2130
# 2021-09-01 22:08:19,107 - INFO -   |--    Epoch Losses (10): [0.0862, 0.0411, 0.0482, 0.0395, 0.0565, 0.0379, 0.0351, 0.0372, 0.0398, 0.0411]
# 2021-09-01 22:08:28,932 - INFO -   |-- [Party 2] Average Train Loss:   0.0376 Train Accuracy: global  15.73% local  99.25% ... 1788 forgettables out of 2130 (83.94%) ... total data used 2130
# 2021-09-01 22:08:28,933 - INFO -   |--    Epoch Losses (10): [0.0776, 0.0478, 0.0405, 0.0341, 0.0277, 0.0277, 0.0294, 0.0281, 0.0283, 0.0342]
# 2021-09-01 22:08:38,921 - INFO -   |-- [Party 3] Average Train Loss:   0.0391 Train Accuracy: global  63.62% local  99.25% ...  766 forgettables out of 2130 (35.96%) ... total data used 2130
# 2021-09-01 22:08:38,922 - INFO -   |--    Epoch Losses (10): [0.0831, 0.0403, 0.044, 0.0335, 0.0292, 0.0309, 0.0344, 0.0313, 0.034, 0.0308]
# 2021-09-01 22:08:49,697 - INFO -   |-- [Party 4] Average Train Loss:   0.0524 Train Accuracy: global  61.97% local  99.01% ...  797 forgettables out of 2130 (37.42%) ... total data used 2130
# 2021-09-01 22:08:49,699 - INFO -   |--    Epoch Losses (10): [0.112, 0.0448, 0.0477, 0.0479, 0.044, 0.0463, 0.0383, 0.051, 0.0425, 0.0494]
# 2021-09-01 22:09:00,580 - INFO -   |-- [Party 5] Average Train Loss:   0.0478 Train Accuracy: global  62.30% local  99.11% ...  793 forgettables out of 2130 (37.23%) ... total data used 2130
# 2021-09-01 22:09:00,581 - INFO -   |--    Epoch Losses (10): [0.0918, 0.0535, 0.0454, 0.0525, 0.0379, 0.0371, 0.0426, 0.0372, 0.0401, 0.0398]
# 2021-09-01 22:09:10,511 - INFO -   |-- [Party 6] Average Train Loss:   0.0423 Train Accuracy: global  83.52% local  99.25% ...  329 forgettables out of 2130 (15.45%) ... total data used 2130
# 2021-09-01 22:09:10,513 - INFO -   |--    Epoch Losses (10): [0.0987, 0.0446, 0.0451, 0.038, 0.0412, 0.0378, 0.0265, 0.0279, 0.0356, 0.028]
# 2021-09-01 22:09:20,630 - INFO -   |-- [Party 7] Average Train Loss:   0.0391 Train Accuracy: global  85.49% local  99.62% ...  301 forgettables out of 2130 (14.13%) ... total data used 2130
# 2021-09-01 22:09:20,632 - INFO -   |--    Epoch Losses (10): [0.0897, 0.0435, 0.0426, 0.0405, 0.0366, 0.0308, 0.0227, 0.0298, 0.0276, 0.0272]
# 2021-09-01 22:09:31,547 - INFO -   |-- [Party 8] Average Train Loss:   0.0385 Train Accuracy: global  85.63% local  99.62% ...  295 forgettables out of 2130 (13.85%) ... total data used 2130
# 2021-09-01 22:09:31,548 - INFO -   |--    Epoch Losses (10): [0.0866, 0.0407, 0.0391, 0.0336, 0.0391, 0.0328, 0.0272, 0.0285, 0.0256, 0.0323]
# 2021-09-01 22:09:41,836 - INFO -   |-- [Party 9] Average Train Loss:   0.0424 Train Accuracy: global  83.94% local  98.92% ...  333 forgettables out of 2130 (15.63%) ... total data used 2130
# 2021-09-01 22:09:41,840 - INFO -   |--    Epoch Losses (10): [0.0893, 0.0431, 0.04, 0.0467, 0.0433, 0.0331, 0.032, 0.0282, 0.0299, 0.0385]
# 2021-09-01 22:09:50,224 - INFO -     |---- Number of Forgettables: 7164 (37.37%)
# 2021-09-01 22:09:50,225 - INFO -     |---- Train Accuracy: 58.61%
# 2021-09-01 22:09:50,226 - INFO -     |---- Test Accuracy: 35.07%
# 2021-09-01 22:09:50,227 - INFO -     |---- Test Loss: 1.4503
# 2021-09-01 22:09:50,227 - INFO -     |---- Elapsed time: 5:48:39.592531
# 2021-09-01 22:09:50,229 - INFO -
# Test Acc: Max 35.0731% (188 round) | Last 35.0731% | Avg 31.0825% (54 round)
#
# 2021-09-01 22:09:50,231 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 22:10:00,165 - INFO -   |-- [Party 1] Average Train Loss:   0.0544 Train Accuracy: global   2.49% local  99.01% ... 2064 forgettables out of 2130 (96.90%) ... total data used 2130
# 2021-09-01 22:10:00,167 - INFO -   |--    Epoch Losses (10): [0.1625, 0.0563, 0.0412, 0.0429, 0.0406, 0.0342, 0.0383, 0.0386, 0.0402, 0.0493]
# 2021-09-01 22:10:11,304 - INFO -   |-- [Party 2] Average Train Loss:   0.0464 Train Accuracy: global   2.11% local  99.86% ... 2069 forgettables out of 2130 (97.14%) ... total data used 2130
# 2021-09-01 22:10:11,306 - INFO -   |--    Epoch Losses (10): [0.1612, 0.0433, 0.0365, 0.0365, 0.0333, 0.0276, 0.0278, 0.0383, 0.0325, 0.0275]
# 2021-09-01 22:10:21,197 - INFO -   |-- [Party 3] Average Train Loss:   0.0392 Train Accuracy: global  56.62% local  99.62% ...  909 forgettables out of 2130 (42.68%) ... total data used 2130
# 2021-09-01 22:10:21,198 - INFO -   |--    Epoch Losses (10): [0.0797, 0.0457, 0.0425, 0.0325, 0.0395, 0.032, 0.0311, 0.0253, 0.0284, 0.0352]
# 2021-09-01 22:10:31,939 - INFO -   |-- [Party 4] Average Train Loss:   0.0505 Train Accuracy: global  56.81% local  99.06% ...  900 forgettables out of 2130 (42.25%) ... total data used 2130
# 2021-09-01 22:10:31,940 - INFO -   |--    Epoch Losses (10): [0.0938, 0.0676, 0.0525, 0.047, 0.0431, 0.0413, 0.0427, 0.0435, 0.0322, 0.041]
# 2021-09-01 22:10:41,808 - INFO -   |-- [Party 5] Average Train Loss:   0.0448 Train Accuracy: global  57.70% local  99.44% ...  884 forgettables out of 2130 (41.50%) ... total data used 2130
# 2021-09-01 22:10:41,809 - INFO -   |--    Epoch Losses (10): [0.0779, 0.0563, 0.0497, 0.0462, 0.0391, 0.0453, 0.0354, 0.0325, 0.0281, 0.0379]
# 2021-09-01 22:10:51,760 - INFO -   |-- [Party 6] Average Train Loss:   0.0379 Train Accuracy: global  87.65% local  99.58% ...  253 forgettables out of 2130 (11.88%) ... total data used 2130
# 2021-09-01 22:10:51,763 - INFO -   |--    Epoch Losses (10): [0.0759, 0.0467, 0.0375, 0.0367, 0.0296, 0.0367, 0.0324, 0.0251, 0.028, 0.0302]
# 2021-09-01 22:11:03,509 - INFO -   |-- [Party 7] Average Train Loss:   0.0338 Train Accuracy: global  88.87% local  99.01% ...  232 forgettables out of 2130 (10.89%) ... total data used 2130
# 2021-09-01 22:11:03,510 - INFO -   |--    Epoch Losses (10): [0.0621, 0.0365, 0.0384, 0.0332, 0.0284, 0.0354, 0.0261, 0.0305, 0.0276, 0.02]
# 2021-09-01 22:11:14,465 - INFO -   |-- [Party 8] Average Train Loss:   0.0385 Train Accuracy: global  89.30% local  99.30% ...  222 forgettables out of 2130 (10.42%) ... total data used 2130
# 2021-09-01 22:11:14,466 - INFO -   |--    Epoch Losses (10): [0.0719, 0.0423, 0.0391, 0.04, 0.029, 0.0377, 0.0251, 0.0387, 0.0314, 0.0301]
# 2021-09-01 22:11:25,311 - INFO -   |-- [Party 9] Average Train Loss:   0.0440 Train Accuracy: global  86.95% local  99.44% ...  268 forgettables out of 2130 (12.58%) ... total data used 2130
# 2021-09-01 22:11:25,312 - INFO -   |--    Epoch Losses (10): [0.0738, 0.0538, 0.0593, 0.0455, 0.0427, 0.0372, 0.0327, 0.0296, 0.0315, 0.0339]
# 2021-09-01 22:11:34,148 - INFO -     |---- Number of Forgettables: 7801 (40.69%)
# 2021-09-01 22:11:34,150 - INFO -     |---- Train Accuracy: 62.81%
# 2021-09-01 22:11:34,151 - INFO -     |---- Test Accuracy: 42.11%
# 2021-09-01 22:11:34,152 - INFO -     |---- Test Loss: 1.2859
# 2021-09-01 22:11:34,153 - INFO -     |---- Elapsed time: 5:50:23.518137
# 2021-09-01 22:11:34,155 - INFO -
# Test Acc: Max 42.1141% (198 round) | Last 42.1141% | Avg 31.1382% (54 round)
#
# 2021-09-01 22:11:34,158 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 22:11:45,195 - INFO -   |-- [Party 1] Average Train Loss:   0.0427 Train Accuracy: global  19.81% local  99.44% ... 1687 forgettables out of 2130 (79.20%) ... total data used 2130
# 2021-09-01 22:11:45,196 - INFO -   |--    Epoch Losses (10): [0.0932, 0.0409, 0.041, 0.0388, 0.0378, 0.0345, 0.0329, 0.033, 0.0348, 0.0397]
# 2021-09-01 22:11:55,156 - INFO -   |-- [Party 2] Average Train Loss:   0.0382 Train Accuracy: global  17.79% local  99.67% ... 1748 forgettables out of 2130 (82.07%) ... total data used 2130
# 2021-09-01 22:11:55,158 - INFO -   |--    Epoch Losses (10): [0.0762, 0.0446, 0.0403, 0.0408, 0.0321, 0.0355, 0.0321, 0.0289, 0.0214, 0.0304]
# 2021-09-01 22:12:05,454 - INFO -   |-- [Party 3] Average Train Loss:   0.0396 Train Accuracy: global  66.43% local  99.53% ...  709 forgettables out of 2130 (33.29%) ... total data used 2130
# 2021-09-01 22:12:05,457 - INFO -   |--    Epoch Losses (10): [0.0775, 0.0481, 0.0318, 0.0408, 0.0347, 0.0278, 0.0456, 0.0284, 0.0334, 0.0281]
# 2021-09-01 22:12:15,314 - INFO -   |-- [Party 4] Average Train Loss:   0.0540 Train Accuracy: global  63.33% local  99.20% ...  765 forgettables out of 2130 (35.92%) ... total data used 2130
# 2021-09-01 22:12:15,316 - INFO -   |--    Epoch Losses (10): [0.1042, 0.0647, 0.0523, 0.0472, 0.0474, 0.045, 0.0435, 0.0344, 0.0517, 0.0496]
# 2021-09-01 22:12:25,128 - INFO -   |-- [Party 5] Average Train Loss:   0.0503 Train Accuracy: global  65.92% local  99.11% ...  719 forgettables out of 2130 (33.76%) ... total data used 2130
# 2021-09-01 22:12:25,130 - INFO -   |--    Epoch Losses (10): [0.0942, 0.0552, 0.0437, 0.0516, 0.058, 0.0383, 0.0378, 0.0455, 0.0392, 0.0398]
# 2021-09-01 22:12:34,938 - INFO -   |-- [Party 6] Average Train Loss:   0.0413 Train Accuracy: global  82.63% local  99.34% ...  362 forgettables out of 2130 (17.00%) ... total data used 2130
# 2021-09-01 22:12:34,940 - INFO -   |--    Epoch Losses (10): [0.1077, 0.0432, 0.0459, 0.0288, 0.0366, 0.0269, 0.039, 0.0278, 0.027, 0.0301]
# 2021-09-01 22:12:44,766 - INFO -   |-- [Party 7] Average Train Loss:   0.0387 Train Accuracy: global  84.18% local  99.77% ...  321 forgettables out of 2130 (15.07%) ... total data used 2130
# 2021-09-01 22:12:44,768 - INFO -   |--    Epoch Losses (10): [0.1066, 0.0426, 0.0318, 0.0333, 0.03, 0.0361, 0.0325, 0.0238, 0.0222, 0.028]
# 2021-09-01 22:12:54,992 - INFO -   |-- [Party 8] Average Train Loss:   0.0381 Train Accuracy: global  82.63% local  99.58% ...  359 forgettables out of 2130 (16.85%) ... total data used 2130
# 2021-09-01 22:12:54,994 - INFO -   |--    Epoch Losses (10): [0.1027, 0.0438, 0.0285, 0.0362, 0.0343, 0.0302, 0.0335, 0.0233, 0.0232, 0.0256]
# 2021-09-01 22:13:04,832 - INFO -   |-- [Party 9] Average Train Loss:   0.0449 Train Accuracy: global  81.55% local  99.44% ...  383 forgettables out of 2130 (17.98%) ... total data used 2130
# 2021-09-01 22:13:04,835 - INFO -   |--    Epoch Losses (10): [0.1157, 0.0445, 0.0392, 0.0393, 0.0321, 0.041, 0.0371, 0.0363, 0.0364, 0.0277]
# 2021-09-01 22:13:13,113 - INFO -     |---- Number of Forgettables: 7053 (36.79%)
# 2021-09-01 22:13:13,115 - INFO -     |---- Train Accuracy: 58.44%
# 2021-09-01 22:13:13,116 - INFO -     |---- Test Accuracy: 35.13%
# 2021-09-01 22:13:13,117 - INFO -     |---- Test Loss: 1.4703
# 2021-09-01 22:13:13,117 - INFO -     |---- Elapsed time: 5:52:02.482410
# 2021-09-01 22:13:13,119 - INFO -
# Test Acc: Max 35.1272% (198 round) | Last 35.1272% | Avg 31.1583% (54 round)
#
# 2021-09-01 22:13:13,124 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 22:13:24,305 - INFO -   |-- [Party 1] Average Train Loss:   0.0531 Train Accuracy: global   1.78% local  99.39% ... 2080 forgettables out of 2130 (97.65%) ... total data used 2130
# 2021-09-01 22:13:24,306 - INFO -   |--    Epoch Losses (10): [0.2, 0.0479, 0.0396, 0.0385, 0.0367, 0.0367, 0.0295, 0.0329, 0.0327, 0.0367]
# 2021-09-01 22:13:34,109 - INFO -   |-- [Party 2] Average Train Loss:   0.0446 Train Accuracy: global   1.74% local  99.58% ... 2086 forgettables out of 2130 (97.93%) ... total data used 2130
# 2021-09-01 22:13:34,110 - INFO -   |--    Epoch Losses (10): [0.1654, 0.0422, 0.0363, 0.0306, 0.0323, 0.0223, 0.029, 0.0342, 0.0281, 0.0255]
# 2021-09-01 22:13:45,136 - INFO -   |-- [Party 3] Average Train Loss:   0.0378 Train Accuracy: global  55.07% local  99.39% ...  948 forgettables out of 2130 (44.51%) ... total data used 2130
# 2021-09-01 22:13:45,138 - INFO -   |--    Epoch Losses (10): [0.0791, 0.0381, 0.0375, 0.0361, 0.0384, 0.0291, 0.0314, 0.032, 0.0287, 0.0271]
# 2021-09-01 22:13:54,989 - INFO -   |-- [Party 4] Average Train Loss:   0.0491 Train Accuracy: global  55.49% local  99.44% ...  935 forgettables out of 2130 (43.90%) ... total data used 2130
# 2021-09-01 22:13:54,992 - INFO -   |--    Epoch Losses (10): [0.0949, 0.0532, 0.0561, 0.0448, 0.0475, 0.037, 0.0425, 0.0458, 0.0374, 0.0311]
# 2021-09-01 22:14:04,814 - INFO -   |-- [Party 5] Average Train Loss:   0.0458 Train Accuracy: global  56.29% local  99.53% ...  917 forgettables out of 2130 (43.05%) ... total data used 2130
# 2021-09-01 22:14:04,816 - INFO -   |--    Epoch Losses (10): [0.084, 0.0498, 0.0555, 0.0414, 0.0417, 0.044, 0.0351, 0.0368, 0.0317, 0.0376]
# 2021-09-01 22:14:14,728 - INFO -   |-- [Party 6] Average Train Loss:   0.0401 Train Accuracy: global  89.06% local  99.58% ...  226 forgettables out of 2130 (10.61%) ... total data used 2130
# 2021-09-01 22:14:14,729 - INFO -   |--    Epoch Losses (10): [0.0655, 0.0562, 0.0439, 0.0367, 0.0394, 0.0422, 0.0343, 0.0296, 0.0259, 0.0271]
# 2021-09-01 22:14:24,952 - INFO -   |-- [Party 7] Average Train Loss:   0.0357 Train Accuracy: global  89.67% local  99.58% ...  216 forgettables out of 2130 (10.14%) ... total data used 2130
# 2021-09-01 22:14:24,954 - INFO -   |--    Epoch Losses (10): [0.0589, 0.0489, 0.0317, 0.0309, 0.0304, 0.0387, 0.036, 0.0223, 0.0299, 0.0291]
# 2021-09-01 22:14:36,049 - INFO -   |-- [Party 8] Average Train Loss:   0.0367 Train Accuracy: global  89.58% local  99.62% ...  216 forgettables out of 2130 (10.14%) ... total data used 2130
# 2021-09-01 22:14:36,051 - INFO -   |--    Epoch Losses (10): [0.0717, 0.0455, 0.0463, 0.0359, 0.0332, 0.0316, 0.0237, 0.0292, 0.0284, 0.0215]
# 2021-09-01 22:14:46,007 - INFO -   |-- [Party 9] Average Train Loss:   0.0417 Train Accuracy: global  88.36% local  99.48% ...  239 forgettables out of 2130 (11.22%) ... total data used 2130
# 2021-09-01 22:14:46,009 - INFO -   |--    Epoch Losses (10): [0.0709, 0.0473, 0.0483, 0.0342, 0.04, 0.0368, 0.0321, 0.034, 0.0354, 0.0385]
# 2021-09-01 22:14:54,259 - INFO -     |---- Number of Forgettables: 7863 (41.02%)
# 2021-09-01 22:14:54,261 - INFO -     |---- Train Accuracy: 62.20%
# 2021-09-01 22:14:54,262 - INFO -     |---- Test Accuracy: 42.10%
# 2021-09-01 22:14:54,262 - INFO -     |---- Test Loss: 1.2803
# 2021-09-01 22:14:54,263 - INFO -     |---- Elapsed time: 5:53:43.628406
# 2021-09-01 22:14:54,264 - INFO -
# Test Acc: Max 42.1021% (198 round) | Last 42.1021% | Avg 31.2130% (54 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

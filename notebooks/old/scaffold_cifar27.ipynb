# %%
# %matplotlib inline

dataset = 'cifar10'
clsimb = [2, 7] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_scaffold'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 0

# %%
import copy
import json
import logging
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Files already downloaded and verified

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
def average_weights(w):
    w_avg = copy.deepcopy(w[0])
        
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
    return w_avg

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, other_models):
    epoch_losses = []
    
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    
    # SCAFFOLD
    global_model, c_global_model, c_local_model = other_models[0], other_models[1], other_models[2]
    c_global_state, c_local_state = c_global_model.state_dict(), c_local_model.state_dict()
    cnt = 0
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())
            
            # SCAFFOLD
            local_state = model.state_dict()
            for  k in local_state:
                local_state[k] = local_state[k] - (lr * (c_global_state[k] - c_local_state[k]))
            model.load_state_dict(local_state)
            cnt += 1

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    # SCAFFOLD        
    new_c_local_state = c_local_model.state_dict()
    c_delta_state = copy.deepcopy(new_c_local_state)
    local_state, global_state = model.state_dict(), global_model.state_dict()
    for k in local_state:
        new_c_local_state[k] = new_c_local_state[k] + ((global_state[k] - local_state[k]) / (lr * cnt) - c_global_state[k])
        c_delta_state[k] = new_c_local_state[k] - c_local_state[k]
    c_local_model.load_state_dict(new_c_local_state)
    
    local_weights = model.state_dict()

    return local_weights, epoch_losses, c_delta_state

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0

logger.info(f'\nAlgorithm: Scaffold\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

# SCAFFOLD
c_fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
c_fed_model.to(device)

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    # SCAFFOLD
    other_models = [fed_model, c_fed_model, copy.deepcopy(c_fed_model)]
    delta_state = copy.deepcopy(fed_model.state_dict())
    for k in delta_state:
        delta_state[k] = 0.0
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls, c_delta_state = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, other_models)

        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
        # SCAFFOLD
        for k in c_delta_state:
            delta_state[k] = delta_state[k] + c_delta_state[k]
        
    fed_weights = average_weights(local_weights)
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    # SCAFFOLD
    c_global_state = c_fed_model.state_dict()
    for k in delta_state:
        c_global_state[k] = c_global_state[k] + (delta_state[k] / sum(clsimb))
    c_fed_model.load_state_dict(c_global_state)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 13:39:51,180 - INFO -
# Algorithm: Scaffold
# Client Split: [2, 7]
# Dataset: cifar10
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 13:39:51,246 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 13:40:02,969 - INFO -   |-- [Party 1] Average Train Loss:   0.3835 Train Accuracy: global   0.00% local  90.48% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:40:02,970 - INFO -   |--    Epoch Losses (10): [0.9496, 0.4562, 0.3928, 0.3545, 0.2978, 0.3091, 0.2824, 0.2906, 0.2631, 0.239]
# 2021-09-01 13:40:15,489 - INFO -   |-- [Party 2] Average Train Loss:   0.3853 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:40:15,493 - INFO -   |--    Epoch Losses (10): [0.9707, 0.4489, 0.3791, 0.3456, 0.331, 0.2938, 0.2812, 0.269, 0.2734, 0.2598]
# 2021-09-01 13:40:25,785 - INFO -   |-- [Party 3] Average Train Loss:   0.5660 Train Accuracy: global   0.00% local  74.16% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:40:25,787 - INFO -   |--    Epoch Losses (10): [1.0261, 0.5757, 0.5542, 0.54, 0.5124, 0.5097, 0.4847, 0.4843, 0.4789, 0.4942]
# 2021-09-01 13:40:36,081 - INFO -   |-- [Party 4] Average Train Loss:   0.5256 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:40:36,084 - INFO -   |--    Epoch Losses (10): [1.0868, 0.5426, 0.5111, 0.4799, 0.4747, 0.4801, 0.4347, 0.4138, 0.4037, 0.4282]
# 2021-09-01 13:40:47,055 - INFO -   |-- [Party 5] Average Train Loss:   0.6073 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:40:47,057 - INFO -   |--    Epoch Losses (10): [1.1113, 0.6248, 0.5856, 0.5633, 0.5547, 0.5482, 0.5321, 0.5543, 0.5114, 0.4871]
# 2021-09-01 13:40:57,490 - INFO -   |-- [Party 6] Average Train Loss:   0.6040 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:40:57,493 - INFO -   |--    Epoch Losses (10): [1.129, 0.6016, 0.5618, 0.5413, 0.5703, 0.5404, 0.5434, 0.5166, 0.5072, 0.5282]
# 2021-09-01 13:41:08,893 - INFO -   |-- [Party 7] Average Train Loss:   0.5383 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:41:08,895 - INFO -   |--    Epoch Losses (10): [1.1169, 0.5143, 0.5087, 0.4784, 0.4997, 0.4727, 0.427, 0.476, 0.462, 0.4278]
# 2021-09-01 13:41:21,480 - INFO -   |-- [Party 8] Average Train Loss:   0.5733 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:41:21,482 - INFO -   |--    Epoch Losses (10): [1.1938, 0.5558, 0.528, 0.5504, 0.5308, 0.5138, 0.5113, 0.4489, 0.4533, 0.4468]
# 2021-09-01 13:41:33,540 - INFO -   |-- [Party 9] Average Train Loss:   0.5952 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:41:33,544 - INFO -   |--    Epoch Losses (10): [1.1799, 0.5666, 0.589, 0.5923, 0.5418, 0.5253, 0.524, 0.4788, 0.492, 0.4623]
# 2021-09-01 13:41:40,128 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 13:41:40,130 - INFO -     |---- Train Accuracy: 38.89%
# 2021-09-01 13:41:40,131 - INFO -     |---- Test Accuracy: 25.00%
# 2021-09-01 13:41:40,132 - INFO -     |---- Test Loss: 2.0719
# 2021-09-01 13:41:40,133 - INFO -     |---- Elapsed time: 0:01:48.888058
# 2021-09-01 13:41:40,134 - INFO -
# Test Acc: Max 25.0000% (1 round) | Last 25.0000% | Avg 25.0000% (1 round)
#
# 2021-09-01 13:41:40,141 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 13:41:52,369 - INFO -   |-- [Party 1] Average Train Loss:   0.3928 Train Accuracy: global   0.00% local  90.13% ... 1292 forgettables out of 1428 (90.48%) ... total data used 1428
# 2021-09-01 13:41:52,372 - INFO -   |--    Epoch Losses (10): [1.1425, 0.4098, 0.384, 0.3451, 0.3126, 0.2838, 0.2607, 0.3052, 0.2624, 0.222]
# 2021-09-01 13:42:04,794 - INFO -   |-- [Party 2] Average Train Loss:   0.4382 Train Accuracy: global   0.00% local  87.96% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:42:04,797 - INFO -   |--    Epoch Losses (10): [1.2012, 0.4523, 0.3986, 0.3577, 0.3511, 0.3307, 0.339, 0.3557, 0.3165, 0.2792]
# 2021-09-01 13:42:15,241 - INFO -   |-- [Party 3] Average Train Loss:   0.5468 Train Accuracy: global  50.00% local   0.00% ...  497 forgettables out of 1428 (34.80%) ... total data used 1428
# 2021-09-01 13:42:15,244 - INFO -   |--    Epoch Losses (10): [0.7302, 0.5742, 0.5565, 0.5455, 0.5289, 0.4978, 0.5081, 0.5234, 0.5146, 0.4891]
# 2021-09-01 13:42:27,120 - INFO -   |-- [Party 4] Average Train Loss:   0.4889 Train Accuracy: global  50.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:42:27,122 - INFO -   |--    Epoch Losses (10): [0.7493, 0.53, 0.5063, 0.5127, 0.4876, 0.4647, 0.4284, 0.3923, 0.393, 0.4241]
# 2021-09-01 13:42:37,579 - INFO -   |-- [Party 5] Average Train Loss:   0.5346 Train Accuracy: global  50.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:42:37,581 - INFO -   |--    Epoch Losses (10): [0.7946, 0.5719, 0.5484, 0.5356, 0.5002, 0.4969, 0.4948, 0.51, 0.4485, 0.4447]
# 2021-09-01 13:42:48,055 - INFO -   |-- [Party 6] Average Train Loss:   0.5263 Train Accuracy: global  50.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:42:48,056 - INFO -   |--    Epoch Losses (10): [0.7441, 0.5634, 0.5242, 0.5301, 0.5335, 0.5093, 0.4858, 0.4742, 0.4346, 0.4638]
# 2021-09-01 13:42:58,767 - INFO -   |-- [Party 7] Average Train Loss:   0.4677 Train Accuracy: global  50.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:42:58,771 - INFO -   |--    Epoch Losses (10): [0.6678, 0.5134, 0.4579, 0.4861, 0.4566, 0.4436, 0.4303, 0.393, 0.4251, 0.4028]
# 2021-09-01 13:43:10,450 - INFO -   |-- [Party 8] Average Train Loss:   0.5335 Train Accuracy: global  50.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:43:10,454 - INFO -   |--    Epoch Losses (10): [0.7238, 0.6012, 0.5468, 0.5217, 0.5167, 0.515, 0.4951, 0.5026, 0.4737, 0.4385]
# 2021-09-01 13:43:21,229 - INFO -   |-- [Party 9] Average Train Loss:   0.5047 Train Accuracy: global  50.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:43:21,232 - INFO -   |--    Epoch Losses (10): [0.735, 0.5486, 0.505, 0.4894, 0.4907, 0.4473, 0.4369, 0.5208, 0.4352, 0.4378]
# 2021-09-01 13:43:27,876 - INFO -     |---- Number of Forgettables: 1789 (13.92%)
# 2021-09-01 13:43:27,878 - INFO -     |---- Train Accuracy: 0.00%
# 2021-09-01 13:43:27,879 - INFO -     |---- Test Accuracy: 0.00%
# 2021-09-01 13:43:27,880 - INFO -     |---- Test Loss: nan
# 2021-09-01 13:43:27,881 - INFO -     |---- Elapsed time: 0:03:36.636173
# 2021-09-01 13:43:27,882 - INFO -
# Test Acc: Max 0.0000% (1 round) | Last 0.0000% | Avg 12.5000% (1 round)
#
# 2021-09-01 13:43:27,885 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 13:43:39,282 - INFO -   |-- [Party 1] Average Train Loss:   0.5343 Train Accuracy: global   0.00% local  90.62% ... 1287 forgettables out of 1428 (90.13%) ... total data used 1428
# 2021-09-01 13:43:39,285 - INFO -   |--    Epoch Losses (10): [2.2948, 0.4675, 0.4041, 0.3849, 0.3608, 0.3339, 0.3063, 0.2761, 0.2583, 0.2565]
# 2021-09-01 13:43:51,446 - INFO -   |-- [Party 2] Average Train Loss:   0.6226 Train Accuracy: global   0.00% local  85.50% ... 1256 forgettables out of 1428 (87.96%) ... total data used 1428
# 2021-09-01 13:43:51,449 - INFO -   |--    Epoch Losses (10): [2.5463, 0.5965, 0.4797, 0.4211, 0.3815, 0.4022, 0.3445, 0.3473, 0.3656, 0.3412]
# 2021-09-01 13:44:02,137 - INFO -   |-- [Party 3] Average Train Loss:   0.5270 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:44:02,139 - INFO -   |--    Epoch Losses (10): [0.6916, 0.5548, 0.5504, 0.5263, 0.5383, 0.5156, 0.4674, 0.4663, 0.4836, 0.4761]
# 2021-09-01 13:44:13,990 - INFO -   |-- [Party 4] Average Train Loss:   0.4860 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:44:13,994 - INFO -   |--    Epoch Losses (10): [0.6734, 0.5711, 0.5262, 0.4961, 0.4906, 0.4463, 0.4407, 0.4309, 0.4003, 0.3849]
# 2021-09-01 13:44:25,920 - INFO -   |-- [Party 5] Average Train Loss:   0.5022 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:44:25,921 - INFO -   |--    Epoch Losses (10): [0.6553, 0.5437, 0.5186, 0.5037, 0.5255, 0.5176, 0.4521, 0.4537, 0.4407, 0.4115]
# 2021-09-01 13:44:37,837 - INFO -   |-- [Party 6] Average Train Loss:   0.4705 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:44:37,838 - INFO -   |--    Epoch Losses (10): [0.6164, 0.5174, 0.4803, 0.4741, 0.4654, 0.454, 0.4483, 0.4159, 0.4186, 0.415]
# 2021-09-01 13:44:50,363 - INFO -   |-- [Party 7] Average Train Loss:   0.4638 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:44:50,366 - INFO -   |--    Epoch Losses (10): [0.6262, 0.5347, 0.4712, 0.4813, 0.4561, 0.4171, 0.401, 0.4313, 0.3992, 0.4203]
# 2021-09-01 13:45:02,657 - INFO -   |-- [Party 8] Average Train Loss:   0.4710 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:45:02,659 - INFO -   |--    Epoch Losses (10): [0.6109, 0.5184, 0.5016, 0.4857, 0.4736, 0.4399, 0.4458, 0.4115, 0.4075, 0.4145]
# 2021-09-01 13:45:14,360 - INFO -   |-- [Party 9] Average Train Loss:   0.4602 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:45:14,361 - INFO -   |--    Epoch Losses (10): [0.6074, 0.4913, 0.4791, 0.4734, 0.4578, 0.4262, 0.4178, 0.4207, 0.4234, 0.4048]
# 2021-09-01 13:45:21,163 - INFO -     |---- Number of Forgettables: 2543 (19.79%)
# 2021-09-01 13:45:21,164 - INFO -     |---- Train Accuracy: 0.00%
# 2021-09-01 13:45:21,165 - INFO -     |---- Test Accuracy: 0.00%
# 2021-09-01 13:45:21,166 - INFO -     |---- Test Loss: nan
# 2021-09-01 13:45:21,167 - INFO -     |---- Elapsed time: 0:05:29.922266
# 2021-09-01 13:45:21,168 - INFO -
# Test Acc: Max 0.0000% (1 round) | Last 0.0000% | Avg 8.3333% (1 round)
#
# 2021-09-01 13:45:21,171 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 13:45:33,579 - INFO -   |-- [Party 1] Average Train Loss:   0.8556 Train Accuracy: global   0.00% local  79.62% ... 1294 forgettables out of 1428 (90.62%) ... total data used 1428
# 2021-09-01 13:45:33,583 - INFO -   |--    Epoch Losses (10): [4.4396, 0.8144, 0.5037, 0.4449, 0.4325, 0.4132, 0.4199, 0.4112, 0.3447, 0.3312]
# 2021-09-01 13:45:46,040 - INFO -   |-- [Party 2] Average Train Loss:   1.0248 Train Accuracy: global   0.00% local   0.00% ... 1221 forgettables out of 1428 (85.50%) ... total data used 1428
# 2021-09-01 13:45:46,042 - INFO -   |--    Epoch Losses (10): [5.1221, 1.5143, 0.73, 0.5116, 0.4946, 0.438, 0.4128, 0.3768, 0.3378, 0.3102]
# 2021-09-01 13:45:56,971 - INFO -   |-- [Party 3] Average Train Loss:   0.4508 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:45:56,973 - INFO -   |--    Epoch Losses (10): [0.5501, 0.4804, 0.4743, 0.4693, 0.4566, 0.4242, 0.4082, 0.4513, 0.4054, 0.3884]
# 2021-09-01 13:46:08,964 - INFO -   |-- [Party 4] Average Train Loss:   0.4350 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:46:08,965 - INFO -   |--    Epoch Losses (10): [0.5584, 0.4877, 0.4583, 0.4267, 0.4238, 0.4453, 0.4196, 0.3977, 0.3638, 0.3692]
# 2021-09-01 13:46:21,104 - INFO -   |-- [Party 5] Average Train Loss:   0.4650 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:46:21,106 - INFO -   |--    Epoch Losses (10): [0.5748, 0.5115, 0.5025, 0.4973, 0.4501, 0.4162, 0.4371, 0.4572, 0.4181, 0.3854]
# 2021-09-01 13:46:33,809 - INFO -   |-- [Party 6] Average Train Loss:   0.4576 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:46:33,813 - INFO -   |--    Epoch Losses (10): [0.5521, 0.5059, 0.4775, 0.4838, 0.4421, 0.4459, 0.4428, 0.4394, 0.3974, 0.3893]
# 2021-09-01 13:46:44,913 - INFO -   |-- [Party 7] Average Train Loss:   0.4321 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:46:44,915 - INFO -   |--    Epoch Losses (10): [0.5276, 0.4724, 0.4499, 0.4414, 0.4197, 0.4372, 0.3872, 0.3984, 0.3886, 0.3983]
# 2021-09-01 13:46:56,442 - INFO -   |-- [Party 8] Average Train Loss:   0.4583 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:46:56,444 - INFO -   |--    Epoch Losses (10): [0.5542, 0.4811, 0.4728, 0.4385, 0.4848, 0.4836, 0.4363, 0.4265, 0.3982, 0.4067]
# 2021-09-01 13:47:07,614 - INFO -   |-- [Party 9] Average Train Loss:   0.4414 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:47:07,616 - INFO -   |--    Epoch Losses (10): [0.5179, 0.5123, 0.4626, 0.468, 0.4351, 0.4084, 0.4471, 0.4193, 0.3809, 0.3624]
# 2021-09-01 13:47:14,420 - INFO -     |---- Number of Forgettables: 2515 (19.57%)
# 2021-09-01 13:47:14,422 - INFO -     |---- Train Accuracy: 47.18%
# 2021-09-01 13:47:14,423 - INFO -     |---- Test Accuracy: 30.23%
# 2021-09-01 13:47:14,424 - INFO -     |---- Test Loss: 5.7298
# 2021-09-01 13:47:14,425 - INFO -     |---- Elapsed time: 0:07:23.179971
# 2021-09-01 13:47:14,426 - INFO -
# Test Acc: Max 30.2250% (4 round) | Last 30.2250% | Avg 13.8063% (1 round)
#
# 2021-09-01 13:47:14,431 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 13:47:25,553 - INFO -   |-- [Party 1] Average Train Loss:   1.3391 Train Accuracy: global   0.00% local  77.59% ... 1137 forgettables out of 1428 (79.62%) ... total data used 1428
# 2021-09-01 13:47:25,557 - INFO -   |--    Epoch Losses (10): [6.8854, 2.218, 1.0988, 0.6086, 0.5094, 0.4942, 0.4173, 0.3944, 0.3973, 0.3677]
# 2021-09-01 13:47:38,150 - INFO -   |-- [Party 2] Average Train Loss:   1.9141 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:47:38,152 - INFO -   |--    Epoch Losses (10): [7.7037, 3.0408, 2.2276, 1.6456, 1.2245, 0.9237, 0.7295, 0.6014, 0.5521, 0.4919]
# 2021-09-01 13:47:49,543 - INFO -   |-- [Party 3] Average Train Loss:   0.4567 Train Accuracy: global  59.73% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:47:49,545 - INFO -   |--    Epoch Losses (10): [0.5497, 0.5024, 0.4931, 0.466, 0.4755, 0.4394, 0.4193, 0.4237, 0.4032, 0.3943]
# 2021-09-01 13:48:01,641 - INFO -   |-- [Party 4] Average Train Loss:   0.4096 Train Accuracy: global  59.87% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:48:01,643 - INFO -   |--    Epoch Losses (10): [0.522, 0.4516, 0.4488, 0.4195, 0.403, 0.376, 0.3825, 0.3831, 0.3736, 0.3362]
# 2021-09-01 13:48:12,838 - INFO -   |-- [Party 5] Average Train Loss:   0.4351 Train Accuracy: global  59.24% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:48:12,841 - INFO -   |--    Epoch Losses (10): [0.5267, 0.5003, 0.4653, 0.437, 0.4158, 0.4201, 0.4041, 0.3848, 0.4069, 0.3894]
# 2021-09-01 13:48:24,737 - INFO -   |-- [Party 6] Average Train Loss:   0.4391 Train Accuracy: global  60.64% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:48:24,741 - INFO -   |--    Epoch Losses (10): [0.5067, 0.4728, 0.4538, 0.4335, 0.4504, 0.4374, 0.4194, 0.4033, 0.4178, 0.3961]
# 2021-09-01 13:48:37,538 - INFO -   |-- [Party 7] Average Train Loss:   0.4004 Train Accuracy: global  60.64% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:48:37,542 - INFO -   |--    Epoch Losses (10): [0.5136, 0.4528, 0.4322, 0.4223, 0.4141, 0.3838, 0.355, 0.3354, 0.3505, 0.3442]
# 2021-09-01 13:48:50,178 - INFO -   |-- [Party 8] Average Train Loss:   0.4245 Train Accuracy: global  61.76% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:48:50,180 - INFO -   |--    Epoch Losses (10): [0.5232, 0.4794, 0.4654, 0.417, 0.4014, 0.4022, 0.4054, 0.3696, 0.4009, 0.3801]
# 2021-09-01 13:49:02,368 - INFO -   |-- [Party 9] Average Train Loss:   0.4158 Train Accuracy: global  62.04% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:49:02,370 - INFO -   |--    Epoch Losses (10): [0.4943, 0.4503, 0.4185, 0.4246, 0.4259, 0.403, 0.3825, 0.3682, 0.3906, 0.4003]
# 2021-09-01 13:49:09,126 - INFO -     |---- Number of Forgettables: 1137 (8.85%)
# 2021-09-01 13:49:09,127 - INFO -     |---- Train Accuracy: 56.62%
# 2021-09-01 13:49:09,127 - INFO -     |---- Test Accuracy: 36.65%
# 2021-09-01 13:49:09,128 - INFO -     |---- Test Loss: 7.0454
# 2021-09-01 13:49:09,128 - INFO -     |---- Elapsed time: 0:09:17.883458
# 2021-09-01 13:49:09,129 - INFO -
# Test Acc: Max 36.6500% (5 round) | Last 36.6500% | Avg 18.3750% (1 round)
#
# 2021-09-01 13:49:09,132 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 13:49:21,630 - INFO -   |-- [Party 1] Average Train Loss:   1.9793 Train Accuracy: global   0.00% local  82.98% ... 1108 forgettables out of 1428 (77.59%) ... total data used 1428
# 2021-09-01 13:49:21,632 - INFO -   |--    Epoch Losses (10): [9.2734, 3.1726, 2.2013, 1.5338, 1.0081, 0.6688, 0.5527, 0.5014, 0.4626, 0.4188]
# 2021-09-01 13:49:33,454 - INFO -   |-- [Party 2] Average Train Loss:   3.2955 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:49:33,458 - INFO -   |--    Epoch Losses (10): [10.5177, 4.201, 2.9314, 2.6331, 2.3482, 2.2641, 2.2017, 2.1058, 1.9736, 1.7788]
# 2021-09-01 13:49:44,428 - INFO -   |-- [Party 3] Average Train Loss:   0.4356 Train Accuracy: global  70.87% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:49:44,430 - INFO -   |--    Epoch Losses (10): [0.5071, 0.4602, 0.4602, 0.4664, 0.4914, 0.4331, 0.4046, 0.3715, 0.3789, 0.3829]
# 2021-09-01 13:49:55,375 - INFO -   |-- [Party 4] Average Train Loss:   0.3840 Train Accuracy: global  71.85% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:49:55,377 - INFO -   |--    Epoch Losses (10): [0.4634, 0.4355, 0.4105, 0.4014, 0.3703, 0.387, 0.3432, 0.3239, 0.3477, 0.3572]
# 2021-09-01 13:50:07,613 - INFO -   |-- [Party 5] Average Train Loss:   0.4192 Train Accuracy: global  73.81% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:50:07,614 - INFO -   |--    Epoch Losses (10): [0.4825, 0.4748, 0.4291, 0.4201, 0.4241, 0.4207, 0.393, 0.3991, 0.3626, 0.3864]
# 2021-09-01 13:50:19,574 - INFO -   |-- [Party 6] Average Train Loss:   0.4335 Train Accuracy: global  72.55% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:50:19,576 - INFO -   |--    Epoch Losses (10): [0.4613, 0.4448, 0.492, 0.4691, 0.4496, 0.4285, 0.4185, 0.3906, 0.3938, 0.3866]
# 2021-09-01 13:50:32,111 - INFO -   |-- [Party 7] Average Train Loss:   0.3940 Train Accuracy: global  73.67% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:50:32,114 - INFO -   |--    Epoch Losses (10): [0.4497, 0.4089, 0.4032, 0.4043, 0.4223, 0.3893, 0.387, 0.342, 0.3465, 0.387]
# 2021-09-01 13:50:43,529 - INFO -   |-- [Party 8] Average Train Loss:   0.3942 Train Accuracy: global  73.25% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:50:43,531 - INFO -   |--    Epoch Losses (10): [0.4402, 0.4254, 0.4324, 0.4111, 0.3636, 0.3932, 0.3856, 0.3904, 0.3703, 0.3298]
# 2021-09-01 13:50:56,069 - INFO -   |-- [Party 9] Average Train Loss:   0.3884 Train Accuracy: global  74.93% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:50:56,072 - INFO -   |--    Epoch Losses (10): [0.4618, 0.4065, 0.3999, 0.4102, 0.3889, 0.3852, 0.3776, 0.329, 0.3546, 0.3699]
# 2021-09-01 13:51:02,785 - INFO -     |---- Number of Forgettables: 1108 (8.62%)
# 2021-09-01 13:51:02,786 - INFO -     |---- Train Accuracy: 60.67%
# 2021-09-01 13:51:02,787 - INFO -     |---- Test Accuracy: 38.77%
# 2021-09-01 13:51:02,788 - INFO -     |---- Test Loss: 7.8480
# 2021-09-01 13:51:02,789 - INFO -     |---- Elapsed time: 0:11:11.543885
# 2021-09-01 13:51:02,790 - INFO -
# Test Acc: Max 38.7750% (6 round) | Last 38.7750% | Avg 21.7750% (1 round)
#
# 2021-09-01 13:51:02,792 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 13:51:15,932 - INFO -   |-- [Party 1] Average Train Loss:   2.6368 Train Accuracy: global   0.00% local  73.53% ... 1185 forgettables out of 1428 (82.98%) ... total data used 1428
# 2021-09-01 13:51:15,936 - INFO -   |--    Epoch Losses (10): [11.2245, 3.7171, 2.5883, 2.1613, 1.8334, 1.4392, 1.0945, 0.8662, 0.7653, 0.6781]
# 2021-09-01 13:51:27,931 - INFO -   |-- [Party 2] Average Train Loss:   3.7929 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:51:27,933 - INFO -   |--    Epoch Losses (10): [12.5288, 4.9658, 3.3205, 2.7949, 2.5378, 2.4203, 2.3869, 2.3647, 2.329, 2.2801]
# 2021-09-01 13:51:40,365 - INFO -   |-- [Party 3] Average Train Loss:   0.4244 Train Accuracy: global  77.66% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:51:40,369 - INFO -   |--    Epoch Losses (10): [0.5002, 0.4738, 0.4365, 0.4379, 0.4218, 0.4216, 0.3863, 0.4047, 0.3952, 0.3657]
# 2021-09-01 13:51:51,410 - INFO -   |-- [Party 4] Average Train Loss:   0.3626 Train Accuracy: global  79.13% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:51:51,413 - INFO -   |--    Epoch Losses (10): [0.4521, 0.4227, 0.3837, 0.3491, 0.3529, 0.3251, 0.3117, 0.3312, 0.3634, 0.3344]
# 2021-09-01 13:52:02,429 - INFO -   |-- [Party 5] Average Train Loss:   0.3890 Train Accuracy: global  77.66% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:52:02,433 - INFO -   |--    Epoch Losses (10): [0.4623, 0.4126, 0.4134, 0.3935, 0.4244, 0.398, 0.348, 0.3427, 0.3366, 0.3581]
# 2021-09-01 13:52:13,509 - INFO -   |-- [Party 6] Average Train Loss:   0.4180 Train Accuracy: global  76.26% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:52:13,512 - INFO -   |--    Epoch Losses (10): [0.4829, 0.4387, 0.4416, 0.4388, 0.4135, 0.407, 0.4171, 0.3796, 0.3685, 0.3929]
# 2021-09-01 13:52:24,464 - INFO -   |-- [Party 7] Average Train Loss:   0.3753 Train Accuracy: global  80.18% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:52:24,467 - INFO -   |--    Epoch Losses (10): [0.413, 0.4038, 0.3954, 0.3751, 0.3569, 0.3562, 0.3847, 0.3637, 0.3546, 0.3495]
# 2021-09-01 13:52:36,138 - INFO -   |-- [Party 8] Average Train Loss:   0.3921 Train Accuracy: global  76.89% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:52:36,140 - INFO -   |--    Epoch Losses (10): [0.4745, 0.4262, 0.4008, 0.4155, 0.3849, 0.3893, 0.3278, 0.3621, 0.3763, 0.3637]
# 2021-09-01 13:52:48,282 - INFO -   |-- [Party 9] Average Train Loss:   0.3728 Train Accuracy: global  80.11% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:52:48,284 - INFO -   |--    Epoch Losses (10): [0.424, 0.3765, 0.3818, 0.3734, 0.3764, 0.3874, 0.3786, 0.3613, 0.3557, 0.313]
# 2021-09-01 13:52:55,139 - INFO -     |---- Number of Forgettables: 1185 (9.22%)
# 2021-09-01 13:52:55,141 - INFO -     |---- Train Accuracy: 63.56%
# 2021-09-01 13:52:55,142 - INFO -     |---- Test Accuracy: 40.38%
# 2021-09-01 13:52:55,142 - INFO -     |---- Test Loss: 8.7162
# 2021-09-01 13:52:55,143 - INFO -     |---- Elapsed time: 0:13:03.898295
# 2021-09-01 13:52:55,144 - INFO -
# Test Acc: Max 40.3750% (7 round) | Last 40.3750% | Avg 24.4321% (1 round)
#
# 2021-09-01 13:52:55,146 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 13:53:08,145 - INFO -   |-- [Party 1] Average Train Loss:   3.2762 Train Accuracy: global   0.00% local  49.44% ... 1050 forgettables out of 1428 (73.53%) ... total data used 1428
# 2021-09-01 13:53:08,147 - INFO -   |--    Epoch Losses (10): [13.2235, 4.5368, 2.8791, 2.3987, 2.1925, 1.997, 1.7595, 1.5018, 1.2489, 1.024]
# 2021-09-01 13:53:19,976 - INFO -   |-- [Party 2] Average Train Loss:   4.2525 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:53:19,980 - INFO -   |--    Epoch Losses (10): [14.3737, 6.1406, 3.9292, 3.0811, 2.7292, 2.5482, 2.4829, 2.4417, 2.4131, 2.3853]
# 2021-09-01 13:53:32,690 - INFO -   |-- [Party 3] Average Train Loss:   0.4039 Train Accuracy: global  78.57% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:53:32,692 - INFO -   |--    Epoch Losses (10): [0.4594, 0.454, 0.4125, 0.424, 0.4035, 0.3955, 0.379, 0.3978, 0.3466, 0.3673]
# 2021-09-01 13:53:45,314 - INFO -   |-- [Party 4] Average Train Loss:   0.3518 Train Accuracy: global  81.23% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:53:45,315 - INFO -   |--    Epoch Losses (10): [0.4305, 0.4109, 0.3747, 0.3681, 0.3431, 0.339, 0.3208, 0.3347, 0.3077, 0.2886]
# 2021-09-01 13:53:57,983 - INFO -   |-- [Party 5] Average Train Loss:   0.3819 Train Accuracy: global  79.69% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:53:57,985 - INFO -   |--    Epoch Losses (10): [0.4459, 0.441, 0.3994, 0.392, 0.3751, 0.3611, 0.3591, 0.3707, 0.3494, 0.3253]
# 2021-09-01 13:54:08,971 - INFO -   |-- [Party 6] Average Train Loss:   0.4115 Train Accuracy: global  80.04% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:54:08,975 - INFO -   |--    Epoch Losses (10): [0.4595, 0.4024, 0.4324, 0.4176, 0.3983, 0.4149, 0.439, 0.3804, 0.3825, 0.3879]
# 2021-09-01 13:54:20,247 - INFO -   |-- [Party 7] Average Train Loss:   0.3652 Train Accuracy: global  83.75% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:54:20,250 - INFO -   |--    Epoch Losses (10): [0.4115, 0.3982, 0.3779, 0.3864, 0.3773, 0.3541, 0.3539, 0.343, 0.3265, 0.3229]
# 2021-09-01 13:54:32,310 - INFO -   |-- [Party 8] Average Train Loss:   0.3739 Train Accuracy: global  80.46% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:54:32,312 - INFO -   |--    Epoch Losses (10): [0.429, 0.3879, 0.404, 0.4071, 0.3745, 0.3696, 0.3394, 0.3567, 0.3413, 0.329]
# 2021-09-01 13:54:44,525 - INFO -   |-- [Party 9] Average Train Loss:   0.3269 Train Accuracy: global  83.68% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:54:44,529 - INFO -   |--    Epoch Losses (10): [0.3731, 0.3547, 0.3293, 0.3265, 0.3063, 0.3385, 0.3138, 0.3075, 0.2953, 0.3242]
# 2021-09-01 13:54:51,301 - INFO -     |---- Number of Forgettables: 1050 (8.17%)
# 2021-09-01 13:54:51,305 - INFO -     |---- Train Accuracy: 64.45%
# 2021-09-01 13:54:51,306 - INFO -     |---- Test Accuracy: 40.95%
# 2021-09-01 13:54:51,307 - INFO -     |---- Test Loss: 9.4533
# 2021-09-01 13:54:51,308 - INFO -     |---- Elapsed time: 0:15:00.062788
# 2021-09-01 13:54:51,309 - INFO -
# Test Acc: Max 40.9500% (8 round) | Last 40.9500% | Avg 26.4969% (4 round)
#
# 2021-09-01 13:54:51,312 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 13:55:04,109 - INFO -   |-- [Party 1] Average Train Loss:   3.5906 Train Accuracy: global   0.00% local  49.79% ...  706 forgettables out of 1428 (49.44%) ... total data used 1428
# 2021-09-01 13:55:04,110 - INFO -   |--    Epoch Losses (10): [13.7294, 4.8074, 3.1097, 2.5232, 2.2688, 2.1757, 2.0684, 1.9473, 1.7456, 1.5309]
# 2021-09-01 13:55:15,644 - INFO -   |-- [Party 2] Average Train Loss:   4.5566 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:55:15,648 - INFO -   |--    Epoch Losses (10): [15.0913, 6.5292, 4.2937, 3.5463, 3.3098, 2.8392, 2.5815, 2.5086, 2.4606, 2.4055]
# 2021-09-01 13:55:27,723 - INFO -   |-- [Party 3] Average Train Loss:   0.3930 Train Accuracy: global  79.83% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:55:27,724 - INFO -   |--    Epoch Losses (10): [0.4453, 0.4305, 0.4416, 0.4036, 0.3979, 0.3778, 0.3784, 0.3731, 0.3554, 0.3266]
# 2021-09-01 13:55:40,210 - INFO -   |-- [Party 4] Average Train Loss:   0.3378 Train Accuracy: global  83.19% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:55:40,212 - INFO -   |--    Epoch Losses (10): [0.4092, 0.3805, 0.3689, 0.3768, 0.3211, 0.3092, 0.2972, 0.303, 0.3056, 0.3068]
# 2021-09-01 13:55:52,522 - INFO -   |-- [Party 5] Average Train Loss:   0.3707 Train Accuracy: global  82.91% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:55:52,524 - INFO -   |--    Epoch Losses (10): [0.4323, 0.3754, 0.3706, 0.3589, 0.3775, 0.4273, 0.3682, 0.3356, 0.3406, 0.3207]
# 2021-09-01 13:56:03,535 - INFO -   |-- [Party 6] Average Train Loss:   0.3662 Train Accuracy: global  81.72% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:56:03,539 - INFO -   |--    Epoch Losses (10): [0.434, 0.3907, 0.4046, 0.3711, 0.3702, 0.3522, 0.3527, 0.3449, 0.3239, 0.318]
# 2021-09-01 13:56:14,583 - INFO -   |-- [Party 7] Average Train Loss:   0.3364 Train Accuracy: global  85.15% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:56:14,587 - INFO -   |--    Epoch Losses (10): [0.3791, 0.3562, 0.3632, 0.3439, 0.3309, 0.3307, 0.3339, 0.3057, 0.3102, 0.3098]
# 2021-09-01 13:56:27,294 - INFO -   |-- [Party 8] Average Train Loss:   0.3508 Train Accuracy: global  83.47% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:56:27,297 - INFO -   |--    Epoch Losses (10): [0.3985, 0.3955, 0.3671, 0.3586, 0.3432, 0.3325, 0.3312, 0.3307, 0.3242, 0.3268]
# 2021-09-01 13:56:38,238 - INFO -   |-- [Party 9] Average Train Loss:   0.3257 Train Accuracy: global  84.45% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:56:38,239 - INFO -   |--    Epoch Losses (10): [0.382, 0.3666, 0.3469, 0.3269, 0.3343, 0.3133, 0.3033, 0.2994, 0.2967, 0.2877]
# 2021-09-01 13:56:45,014 - INFO -     |---- Number of Forgettables: 706 (5.49%)
# 2021-09-01 13:56:45,017 - INFO -     |---- Train Accuracy: 65.23%
# 2021-09-01 13:56:45,019 - INFO -     |---- Test Accuracy: 41.35%
# 2021-09-01 13:56:45,020 - INFO -     |---- Test Loss: 9.5804
# 2021-09-01 13:56:45,022 - INFO -     |---- Elapsed time: 0:16:53.777035
# 2021-09-01 13:56:45,024 - INFO -
# Test Acc: Max 41.3500% (9 round) | Last 41.3500% | Avg 28.1472% (4 round)
#
# 2021-09-01 13:56:45,029 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 13:56:56,020 - INFO -   |-- [Party 1] Average Train Loss:   3.8021 Train Accuracy: global   0.00% local   0.00% ...  711 forgettables out of 1428 (49.79%) ... total data used 1428
# 2021-09-01 13:56:56,022 - INFO -   |--    Epoch Losses (10): [14.2523, 5.1769, 3.2759, 2.6182, 2.3316, 2.2438, 2.1759, 2.0918, 1.9904, 1.8642]
# 2021-09-01 13:57:08,935 - INFO -   |-- [Party 2] Average Train Loss:   4.7231 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:57:08,939 - INFO -   |--    Epoch Losses (10): [15.7161, 7.0499, 4.474, 3.8132, 3.1939, 2.7907, 2.6197, 2.5467, 2.5254, 2.501]
# 2021-09-01 13:57:20,240 - INFO -   |-- [Party 3] Average Train Loss:   0.3761 Train Accuracy: global  81.09% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:57:20,242 - INFO -   |--    Epoch Losses (10): [0.4222, 0.4227, 0.414, 0.3975, 0.3604, 0.3572, 0.3524, 0.3491, 0.3272, 0.3583]
# 2021-09-01 13:57:33,258 - INFO -   |-- [Party 4] Average Train Loss:   0.3260 Train Accuracy: global  84.10% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:57:33,260 - INFO -   |--    Epoch Losses (10): [0.3759, 0.3469, 0.358, 0.3236, 0.34, 0.3169, 0.2943, 0.2997, 0.2867, 0.3186]
# 2021-09-01 13:57:44,991 - INFO -   |-- [Party 5] Average Train Loss:   0.3547 Train Accuracy: global  83.61% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:57:44,995 - INFO -   |--    Epoch Losses (10): [0.4037, 0.3902, 0.372, 0.3598, 0.3438, 0.3321, 0.3433, 0.3413, 0.3205, 0.3401]
# 2021-09-01 13:57:57,526 - INFO -   |-- [Party 6] Average Train Loss:   0.3669 Train Accuracy: global  82.28% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:57:57,529 - INFO -   |--    Epoch Losses (10): [0.4261, 0.3899, 0.3987, 0.3688, 0.3604, 0.3656, 0.3631, 0.3366, 0.3258, 0.3343]
# 2021-09-01 13:58:08,586 - INFO -   |-- [Party 7] Average Train Loss:   0.3223 Train Accuracy: global  84.80% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:58:08,590 - INFO -   |--    Epoch Losses (10): [0.3868, 0.3421, 0.3432, 0.3392, 0.3511, 0.3217, 0.2864, 0.2912, 0.2829, 0.2788]
# 2021-09-01 13:58:19,674 - INFO -   |-- [Party 8] Average Train Loss:   0.3369 Train Accuracy: global  84.73% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:58:19,677 - INFO -   |--    Epoch Losses (10): [0.4087, 0.3734, 0.3731, 0.3324, 0.3381, 0.3211, 0.3408, 0.301, 0.2918, 0.289]
# 2021-09-01 13:58:31,916 - INFO -   |-- [Party 9] Average Train Loss:   0.2897 Train Accuracy: global  85.99% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:58:31,920 - INFO -   |--    Epoch Losses (10): [0.3299, 0.3161, 0.2969, 0.2755, 0.2881, 0.3035, 0.2913, 0.2611, 0.265, 0.2692]
# 2021-09-01 13:58:38,695 - INFO -     |---- Number of Forgettables: 711 (5.53%)
# 2021-09-01 13:58:38,697 - INFO -     |---- Train Accuracy: 65.16%
# 2021-09-01 13:58:38,698 - INFO -     |---- Test Accuracy: 41.48%
# 2021-09-01 13:58:38,699 - INFO -     |---- Test Loss: 9.8368
# 2021-09-01 13:58:38,700 - INFO -     |---- Elapsed time: 0:18:47.454883
# 2021-09-01 13:58:38,701 - INFO -
# Test Acc: Max 41.4750% (10 round) | Last 41.4750% | Avg 29.4800% (4 round)
#
# 2021-09-01 13:58:38,703 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 13:58:50,711 - INFO -   |-- [Party 1] Average Train Loss:   3.8665 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:58:50,714 - INFO -   |--    Epoch Losses (10): [14.2759, 5.42, 3.3543, 2.5699, 2.3388, 2.2641, 2.2141, 2.1577, 2.0816, 1.9884]
# 2021-09-01 13:59:01,566 - INFO -   |-- [Party 2] Average Train Loss:   4.8049 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:59:01,570 - INFO -   |--    Epoch Losses (10): [16.1378, 7.5095, 4.6901, 3.5689, 3.0903, 2.7551, 2.6331, 2.5823, 2.5511, 2.5312]
# 2021-09-01 13:59:12,807 - INFO -   |-- [Party 3] Average Train Loss:   0.3720 Train Accuracy: global  81.37% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:59:12,808 - INFO -   |--    Epoch Losses (10): [0.4368, 0.4168, 0.3933, 0.4014, 0.3748, 0.3594, 0.3533, 0.3309, 0.3361, 0.3176]
# 2021-09-01 13:59:24,679 - INFO -   |-- [Party 4] Average Train Loss:   0.3023 Train Accuracy: global  83.54% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:59:24,681 - INFO -   |--    Epoch Losses (10): [0.3309, 0.3318, 0.3104, 0.3117, 0.3359, 0.2978, 0.2849, 0.2816, 0.2638, 0.274]
# 2021-09-01 13:59:36,824 - INFO -   |-- [Party 5] Average Train Loss:   0.3413 Train Accuracy: global  82.49% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:59:36,828 - INFO -   |--    Epoch Losses (10): [0.4092, 0.3827, 0.3532, 0.3373, 0.3389, 0.3091, 0.3236, 0.3434, 0.3093, 0.3058]
# 2021-09-01 13:59:48,509 - INFO -   |-- [Party 6] Average Train Loss:   0.3591 Train Accuracy: global  81.72% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:59:48,512 - INFO -   |--    Epoch Losses (10): [0.4104, 0.3801, 0.3816, 0.3618, 0.3589, 0.3387, 0.3355, 0.3503, 0.3516, 0.3217]
# 2021-09-01 13:59:59,956 - INFO -   |-- [Party 7] Average Train Loss:   0.3244 Train Accuracy: global  84.03% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:59:59,960 - INFO -   |--    Epoch Losses (10): [0.361, 0.3648, 0.3256, 0.328, 0.3324, 0.3347, 0.3243, 0.3073, 0.2932, 0.2724]
# 2021-09-01 14:00:11,008 - INFO -   |-- [Party 8] Average Train Loss:   0.3169 Train Accuracy: global  84.59% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:00:11,010 - INFO -   |--    Epoch Losses (10): [0.3623, 0.3526, 0.3301, 0.3053, 0.3219, 0.3251, 0.3162, 0.2921, 0.2713, 0.2921]
# 2021-09-01 14:00:23,534 - INFO -   |-- [Party 9] Average Train Loss:   0.2639 Train Accuracy: global  85.99% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:00:23,538 - INFO -   |--    Epoch Losses (10): [0.3307, 0.2888, 0.2547, 0.2524, 0.2773, 0.2537, 0.2449, 0.2506, 0.2416, 0.2444]
# 2021-09-01 14:00:30,329 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 14:00:30,331 - INFO -     |---- Train Accuracy: 65.59%
# 2021-09-01 14:00:30,332 - INFO -     |---- Test Accuracy: 42.02%
# 2021-09-01 14:00:30,333 - INFO -     |---- Test Loss: 9.6928
# 2021-09-01 14:00:30,334 - INFO -     |---- Elapsed time: 0:20:39.088694
# 2021-09-01 14:00:30,335 - INFO -
# Test Acc: Max 42.0250% (11 round) | Last 42.0250% | Avg 30.6205% (5 round)
#
# 2021-09-01 14:00:30,339 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 14:00:42,729 - INFO -   |-- [Party 1] Average Train Loss:   4.0391 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:00:42,731 - INFO -   |--    Epoch Losses (10): [14.8373, 5.9946, 3.6231, 2.6462, 2.3726, 2.2903, 2.239, 2.1923, 2.1338, 2.0618]
# 2021-09-01 14:00:54,193 - INFO -   |-- [Party 2] Average Train Loss:   5.1310 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:00:54,194 - INFO -   |--    Epoch Losses (10): [16.2273, 7.9893, 5.4622, 4.3865, 3.5985, 3.0245, 2.7642, 2.6665, 2.6137, 2.5771]
# 2021-09-01 14:01:05,386 - INFO -   |-- [Party 3] Average Train Loss:   0.3388 Train Accuracy: global  82.49% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:01:05,389 - INFO -   |--    Epoch Losses (10): [0.4105, 0.3597, 0.3699, 0.3404, 0.3495, 0.3379, 0.3199, 0.3125, 0.2918, 0.2958]
# 2021-09-01 14:01:18,169 - INFO -   |-- [Party 4] Average Train Loss:   0.2937 Train Accuracy: global  84.38% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:01:18,173 - INFO -   |--    Epoch Losses (10): [0.36, 0.3096, 0.3233, 0.2998, 0.2769, 0.2859, 0.3017, 0.2704, 0.2565, 0.2528]
# 2021-09-01 14:01:29,416 - INFO -   |-- [Party 5] Average Train Loss:   0.3351 Train Accuracy: global  83.26% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:01:29,420 - INFO -   |--    Epoch Losses (10): [0.3974, 0.3517, 0.365, 0.3435, 0.3331, 0.3282, 0.3285, 0.3038, 0.3014, 0.2986]
# 2021-09-01 14:01:41,272 - INFO -   |-- [Party 6] Average Train Loss:   0.3390 Train Accuracy: global  83.61% local  88.52% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:01:41,275 - INFO -   |--    Epoch Losses (10): [0.3867, 0.368, 0.3275, 0.3248, 0.3511, 0.3271, 0.3371, 0.3319, 0.3123, 0.3237]
# 2021-09-01 14:01:53,110 - INFO -   |-- [Party 7] Average Train Loss:   0.2898 Train Accuracy: global  86.13% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:01:53,114 - INFO -   |--    Epoch Losses (10): [0.3488, 0.3231, 0.3059, 0.3062, 0.2919, 0.2803, 0.2862, 0.2784, 0.2457, 0.2318]
# 2021-09-01 14:02:04,954 - INFO -   |-- [Party 8] Average Train Loss:   0.3042 Train Accuracy: global  84.66% local  89.01% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:02:04,957 - INFO -   |--    Epoch Losses (10): [0.3441, 0.3312, 0.3068, 0.3002, 0.3063, 0.3123, 0.2997, 0.2789, 0.2937, 0.2684]
# 2021-09-01 14:02:17,431 - INFO -   |-- [Party 9] Average Train Loss:   0.2452 Train Accuracy: global  87.68% local  49.58% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:02:17,432 - INFO -   |--    Epoch Losses (10): [0.2923, 0.2767, 0.2506, 0.2388, 0.2552, 0.2315, 0.2173, 0.2339, 0.2384, 0.2176]
# 2021-09-01 14:02:24,124 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 14:02:24,125 - INFO -     |---- Train Accuracy: 64.88%
# 2021-09-01 14:02:24,126 - INFO -     |---- Test Accuracy: 41.95%
# 2021-09-01 14:02:24,127 - INFO -     |---- Test Loss: 9.7524
# 2021-09-01 14:02:24,127 - INFO -     |---- Elapsed time: 0:22:32.882622
# 2021-09-01 14:02:24,129 - INFO -
# Test Acc: Max 41.9500% (11 round) | Last 41.9500% | Avg 31.5646% (5 round)
#
# 2021-09-01 14:02:24,131 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 14:02:35,499 - INFO -   |-- [Party 1] Average Train Loss:   4.1126 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:02:35,503 - INFO -   |--    Epoch Losses (10): [14.989, 6.1074, 3.602, 2.8437, 2.4501, 2.3182, 2.2732, 2.2278, 2.1855, 2.1292]
# 2021-09-01 14:02:46,567 - INFO -   |-- [Party 2] Average Train Loss:   5.3399 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:02:46,571 - INFO -   |--    Epoch Losses (10): [16.7057, 8.4292, 5.6102, 4.7536, 3.8506, 3.1813, 2.862, 2.7225, 2.66, 2.6235]
# 2021-09-01 14:02:57,506 - INFO -   |-- [Party 3] Average Train Loss:   0.3304 Train Accuracy: global  81.79% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:02:57,509 - INFO -   |--    Epoch Losses (10): [0.3846, 0.3553, 0.3619, 0.3379, 0.3253, 0.2942, 0.3301, 0.313, 0.3046, 0.2972]
# 2021-09-01 14:03:09,579 - INFO -   |-- [Party 4] Average Train Loss:   0.2855 Train Accuracy: global  83.19% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:03:09,580 - INFO -   |--    Epoch Losses (10): [0.3051, 0.319, 0.2976, 0.2768, 0.2799, 0.3008, 0.281, 0.2727, 0.2698, 0.2522]
# 2021-09-01 14:03:20,593 - INFO -   |-- [Party 5] Average Train Loss:   0.3094 Train Accuracy: global  82.28% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:03:20,596 - INFO -   |--    Epoch Losses (10): [0.3668, 0.32, 0.3147, 0.3076, 0.292, 0.3002, 0.2802, 0.3317, 0.312, 0.2684]
# 2021-09-01 14:03:33,358 - INFO -   |-- [Party 6] Average Train Loss:   0.3225 Train Accuracy: global  82.21% local  87.04% ...  145 forgettables out of 1428 (10.15%) ... total data used 1428
# 2021-09-01 14:03:33,362 - INFO -   |--    Epoch Losses (10): [0.3808, 0.355, 0.3385, 0.3299, 0.3068, 0.3164, 0.3192, 0.2956, 0.2916, 0.2912]
# 2021-09-01 14:03:44,459 - INFO -   |-- [Party 7] Average Train Loss:   0.2854 Train Accuracy: global  83.96% local  49.30% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:03:44,463 - INFO -   |--    Epoch Losses (10): [0.3186, 0.3051, 0.2903, 0.2877, 0.2836, 0.2894, 0.2708, 0.2785, 0.2585, 0.2715]
# 2021-09-01 14:03:56,604 - INFO -   |-- [Party 8] Average Train Loss:   0.2819 Train Accuracy: global  83.68% local  87.39% ...  119 forgettables out of 1428 ( 8.33%) ... total data used 1428
# 2021-09-01 14:03:56,608 - INFO -   |--    Epoch Losses (10): [0.3327, 0.322, 0.2906, 0.3218, 0.2599, 0.2488, 0.2547, 0.2626, 0.275, 0.2513]
# 2021-09-01 14:04:09,183 - INFO -   |-- [Party 9] Average Train Loss:   0.2280 Train Accuracy: global  86.83% local  92.86% ...  166 forgettables out of 1428 (11.62%) ... total data used 1428
# 2021-09-01 14:04:09,186 - INFO -   |--    Epoch Losses (10): [0.2724, 0.2331, 0.2185, 0.2195, 0.2592, 0.253, 0.2273, 0.2084, 0.1976, 0.1906]
# 2021-09-01 14:04:16,063 - INFO -     |---- Number of Forgettables: 430 (3.35%)
# 2021-09-01 14:04:16,064 - INFO -     |---- Train Accuracy: 64.43%
# 2021-09-01 14:04:16,065 - INFO -     |---- Test Accuracy: 41.75%
# 2021-09-01 14:04:16,066 - INFO -     |---- Test Loss: 9.4817
# 2021-09-01 14:04:16,067 - INFO -     |---- Elapsed time: 0:24:24.822443
# 2021-09-01 14:04:16,069 - INFO -
# Test Acc: Max 41.7500% (11 round) | Last 41.7500% | Avg 32.3481% (5 round)
#
# 2021-09-01 14:04:16,072 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 14:04:28,913 - INFO -   |-- [Party 1] Average Train Loss:   4.2212 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:04:28,917 - INFO -   |--    Epoch Losses (10): [15.3643, 6.3619, 3.8729, 2.8804, 2.4644, 2.3353, 2.2851, 2.2508, 2.2187, 2.1783]
# 2021-09-01 14:04:40,716 - INFO -   |-- [Party 2] Average Train Loss:   5.4409 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:04:40,719 - INFO -   |--    Epoch Losses (10): [16.8299, 8.9075, 5.8473, 4.629, 3.7539, 3.2663, 2.957, 2.8025, 2.7289, 2.6862]
# 2021-09-01 14:04:52,126 - INFO -   |-- [Party 3] Average Train Loss:   0.3205 Train Accuracy: global  80.25% local  89.57% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:04:52,128 - INFO -   |--    Epoch Losses (10): [0.3968, 0.3538, 0.3367, 0.3254, 0.3111, 0.3071, 0.2989, 0.303, 0.2993, 0.2731]
# 2021-09-01 14:05:04,522 - INFO -   |-- [Party 4] Average Train Loss:   0.2715 Train Accuracy: global  82.42% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:05:04,525 - INFO -   |--    Epoch Losses (10): [0.329, 0.3004, 0.2642, 0.2743, 0.2746, 0.2608, 0.2637, 0.2834, 0.2437, 0.2208]
# 2021-09-01 14:05:15,742 - INFO -   |-- [Party 5] Average Train Loss:   0.3059 Train Accuracy: global  82.07% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 14:05:15,745 - INFO -   |--    Epoch Losses (10): [0.3614, 0.309, 0.3099, 0.3139, 0.3112, 0.2961, 0.2686, 0.2919, 0.3016, 0.2955]
# 2021-09-01 14:05:27,110 - INFO -   |-- [Party 6] Average Train Loss:   0.3210 Train Accuracy: global  81.79% local   0.00% ...  183 forgettables out of 1428 (12.82%) ... total data used 1428
# 2021-09-01 14:05:27,114 - INFO -   |--    Epoch Losses (10): [0.3698, 0.3374, 0.3502, 0.3417, 0.323, 0.3059, 0.2996, 0.3202, 0.2931, 0.2693]
# ...
# 2021-09-01 19:49:10,164 - INFO -   |-- [Party 6] Average Train Loss:   0.5586 Train Accuracy: global  86.83% local  49.30% ...   34 forgettables out of 1428 ( 2.38%) ... total data used 1428
# 2021-09-01 19:49:10,168 - INFO -   |--    Epoch Losses (10): [0.9601, 0.7545, 0.7186, 0.6062, 0.5232, 0.5313, 0.4216, 0.4086, 0.3463, 0.3155]
# 2021-09-01 19:49:20,951 - INFO -   |-- [Party 7] Average Train Loss:   0.4328 Train Accuracy: global  88.52% local  49.30% ...  129 forgettables out of 1428 ( 9.03%) ... total data used 1428
# 2021-09-01 19:49:20,953 - INFO -   |--    Epoch Losses (10): [0.8375, 0.6222, 0.4955, 0.3858, 0.4257, 0.3185, 0.3224, 0.2713, 0.3209, 0.3279]
# 2021-09-01 19:49:32,506 - INFO -   |-- [Party 8] Average Train Loss:   0.3985 Train Accuracy: global  88.31% local  49.65% ...  126 forgettables out of 1428 ( 8.82%) ... total data used 1428
# 2021-09-01 19:49:32,509 - INFO -   |--    Epoch Losses (10): [0.7378, 0.4801, 0.4588, 0.3937, 0.2954, 0.3455, 0.326, 0.3395, 0.3175, 0.2903]
# 2021-09-01 19:49:45,363 - INFO -   |-- [Party 9] Average Train Loss:   0.0100 Train Accuracy: global  99.65% local  99.93% ...    5 forgettables out of 1428 ( 0.35%) ... total data used 1428
# 2021-09-01 19:49:45,367 - INFO -   |--    Epoch Losses (10): [0.0002, 0.0038, 0.0002, 0.0044, 0.0611, 0.0153, 0.0046, 0.0089, 0.0009, 0.0004]
# 2021-09-01 19:49:52,041 - INFO -     |---- Number of Forgettables: 488 (3.80%)
# 2021-09-01 19:49:52,044 - INFO -     |---- Train Accuracy: 68.37%
# 2021-09-01 19:49:52,045 - INFO -     |---- Test Accuracy: 43.33%
# 2021-09-01 19:49:52,046 - INFO -     |---- Test Loss: 9.3092
# 2021-09-01 19:49:52,047 - INFO -     |---- Elapsed time: 6:10:00.802626
# 2021-09-01 19:49:52,049 - INFO -
# Test Acc: Max 43.3250% (161 round) | Last 43.3250% | Avg 42.0955% (17 round)
#
# 2021-09-01 19:49:52,052 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 19:50:04,108 - INFO -   |-- [Party 1] Average Train Loss:  11.5480 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:50:04,110 - INFO -   |--    Epoch Losses (10): [40.9303, 26.1829, 15.0965, 8.8309, 5.8771, 4.6975, 3.9727, 3.6207, 3.2334, 3.0378]
# 2021-09-01 19:50:16,386 - INFO -   |-- [Party 2] Average Train Loss:  17.4026 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:50:16,390 - INFO -   |--    Epoch Losses (10): [43.4872, 34.0648, 26.1031, 19.5322, 14.1988, 10.8438, 8.3086, 6.7831, 5.8937, 4.8109]
# 2021-09-01 19:50:27,211 - INFO -   |-- [Party 3] Average Train Loss:   0.5906 Train Accuracy: global  83.89% local  49.44% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:50:27,214 - INFO -   |--    Epoch Losses (10): [1.1002, 0.8248, 0.6499, 0.6511, 0.6532, 0.532, 0.401, 0.4331, 0.3376, 0.3233]
# 2021-09-01 19:50:39,012 - INFO -   |-- [Party 4] Average Train Loss:   0.4901 Train Accuracy: global  86.13% local  93.49% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:50:39,015 - INFO -   |--    Epoch Losses (10): [0.9326, 0.7027, 0.5583, 0.5336, 0.3855, 0.4812, 0.331, 0.3314, 0.3212, 0.323]
# 2021-09-01 19:50:51,154 - INFO -   |-- [Party 5] Average Train Loss:   0.5341 Train Accuracy: global  85.01% local  92.93% ...  181 forgettables out of 1428 (12.68%) ... total data used 1428
# 2021-09-01 19:50:51,158 - INFO -   |--    Epoch Losses (10): [0.9112, 0.6619, 0.619, 0.4335, 0.5733, 0.4882, 0.4316, 0.4542, 0.4108, 0.3568]
# 2021-09-01 19:51:02,045 - INFO -   |-- [Party 6] Average Train Loss:   0.5168 Train Accuracy: global  85.92% local  92.51% ...   31 forgettables out of 1428 ( 2.17%) ... total data used 1428
# 2021-09-01 19:51:02,049 - INFO -   |--    Epoch Losses (10): [0.9885, 0.7033, 0.6755, 0.6101, 0.4564, 0.3827, 0.3725, 0.2916, 0.4213, 0.2659]
# 2021-09-01 19:51:14,016 - INFO -   |-- [Party 7] Average Train Loss:   0.4673 Train Accuracy: global  87.25% local  92.44% ...  150 forgettables out of 1428 (10.50%) ... total data used 1428
# 2021-09-01 19:51:14,020 - INFO -   |--    Epoch Losses (10): [0.9536, 0.619, 0.5391, 0.5018, 0.3307, 0.3328, 0.3056, 0.2726, 0.4401, 0.3773]
# 2021-09-01 19:51:26,406 - INFO -   |-- [Party 8] Average Train Loss:   0.3685 Train Accuracy: global  87.68% local  95.31% ...  147 forgettables out of 1428 (10.29%) ... total data used 1428
# 2021-09-01 19:51:26,410 - INFO -   |--    Epoch Losses (10): [0.6377, 0.5296, 0.4058, 0.3626, 0.3956, 0.334, 0.2841, 0.2208, 0.2393, 0.2754]
# 2021-09-01 19:51:37,486 - INFO -   |-- [Party 9] Average Train Loss:   0.0077 Train Accuracy: global  98.81% local  99.79% ...   17 forgettables out of 1428 ( 1.19%) ... total data used 1428
# 2021-09-01 19:51:37,489 - INFO -   |--    Epoch Losses (10): [0.0002, 0.0002, 0.0001, 0.0001, 0.0229, 0.0087, 0.0139, 0.0175, 0.0081, 0.0052]
# 2021-09-01 19:51:44,195 - INFO -     |---- Number of Forgettables: 526 (4.09%)
# 2021-09-01 19:51:44,198 - INFO -     |---- Train Accuracy: 68.92%
# 2021-09-01 19:51:44,199 - INFO -     |---- Test Accuracy: 43.62%
# 2021-09-01 19:51:44,200 - INFO -     |---- Test Loss: 9.8171
# 2021-09-01 19:51:44,201 - INFO -     |---- Elapsed time: 6:11:52.956356
# 2021-09-01 19:51:44,203 - INFO -
# Test Acc: Max 43.6250% (161 round) | Last 43.6250% | Avg 42.1033% (17 round)
#
# 2021-09-01 19:51:44,205 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 19:51:55,269 - INFO -   |-- [Party 1] Average Train Loss:  11.6679 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:51:55,271 - INFO -   |--    Epoch Losses (10): [40.7389, 26.4842, 15.8781, 9.1723, 6.0463, 4.566, 4.0438, 3.5012, 3.2086, 3.0392]
# 2021-09-01 19:52:06,826 - INFO -   |-- [Party 2] Average Train Loss:  17.1919 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:52:06,830 - INFO -   |--    Epoch Losses (10): [43.0938, 33.9768, 26.426, 19.5977, 13.6815, 9.7996, 7.5923, 6.3879, 5.9031, 5.4601]
# 2021-09-01 19:52:18,160 - INFO -   |-- [Party 3] Average Train Loss:   0.5846 Train Accuracy: global  84.31% local  49.44% ...   34 forgettables out of 1428 ( 2.38%) ... total data used 1428
# 2021-09-01 19:52:18,161 - INFO -   |--    Epoch Losses (10): [1.0832, 0.9337, 0.7521, 0.5807, 0.542, 0.4152, 0.3841, 0.3489, 0.4972, 0.309]
# 2021-09-01 19:52:28,982 - INFO -   |-- [Party 4] Average Train Loss:   0.4346 Train Accuracy: global  86.83% local  49.23% ...  148 forgettables out of 1428 (10.36%) ... total data used 1428
# 2021-09-01 19:52:28,985 - INFO -   |--    Epoch Losses (10): [0.7915, 0.5656, 0.5552, 0.4206, 0.4233, 0.3683, 0.3154, 0.3398, 0.2701, 0.2962]
# 2021-09-01 19:52:39,762 - INFO -   |-- [Party 5] Average Train Loss:   0.5347 Train Accuracy: global  86.62% local  49.30% ...  152 forgettables out of 1428 (10.64%) ... total data used 1428
# 2021-09-01 19:52:39,764 - INFO -   |--    Epoch Losses (10): [0.9056, 0.6732, 0.7802, 0.6949, 0.474, 0.4096, 0.3856, 0.4213, 0.3155, 0.2873]
# 2021-09-01 19:52:50,641 - INFO -   |-- [Party 6] Average Train Loss:   0.5533 Train Accuracy: global  86.34% local  49.30% ...  143 forgettables out of 1428 (10.01%) ... total data used 1428
# 2021-09-01 19:52:50,645 - INFO -   |--    Epoch Losses (10): [1.0742, 0.761, 0.6808, 0.5751, 0.4703, 0.5006, 0.4293, 0.401, 0.3809, 0.2598]
# 2021-09-01 19:53:01,461 - INFO -   |-- [Party 7] Average Train Loss:   0.4373 Train Accuracy: global  88.66% local  49.30% ...  113 forgettables out of 1428 ( 7.91%) ... total data used 1428
# 2021-09-01 19:53:01,463 - INFO -   |--    Epoch Losses (10): [0.7423, 0.6173, 0.5654, 0.4161, 0.3356, 0.3952, 0.2978, 0.3828, 0.2974, 0.3235]
# 2021-09-01 19:53:12,289 - INFO -   |-- [Party 8] Average Train Loss:   0.3838 Train Accuracy: global  88.45% local   0.00% ...  137 forgettables out of 1428 ( 9.59%) ... total data used 1428
# 2021-09-01 19:53:12,291 - INFO -   |--    Epoch Losses (10): [0.7031, 0.652, 0.3954, 0.3227, 0.2923, 0.3192, 0.3484, 0.292, 0.2512, 0.2619]
# 2021-09-01 19:53:23,093 - INFO -   |-- [Party 9] Average Train Loss:   0.0295 Train Accuracy: global  99.65% local  49.58% ...    5 forgettables out of 1428 ( 0.35%) ... total data used 1428
# 2021-09-01 19:53:23,095 - INFO -   |--    Epoch Losses (10): [0.0, 0.0, 0.0, 0.0037, 0.0003, 0.2152, 0.0285, 0.0372, 0.0073, 0.0025]
# 2021-09-01 19:53:29,664 - INFO -     |---- Number of Forgettables: 732 (5.70%)
# 2021-09-01 19:53:29,665 - INFO -     |---- Train Accuracy: 69.65%
# 2021-09-01 19:53:29,666 - INFO -     |---- Test Accuracy: 43.92%
# 2021-09-01 19:53:29,667 - INFO -     |---- Test Loss: 10.6269
# 2021-09-01 19:53:29,668 - INFO -     |---- Elapsed time: 6:13:38.423345
# 2021-09-01 19:53:29,670 - INFO -
# Test Acc: Max 43.9250% (161 round) | Last 43.9250% | Avg 42.1125% (17 round)
#
# 2021-09-01 19:53:29,673 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 19:53:40,552 - INFO -   |-- [Party 1] Average Train Loss:  11.5051 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:53:40,553 - INFO -   |--    Epoch Losses (10): [40.7923, 26.1969, 14.8481, 8.7505, 5.9858, 4.6959, 3.9455, 3.517, 3.2843, 3.0344]
# 2021-09-01 19:53:51,520 - INFO -   |-- [Party 2] Average Train Loss:  17.5384 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:53:51,524 - INFO -   |--    Epoch Losses (10): [43.0697, 33.8614, 26.3814, 19.8452, 14.4625, 10.8484, 8.487, 7.2613, 5.9891, 5.1782]
# 2021-09-01 19:54:02,338 - INFO -   |-- [Party 3] Average Train Loss:   0.6286 Train Accuracy: global  85.78% local  49.44% ...   45 forgettables out of 1428 ( 3.15%) ... total data used 1428
# 2021-09-01 19:54:02,341 - INFO -   |--    Epoch Losses (10): [1.2654, 0.8606, 0.8213, 0.6244, 0.576, 0.4689, 0.4472, 0.4765, 0.3822, 0.3634]
# 2021-09-01 19:54:13,174 - INFO -   |-- [Party 4] Average Train Loss:   0.4448 Train Accuracy: global  88.24% local  49.23% ...  140 forgettables out of 1428 ( 9.80%) ... total data used 1428
# 2021-09-01 19:54:13,175 - INFO -   |--    Epoch Losses (10): [0.9273, 0.6451, 0.512, 0.3964, 0.4079, 0.3441, 0.3994, 0.3321, 0.2093, 0.274]
# 2021-09-01 19:54:23,977 - INFO -   |-- [Party 5] Average Train Loss:   0.5183 Train Accuracy: global  88.03% local  49.30% ...  130 forgettables out of 1428 ( 9.10%) ... total data used 1428
# 2021-09-01 19:54:23,979 - INFO -   |--    Epoch Losses (10): [0.9615, 0.8215, 0.5256, 0.5265, 0.5481, 0.4603, 0.4406, 0.309, 0.3278, 0.2624]
# 2021-09-01 19:54:36,544 - INFO -   |-- [Party 6] Average Train Loss:   0.5557 Train Accuracy: global  87.46% local  92.79% ...   39 forgettables out of 1428 ( 2.73%) ... total data used 1428
# 2021-09-01 19:54:36,546 - INFO -   |--    Epoch Losses (10): [1.0178, 0.7233, 0.6853, 0.599, 0.6329, 0.4205, 0.4369, 0.3438, 0.318, 0.3791]
# 2021-09-01 19:54:47,360 - INFO -   |-- [Party 7] Average Train Loss:   0.4233 Train Accuracy: global  89.22% local  93.00% ...  110 forgettables out of 1428 ( 7.70%) ... total data used 1428
# 2021-09-01 19:54:47,364 - INFO -   |--    Epoch Losses (10): [0.796, 0.5574, 0.4736, 0.4504, 0.3809, 0.4322, 0.2997, 0.2402, 0.2884, 0.3143]
# 2021-09-01 19:54:59,298 - INFO -   |-- [Party 8] Average Train Loss:   0.3810 Train Accuracy: global  88.94% local  95.31% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:54:59,300 - INFO -   |--    Epoch Losses (10): [0.5966, 0.5755, 0.405, 0.4092, 0.3466, 0.3112, 0.2996, 0.2884, 0.3035, 0.2742]
# 2021-09-01 19:55:10,119 - INFO -   |-- [Party 9] Average Train Loss:   0.0028 Train Accuracy: global  99.72% local 100.00% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 19:55:10,120 - INFO -   |--    Epoch Losses (10): [0.0139, 0.0, 0.0015, 0.0, 0.0008, 0.0024, 0.0077, 0.0002, 0.0011, 0.0006]
# 2021-09-01 19:55:16,729 - INFO -     |---- Number of Forgettables: 468 (3.64%)
# 2021-09-01 19:55:16,730 - INFO -     |---- Train Accuracy: 69.93%
# 2021-09-01 19:55:16,731 - INFO -     |---- Test Accuracy: 44.35%
# 2021-09-01 19:55:16,732 - INFO -     |---- Test Loss: 10.7402
# 2021-09-01 19:55:16,733 - INFO -     |---- Elapsed time: 6:15:25.488389
# 2021-09-01 19:55:16,734 - INFO -
# Test Acc: Max 44.3500% (199 round) | Last 44.3500% | Avg 42.1237% (17 round)
#
# 2021-09-01 19:55:16,737 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 19:55:27,622 - INFO -   |-- [Party 1] Average Train Loss:  11.3149 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:55:27,624 - INFO -   |--    Epoch Losses (10): [40.6305, 25.6641, 14.1564, 8.4649, 5.8387, 4.6357, 3.9542, 3.5066, 3.2424, 3.0556]
# 2021-09-01 19:55:38,405 - INFO -   |-- [Party 2] Average Train Loss:  16.4882 Train Accuracy: global   0.00% local   0.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 19:55:38,409 - INFO -   |--    Epoch Losses (10): [43.2429, 33.3725, 24.8802, 17.6921, 12.704, 9.2325, 7.5584, 6.1555, 5.191, 4.8534]
# 2021-09-01 19:55:49,245 - INFO -   |-- [Party 3] Average Train Loss:   0.5578 Train Accuracy: global  85.43% local  49.44% ...   47 forgettables out of 1428 ( 3.29%) ... total data used 1428
# 2021-09-01 19:55:49,247 - INFO -   |--    Epoch Losses (10): [1.0998, 0.7483, 0.6631, 0.5865, 0.4919, 0.4815, 0.4338, 0.4079, 0.3398, 0.3258]
# 2021-09-01 19:56:00,089 - INFO -   |-- [Party 4] Average Train Loss:   0.5074 Train Accuracy: global  88.03% local  49.37% ...  139 forgettables out of 1428 ( 9.73%) ... total data used 1428
# 2021-09-01 19:56:00,090 - INFO -   |--    Epoch Losses (10): [0.9284, 0.6601, 0.6775, 0.4592, 0.4551, 0.4668, 0.4394, 0.3591, 0.3236, 0.3053]
# 2021-09-01 19:56:10,906 - INFO -   |-- [Party 5] Average Train Loss:   0.4725 Train Accuracy: global  87.75% local  49.30% ...  130 forgettables out of 1428 ( 9.10%) ... total data used 1428
# 2021-09-01 19:56:10,908 - INFO -   |--    Epoch Losses (10): [0.8294, 0.5849, 0.57, 0.5202, 0.4043, 0.4288, 0.3695, 0.3679, 0.3893, 0.2603]
# 2021-09-01 19:56:21,908 - INFO -   |-- [Party 6] Average Train Loss:   0.5703 Train Accuracy: global  88.66% local  91.32% ...  100 forgettables out of 1428 ( 7.00%) ... total data used 1428
# 2021-09-01 19:56:21,909 - INFO -   |--    Epoch Losses (10): [1.0127, 0.7054, 0.6699, 0.6053, 0.6258, 0.4784, 0.4254, 0.4002, 0.3731, 0.4072]
# 2021-09-01 19:56:32,811 - INFO -   |-- [Party 7] Average Train Loss:   0.4683 Train Accuracy: global  89.92% local  93.77% ...  114 forgettables out of 1428 ( 7.98%) ... total data used 1428
# 2021-09-01 19:56:32,814 - INFO -   |--    Epoch Losses (10): [0.9402, 0.638, 0.5853, 0.5161, 0.3304, 0.4566, 0.275, 0.3122, 0.3476, 0.2817]
# 2021-09-01 19:56:43,603 - INFO -   |-- [Party 8] Average Train Loss:   0.3769 Train Accuracy: global  89.15% local  95.10% ...  126 forgettables out of 1428 ( 8.82%) ... total data used 1428
# 2021-09-01 19:56:43,604 - INFO -   |--    Epoch Losses (10): [0.7446, 0.4675, 0.4513, 0.4192, 0.3165, 0.2746, 0.3499, 0.2905, 0.2582, 0.197]
# 2021-09-01 19:56:54,413 - INFO -   |-- [Party 9] Average Train Loss:   0.0038 Train Accuracy: global  99.72% local  99.79% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 19:56:54,415 - INFO -   |--    Epoch Losses (10): [0.0035, 0.0011, 0.0004, 0.0004, 0.0025, 0.0141, 0.0028, 0.0017, 0.005, 0.0066]
# 2021-09-01 19:57:01,052 - INFO -     |---- Number of Forgettables: 660 (5.14%)
# 2021-09-01 19:57:01,054 - INFO -     |---- Train Accuracy: 69.99%
# 2021-09-01 19:57:01,055 - INFO -     |---- Test Accuracy: 44.22%
# 2021-09-01 19:57:01,056 - INFO -     |---- Test Loss: 10.2494
# 2021-09-01 19:57:01,057 - INFO -     |---- Elapsed time: 6:17:09.812368
# 2021-09-01 19:57:01,059 - INFO -
# Test Acc: Max 44.2250% (199 round) | Last 44.2250% | Avg 42.1342% (17 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

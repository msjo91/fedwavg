# %%
# %matplotlib inline

dataset = 'svhn'
clsimb = [2, 3, 4] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_fedprox'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 3

# %%
import copy
import json
import logging
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/train_32x32.mat
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/test_32x32.mat

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
def average_weights(w):
    w_avg = copy.deepcopy(w[0])
        
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
    return w_avg

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, global_model, mu=0.01):
    epoch_losses = []
    
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    
    global_params = list(global_model.parameters())
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            prox_reg = 0.0
            for i, param in enumerate(model.parameters()):
                prox_reg += ((mu / 2) * torch.norm((param - global_params[i])) ** 2)
            loss += prox_reg
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    local_weights = model.state_dict()

    return local_weights, epoch_losses

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0

logger.info(f'\nAlgorithm: FedProx\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, fed_model, mu=0.01)

        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
    fed_weights = average_weights(local_weights)
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 13:25:39,424 - INFO -
# Algorithm: FedProx
# Client Split: [2, 3, 4]
# Dataset: svhn
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 13:25:39,429 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 13:25:57,305 - INFO -   |-- [Party 1] Average Train Loss:   0.5946 Train Accuracy: global   0.00% local  96.29% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:25:57,308 - INFO -   |--    Epoch Losses (10): [1.157, 0.9838, 0.8171, 0.648, 0.5031, 0.4365, 0.3842, 0.3638, 0.3445, 0.3077]
# 2021-09-01 13:26:13,118 - INFO -   |-- [Party 2] Average Train Loss:   0.5676 Train Accuracy: global   0.00% local  94.74% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:26:13,120 - INFO -   |--    Epoch Losses (10): [1.1743, 0.9862, 0.7983, 0.6229, 0.4547, 0.3648, 0.3399, 0.3417, 0.3067, 0.2865]
# 2021-09-01 13:26:27,093 - INFO -   |-- [Party 3] Average Train Loss:   0.7185 Train Accuracy: global   0.00% local  89.30% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:26:27,096 - INFO -   |--    Epoch Losses (10): [1.2923, 1.0734, 0.9109, 0.8116, 0.7212, 0.5843, 0.5184, 0.4364, 0.4191, 0.417]
# 2021-09-01 13:26:41,109 - INFO -   |-- [Party 4] Average Train Loss:   0.7153 Train Accuracy: global   0.00% local  91.08% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:26:41,110 - INFO -   |--    Epoch Losses (10): [1.2662, 1.0521, 0.9031, 0.7989, 0.7171, 0.5697, 0.527, 0.4667, 0.4337, 0.4188]
# 2021-09-01 13:26:56,381 - INFO -   |-- [Party 5] Average Train Loss:   0.7439 Train Accuracy: global   0.00% local  90.80% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:26:56,384 - INFO -   |--    Epoch Losses (10): [1.2448, 1.0577, 0.9105, 0.8011, 0.7821, 0.7106, 0.5542, 0.4954, 0.4472, 0.4352]
# 2021-09-01 13:27:10,566 - INFO -   |-- [Party 6] Average Train Loss:   0.6930 Train Accuracy: global  48.50% local  91.60% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:27:10,568 - INFO -   |--    Epoch Losses (10): [1.217, 1.0897, 0.909, 0.7988, 0.6678, 0.5099, 0.4682, 0.4605, 0.4147, 0.394]
# 2021-09-01 13:27:24,680 - INFO -   |-- [Party 7] Average Train Loss:   0.6658 Train Accuracy: global  48.50% local  83.29% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:27:24,682 - INFO -   |--    Epoch Losses (10): [1.2418, 1.0869, 0.9296, 0.7324, 0.5633, 0.4441, 0.4359, 0.4443, 0.3945, 0.3853]
# 2021-09-01 13:27:41,024 - INFO -   |-- [Party 8] Average Train Loss:   0.6974 Train Accuracy: global  48.50% local  93.62% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:27:41,026 - INFO -   |--    Epoch Losses (10): [1.2269, 1.0996, 0.9301, 0.8049, 0.6817, 0.5434, 0.4806, 0.4251, 0.3798, 0.4019]
# 2021-09-01 13:27:58,332 - INFO -   |-- [Party 9] Average Train Loss:   0.7792 Train Accuracy: global  48.50% local  78.17% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 13:27:58,336 - INFO -   |--    Epoch Losses (10): [1.2487, 1.0843, 0.948, 0.8513, 0.7756, 0.7643, 0.6632, 0.5268, 0.4719, 0.4577]
# 2021-09-01 13:28:10,439 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 13:28:10,440 - INFO -     |---- Train Accuracy: 21.55%
# 2021-09-01 13:28:10,442 - INFO -     |---- Test Accuracy: 9.59%
# 2021-09-01 13:28:10,443 - INFO -     |---- Test Loss: 2.1934
# 2021-09-01 13:28:10,444 - INFO -     |---- Elapsed time: 0:02:31.017139
# 2021-09-01 13:28:10,445 - INFO -
# Test Acc: Max 9.5905% (1 round) | Last 9.5905% | Avg 9.5905% (1 round)
#
# 2021-09-01 13:28:10,448 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 13:28:24,610 - INFO -   |-- [Party 1] Average Train Loss:   0.3834 Train Accuracy: global   0.00% local  97.28% ... 2051 forgettables out of 2130 (96.29%) ... total data used 2130
# 2021-09-01 13:28:24,611 - INFO -   |--    Epoch Losses (10): [0.8686, 0.5851, 0.4048, 0.3277, 0.3027, 0.2615, 0.258, 0.2665, 0.278, 0.2812]
# 2021-09-01 13:28:40,446 - INFO -   |-- [Party 2] Average Train Loss:   0.3823 Train Accuracy: global   0.00% local  93.85% ... 2018 forgettables out of 2130 (94.74%) ... total data used 2130
# 2021-09-01 13:28:40,447 - INFO -   |--    Epoch Losses (10): [0.9028, 0.5829, 0.4057, 0.3143, 0.3034, 0.2664, 0.2612, 0.2515, 0.2692, 0.2654]
# 2021-09-01 13:28:57,403 - INFO -   |-- [Party 3] Average Train Loss:   0.4079 Train Accuracy: global   0.00% local  94.27% ... 1902 forgettables out of 2130 (89.30%) ... total data used 2130
# 2021-09-01 13:28:57,405 - INFO -   |--    Epoch Losses (10): [0.7935, 0.5756, 0.4136, 0.3585, 0.3435, 0.3365, 0.3246, 0.3132, 0.3073, 0.3124]
# 2021-09-01 13:29:12,538 - INFO -   |-- [Party 4] Average Train Loss:   0.4182 Train Accuracy: global   0.00% local  87.70% ... 1940 forgettables out of 2130 (91.08%) ... total data used 2130
# 2021-09-01 13:29:12,540 - INFO -   |--    Epoch Losses (10): [0.7902, 0.5827, 0.4166, 0.366, 0.339, 0.3436, 0.352, 0.3192, 0.3396, 0.3327]
# 2021-09-01 13:29:26,825 - INFO -   |-- [Party 5] Average Train Loss:   0.4254 Train Accuracy: global   0.00% local  88.54% ... 1934 forgettables out of 2130 (90.80%) ... total data used 2130
# 2021-09-01 13:29:26,827 - INFO -   |--    Epoch Losses (10): [0.8543, 0.6147, 0.4309, 0.3899, 0.3472, 0.3253, 0.3125, 0.3319, 0.3489, 0.2982]
# 2021-09-01 13:29:42,462 - INFO -   |-- [Party 6] Average Train Loss:   0.4427 Train Accuracy: global  48.50% local  95.21% ...  993 forgettables out of 2130 (46.62%) ... total data used 2130
# 2021-09-01 13:29:42,463 - INFO -   |--    Epoch Losses (10): [0.895, 0.6718, 0.4578, 0.3752, 0.3843, 0.3434, 0.3438, 0.326, 0.3224, 0.3078]
# 2021-09-01 13:29:56,598 - INFO -   |-- [Party 7] Average Train Loss:   0.4228 Train Accuracy: global  48.50% local  89.81% ... 1075 forgettables out of 2130 (50.47%) ... total data used 2130
# 2021-09-01 13:29:56,599 - INFO -   |--    Epoch Losses (10): [0.8524, 0.6136, 0.453, 0.3839, 0.3529, 0.3351, 0.3012, 0.3184, 0.3131, 0.3042]
# 2021-09-01 13:30:10,841 - INFO -   |-- [Party 8] Average Train Loss:   0.4275 Train Accuracy: global  48.50% local  94.27% ... 1065 forgettables out of 2130 (50.00%) ... total data used 2130
# 2021-09-01 13:30:10,845 - INFO -   |--    Epoch Losses (10): [0.8449, 0.6218, 0.4398, 0.3898, 0.3663, 0.3314, 0.3184, 0.3027, 0.3408, 0.3195]
# 2021-09-01 13:30:26,994 - INFO -   |-- [Party 9] Average Train Loss:   0.4348 Train Accuracy: global  48.50% local  93.15% ...  635 forgettables out of 2130 (29.81%) ... total data used 2130
# 2021-09-01 13:30:26,996 - INFO -   |--    Epoch Losses (10): [0.8366, 0.6222, 0.463, 0.3819, 0.3581, 0.3545, 0.3596, 0.309, 0.3243, 0.3388]
# 2021-09-01 13:30:38,835 - INFO -     |---- Number of Forgettables: 13613 (71.01%)
# 2021-09-01 13:30:38,837 - INFO -     |---- Train Accuracy: 39.46%
# 2021-09-01 13:30:38,838 - INFO -     |---- Test Accuracy: 17.74%
# 2021-09-01 13:30:38,838 - INFO -     |---- Test Loss: 2.1908
# 2021-09-01 13:30:38,839 - INFO -     |---- Elapsed time: 0:04:59.412187
# 2021-09-01 13:30:38,840 - INFO -
# Test Acc: Max 17.7380% (2 round) | Last 17.7380% | Avg 13.6642% (2 round)
#
# 2021-09-01 13:30:38,843 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 13:30:54,162 - INFO -   |-- [Party 1] Average Train Loss:   0.3131 Train Accuracy: global   0.00% local  98.12% ... 2072 forgettables out of 2130 (97.28%) ... total data used 2130
# 2021-09-01 13:30:54,165 - INFO -   |--    Epoch Losses (10): [0.7279, 0.4834, 0.3208, 0.237, 0.2211, 0.234, 0.2308, 0.2344, 0.2319, 0.2098]
# 2021-09-01 13:31:09,962 - INFO -   |-- [Party 2] Average Train Loss:   0.3073 Train Accuracy: global   0.00% local  87.23% ... 1999 forgettables out of 2130 (93.85%) ... total data used 2130
# 2021-09-01 13:31:09,963 - INFO -   |--    Epoch Losses (10): [0.7102, 0.4771, 0.3361, 0.2799, 0.2427, 0.1924, 0.2044, 0.2071, 0.2043, 0.2193]
# 2021-09-01 13:31:24,220 - INFO -   |-- [Party 3] Average Train Loss:   0.3141 Train Accuracy: global   0.00% local  94.23% ... 2008 forgettables out of 2130 (94.27%) ... total data used 2130
# 2021-09-01 13:31:24,221 - INFO -   |--    Epoch Losses (10): [0.5814, 0.4429, 0.3257, 0.2717, 0.2418, 0.2547, 0.2339, 0.2578, 0.2672, 0.264]
# 2021-09-01 13:31:38,370 - INFO -   |-- [Party 4] Average Train Loss:   0.3375 Train Accuracy: global   0.00% local  94.74% ... 1868 forgettables out of 2130 (87.70%) ... total data used 2130
# 2021-09-01 13:31:38,373 - INFO -   |--    Epoch Losses (10): [0.6227, 0.4823, 0.3386, 0.3068, 0.3133, 0.266, 0.2653, 0.2371, 0.2764, 0.2665]
# 2021-09-01 13:31:53,718 - INFO -   |-- [Party 5] Average Train Loss:   0.3347 Train Accuracy: global   0.00% local  86.34% ... 1886 forgettables out of 2130 (88.54%) ... total data used 2130
# 2021-09-01 13:31:53,719 - INFO -   |--    Epoch Losses (10): [0.6163, 0.4818, 0.3244, 0.2788, 0.2635, 0.2584, 0.268, 0.2813, 0.2724, 0.3023]
# 2021-09-01 13:32:09,350 - INFO -   |-- [Party 6] Average Train Loss:   0.3073 Train Accuracy: global  87.93% local  85.45% ...  189 forgettables out of 2130 ( 8.87%) ... total data used 2130
# 2021-09-01 13:32:09,352 - INFO -   |--    Epoch Losses (10): [0.4601, 0.3869, 0.2995, 0.2614, 0.2779, 0.2819, 0.279, 0.2924, 0.2746, 0.2592]
# 2021-09-01 13:32:25,340 - INFO -   |-- [Party 7] Average Train Loss:   0.2957 Train Accuracy: global  89.34% local  95.12% ...  131 forgettables out of 2130 ( 6.15%) ... total data used 2130
# 2021-09-01 13:32:25,343 - INFO -   |--    Epoch Losses (10): [0.4657, 0.3886, 0.3049, 0.2598, 0.2645, 0.2667, 0.2599, 0.2476, 0.2493, 0.2502]
# 2021-09-01 13:32:39,408 - INFO -   |-- [Party 8] Average Train Loss:   0.2953 Train Accuracy: global  89.62% local  79.39% ...  152 forgettables out of 2130 ( 7.14%) ... total data used 2130
# 2021-09-01 13:32:39,410 - INFO -   |--    Epoch Losses (10): [0.4741, 0.401, 0.304, 0.2648, 0.2423, 0.2473, 0.2547, 0.268, 0.2524, 0.2441]
# 2021-09-01 13:32:53,617 - INFO -   |-- [Party 9] Average Train Loss:   0.3172 Train Accuracy: global  87.56% local  94.98% ...  195 forgettables out of 2130 ( 9.15%) ... total data used 2130
# 2021-09-01 13:32:53,618 - INFO -   |--    Epoch Losses (10): [0.4786, 0.3893, 0.3284, 0.301, 0.2747, 0.3019, 0.2995, 0.2727, 0.2551, 0.2709]
# 2021-09-01 13:33:05,321 - INFO -     |---- Number of Forgettables: 10500 (54.77%)
# 2021-09-01 13:33:05,323 - INFO -     |---- Train Accuracy: 41.53%
# 2021-09-01 13:33:05,324 - INFO -     |---- Test Accuracy: 18.45%
# 2021-09-01 13:33:05,324 - INFO -     |---- Test Loss: 2.1753
# 2021-09-01 13:33:05,325 - INFO -     |---- Elapsed time: 0:07:25.898190
# 2021-09-01 13:33:05,326 - INFO -
# Test Acc: Max 18.4535% (3 round) | Last 18.4535% | Avg 15.2607% (2 round)
#
# 2021-09-01 13:33:05,329 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 13:33:21,400 - INFO -   |-- [Party 1] Average Train Loss:   0.2736 Train Accuracy: global   0.00% local  96.76% ... 2090 forgettables out of 2130 (98.12%) ... total data used 2130
# 2021-09-01 13:33:21,403 - INFO -   |--    Epoch Losses (10): [0.7108, 0.4448, 0.282, 0.2073, 0.1844, 0.1754, 0.1784, 0.1785, 0.1778, 0.1964]
# 2021-09-01 13:33:38,610 - INFO -   |-- [Party 2] Average Train Loss:   0.2639 Train Accuracy: global   0.00% local  89.20% ... 1858 forgettables out of 2130 (87.23%) ... total data used 2130
# 2021-09-01 13:33:38,611 - INFO -   |--    Epoch Losses (10): [0.7022, 0.4111, 0.2623, 0.1947, 0.1819, 0.1949, 0.1911, 0.1755, 0.1706, 0.1551]
# 2021-09-01 13:33:53,102 - INFO -   |-- [Party 3] Average Train Loss:   0.2690 Train Accuracy: global   0.00% local  96.90% ... 2007 forgettables out of 2130 (94.23%) ... total data used 2130
# 2021-09-01 13:33:53,104 - INFO -   |--    Epoch Losses (10): [0.526, 0.3902, 0.2491, 0.2219, 0.2215, 0.22, 0.2217, 0.2194, 0.1966, 0.2237]
# 2021-09-01 13:34:09,033 - INFO -   |-- [Party 4] Average Train Loss:   0.2837 Train Accuracy: global   0.00% local  92.39% ... 2018 forgettables out of 2130 (94.74%) ... total data used 2130
# 2021-09-01 13:34:09,035 - INFO -   |--    Epoch Losses (10): [0.5497, 0.4032, 0.2746, 0.2274, 0.2084, 0.2629, 0.2321, 0.2306, 0.2267, 0.2219]
# 2021-09-01 13:34:23,135 - INFO -   |-- [Party 5] Average Train Loss:   0.2761 Train Accuracy: global   0.09% local  82.96% ... 1837 forgettables out of 2130 (86.24%) ... total data used 2130
# 2021-09-01 13:34:23,136 - INFO -   |--    Epoch Losses (10): [0.5408, 0.404, 0.2736, 0.2177, 0.2262, 0.2099, 0.2085, 0.2138, 0.2375, 0.2285]
# 2021-09-01 13:34:37,300 - INFO -   |-- [Party 6] Average Train Loss:   0.2470 Train Accuracy: global  93.00% local  85.77% ...  109 forgettables out of 2130 ( 5.12%) ... total data used 2130
# 2021-09-01 13:34:37,301 - INFO -   |--    Epoch Losses (10): [0.3577, 0.2766, 0.2268, 0.2197, 0.2276, 0.2351, 0.2212, 0.2345, 0.2382, 0.2328]
# 2021-09-01 13:34:51,886 - INFO -   |-- [Party 7] Average Train Loss:   0.2447 Train Accuracy: global  94.65% local  92.25% ...   83 forgettables out of 2130 ( 3.90%) ... total data used 2130
# 2021-09-01 13:34:51,889 - INFO -   |--    Epoch Losses (10): [0.3637, 0.3029, 0.2603, 0.2429, 0.2148, 0.2091, 0.2145, 0.2026, 0.2192, 0.2171]
# 2021-09-01 13:35:06,624 - INFO -   |-- [Party 8] Average Train Loss:   0.2498 Train Accuracy: global  93.85% local  95.59% ...   97 forgettables out of 2130 ( 4.55%) ... total data used 2130
# 2021-09-01 13:35:06,626 - INFO -   |--    Epoch Losses (10): [0.3771, 0.3033, 0.2095, 0.2147, 0.2317, 0.2478, 0.2257, 0.2393, 0.2178, 0.2309]
# 2021-09-01 13:35:21,004 - INFO -   |-- [Party 9] Average Train Loss:   0.2653 Train Accuracy: global  92.82% local  93.24% ...  108 forgettables out of 2130 ( 5.07%) ... total data used 2130
# 2021-09-01 13:35:21,006 - INFO -   |--    Epoch Losses (10): [0.3934, 0.3123, 0.2655, 0.2285, 0.22, 0.2382, 0.2556, 0.2571, 0.232, 0.2503]
# 2021-09-01 13:35:32,819 - INFO -     |---- Number of Forgettables: 10207 (53.24%)
# 2021-09-01 13:35:32,823 - INFO -     |---- Train Accuracy: 42.43%
# 2021-09-01 13:35:32,824 - INFO -     |---- Test Accuracy: 18.87%
# 2021-09-01 13:35:32,825 - INFO -     |---- Test Loss: 2.3316
# 2021-09-01 13:35:32,825 - INFO -     |---- Elapsed time: 0:09:53.398525
# 2021-09-01 13:35:32,827 - INFO -
# Test Acc: Max 18.8744% (4 round) | Last 18.8744% | Avg 16.1641% (2 round)
#
# 2021-09-01 13:35:32,830 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 13:35:47,209 - INFO -   |-- [Party 1] Average Train Loss:   0.2454 Train Accuracy: global   0.00% local  94.65% ... 2061 forgettables out of 2130 (96.76%) ... total data used 2130
# 2021-09-01 13:35:47,211 - INFO -   |--    Epoch Losses (10): [0.6774, 0.4129, 0.2506, 0.1855, 0.1646, 0.138, 0.1457, 0.1553, 0.17, 0.1542]
# 2021-09-01 13:36:01,504 - INFO -   |-- [Party 2] Average Train Loss:   0.2416 Train Accuracy: global   0.00% local  98.08% ... 1900 forgettables out of 2130 (89.20%) ... total data used 2130
# 2021-09-01 13:36:01,506 - INFO -   |--    Epoch Losses (10): [0.6654, 0.4021, 0.2444, 0.1863, 0.172, 0.1443, 0.1597, 0.1538, 0.1516, 0.1366]
# 2021-09-01 13:36:16,009 - INFO -   |-- [Party 3] Average Train Loss:   0.2397 Train Accuracy: global   0.28% local  88.78% ... 2058 forgettables out of 2130 (96.62%) ... total data used 2130
# 2021-09-01 13:36:16,011 - INFO -   |--    Epoch Losses (10): [0.507, 0.3597, 0.2203, 0.1659, 0.1926, 0.1775, 0.1621, 0.198, 0.2203, 0.1935]
# 2021-09-01 13:36:31,834 - INFO -   |-- [Party 4] Average Train Loss:   0.2592 Train Accuracy: global   0.09% local  95.35% ... 1966 forgettables out of 2130 (92.30%) ... total data used 2130
# 2021-09-01 13:36:31,838 - INFO -   |--    Epoch Losses (10): [0.5211, 0.3693, 0.2429, 0.2157, 0.2087, 0.2043, 0.2027, 0.2117, 0.218, 0.1976]
# 2021-09-01 13:36:49,594 - INFO -   |-- [Party 5] Average Train Loss:   0.2533 Train Accuracy: global   0.33% local  94.84% ... 1760 forgettables out of 2130 (82.63%) ... total data used 2130
# 2021-09-01 13:36:49,596 - INFO -   |--    Epoch Losses (10): [0.5234, 0.3658, 0.2581, 0.2044, 0.199, 0.2043, 0.2049, 0.1948, 0.1912, 0.1872]
# 2021-09-01 13:37:05,880 - INFO -   |-- [Party 6] Average Train Loss:   0.2157 Train Accuracy: global  95.63% local  93.43% ...   67 forgettables out of 2130 ( 3.15%) ... total data used 2130
# 2021-09-01 13:37:05,881 - INFO -   |--    Epoch Losses (10): [0.3108, 0.2516, 0.207, 0.1857, 0.1836, 0.2056, 0.198, 0.2001, 0.2209, 0.1932]
# 2021-09-01 13:37:21,957 - INFO -   |-- [Party 7] Average Train Loss:   0.2044 Train Accuracy: global  95.73% local  97.56% ...   32 forgettables out of 2130 ( 1.50%) ... total data used 2130
# 2021-09-01 13:37:21,960 - INFO -   |--    Epoch Losses (10): [0.2932, 0.214, 0.2057, 0.2133, 0.2056, 0.1824, 0.1774, 0.1702, 0.1939, 0.188]
# 2021-09-01 13:37:36,211 - INFO -   |-- [Party 8] Average Train Loss:   0.2241 Train Accuracy: global  95.02% local  87.23% ...   53 forgettables out of 2130 ( 2.49%) ... total data used 2130
# 2021-09-01 13:37:36,212 - INFO -   |--    Epoch Losses (10): [0.3373, 0.2498, 0.2312, 0.2154, 0.2091, 0.2, 0.1964, 0.1896, 0.2094, 0.2027]
# 2021-09-01 13:37:52,336 - INFO -   |-- [Party 9] Average Train Loss:   0.2372 Train Accuracy: global  94.74% local  97.18% ...   72 forgettables out of 2130 ( 3.38%) ... total data used 2130
# 2021-09-01 13:37:52,337 - INFO -   |--    Epoch Losses (10): [0.3423, 0.2601, 0.2183, 0.2408, 0.2178, 0.2341, 0.2326, 0.2284, 0.1969, 0.2005]
# 2021-09-01 13:38:05,580 - INFO -     |---- Number of Forgettables: 9969 (52.00%)
# 2021-09-01 13:38:05,583 - INFO -     |---- Train Accuracy: 43.15%
# 2021-09-01 13:38:05,584 - INFO -     |---- Test Accuracy: 19.99%
# 2021-09-01 13:38:05,585 - INFO -     |---- Test Loss: 2.2044
# 2021-09-01 13:38:05,585 - INFO -     |---- Elapsed time: 0:12:26.158244
# 2021-09-01 13:38:05,586 - INFO -
# Test Acc: Max 19.9868% (5 round) | Last 19.9868% | Avg 16.9286% (2 round)
#
# 2021-09-01 13:38:05,590 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 13:38:22,003 - INFO -   |-- [Party 1] Average Train Loss:   0.2289 Train Accuracy: global   0.00% local  97.04% ... 2016 forgettables out of 2130 (94.65%) ... total data used 2130
# 2021-09-01 13:38:22,005 - INFO -   |--    Epoch Losses (10): [0.6593, 0.3911, 0.2413, 0.1661, 0.1397, 0.1203, 0.1349, 0.1301, 0.1521, 0.1545]
# 2021-09-01 13:38:38,316 - INFO -   |-- [Party 2] Average Train Loss:   0.2200 Train Accuracy: global   0.00% local  91.03% ... 2089 forgettables out of 2130 (98.08%) ... total data used 2130
# 2021-09-01 13:38:38,318 - INFO -   |--    Epoch Losses (10): [0.6428, 0.3715, 0.2284, 0.1587, 0.1474, 0.1409, 0.1331, 0.1332, 0.1292, 0.115]
# 2021-09-01 13:38:54,455 - INFO -   |-- [Party 3] Average Train Loss:   0.2224 Train Accuracy: global   0.89% local  97.70% ... 1872 forgettables out of 2130 (87.89%) ... total data used 2130
# 2021-09-01 13:38:54,456 - INFO -   |--    Epoch Losses (10): [0.4534, 0.3265, 0.2217, 0.1937, 0.1835, 0.1779, 0.1562, 0.1515, 0.1776, 0.1821]
# 2021-09-01 13:39:08,803 - INFO -   |-- [Party 4] Average Train Loss:   0.2357 Train Accuracy: global   1.60% local  95.35% ... 1997 forgettables out of 2130 (93.76%) ... total data used 2130
# 2021-09-01 13:39:08,805 - INFO -   |--    Epoch Losses (10): [0.5125, 0.3462, 0.233, 0.1891, 0.1798, 0.1771, 0.187, 0.1753, 0.1702, 0.1873]
# 2021-09-01 13:39:22,950 - INFO -   |-- [Party 5] Average Train Loss:   0.2259 Train Accuracy: global   1.31% local  96.01% ... 1992 forgettables out of 2130 (93.52%) ... total data used 2130
# 2021-09-01 13:39:22,952 - INFO -   |--    Epoch Losses (10): [0.4942, 0.3422, 0.2101, 0.1901, 0.2103, 0.192, 0.1565, 0.1462, 0.159, 0.1583]
# 2021-09-01 13:39:38,509 - INFO -   |-- [Party 6] Average Train Loss:   0.1933 Train Accuracy: global  96.43% local  96.34% ...   46 forgettables out of 2130 ( 2.16%) ... total data used 2130
# 2021-09-01 13:39:38,511 - INFO -   |--    Epoch Losses (10): [0.258, 0.1995, 0.1838, 0.1884, 0.1919, 0.1842, 0.1782, 0.1749, 0.1778, 0.196]
# 2021-09-01 13:39:52,638 - INFO -   |-- [Party 7] Average Train Loss:   0.1878 Train Accuracy: global  96.81% local  97.51% ...   47 forgettables out of 2130 ( 2.21%) ... total data used 2130
# 2021-09-01 13:39:52,640 - INFO -   |--    Epoch Losses (10): [0.2685, 0.2037, 0.1912, 0.1736, 0.176, 0.172, 0.1876, 0.1698, 0.1653, 0.1699]
# 2021-09-01 13:40:06,780 - INFO -   |-- [Party 8] Average Train Loss:   0.1909 Train Accuracy: global  96.43% local  95.77% ...   37 forgettables out of 2130 ( 1.74%) ... total data used 2130
# 2021-09-01 13:40:06,783 - INFO -   |--    Epoch Losses (10): [0.2712, 0.2371, 0.2098, 0.1816, 0.1616, 0.1649, 0.1752, 0.1807, 0.1715, 0.1554]
# 2021-09-01 13:40:23,142 - INFO -   |-- [Party 9] Average Train Loss:   0.2240 Train Accuracy: global  95.45% local  95.31% ...   66 forgettables out of 2130 ( 3.10%) ... total data used 2130
# 2021-09-01 13:40:23,143 - INFO -   |--    Epoch Losses (10): [0.3178, 0.2478, 0.2137, 0.2137, 0.2035, 0.1948, 0.2094, 0.2256, 0.221, 0.1929]
# 2021-09-01 13:40:34,746 - INFO -     |---- Number of Forgettables: 10162 (53.01%)
# 2021-09-01 13:40:34,747 - INFO -     |---- Train Accuracy: 46.42%
# 2021-09-01 13:40:34,749 - INFO -     |---- Test Accuracy: 22.42%
# 2021-09-01 13:40:34,750 - INFO -     |---- Test Loss: 2.1087
# 2021-09-01 13:40:34,752 - INFO -     |---- Elapsed time: 0:14:55.324832
# 2021-09-01 13:40:34,753 - INFO -
# Test Acc: Max 22.4220% (6 round) | Last 22.4220% | Avg 17.8442% (3 round)
#
# 2021-09-01 13:40:34,755 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 13:40:49,089 - INFO -   |-- [Party 1] Average Train Loss:   0.2176 Train Accuracy: global   0.00% local  96.57% ... 2067 forgettables out of 2130 (97.04%) ... total data used 2130
# 2021-09-01 13:40:49,090 - INFO -   |--    Epoch Losses (10): [0.6204, 0.3724, 0.2258, 0.1535, 0.1276, 0.1229, 0.1317, 0.1336, 0.1405, 0.1471]
# 2021-09-01 13:41:03,951 - INFO -   |-- [Party 2] Average Train Loss:   0.2143 Train Accuracy: global   0.00% local  99.11% ... 1939 forgettables out of 2130 (91.03%) ... total data used 2130
# 2021-09-01 13:41:03,954 - INFO -   |--    Epoch Losses (10): [0.6248, 0.3756, 0.2125, 0.144, 0.1359, 0.1232, 0.1486, 0.1381, 0.1181, 0.1224]
# 2021-09-01 13:41:18,889 - INFO -   |-- [Party 3] Average Train Loss:   0.2179 Train Accuracy: global  11.50% local  95.96% ... 1836 forgettables out of 2130 (86.20%) ... total data used 2130
# 2021-09-01 13:41:18,890 - INFO -   |--    Epoch Losses (10): [0.4637, 0.326, 0.2159, 0.1621, 0.1467, 0.1803, 0.1845, 0.1688, 0.166, 0.1651]
# 2021-09-01 13:41:34,100 - INFO -   |-- [Party 4] Average Train Loss:   0.2202 Train Accuracy: global  12.07% local  97.09% ... 1774 forgettables out of 2130 (83.29%) ... total data used 2130
# 2021-09-01 13:41:34,101 - INFO -   |--    Epoch Losses (10): [0.4684, 0.304, 0.2188, 0.1741, 0.1586, 0.1686, 0.1729, 0.1717, 0.1728, 0.1925]
# 2021-09-01 13:41:48,502 - INFO -   |-- [Party 5] Average Train Loss:   0.2105 Train Accuracy: global  11.08% local  88.08% ... 1809 forgettables out of 2130 (84.93%) ... total data used 2130
# 2021-09-01 13:41:48,507 - INFO -   |--    Epoch Losses (10): [0.4469, 0.3131, 0.1995, 0.1606, 0.1731, 0.1515, 0.1519, 0.1693, 0.1697, 0.1692]
# 2021-09-01 13:42:05,359 - INFO -   |-- [Party 6] Average Train Loss:   0.1843 Train Accuracy: global  95.92% local  95.12% ...   60 forgettables out of 2130 ( 2.82%) ... total data used 2130
# 2021-09-01 13:42:05,363 - INFO -   |--    Epoch Losses (10): [0.2518, 0.1988, 0.1482, 0.1793, 0.1884, 0.183, 0.1774, 0.1696, 0.1659, 0.1802]
# 2021-09-01 13:42:19,697 - INFO -   |-- [Party 7] Average Train Loss:   0.1718 Train Accuracy: global  96.20% local  94.37% ...   54 forgettables out of 2130 ( 2.54%) ... total data used 2130
# 2021-09-01 13:42:19,699 - INFO -   |--    Epoch Losses (10): [0.2646, 0.2021, 0.1588, 0.1462, 0.1459, 0.1541, 0.1911, 0.1749, 0.1466, 0.1341]
# 2021-09-01 13:42:34,441 - INFO -   |-- [Party 8] Average Train Loss:   0.1867 Train Accuracy: global  95.87% local  96.95% ...   39 forgettables out of 2130 ( 1.83%) ... total data used 2130
# 2021-09-01 13:42:34,444 - INFO -   |--    Epoch Losses (10): [0.2355, 0.2095, 0.1978, 0.1898, 0.1752, 0.1717, 0.176, 0.1691, 0.1645, 0.1779]
# 2021-09-01 13:42:48,629 - INFO -   |-- [Party 9] Average Train Loss:   0.1923 Train Accuracy: global  95.45% local  94.74% ...   70 forgettables out of 2130 ( 3.29%) ... total data used 2130
# 2021-09-01 13:42:48,631 - INFO -   |--    Epoch Losses (10): [0.2525, 0.2246, 0.1887, 0.1717, 0.1961, 0.1575, 0.1697, 0.1837, 0.1866, 0.1922]
# 2021-09-01 13:43:00,346 - INFO -     |---- Number of Forgettables: 9648 (50.33%)
# 2021-09-01 13:43:00,348 - INFO -     |---- Train Accuracy: 48.61%
# 2021-09-01 13:43:00,349 - INFO -     |---- Test Accuracy: 25.30%
# 2021-09-01 13:43:00,351 - INFO -     |---- Test Loss: 2.0638
# 2021-09-01 13:43:00,352 - INFO -     |---- Elapsed time: 0:17:20.924740
# 2021-09-01 13:43:00,353 - INFO -
# Test Acc: Max 25.2961% (7 round) | Last 25.2961% | Avg 18.9088% (5 round)
#
# 2021-09-01 13:43:00,356 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 13:43:16,293 - INFO -   |-- [Party 1] Average Train Loss:   0.2106 Train Accuracy: global   0.00% local  97.23% ... 2057 forgettables out of 2130 (96.57%) ... total data used 2130
# 2021-09-01 13:43:16,295 - INFO -   |--    Epoch Losses (10): [0.6091, 0.3603, 0.2019, 0.1327, 0.1202, 0.1406, 0.1505, 0.1379, 0.1164, 0.1366]
# 2021-09-01 13:43:30,475 - INFO -   |-- [Party 2] Average Train Loss:   0.1963 Train Accuracy: global   0.00% local  97.23% ... 2111 forgettables out of 2130 (99.11%) ... total data used 2130
# 2021-09-01 13:43:30,477 - INFO -   |--    Epoch Losses (10): [0.5854, 0.3464, 0.1972, 0.1317, 0.1233, 0.1203, 0.1128, 0.1154, 0.1183, 0.1121]
# 2021-09-01 13:43:45,703 - INFO -   |-- [Party 3] Average Train Loss:   0.1900 Train Accuracy: global  17.42% local  90.47% ... 1673 forgettables out of 2130 (78.54%) ... total data used 2130
# 2021-09-01 13:43:45,704 - INFO -   |--    Epoch Losses (10): [0.4069, 0.2718, 0.1654, 0.1612, 0.1444, 0.1503, 0.143, 0.1511, 0.1328, 0.173]
# 2021-09-01 13:44:00,964 - INFO -   |-- [Party 4] Average Train Loss:   0.2098 Train Accuracy: global  18.31% local  97.79% ... 1678 forgettables out of 2130 (78.78%) ... total data used 2130
# 2021-09-01 13:44:00,966 - INFO -   |--    Epoch Losses (10): [0.4347, 0.3069, 0.2028, 0.1668, 0.1557, 0.1797, 0.1578, 0.1675, 0.1639, 0.1625]
# 2021-09-01 13:44:17,054 - INFO -   |-- [Party 5] Average Train Loss:   0.1900 Train Accuracy: global  18.59% local  95.40% ... 1482 forgettables out of 2130 (69.58%) ... total data used 2130
# 2021-09-01 13:44:17,055 - INFO -   |--    Epoch Losses (10): [0.4357, 0.2827, 0.1856, 0.1443, 0.1669, 0.1455, 0.1294, 0.1267, 0.1378, 0.1452]
# 2021-09-01 13:44:31,217 - INFO -   |-- [Party 6] Average Train Loss:   0.1692 Train Accuracy: global  96.57% local  96.85% ...   31 forgettables out of 2130 ( 1.46%) ... total data used 2130
# 2021-09-01 13:44:31,219 - INFO -   |--    Epoch Losses (10): [0.2506, 0.1784, 0.1549, 0.1612, 0.1594, 0.1406, 0.1434, 0.1698, 0.1698, 0.1637]
# 2021-09-01 13:44:45,260 - INFO -   |-- [Party 7] Average Train Loss:   0.1651 Train Accuracy: global  96.67% local  97.46% ...   38 forgettables out of 2130 ( 1.78%) ... total data used 2130
# 2021-09-01 13:44:45,261 - INFO -   |--    Epoch Losses (10): [0.2343, 0.189, 0.1627, 0.1542, 0.1596, 0.1542, 0.1363, 0.1654, 0.1448, 0.1507]
# 2021-09-01 13:44:59,643 - INFO -   |-- [Party 8] Average Train Loss:   0.1825 Train Accuracy: global  96.24% local  97.28% ...   49 forgettables out of 2130 ( 2.30%) ... total data used 2130
# 2021-09-01 13:44:59,644 - INFO -   |--    Epoch Losses (10): [0.2386, 0.2098, 0.1828, 0.1615, 0.1643, 0.1652, 0.1586, 0.1652, 0.1845, 0.1942]
# 2021-09-01 13:45:14,639 - INFO -   |-- [Party 9] Average Train Loss:   0.1882 Train Accuracy: global  95.63% local  96.67% ...   68 forgettables out of 2130 ( 3.19%) ... total data used 2130
# 2021-09-01 13:45:14,642 - INFO -   |--    Epoch Losses (10): [0.2439, 0.221, 0.1933, 0.1863, 0.1638, 0.1623, 0.1958, 0.1882, 0.1631, 0.1644]
# 2021-09-01 13:45:26,361 - INFO -     |---- Number of Forgettables: 9187 (47.92%)
# 2021-09-01 13:45:26,363 - INFO -     |---- Train Accuracy: 52.30%
# 2021-09-01 13:45:26,364 - INFO -     |---- Test Accuracy: 28.97%
# 2021-09-01 13:45:26,364 - INFO -     |---- Test Loss: 1.8944
# 2021-09-01 13:45:26,365 - INFO -     |---- Elapsed time: 0:19:46.938116
# 2021-09-01 13:45:26,366 - INFO -
# Test Acc: Max 28.9700% (8 round) | Last 28.9700% | Avg 20.1664% (6 round)
#
# 2021-09-01 13:45:26,368 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 13:45:40,656 - INFO -   |-- [Party 1] Average Train Loss:   0.2028 Train Accuracy: global   0.00% local  98.22% ... 2071 forgettables out of 2130 (97.23%) ... total data used 2130
# 2021-09-01 13:45:40,658 - INFO -   |--    Epoch Losses (10): [0.5827, 0.345, 0.2022, 0.1651, 0.1253, 0.1145, 0.1142, 0.121, 0.1276, 0.1303]
# 2021-09-01 13:45:54,732 - INFO -   |-- [Party 2] Average Train Loss:   0.1918 Train Accuracy: global   0.00% local  98.26% ... 2071 forgettables out of 2130 (97.23%) ... total data used 2130
# 2021-09-01 13:45:54,734 - INFO -   |--    Epoch Losses (10): [0.5906, 0.3364, 0.1903, 0.1357, 0.1079, 0.1237, 0.1092, 0.1116, 0.1013, 0.1118]
# 2021-09-01 13:46:08,917 - INFO -   |-- [Party 3] Average Train Loss:   0.1815 Train Accuracy: global  29.95% local  96.85% ... 1312 forgettables out of 2130 (61.60%) ... total data used 2130
# 2021-09-01 13:46:08,921 - INFO -   |--    Epoch Losses (10): [0.4037, 0.2478, 0.1671, 0.1477, 0.1412, 0.1457, 0.1443, 0.1418, 0.1477, 0.128]
# 2021-09-01 13:46:25,267 - INFO -   |-- [Party 4] Average Train Loss:   0.1962 Train Accuracy: global  29.58% local  97.89% ... 1453 forgettables out of 2130 (68.22%) ... total data used 2130
# 2021-09-01 13:46:25,271 - INFO -   |--    Epoch Losses (10): [0.4202, 0.2761, 0.177, 0.1786, 0.1612, 0.1433, 0.1349, 0.146, 0.1604, 0.1641]
# 2021-09-01 13:46:39,412 - INFO -   |-- [Party 5] Average Train Loss:   0.1802 Train Accuracy: global  29.15% local  96.20% ... 1411 forgettables out of 2130 (66.24%) ... total data used 2130
# 2021-09-01 13:46:39,413 - INFO -   |--    Epoch Losses (10): [0.4273, 0.2732, 0.1568, 0.1366, 0.1302, 0.1335, 0.1294, 0.1342, 0.1431, 0.1381]
# 2021-09-01 13:46:53,864 - INFO -   |-- [Party 6] Average Train Loss:   0.1582 Train Accuracy: global  95.45% local  83.00% ...   74 forgettables out of 2130 ( 3.47%) ... total data used 2130
# 2021-09-01 13:46:53,865 - INFO -   |--    Epoch Losses (10): [0.2065, 0.173, 0.1562, 0.1769, 0.1558, 0.1471, 0.1241, 0.149, 0.1408, 0.153]
# 2021-09-01 13:47:09,070 - INFO -   |-- [Party 7] Average Train Loss:   0.1508 Train Accuracy: global  95.77% local  97.70% ...   70 forgettables out of 2130 ( 3.29%) ... total data used 2130
# 2021-09-01 13:47:09,071 - INFO -   |--    Epoch Losses (10): [0.2022, 0.1757, 0.1437, 0.1484, 0.1415, 0.1375, 0.1401, 0.1379, 0.1355, 0.1456]
# 2021-09-01 13:47:25,656 - INFO -   |-- [Party 8] Average Train Loss:   0.1690 Train Accuracy: global  95.59% local  96.76% ...   63 forgettables out of 2130 ( 2.96%) ... total data used 2130
# 2021-09-01 13:47:25,658 - INFO -   |--    Epoch Losses (10): [0.2167, 0.1797, 0.1725, 0.1688, 0.1795, 0.1642, 0.1632, 0.1569, 0.1419, 0.1464]
# 2021-09-01 13:47:40,756 - INFO -   |-- [Party 9] Average Train Loss:   0.1725 Train Accuracy: global  94.79% local  97.32% ...   71 forgettables out of 2130 ( 3.33%) ... total data used 2130
# 2021-09-01 13:47:40,760 - INFO -   |--    Epoch Losses (10): [0.239, 0.1798, 0.1607, 0.1763, 0.175, 0.1561, 0.1508, 0.1512, 0.1641, 0.1718]
# 2021-09-01 13:47:52,678 - INFO -     |---- Number of Forgettables: 8596 (44.84%)
# 2021-09-01 13:47:52,680 - INFO -     |---- Train Accuracy: 52.04%
# 2021-09-01 13:47:52,681 - INFO -     |---- Test Accuracy: 30.05%
# 2021-09-01 13:47:52,681 - INFO -     |---- Test Loss: 1.8743
# 2021-09-01 13:47:52,682 - INFO -     |---- Elapsed time: 0:22:13.255515
# 2021-09-01 13:47:52,683 - INFO -
# Test Acc: Max 30.0463% (9 round) | Last 30.0463% | Avg 21.2642% (6 round)
#
# 2021-09-01 13:47:52,685 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 13:48:08,790 - INFO -   |-- [Party 1] Average Train Loss:   0.1862 Train Accuracy: global   0.00% local  98.97% ... 2092 forgettables out of 2130 (98.22%) ... total data used 2130
# 2021-09-01 13:48:08,792 - INFO -   |--    Epoch Losses (10): [0.5668, 0.32, 0.1811, 0.1352, 0.1106, 0.1066, 0.1023, 0.1192, 0.1142, 0.1063]
# 2021-09-01 13:48:22,943 - INFO -   |-- [Party 2] Average Train Loss:   0.1909 Train Accuracy: global   0.00% local  98.69% ... 2093 forgettables out of 2130 (98.26%) ... total data used 2130
# 2021-09-01 13:48:22,946 - INFO -   |--    Epoch Losses (10): [0.5775, 0.3214, 0.1831, 0.1284, 0.1025, 0.1156, 0.117, 0.0972, 0.1241, 0.1425]
# 2021-09-01 13:48:37,986 - INFO -   |-- [Party 3] Average Train Loss:   0.1764 Train Accuracy: global  28.08% local  95.92% ... 1468 forgettables out of 2130 (68.92%) ... total data used 2130
# 2021-09-01 13:48:37,987 - INFO -   |--    Epoch Losses (10): [0.3911, 0.2534, 0.1537, 0.1177, 0.1076, 0.175, 0.1635, 0.1489, 0.1342, 0.1193]
# 2021-09-01 13:48:53,829 - INFO -   |-- [Party 4] Average Train Loss:   0.1890 Train Accuracy: global  27.75% local  97.04% ... 1495 forgettables out of 2130 (70.19%) ... total data used 2130
# 2021-09-01 13:48:53,830 - INFO -   |--    Epoch Losses (10): [0.4147, 0.2669, 0.1912, 0.1672, 0.1582, 0.1571, 0.1572, 0.1326, 0.1123, 0.133]
# 2021-09-01 13:49:07,437 - INFO -   |-- [Party 5] Average Train Loss:   0.1765 Train Accuracy: global  27.28% local  94.46% ... 1469 forgettables out of 2130 (68.97%) ... total data used 2130
# 2021-09-01 13:49:07,439 - INFO -   |--    Epoch Losses (10): [0.4015, 0.2575, 0.1833, 0.1382, 0.1103, 0.1266, 0.1451, 0.1428, 0.124, 0.1362]
# 2021-09-01 13:49:21,558 - INFO -   |-- [Party 6] Average Train Loss:   0.1532 Train Accuracy: global  96.62% local  97.37% ...   56 forgettables out of 2130 ( 2.63%) ... total data used 2130
# 2021-09-01 13:49:21,560 - INFO -   |--    Epoch Losses (10): [0.2215, 0.1513, 0.1345, 0.1325, 0.1527, 0.1345, 0.145, 0.1539, 0.156, 0.1506]
# 2021-09-01 13:49:37,001 - INFO -   |-- [Party 7] Average Train Loss:   0.1480 Train Accuracy: global  97.04% local  78.40% ...   37 forgettables out of 2130 ( 1.74%) ... total data used 2130
# 2021-09-01 13:49:37,003 - INFO -   |--    Epoch Losses (10): [0.2082, 0.15, 0.1295, 0.1408, 0.14, 0.1552, 0.1492, 0.1506, 0.1232, 0.1336]
# 2021-09-01 13:49:53,658 - INFO -   |-- [Party 8] Average Train Loss:   0.1605 Train Accuracy: global  96.01% local  94.93% ...   42 forgettables out of 2130 ( 1.97%) ... total data used 2130
# 2021-09-01 13:49:53,659 - INFO -   |--    Epoch Losses (10): [0.2258, 0.1834, 0.1361, 0.1532, 0.1609, 0.1591, 0.1544, 0.1601, 0.1435, 0.1284]
# 2021-09-01 13:50:09,574 - INFO -   |-- [Party 9] Average Train Loss:   0.1655 Train Accuracy: global  96.06% local  96.62% ...   60 forgettables out of 2130 ( 2.82%) ... total data used 2130
# 2021-09-01 13:50:09,575 - INFO -   |--    Epoch Losses (10): [0.2239, 0.1829, 0.1625, 0.1604, 0.151, 0.1348, 0.1423, 0.1513, 0.1629, 0.1835]
# 2021-09-01 13:50:21,268 - INFO -     |---- Number of Forgettables: 8812 (45.97%)
# 2021-09-01 13:50:21,269 - INFO -     |---- Train Accuracy: 55.33%
# 2021-09-01 13:50:21,269 - INFO -     |---- Test Accuracy: 32.67%
# 2021-09-01 13:50:21,270 - INFO -     |---- Test Loss: 2.0203
# 2021-09-01 13:50:21,270 - INFO -     |---- Elapsed time: 0:24:41.843136
# 2021-09-01 13:50:21,271 - INFO -
# Test Acc: Max 32.6679% (10 round) | Last 32.6679% | Avg 22.4045% (6 round)
#
# 2021-09-01 13:50:21,272 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 13:50:36,239 - INFO -   |-- [Party 1] Average Train Loss:   0.1852 Train Accuracy: global   0.00% local  95.40% ... 2108 forgettables out of 2130 (98.97%) ... total data used 2130
# 2021-09-01 13:50:36,240 - INFO -   |--    Epoch Losses (10): [0.5483, 0.3379, 0.2043, 0.1301, 0.1159, 0.1004, 0.1033, 0.0891, 0.0899, 0.1333]
# 2021-09-01 13:50:50,411 - INFO -   |-- [Party 2] Average Train Loss:   0.1817 Train Accuracy: global   0.00% local  97.79% ... 2102 forgettables out of 2130 (98.69%) ... total data used 2130
# 2021-09-01 13:50:50,413 - INFO -   |--    Epoch Losses (10): [0.5645, 0.3276, 0.1946, 0.1267, 0.1224, 0.1053, 0.0977, 0.0916, 0.0954, 0.0915]
# 2021-09-01 13:51:04,453 - INFO -   |-- [Party 3] Average Train Loss:   0.1669 Train Accuracy: global  39.72% local  96.67% ... 1197 forgettables out of 2130 (56.20%) ... total data used 2130
# 2021-09-01 13:51:04,455 - INFO -   |--    Epoch Losses (10): [0.369, 0.2325, 0.1565, 0.1159, 0.1218, 0.1219, 0.1488, 0.1461, 0.1401, 0.1161]
# 2021-09-01 13:51:20,593 - INFO -   |-- [Party 4] Average Train Loss:   0.1794 Train Accuracy: global  38.78% local  94.46% ... 1251 forgettables out of 2130 (58.73%) ... total data used 2130
# 2021-09-01 13:51:20,594 - INFO -   |--    Epoch Losses (10): [0.3816, 0.2652, 0.1681, 0.1311, 0.1566, 0.1574, 0.1274, 0.13, 0.1398, 0.1373]
# 2021-09-01 13:51:34,744 - INFO -   |-- [Party 5] Average Train Loss:   0.1762 Train Accuracy: global  38.36% local  93.29% ... 1196 forgettables out of 2130 (56.15%) ... total data used 2130
# 2021-09-01 13:51:34,745 - INFO -   |--    Epoch Losses (10): [0.3901, 0.2577, 0.1767, 0.1305, 0.1215, 0.137, 0.1299, 0.1354, 0.1369, 0.1468]
# 2021-09-01 13:51:48,932 - INFO -   |-- [Party 6] Average Train Loss:   0.1499 Train Accuracy: global  95.68% local  97.98% ...   55 forgettables out of 2130 ( 2.58%) ... total data used 2130
# 2021-09-01 13:51:48,934 - INFO -   |--    Epoch Losses (10): [0.1858, 0.1628, 0.1527, 0.1411, 0.137, 0.1748, 0.1445, 0.1417, 0.1264, 0.132]
# 2021-09-01 13:52:03,045 - INFO -   |-- [Party 7] Average Train Loss:   0.1373 Train Accuracy: global  96.15% local  90.38% ...   16 forgettables out of 2130 ( 0.75%) ... total data used 2130
# 2021-09-01 13:52:03,046 - INFO -   |--    Epoch Losses (10): [0.1964, 0.1505, 0.1349, 0.1206, 0.1417, 0.1162, 0.1168, 0.1345, 0.1254, 0.1363]
# 2021-09-01 13:52:17,210 - INFO -   |-- [Party 8] Average Train Loss:   0.1521 Train Accuracy: global  95.49% local  97.75% ...   45 forgettables out of 2130 ( 2.11%) ... total data used 2130
# 2021-09-01 13:52:17,211 - INFO -   |--    Epoch Losses (10): [0.218, 0.1884, 0.1706, 0.1466, 0.1407, 0.1266, 0.1379, 0.133, 0.1249, 0.1344]
# 2021-09-01 13:52:31,574 - INFO -   |-- [Party 9] Average Train Loss:   0.1606 Train Accuracy: global  95.07% local  94.55% ...   92 forgettables out of 2130 ( 4.32%) ... total data used 2130
# 2021-09-01 13:52:31,576 - INFO -   |--    Epoch Losses (10): [0.2147, 0.1929, 0.1825, 0.1646, 0.1379, 0.138, 0.1351, 0.1513, 0.1456, 0.1436]
# 2021-09-01 13:52:43,280 - INFO -     |---- Number of Forgettables: 8062 (42.06%)
# 2021-09-01 13:52:43,282 - INFO -     |---- Train Accuracy: 57.88%
# 2021-09-01 13:52:43,283 - INFO -     |---- Test Accuracy: 37.25%
# 2021-09-01 13:52:43,285 - INFO -     |---- Test Loss: 1.7313
# 2021-09-01 13:52:43,286 - INFO -     |---- Elapsed time: 0:27:03.858805
# 2021-09-01 13:52:43,287 - INFO -
# Test Acc: Max 37.2497% (11 round) | Last 37.2497% | Avg 23.7541% (7 round)
#
# 2021-09-01 13:52:43,291 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 13:53:00,079 - INFO -   |-- [Party 1] Average Train Loss:   0.1796 Train Accuracy: global   0.00% local  97.84% ... 2032 forgettables out of 2130 (95.40%) ... total data used 2130
# 2021-09-01 13:53:00,083 - INFO -   |--    Epoch Losses (10): [0.5357, 0.3101, 0.1745, 0.1188, 0.1176, 0.1204, 0.102, 0.1051, 0.1067, 0.1052]
# 2021-09-01 13:53:14,367 - INFO -   |-- [Party 2] Average Train Loss:   0.1754 Train Accuracy: global   0.00% local  97.51% ... 2083 forgettables out of 2130 (97.79%) ... total data used 2130
# 2021-09-01 13:53:14,369 - INFO -   |--    Epoch Losses (10): [0.5415, 0.3119, 0.168, 0.1066, 0.0898, 0.081, 0.0963, 0.1079, 0.1253, 0.1257]
# 2021-09-01 13:53:29,300 - INFO -   |-- [Party 3] Average Train Loss:   0.1580 Train Accuracy: global  46.01% local  90.33% ... 1080 forgettables out of 2130 (50.70%) ... total data used 2130
# 2021-09-01 13:53:29,304 - INFO -   |--    Epoch Losses (10): [0.3677, 0.2398, 0.1493, 0.119, 0.1093, 0.1088, 0.1131, 0.127, 0.1189, 0.127]
# 2021-09-01 13:53:43,579 - INFO -   |-- [Party 4] Average Train Loss:   0.1725 Train Accuracy: global  44.65% local  96.95% ... 1067 forgettables out of 2130 (50.09%) ... total data used 2130
# 2021-09-01 13:53:43,580 - INFO -   |--    Epoch Losses (10): [0.406, 0.2622, 0.1681, 0.1341, 0.127, 0.1232, 0.1241, 0.1254, 0.1275, 0.1272]
# 2021-09-01 13:53:57,781 - INFO -   |-- [Party 5] Average Train Loss:   0.1651 Train Accuracy: global  45.77% local  97.04% ... 1059 forgettables out of 2130 (49.72%) ... total data used 2130
# 2021-09-01 13:53:57,784 - INFO -   |--    Epoch Losses (10): [0.3787, 0.2428, 0.1573, 0.1403, 0.1125, 0.103, 0.11, 0.1267, 0.133, 0.1466]
# 2021-09-01 13:54:12,045 - INFO -   |-- [Party 6] Average Train Loss:   0.1462 Train Accuracy: global  95.87% local  97.09% ...   62 forgettables out of 2130 ( 2.91%) ... total data used 2130
# 2021-09-01 13:54:12,047 - INFO -   |--    Epoch Losses (10): [0.2134, 0.1602, 0.148, 0.1261, 0.138, 0.1414, 0.1541, 0.1314, 0.1304, 0.1185]
# 2021-09-01 13:54:28,397 - INFO -   |-- [Party 7] Average Train Loss:   0.1423 Train Accuracy: global  96.57% local  98.59% ...   24 forgettables out of 2130 ( 1.13%) ... total data used 2130
# 2021-09-01 13:54:28,398 - INFO -   |--    Epoch Losses (10): [0.2028, 0.1741, 0.1255, 0.1128, 0.1227, 0.1217, 0.1404, 0.1452, 0.125, 0.153]
# 2021-09-01 13:54:41,989 - INFO -   |-- [Party 8] Average Train Loss:   0.1453 Train Accuracy: global  95.49% local  97.28% ...   64 forgettables out of 2130 ( 3.00%) ... total data used 2130
# 2021-09-01 13:54:41,992 - INFO -   |--    Epoch Losses (10): [0.2201, 0.1492, 0.1411, 0.1302, 0.1216, 0.144, 0.1367, 0.138, 0.1377, 0.1344]
# 2021-09-01 13:54:55,526 - INFO -   |-- [Party 9] Average Train Loss:   0.1592 Train Accuracy: global  95.49% local  93.80% ...   56 forgettables out of 2130 ( 2.63%) ... total data used 2130
# 2021-09-01 13:54:55,528 - INFO -   |--    Epoch Losses (10): [0.2075, 0.18, 0.1624, 0.1465, 0.1387, 0.1373, 0.1387, 0.1361, 0.1613, 0.1835]
# 2021-09-01 13:55:07,304 - INFO -     |---- Number of Forgettables: 7527 (39.26%)
# 2021-09-01 13:55:07,305 - INFO -     |---- Train Accuracy: 58.78%
# 2021-09-01 13:55:07,306 - INFO -     |---- Test Accuracy: 38.21%
# 2021-09-01 13:55:07,307 - INFO -     |---- Test Loss: 1.7881
# 2021-09-01 13:55:07,308 - INFO -     |---- Elapsed time: 0:29:27.881456
# 2021-09-01 13:55:07,310 - INFO -
# Test Acc: Max 38.2058% (12 round) | Last 38.2058% | Avg 24.9584% (7 round)
#
# 2021-09-01 13:55:07,312 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 13:55:23,353 - INFO -   |-- [Party 1] Average Train Loss:   0.1805 Train Accuracy: global   0.00% local  99.01% ... 2084 forgettables out of 2130 (97.84%) ... total data used 2130
# 2021-09-01 13:55:23,354 - INFO -   |--    Epoch Losses (10): [0.5485, 0.3294, 0.1844, 0.1318, 0.0981, 0.0848, 0.1097, 0.1116, 0.1109, 0.0954]
# 2021-09-01 13:55:39,526 - INFO -   |-- [Party 2] Average Train Loss:   0.1682 Train Accuracy: global   0.00% local  96.62% ... 2077 forgettables out of 2130 (97.51%) ... total data used 2130
# 2021-09-01 13:55:39,529 - INFO -   |--    Epoch Losses (10): [0.5254, 0.2932, 0.1751, 0.1184, 0.0923, 0.0966, 0.0969, 0.1048, 0.0961, 0.0831]
# 2021-09-01 13:55:54,636 - INFO -   |-- [Party 3] Average Train Loss:   0.1525 Train Accuracy: global  48.22% local  97.84% ...  910 forgettables out of 2130 (42.72%) ... total data used 2130
# 2021-09-01 13:55:54,638 - INFO -   |--    Epoch Losses (10): [0.3419, 0.2237, 0.1367, 0.1177, 0.1211, 0.1238, 0.1192, 0.1069, 0.1063, 0.1271]
# 2021-09-01 13:56:11,443 - INFO -   |-- [Party 4] Average Train Loss:   0.1689 Train Accuracy: global  47.28% local  97.84% ... 1066 forgettables out of 2130 (50.05%) ... total data used 2130
# 2021-09-01 13:56:11,446 - INFO -   |--    Epoch Losses (10): [0.3609, 0.2417, 0.1373, 0.1219, 0.1443, 0.137, 0.1502, 0.137, 0.1366, 0.1223]
# 2021-09-01 13:56:25,657 - INFO -   |-- [Party 5] Average Train Loss:   0.1567 Train Accuracy: global  46.85% local  98.36% ... 1083 forgettables out of 2130 (50.85%) ... total data used 2130
# 2021-09-01 13:56:25,660 - INFO -   |--    Epoch Losses (10): [0.348, 0.2093, 0.1307, 0.1157, 0.135, 0.1252, 0.1069, 0.1059, 0.1442, 0.1456]
# 2021-09-01 13:56:40,263 - INFO -   |-- [Party 6] Average Train Loss:   0.1344 Train Accuracy: global  96.38% local  98.22% ...   48 forgettables out of 2130 ( 2.25%) ... total data used 2130
# 2021-09-01 13:56:40,266 - INFO -   |--    Epoch Losses (10): [0.1828, 0.1607, 0.1506, 0.1385, 0.1178, 0.1101, 0.1221, 0.1169, 0.1091, 0.1353]
# 2021-09-01 13:56:56,710 - INFO -   |-- [Party 7] Average Train Loss:   0.1375 Train Accuracy: global  97.28% local  97.04% ...   40 forgettables out of 2130 ( 1.88%) ... total data used 2130
# 2021-09-01 13:56:56,710 - INFO -   |--    Epoch Losses (10): [0.1878, 0.1422, 0.1231, 0.1375, 0.1267, 0.1333, 0.1511, 0.1289, 0.1228, 0.1217]
# 2021-09-01 13:57:12,114 - INFO -   |-- [Party 8] Average Train Loss:   0.1391 Train Accuracy: global  95.68% local  97.46% ...   70 forgettables out of 2130 ( 3.29%) ... total data used 2130
# 2021-09-01 13:57:12,116 - INFO -   |--    Epoch Losses (10): [0.2086, 0.1584, 0.1447, 0.1364, 0.1382, 0.126, 0.1173, 0.1163, 0.1337, 0.1115]
# 2021-09-01 13:57:26,664 - INFO -   |-- [Party 9] Average Train Loss:   0.1485 Train Accuracy: global  95.49% local  97.84% ...   48 forgettables out of 2130 ( 2.25%) ... total data used 2130
# 2021-09-01 13:57:26,667 - INFO -   |--    Epoch Losses (10): [0.1978, 0.1604, 0.1524, 0.1572, 0.1297, 0.1362, 0.1468, 0.1454, 0.1286, 0.1306]
# 2021-09-01 13:57:38,448 - INFO -     |---- Number of Forgettables: 7426 (38.74%)
# 2021-09-01 13:57:38,450 - INFO -     |---- Train Accuracy: 58.86%
# 2021-09-01 13:57:38,451 - INFO -     |---- Test Accuracy: 38.57%
# 2021-09-01 13:57:38,451 - INFO -     |---- Test Loss: 1.5664
# 2021-09-01 13:57:38,452 - INFO -     |---- Elapsed time: 0:31:59.025198
# 2021-09-01 13:57:38,453 - INFO -
# Test Acc: Max 38.5665% (13 round) | Last 38.5665% | Avg 26.0052% (8 round)
#
# 2021-09-01 13:57:38,456 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 13:57:52,938 - INFO -   |-- [Party 1] Average Train Loss:   0.1703 Train Accuracy: global   0.00% local  95.45% ... 2109 forgettables out of 2130 (99.01%) ... total data used 2130
# 2021-09-01 13:57:52,940 - INFO -   |--    Epoch Losses (10): [0.5027, 0.2935, 0.1704, 0.1247, 0.1029, 0.0968, 0.1019, 0.0959, 0.1082, 0.1066]
# 2021-09-01 13:58:07,179 - INFO -   |-- [Party 2] Average Train Loss:   0.1618 Train Accuracy: global   0.00% local  98.54% ... 2058 forgettables out of 2130 (96.62%) ... total data used 2130
# 2021-09-01 13:58:07,181 - INFO -   |--    Epoch Losses (10): [0.5156, 0.2844, 0.1581, 0.1053, 0.0911, 0.0799, 0.0935, 0.0847, 0.0955, 0.1096]
# 2021-09-01 13:58:21,655 - INFO -   |-- [Party 3] Average Train Loss:   0.1447 Train Accuracy: global  47.65% local  98.03% ... 1073 forgettables out of 2130 (50.38%) ... total data used 2130
# 2021-09-01 13:58:21,656 - INFO -   |--    Epoch Losses (10): [0.3296, 0.2288, 0.1405, 0.1053, 0.0989, 0.1014, 0.0982, 0.0993, 0.118, 0.1269]
# 2021-09-01 13:58:37,546 - INFO -   |-- [Party 4] Average Train Loss:   0.1606 Train Accuracy: global  47.79% local  98.73% ... 1068 forgettables out of 2130 (50.14%) ... total data used 2130
# 2021-09-01 13:58:37,547 - INFO -   |--    Epoch Losses (10): [0.3454, 0.2212, 0.1371, 0.1441, 0.1368, 0.1235, 0.1204, 0.1258, 0.1268, 0.1253]
# 2021-09-01 13:58:53,261 - INFO -   |-- [Party 5] Average Train Loss:   0.1453 Train Accuracy: global  46.48% local  97.84% ... 1106 forgettables out of 2130 (51.92%) ... total data used 2130
# 2021-09-01 13:58:53,263 - INFO -   |--    Epoch Losses (10): [0.3203, 0.1898, 0.1372, 0.1056, 0.1134, 0.1089, 0.1032, 0.116, 0.1296, 0.1287]
# 2021-09-01 13:59:07,974 - INFO -   |-- [Party 6] Average Train Loss:   0.1376 Train Accuracy: global  96.81% local  85.45% ...   56 forgettables out of 2130 ( 2.63%) ... total data used 2130
# 2021-09-01 13:59:07,978 - INFO -   |--    Epoch Losses (10): [0.2049, 0.1699, 0.123, 0.1166, 0.1018, 0.1054, 0.1174, 0.1235, 0.1619, 0.1515]
# ...
# 2021-09-01 21:33:27,113 - INFO -   |--    Epoch Losses (10): [0.0465, 0.0263, 0.0152, 0.0234, 0.0682, 0.1407, 0.1602, 0.1501, 0.111, 0.0671]
# 2021-09-01 21:33:41,399 - INFO -   |-- [Party 6] Average Train Loss:   0.0332 Train Accuracy: global  94.27% local 100.00% ...  122 forgettables out of 2130 ( 5.73%) ... total data used 2130
# 2021-09-01 21:33:41,401 - INFO -   |--    Epoch Losses (10): [0.0833, 0.0918, 0.0628, 0.0422, 0.0254, 0.0129, 0.0063, 0.0034, 0.0021, 0.0017]
# 2021-09-01 21:33:57,466 - INFO -   |-- [Party 7] Average Train Loss:   0.0566 Train Accuracy: global  94.69% local 100.00% ...  113 forgettables out of 2130 ( 5.31%) ... total data used 2130
# 2021-09-01 21:33:57,469 - INFO -   |--    Epoch Losses (10): [0.055, 0.0514, 0.0375, 0.0485, 0.0613, 0.0598, 0.0684, 0.0726, 0.0638, 0.048]
# 2021-09-01 21:34:12,788 - INFO -   |-- [Party 8] Average Train Loss:   0.0499 Train Accuracy: global  94.60% local 100.00% ...  115 forgettables out of 2130 ( 5.40%) ... total data used 2130
# 2021-09-01 21:34:12,790 - INFO -   |--    Epoch Losses (10): [0.0649, 0.0565, 0.0551, 0.0495, 0.071, 0.0733, 0.0528, 0.0391, 0.0244, 0.0122]
# 2021-09-01 21:34:29,632 - INFO -   |-- [Party 9] Average Train Loss:   0.0555 Train Accuracy: global  94.32% local 100.00% ...  121 forgettables out of 2130 ( 5.68%) ... total data used 2130
# 2021-09-01 21:34:29,634 - INFO -   |--    Epoch Losses (10): [0.058, 0.0568, 0.0694, 0.0846, 0.0679, 0.0514, 0.0518, 0.0518, 0.0411, 0.0218]
# 2021-09-01 21:34:42,621 - INFO -     |---- Number of Forgettables: 3516 (18.34%)
# 2021-09-01 21:34:42,623 - INFO -     |---- Train Accuracy: 77.98%
# 2021-09-01 21:34:42,624 - INFO -     |---- Test Accuracy: 68.20%
# 2021-09-01 21:34:42,625 - INFO -     |---- Test Loss: 0.8682
# 2021-09-01 21:34:42,626 - INFO -     |---- Elapsed time: 8:09:03.198885
# 2021-09-01 21:34:42,627 - INFO -
# Test Acc: Max 68.1979% (194 round) | Last 68.1979% | Avg 58.9583% (62 round)
#
# 2021-09-01 21:34:42,631 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 21:34:58,975 - INFO -   |-- [Party 1] Average Train Loss:   0.0524 Train Accuracy: global  52.63% local 100.00% ... 1009 forgettables out of 2130 (47.37%) ... total data used 2130
# 2021-09-01 21:34:58,977 - INFO -   |--    Epoch Losses (10): [0.1343, 0.0952, 0.0789, 0.0745, 0.0582, 0.0347, 0.0196, 0.0123, 0.0093, 0.007]
# 2021-09-01 21:35:15,539 - INFO -   |-- [Party 2] Average Train Loss:   0.0429 Train Accuracy: global  51.55% local 100.00% ... 1032 forgettables out of 2130 (48.45%) ... total data used 2130
# 2021-09-01 21:35:15,540 - INFO -   |--    Epoch Losses (10): [0.144, 0.1081, 0.0702, 0.0409, 0.0245, 0.017, 0.0102, 0.0057, 0.0043, 0.0038]
# 2021-09-01 21:35:31,583 - INFO -   |-- [Party 3] Average Train Loss:   0.0289 Train Accuracy: global  70.75% local 100.00% ...  623 forgettables out of 2130 (29.25%) ... total data used 2130
# 2021-09-01 21:35:31,586 - INFO -   |--    Epoch Losses (10): [0.0607, 0.0646, 0.0629, 0.0443, 0.0266, 0.0151, 0.0071, 0.0034, 0.0022, 0.0019]
# 2021-09-01 21:35:45,809 - INFO -   |-- [Party 4] Average Train Loss:   0.0542 Train Accuracy: global  70.38% local 100.00% ...  631 forgettables out of 2130 (29.62%) ... total data used 2130
# 2021-09-01 21:35:45,811 - INFO -   |--    Epoch Losses (10): [0.0562, 0.0682, 0.0654, 0.0731, 0.0743, 0.0537, 0.0466, 0.0399, 0.0407, 0.0237]
# 2021-09-01 21:36:01,009 - INFO -   |-- [Party 5] Average Train Loss:   0.0566 Train Accuracy: global  70.42% local 100.00% ...  630 forgettables out of 2130 (29.58%) ... total data used 2130
# 2021-09-01 21:36:01,011 - INFO -   |--    Epoch Losses (10): [0.0462, 0.0489, 0.0329, 0.0315, 0.0922, 0.1123, 0.0749, 0.0533, 0.0411, 0.0324]
# 2021-09-01 21:36:16,515 - INFO -   |-- [Party 6] Average Train Loss:   0.0725 Train Accuracy: global  95.96% local  99.62% ...   86 forgettables out of 2130 ( 4.04%) ... total data used 2130
# 2021-09-01 21:36:16,517 - INFO -   |--    Epoch Losses (10): [0.0751, 0.0434, 0.0473, 0.066, 0.0488, 0.0409, 0.0709, 0.1253, 0.1233, 0.0843]
# 2021-09-01 21:36:33,005 - INFO -   |-- [Party 7] Average Train Loss:   0.0550 Train Accuracy: global  96.24% local  95.02% ...   80 forgettables out of 2130 ( 3.76%) ... total data used 2130
# 2021-09-01 21:36:33,009 - INFO -   |--    Epoch Losses (10): [0.0771, 0.0653, 0.0354, 0.0208, 0.0404, 0.058, 0.0682, 0.0698, 0.0527, 0.062]
# 2021-09-01 21:36:49,120 - INFO -   |-- [Party 8] Average Train Loss:   0.0638 Train Accuracy: global  95.68% local  99.67% ...   92 forgettables out of 2130 ( 4.32%) ... total data used 2130
# 2021-09-01 21:36:49,121 - INFO -   |--    Epoch Losses (10): [0.0658, 0.0567, 0.0308, 0.0307, 0.0474, 0.0705, 0.0978, 0.1099, 0.079, 0.0489]
# 2021-09-01 21:37:04,557 - INFO -   |-- [Party 9] Average Train Loss:   0.0603 Train Accuracy: global  95.73% local  99.44% ...   91 forgettables out of 2130 ( 4.27%) ... total data used 2130
# 2021-09-01 21:37:04,559 - INFO -   |--    Epoch Losses (10): [0.0443, 0.0573, 0.0584, 0.0433, 0.034, 0.0378, 0.051, 0.0714, 0.0917, 0.1134]
# 2021-09-01 21:37:16,166 - INFO -     |---- Number of Forgettables: 4274 (22.30%)
# 2021-09-01 21:37:16,169 - INFO -     |---- Train Accuracy: 70.82%
# 2021-09-01 21:37:16,170 - INFO -     |---- Test Accuracy: 60.95%
# 2021-09-01 21:37:16,171 - INFO -     |---- Test Loss: 1.0194
# 2021-09-01 21:37:16,172 - INFO -     |---- Elapsed time: 8:11:36.745062
# 2021-09-01 21:37:16,173 - INFO -
# Test Acc: Max 60.9524% (194 round) | Last 60.9524% | Avg 58.9684% (62 round)
#
# 2021-09-01 21:37:16,177 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 21:37:30,820 - INFO -   |-- [Party 1] Average Train Loss:   0.0631 Train Accuracy: global  37.28% local  99.20% ... 1336 forgettables out of 2130 (62.72%) ... total data used 2130
# 2021-09-01 21:37:30,821 - INFO -   |--    Epoch Losses (10): [0.1382, 0.106, 0.0706, 0.0547, 0.0438, 0.0393, 0.0352, 0.0419, 0.0484, 0.0532]
# 2021-09-01 21:37:45,565 - INFO -   |-- [Party 2] Average Train Loss:   0.0512 Train Accuracy: global  34.79% local 100.00% ... 1389 forgettables out of 2130 (65.21%) ... total data used 2130
# 2021-09-01 21:37:45,566 - INFO -   |--    Epoch Losses (10): [0.1777, 0.1319, 0.0777, 0.0444, 0.0292, 0.0195, 0.0127, 0.0086, 0.0057, 0.0044]
# 2021-09-01 21:38:01,515 - INFO -   |-- [Party 3] Average Train Loss:   0.0302 Train Accuracy: global  58.26% local 100.00% ...  889 forgettables out of 2130 (41.74%) ... total data used 2130
# 2021-09-01 21:38:01,518 - INFO -   |--    Epoch Losses (10): [0.0714, 0.0736, 0.0614, 0.0422, 0.023, 0.0102, 0.0071, 0.0059, 0.0041, 0.0026]
# 2021-09-01 21:38:17,559 - INFO -   |-- [Party 4] Average Train Loss:   0.0459 Train Accuracy: global  57.56% local 100.00% ...  904 forgettables out of 2130 (42.44%) ... total data used 2130
# 2021-09-01 21:38:17,560 - INFO -   |--    Epoch Losses (10): [0.0765, 0.0734, 0.0717, 0.069, 0.066, 0.0448, 0.0274, 0.0152, 0.0086, 0.0058]
# 2021-09-01 21:38:31,941 - INFO -   |-- [Party 5] Average Train Loss:   0.0321 Train Accuracy: global  57.98% local  99.91% ...  895 forgettables out of 2130 (42.02%) ... total data used 2130
# 2021-09-01 21:38:31,943 - INFO -   |--    Epoch Losses (10): [0.087, 0.0781, 0.0569, 0.0326, 0.0248, 0.0143, 0.0059, 0.0033, 0.0036, 0.0141]
# 2021-09-01 21:38:49,487 - INFO -   |-- [Party 6] Average Train Loss:   0.0390 Train Accuracy: global  98.12% local 100.00% ...   37 forgettables out of 2130 ( 1.74%) ... total data used 2130
# 2021-09-01 21:38:49,491 - INFO -   |--    Epoch Losses (10): [0.0552, 0.0691, 0.0776, 0.0792, 0.0518, 0.0261, 0.0126, 0.0071, 0.0066, 0.0049]
# 2021-09-01 21:39:06,197 - INFO -   |-- [Party 7] Average Train Loss:   0.0643 Train Accuracy: global  98.31% local 100.00% ...   29 forgettables out of 2130 ( 1.36%) ... total data used 2130
# 2021-09-01 21:39:06,198 - INFO -   |--    Epoch Losses (10): [0.0314, 0.0226, 0.0116, 0.0529, 0.1193, 0.1347, 0.1112, 0.0822, 0.0518, 0.0258]
# 2021-09-01 21:39:22,669 - INFO -   |-- [Party 8] Average Train Loss:   0.0388 Train Accuracy: global  98.03% local 100.00% ...   41 forgettables out of 2130 ( 1.92%) ... total data used 2130
# 2021-09-01 21:39:22,671 - INFO -   |--    Epoch Losses (10): [0.0367, 0.036, 0.0527, 0.0614, 0.0663, 0.0544, 0.0354, 0.02, 0.015, 0.0102]
# 2021-09-01 21:39:39,104 - INFO -   |-- [Party 9] Average Train Loss:   0.0166 Train Accuracy: global  98.31% local 100.00% ...   33 forgettables out of 2130 ( 1.55%) ... total data used 2130
# 2021-09-01 21:39:39,107 - INFO -   |--    Epoch Losses (10): [0.049, 0.0465, 0.0292, 0.0187, 0.0107, 0.0046, 0.002, 0.0016, 0.0019, 0.0012]
# 2021-09-01 21:39:50,828 - INFO -     |---- Number of Forgettables: 5553 (28.97%)
# 2021-09-01 21:39:50,830 - INFO -     |---- Train Accuracy: 80.57%
# 2021-09-01 21:39:50,831 - INFO -     |---- Test Accuracy: 72.19%
# 2021-09-01 21:39:50,832 - INFO -     |---- Test Loss: 0.7818
# 2021-09-01 21:39:50,833 - INFO -     |---- Elapsed time: 8:14:11.405913
# 2021-09-01 21:39:50,834 - INFO -
# Test Acc: Max 72.1905% (194 round) | Last 72.1905% | Avg 59.0352% (62 round)
#
# 2021-09-01 21:39:50,837 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 21:40:06,171 - INFO -   |-- [Party 1] Average Train Loss:   0.0378 Train Accuracy: global  71.92% local 100.00% ...  586 forgettables out of 2130 (27.51%) ... total data used 2130
# 2021-09-01 21:40:06,172 - INFO -   |--    Epoch Losses (10): [0.112, 0.0942, 0.0582, 0.0382, 0.0339, 0.0189, 0.0089, 0.0054, 0.0047, 0.0039]
# 2021-09-01 21:40:20,487 - INFO -   |-- [Party 2] Average Train Loss:   0.0596 Train Accuracy: global  67.00% local  99.91% ...  703 forgettables out of 2130 (33.00%) ... total data used 2130
# 2021-09-01 21:40:20,489 - INFO -   |--    Epoch Losses (10): [0.1129, 0.0816, 0.0537, 0.0437, 0.0509, 0.0673, 0.0509, 0.0491, 0.0451, 0.0405]
# 2021-09-01 21:40:36,408 - INFO -   |-- [Party 3] Average Train Loss:   0.0218 Train Accuracy: global  70.61% local 100.00% ...  626 forgettables out of 2130 (29.39%) ... total data used 2130
# 2021-09-01 21:40:36,411 - INFO -   |--    Epoch Losses (10): [0.0701, 0.0688, 0.039, 0.0178, 0.0081, 0.0059, 0.0034, 0.0021, 0.0015, 0.0017]
# 2021-09-01 21:40:50,725 - INFO -   |-- [Party 4] Average Train Loss:   0.0524 Train Accuracy: global  70.52% local 100.00% ...  628 forgettables out of 2130 (29.48%) ... total data used 2130
# 2021-09-01 21:40:50,726 - INFO -   |--    Epoch Losses (10): [0.0738, 0.0721, 0.0852, 0.0976, 0.0756, 0.0508, 0.0306, 0.0187, 0.0119, 0.007]
# 2021-09-01 21:41:04,853 - INFO -   |-- [Party 5] Average Train Loss:   0.0544 Train Accuracy: global  70.89% local 100.00% ...  618 forgettables out of 2130 (29.01%) ... total data used 2130
# 2021-09-01 21:41:04,854 - INFO -   |--    Epoch Losses (10): [0.0582, 0.0545, 0.0451, 0.0749, 0.1018, 0.0758, 0.0494, 0.0406, 0.0272, 0.0168]
# 2021-09-01 21:41:19,899 - INFO -   |-- [Party 6] Average Train Loss:   0.0237 Train Accuracy: global  93.94% local 100.00% ...  129 forgettables out of 2130 ( 6.06%) ... total data used 2130
# 2021-09-01 21:41:19,901 - INFO -   |--    Epoch Losses (10): [0.0769, 0.0625, 0.0364, 0.0277, 0.0178, 0.0078, 0.0031, 0.0017, 0.0015, 0.0019]
# 2021-09-01 21:41:34,312 - INFO -   |-- [Party 7] Average Train Loss:   0.0417 Train Accuracy: global  94.60% local 100.00% ...  115 forgettables out of 2130 ( 5.40%) ... total data used 2130
# 2021-09-01 21:41:34,313 - INFO -   |--    Epoch Losses (10): [0.0994, 0.0848, 0.0538, 0.0288, 0.0227, 0.0312, 0.0382, 0.0284, 0.0197, 0.0096]
# 2021-09-01 21:41:49,971 - INFO -   |-- [Party 8] Average Train Loss:   0.0261 Train Accuracy: global  94.60% local 100.00% ...  115 forgettables out of 2130 ( 5.40%) ... total data used 2130
# 2021-09-01 21:41:49,973 - INFO -   |--    Epoch Losses (10): [0.0985, 0.076, 0.039, 0.0209, 0.0111, 0.005, 0.0038, 0.0026, 0.0017, 0.0024]
# 2021-09-01 21:42:05,959 - INFO -   |-- [Party 9] Average Train Loss:   0.0536 Train Accuracy: global  94.27% local 100.00% ...  122 forgettables out of 2130 ( 5.73%) ... total data used 2130
# 2021-09-01 21:42:05,960 - INFO -   |--    Epoch Losses (10): [0.0566, 0.0557, 0.0429, 0.0403, 0.075, 0.0897, 0.0816, 0.0515, 0.0284, 0.0145]
# 2021-09-01 21:42:17,606 - INFO -     |---- Number of Forgettables: 3642 (19.00%)
# 2021-09-01 21:42:17,609 - INFO -     |---- Train Accuracy: 78.81%
# 2021-09-01 21:42:17,609 - INFO -     |---- Test Accuracy: 68.93%
# 2021-09-01 21:42:17,610 - INFO -     |---- Test Loss: 0.8441
# 2021-09-01 21:42:17,610 - INFO -     |---- Elapsed time: 8:16:38.183487
# 2021-09-01 21:42:17,611 - INFO -
# Test Acc: Max 68.9255% (194 round) | Last 68.9255% | Avg 59.0849% (62 round)
#
# 2021-09-01 21:42:17,614 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 21:42:33,906 - INFO -   |-- [Party 1] Average Train Loss:   0.0428 Train Accuracy: global  61.74% local 100.00% ...  815 forgettables out of 2130 (38.26%) ... total data used 2130
# 2021-09-01 21:42:33,908 - INFO -   |--    Epoch Losses (10): [0.1353, 0.0957, 0.061, 0.0445, 0.0294, 0.0199, 0.0139, 0.0107, 0.0097, 0.0078]
# 2021-09-01 21:42:50,186 - INFO -   |-- [Party 2] Average Train Loss:   0.0414 Train Accuracy: global  59.30% local 100.00% ...  867 forgettables out of 2130 (40.70%) ... total data used 2130
# 2021-09-01 21:42:50,189 - INFO -   |--    Epoch Losses (10): [0.1287, 0.088, 0.0657, 0.0504, 0.0332, 0.0189, 0.0132, 0.0075, 0.0042, 0.0044]
# 2021-09-01 21:43:04,506 - INFO -   |-- [Party 3] Average Train Loss:   0.0281 Train Accuracy: global  68.22% local  99.91% ...  677 forgettables out of 2130 (31.78%) ... total data used 2130
# 2021-09-01 21:43:04,508 - INFO -   |--    Epoch Losses (10): [0.0818, 0.0701, 0.0496, 0.028, 0.0131, 0.0068, 0.0038, 0.0023, 0.0057, 0.0198]
# 2021-09-01 21:43:19,809 - INFO -   |-- [Party 4] Average Train Loss:   0.0584 Train Accuracy: global  67.98% local 100.00% ...  682 forgettables out of 2130 (32.02%) ... total data used 2130
# 2021-09-01 21:43:19,811 - INFO -   |--    Epoch Losses (10): [0.0594, 0.0643, 0.0727, 0.0953, 0.0781, 0.0605, 0.0534, 0.0514, 0.0339, 0.0153]
# 2021-09-01 21:43:35,794 - INFO -   |-- [Party 5] Average Train Loss:   0.0438 Train Accuracy: global  68.59% local 100.00% ...  669 forgettables out of 2130 (31.41%) ... total data used 2130
# 2021-09-01 21:43:35,795 - INFO -   |--    Epoch Losses (10): [0.0429, 0.0748, 0.0938, 0.0888, 0.0694, 0.035, 0.0167, 0.0083, 0.0047, 0.0032]
# 2021-09-01 21:43:50,243 - INFO -   |-- [Party 6] Average Train Loss:   0.0303 Train Accuracy: global  95.31% local 100.00% ...  100 forgettables out of 2130 ( 4.69%) ... total data used 2130
# 2021-09-01 21:43:50,244 - INFO -   |--    Epoch Losses (10): [0.068, 0.0788, 0.0612, 0.0437, 0.0235, 0.0137, 0.0067, 0.0033, 0.0024, 0.0021]
# 2021-09-01 21:44:05,938 - INFO -   |-- [Party 7] Average Train Loss:   0.0284 Train Accuracy: global  96.43% local 100.00% ...   76 forgettables out of 2130 ( 3.57%) ... total data used 2130
# 2021-09-01 21:44:05,939 - INFO -   |--    Epoch Losses (10): [0.0797, 0.0691, 0.0551, 0.0352, 0.022, 0.0105, 0.0052, 0.0035, 0.0024, 0.0016]
# 2021-09-01 21:44:22,048 - INFO -   |-- [Party 8] Average Train Loss:   0.0359 Train Accuracy: global  95.68% local 100.00% ...   92 forgettables out of 2130 ( 4.32%) ... total data used 2130
# 2021-09-01 21:44:22,052 - INFO -   |--    Epoch Losses (10): [0.0671, 0.0713, 0.0622, 0.0593, 0.0459, 0.0283, 0.0132, 0.0061, 0.0033, 0.0026]
# 2021-09-01 21:44:39,141 - INFO -   |-- [Party 9] Average Train Loss:   0.0426 Train Accuracy: global  95.45% local 100.00% ...   97 forgettables out of 2130 ( 4.55%) ... total data used 2130
# 2021-09-01 21:44:39,143 - INFO -   |--    Epoch Losses (10): [0.0678, 0.0746, 0.0695, 0.0659, 0.0484, 0.0388, 0.0291, 0.0171, 0.0094, 0.0052]
# 2021-09-01 21:44:50,808 - INFO -     |---- Number of Forgettables: 4075 (21.26%)
# 2021-09-01 21:44:50,810 - INFO -     |---- Train Accuracy: 81.50%
# 2021-09-01 21:44:50,811 - INFO -     |---- Test Accuracy: 70.79%
# 2021-09-01 21:44:50,812 - INFO -     |---- Test Loss: 0.7946
# 2021-09-01 21:44:50,813 - INFO -     |---- Elapsed time: 8:19:11.385678
# 2021-09-01 21:44:50,814 - INFO -
# Test Acc: Max 70.7895% (194 round) | Last 70.7895% | Avg 59.1434% (62 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

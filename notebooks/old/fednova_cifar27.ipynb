# %%
# %matplotlib inline

dataset = 'cifar10'
clsimb = [2, 7] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_fednova'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 0

# %%
import copy
import json
import logging
import math
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Files already downloaded and verified

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
# def average_weights(w):
#     w_avg = copy.deepcopy(w[0])
        
#     for key in w_avg.keys():
#         for i in range(1, len(w)):
#             w_avg[key] += w[i][key]
#         w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
#     return w_avg

# %%
# FedNova
def nova_update(w, a_list, d_list, n_list, n_client, device):
    coeff = 0.0
    n_round = sum(n_list)
    d_round = copy.deepcopy(w)
    for k in d_round:
        d_round[k] = 0.0
    for i in range(n_client):
        d_w = d_list[i]
        for k in d_w:
            d_round[k] = d_round[k] + (d_w[k] * n_list[i] / n_round)
        coeff += (a_list[i] * n_list[i] / n_round)
    for k in w:
        w[k] = w[k] - (coeff * d_round[k]).cpu()
    return w

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, global_state, momentum=0.9):
    epoch_losses = []
    
    # FedNova
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
    tau = 0
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())
            
            # FedNova
            tau += 1

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    # FedNova
    a_i = (tau - momentum * (1 - math.pow(momentum, tau)) / (1 - momentum)) / (1 - momentum)
    local_weights = model.state_dict()
    norm_grad = copy.deepcopy(global_state)
    for k in norm_grad:
        norm_grad[k] = torch.true_divide(global_state[k] - local_weights[k], a_i)
    
    local_weights = model.state_dict()

    return local_weights, epoch_losses, a_i, norm_grad

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0
momentum = 0.9

logger.info(f'\nAlgorithm: FedNova\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    # FedNova
    a_list, d_list, n_list = [], [], []
    global_state = fed_model.state_dict()
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls, a_i, norm_grad = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, global_state, momentum)
        
        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
        # FedNova
        a_list.append(a_i)
        d_list.append(norm_grad)
        n_list.append(len(trainloader))
        
    # FedNova
    fed_weights = nova_update(fed_weights, a_list, d_list, n_list, sum(clsimb), device)
    
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 16:12:46,763 - INFO -
# Algorithm: FedNova
# Client Split: [2, 7]
# Dataset: cifar10
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 16:12:46,766 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 16:12:54,709 - INFO -   |-- [Party 1] Average Train Loss:   0.5420 Train Accuracy: global   0.00% local  86.34% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:12:54,710 - INFO -   |--    Epoch Losses (10): [1.6001, 0.5758, 0.4913, 0.4497, 0.4236, 0.4029, 0.3874, 0.3812, 0.3575, 0.3506]
# 2021-09-01 16:13:01,288 - INFO -   |-- [Party 2] Average Train Loss:   0.5168 Train Accuracy: global   0.00% local  87.04% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:01,292 - INFO -   |--    Epoch Losses (10): [1.5939, 0.574, 0.4661, 0.43, 0.3851, 0.3832, 0.3665, 0.3396, 0.334, 0.296]
# 2021-09-01 16:13:07,810 - INFO -   |-- [Party 3] Average Train Loss:   0.6708 Train Accuracy: global   0.00% local  74.93% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:07,811 - INFO -   |--    Epoch Losses (10): [1.6716, 0.6898, 0.5914, 0.577, 0.552, 0.5371, 0.5182, 0.5297, 0.5188, 0.5221]
# 2021-09-01 16:13:14,368 - INFO -   |-- [Party 4] Average Train Loss:   0.6445 Train Accuracy: global   0.00% local  79.97% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:14,369 - INFO -   |--    Epoch Losses (10): [1.6716, 0.6846, 0.5911, 0.5515, 0.5312, 0.5041, 0.4901, 0.4924, 0.4602, 0.4688]
# 2021-09-01 16:13:21,496 - INFO -   |-- [Party 5] Average Train Loss:   0.6577 Train Accuracy: global   0.00% local  76.54% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:21,499 - INFO -   |--    Epoch Losses (10): [1.6726, 0.6963, 0.6022, 0.5612, 0.5485, 0.5244, 0.5135, 0.4954, 0.4837, 0.4786]
# 2021-09-01 16:13:29,108 - INFO -   |-- [Party 6] Average Train Loss:   0.6536 Train Accuracy: global   0.00% local  78.43% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:29,110 - INFO -   |--    Epoch Losses (10): [1.6618, 0.6788, 0.5881, 0.5586, 0.5384, 0.5266, 0.5175, 0.4956, 0.4845, 0.4863]
# 2021-09-01 16:13:36,623 - INFO -   |-- [Party 7] Average Train Loss:   0.6205 Train Accuracy: global   0.00% local  80.04% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:36,624 - INFO -   |--    Epoch Losses (10): [1.661, 0.6463, 0.5793, 0.5189, 0.4965, 0.4824, 0.4749, 0.4639, 0.4487, 0.4336]
# 2021-09-01 16:13:43,897 - INFO -   |-- [Party 8] Average Train Loss:   0.6560 Train Accuracy: global   0.00% local  78.36% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:43,898 - INFO -   |--    Epoch Losses (10): [1.6789, 0.6845, 0.5999, 0.5533, 0.5517, 0.517, 0.5162, 0.5018, 0.4894, 0.4673]
# 2021-09-01 16:13:51,154 - INFO -   |-- [Party 9] Average Train Loss:   0.6336 Train Accuracy: global   0.00% local  78.43% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:13:51,158 - INFO -   |--    Epoch Losses (10): [1.6663, 0.6708, 0.5739, 0.5325, 0.4969, 0.4921, 0.4793, 0.4884, 0.4686, 0.4673]
# 2021-09-01 16:13:55,377 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 16:13:55,378 - INFO -     |---- Train Accuracy: 58.89%
# 2021-09-01 16:13:55,379 - INFO -     |---- Test Accuracy: 36.78%
# 2021-09-01 16:13:55,380 - INFO -     |---- Test Loss: 2.5974
# 2021-09-01 16:13:55,381 - INFO -     |---- Elapsed time: 0:01:08.616021
# 2021-09-01 16:13:55,382 - INFO -
# Test Acc: Max 36.7750% (1 round) | Last 36.7750% | Avg 36.7750% (1 round)
#
# 2021-09-01 16:13:55,385 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 16:14:02,359 - INFO -   |-- [Party 1] Average Train Loss:   0.5885 Train Accuracy: global   0.00% local  83.82% ... 1233 forgettables out of 1428 (86.34%) ... total data used 1428
# 2021-09-01 16:14:02,361 - INFO -   |--    Epoch Losses (10): [2.4913, 0.472, 0.4333, 0.3936, 0.3971, 0.3583, 0.3581, 0.339, 0.328, 0.3146]
# 2021-09-01 16:14:08,943 - INFO -   |-- [Party 2] Average Train Loss:   0.5598 Train Accuracy: global   0.00% local  88.94% ... 1243 forgettables out of 1428 (87.04%) ... total data used 1428
# 2021-09-01 16:14:08,944 - INFO -   |--    Epoch Losses (10): [2.4908, 0.4464, 0.4206, 0.3604, 0.3452, 0.336, 0.3167, 0.2967, 0.2856, 0.2995]
# 2021-09-01 16:14:16,272 - INFO -   |-- [Party 3] Average Train Loss:   0.4969 Train Accuracy: global  74.23% local  79.13% ...  131 forgettables out of 1428 ( 9.17%) ... total data used 1428
# 2021-09-01 16:14:16,273 - INFO -   |--    Epoch Losses (10): [0.5377, 0.5252, 0.5139, 0.5055, 0.5008, 0.5112, 0.4852, 0.4613, 0.4772, 0.4512]
# 2021-09-01 16:14:22,900 - INFO -   |-- [Party 4] Average Train Loss:   0.4482 Train Accuracy: global  75.07% local  81.51% ...  145 forgettables out of 1428 (10.15%) ... total data used 1428
# 2021-09-01 16:14:22,904 - INFO -   |--    Epoch Losses (10): [0.5109, 0.4979, 0.4751, 0.4516, 0.4421, 0.432, 0.4237, 0.4019, 0.3945, 0.4521]
# 2021-09-01 16:14:29,485 - INFO -   |-- [Party 5] Average Train Loss:   0.4840 Train Accuracy: global  76.19% local  79.62% ...   91 forgettables out of 1428 ( 6.37%) ... total data used 1428
# 2021-09-01 16:14:29,487 - INFO -   |--    Epoch Losses (10): [0.5276, 0.5164, 0.4961, 0.5035, 0.4651, 0.4815, 0.4789, 0.4833, 0.4538, 0.434]
# 2021-09-01 16:14:36,710 - INFO -   |-- [Party 6] Average Train Loss:   0.4750 Train Accuracy: global  73.53% local  72.13% ...  136 forgettables out of 1428 ( 9.52%) ... total data used 1428
# 2021-09-01 16:14:36,717 - INFO -   |--    Epoch Losses (10): [0.5305, 0.5316, 0.5034, 0.4861, 0.4683, 0.4753, 0.4551, 0.4365, 0.4318, 0.4317]
# 2021-09-01 16:14:44,372 - INFO -   |-- [Party 7] Average Train Loss:   0.4353 Train Accuracy: global  78.99% local  80.46% ...   93 forgettables out of 1428 ( 6.51%) ... total data used 1428
# 2021-09-01 16:14:44,373 - INFO -   |--    Epoch Losses (10): [0.4891, 0.4787, 0.4547, 0.4281, 0.4327, 0.4214, 0.402, 0.4056, 0.4322, 0.4088]
# 2021-09-01 16:14:52,029 - INFO -   |-- [Party 8] Average Train Loss:   0.4756 Train Accuracy: global  74.58% local  80.53% ...  130 forgettables out of 1428 ( 9.10%) ... total data used 1428
# 2021-09-01 16:14:52,032 - INFO -   |--    Epoch Losses (10): [0.5253, 0.5093, 0.5004, 0.4813, 0.5009, 0.4701, 0.4655, 0.451, 0.4385, 0.4142]
# 2021-09-01 16:14:58,707 - INFO -   |-- [Party 9] Average Train Loss:   0.4566 Train Accuracy: global  77.17% local  81.16% ...  102 forgettables out of 1428 ( 7.14%) ... total data used 1428
# 2021-09-01 16:14:58,708 - INFO -   |--    Epoch Losses (10): [0.4948, 0.4812, 0.5023, 0.4649, 0.4526, 0.4365, 0.4458, 0.4357, 0.4365, 0.4156]
# 2021-09-01 16:15:02,618 - INFO -     |---- Number of Forgettables: 3304 (25.71%)
# 2021-09-01 16:15:02,619 - INFO -     |---- Train Accuracy: 61.13%
# 2021-09-01 16:15:02,619 - INFO -     |---- Test Accuracy: 38.82%
# 2021-09-01 16:15:02,620 - INFO -     |---- Test Loss: 1.7560
# 2021-09-01 16:15:02,621 - INFO -     |---- Elapsed time: 0:02:15.855743
# 2021-09-01 16:15:02,621 - INFO -
# Test Acc: Max 38.8250% (2 round) | Last 38.8250% | Avg 37.8000% (2 round)
#
# 2021-09-01 16:15:02,623 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 16:15:09,630 - INFO -   |-- [Party 1] Average Train Loss:   0.4623 Train Accuracy: global   0.00% local  85.85% ... 1197 forgettables out of 1428 (83.82%) ... total data used 1428
# 2021-09-01 16:15:09,631 - INFO -   |--    Epoch Losses (10): [1.4858, 0.4281, 0.3967, 0.3899, 0.3547, 0.3649, 0.3259, 0.3083, 0.2914, 0.2777]
# 2021-09-01 16:15:16,699 - INFO -   |-- [Party 2] Average Train Loss:   0.4235 Train Accuracy: global   0.00% local  78.50% ... 1270 forgettables out of 1428 (88.94%) ... total data used 1428
# 2021-09-01 16:15:16,701 - INFO -   |--    Epoch Losses (10): [1.4664, 0.422, 0.3632, 0.3237, 0.2962, 0.277, 0.2782, 0.2765, 0.2721, 0.2597]
# 2021-09-01 16:15:24,062 - INFO -   |-- [Party 3] Average Train Loss:   0.4697 Train Accuracy: global  77.03% local  79.62% ...  128 forgettables out of 1428 ( 8.96%) ... total data used 1428
# 2021-09-01 16:15:24,064 - INFO -   |--    Epoch Losses (10): [0.5433, 0.4998, 0.4997, 0.498, 0.4625, 0.4525, 0.4475, 0.4341, 0.4332, 0.4264]
# 2021-09-01 16:15:30,657 - INFO -   |-- [Party 4] Average Train Loss:   0.4225 Train Accuracy: global  77.87% local  84.17% ...  149 forgettables out of 1428 (10.43%) ... total data used 1428
# 2021-09-01 16:15:30,658 - INFO -   |--    Epoch Losses (10): [0.5022, 0.4618, 0.4429, 0.458, 0.4252, 0.4133, 0.4274, 0.3746, 0.3691, 0.3504]
# 2021-09-01 16:15:37,256 - INFO -   |-- [Party 5] Average Train Loss:   0.4560 Train Accuracy: global  77.38% local  81.51% ...  109 forgettables out of 1428 ( 7.63%) ... total data used 1428
# 2021-09-01 16:15:37,259 - INFO -   |--    Epoch Losses (10): [0.5297, 0.5084, 0.4826, 0.4614, 0.4493, 0.4478, 0.4167, 0.4317, 0.414, 0.4184]
# 2021-09-01 16:15:43,823 - INFO -   |-- [Party 6] Average Train Loss:   0.4473 Train Accuracy: global  77.73% local  83.89% ...  142 forgettables out of 1428 ( 9.94%) ... total data used 1428
# 2021-09-01 16:15:43,826 - INFO -   |--    Epoch Losses (10): [0.5279, 0.4783, 0.4491, 0.4453, 0.4481, 0.4429, 0.4358, 0.413, 0.4173, 0.4154]
# 2021-09-01 16:15:51,084 - INFO -   |-- [Party 7] Average Train Loss:   0.4078 Train Accuracy: global  80.53% local  84.17% ...  112 forgettables out of 1428 ( 7.84%) ... total data used 1428
# 2021-09-01 16:15:51,085 - INFO -   |--    Epoch Losses (10): [0.4819, 0.4543, 0.4299, 0.4108, 0.3925, 0.3816, 0.3856, 0.3764, 0.3905, 0.3741]
# 2021-09-01 16:15:58,181 - INFO -   |-- [Party 8] Average Train Loss:   0.4281 Train Accuracy: global  78.99% local  79.27% ...  104 forgettables out of 1428 ( 7.28%) ... total data used 1428
# 2021-09-01 16:15:58,183 - INFO -   |--    Epoch Losses (10): [0.5026, 0.4884, 0.4455, 0.4431, 0.4054, 0.4149, 0.4253, 0.3809, 0.3858, 0.3892]
# 2021-09-01 16:16:05,257 - INFO -   |-- [Party 9] Average Train Loss:   0.4302 Train Accuracy: global  80.53% local  84.38% ...   84 forgettables out of 1428 ( 5.88%) ... total data used 1428
# 2021-09-01 16:16:05,259 - INFO -   |--    Epoch Losses (10): [0.4862, 0.4658, 0.4728, 0.459, 0.4247, 0.4144, 0.3901, 0.4004, 0.397, 0.3912]
# 2021-09-01 16:16:09,264 - INFO -     |---- Number of Forgettables: 3295 (25.64%)
# 2021-09-01 16:16:09,266 - INFO -     |---- Train Accuracy: 63.61%
# 2021-09-01 16:16:09,267 - INFO -     |---- Test Accuracy: 40.02%
# 2021-09-01 16:16:09,268 - INFO -     |---- Test Loss: 1.7488
# 2021-09-01 16:16:09,268 - INFO -     |---- Elapsed time: 0:03:22.503453
# 2021-09-01 16:16:09,269 - INFO -
# Test Acc: Max 40.0250% (3 round) | Last 40.0250% | Avg 38.5417% (2 round)
#
# 2021-09-01 16:16:09,271 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 16:16:16,644 - INFO -   |-- [Party 1] Average Train Loss:   0.4323 Train Accuracy: global   0.00% local  87.46% ... 1226 forgettables out of 1428 (85.85%) ... total data used 1428
# 2021-09-01 16:16:16,646 - INFO -   |--    Epoch Losses (10): [1.4635, 0.4089, 0.3518, 0.3307, 0.3349, 0.325, 0.2947, 0.2739, 0.2751, 0.2642]
# 2021-09-01 16:16:24,022 - INFO -   |-- [Party 2] Average Train Loss:   0.4033 Train Accuracy: global   0.00% local  91.60% ... 1121 forgettables out of 1428 (78.50%) ... total data used 1428
# 2021-09-01 16:16:24,025 - INFO -   |--    Epoch Losses (10): [1.4535, 0.3879, 0.3374, 0.301, 0.2836, 0.2743, 0.2637, 0.2554, 0.2439, 0.232]
# 2021-09-01 16:16:30,656 - INFO -   |-- [Party 3] Average Train Loss:   0.4458 Train Accuracy: global  79.20% local  79.62% ...  114 forgettables out of 1428 ( 7.98%) ... total data used 1428
# 2021-09-01 16:16:30,658 - INFO -   |--    Epoch Losses (10): [0.4866, 0.4586, 0.4511, 0.457, 0.4584, 0.4493, 0.4227, 0.4229, 0.4138, 0.4371]
# 2021-09-01 16:16:37,254 - INFO -   |-- [Party 4] Average Train Loss:   0.3832 Train Accuracy: global  82.14% local  82.56% ...  103 forgettables out of 1428 ( 7.21%) ... total data used 1428
# 2021-09-01 16:16:37,255 - INFO -   |--    Epoch Losses (10): [0.4565, 0.4203, 0.433, 0.3821, 0.3516, 0.3693, 0.3551, 0.3646, 0.3472, 0.3522]
# 2021-09-01 16:16:44,792 - INFO -   |-- [Party 5] Average Train Loss:   0.4137 Train Accuracy: global  81.09% local  85.15% ...  104 forgettables out of 1428 ( 7.28%) ... total data used 1428
# 2021-09-01 16:16:44,794 - INFO -   |--    Epoch Losses (10): [0.476, 0.452, 0.4312, 0.4196, 0.4101, 0.4117, 0.4203, 0.3845, 0.3596, 0.3721]
# 2021-09-01 16:16:51,430 - INFO -   |-- [Party 6] Average Train Loss:   0.4193 Train Accuracy: global  80.39% local  84.17% ...  112 forgettables out of 1428 ( 7.84%) ... total data used 1428
# 2021-09-01 16:16:51,432 - INFO -   |--    Epoch Losses (10): [0.4845, 0.4608, 0.4482, 0.4154, 0.4082, 0.414, 0.4005, 0.3809, 0.3801, 0.4004]
# 2021-09-01 16:16:58,920 - INFO -   |-- [Party 7] Average Train Loss:   0.3690 Train Accuracy: global  83.96% local  85.22% ...   78 forgettables out of 1428 ( 5.46%) ... total data used 1428
# 2021-09-01 16:16:58,922 - INFO -   |--    Epoch Losses (10): [0.4453, 0.3969, 0.3878, 0.3803, 0.3503, 0.3604, 0.3449, 0.3493, 0.3403, 0.3347]
# 2021-09-01 16:17:06,061 - INFO -   |-- [Party 8] Average Train Loss:   0.3956 Train Accuracy: global  82.28% local  85.43% ...   76 forgettables out of 1428 ( 5.32%) ... total data used 1428
# 2021-09-01 16:17:06,064 - INFO -   |--    Epoch Losses (10): [0.4502, 0.4448, 0.4129, 0.4308, 0.424, 0.3741, 0.36, 0.3722, 0.3466, 0.3402]
# 2021-09-01 16:17:13,490 - INFO -   |-- [Party 9] Average Train Loss:   0.3914 Train Accuracy: global  82.21% local  81.30% ...   98 forgettables out of 1428 ( 6.86%) ... total data used 1428
# 2021-09-01 16:17:13,491 - INFO -   |--    Epoch Losses (10): [0.4501, 0.4307, 0.414, 0.4118, 0.3813, 0.3651, 0.4066, 0.3585, 0.3528, 0.3435]
# 2021-09-01 16:17:17,390 - INFO -     |---- Number of Forgettables: 3032 (23.59%)
# 2021-09-01 16:17:17,391 - INFO -     |---- Train Accuracy: 64.87%
# 2021-09-01 16:17:17,391 - INFO -     |---- Test Accuracy: 41.10%
# 2021-09-01 16:17:17,392 - INFO -     |---- Test Loss: 1.7046
# 2021-09-01 16:17:17,392 - INFO -     |---- Elapsed time: 0:04:30.627374
# 2021-09-01 16:17:17,393 - INFO -
# Test Acc: Max 41.1000% (4 round) | Last 41.1000% | Avg 39.1812% (3 round)
#
# 2021-09-01 16:17:17,395 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 16:17:24,035 - INFO -   |-- [Party 1] Average Train Loss:   0.4090 Train Accuracy: global   0.00% local  87.46% ... 1249 forgettables out of 1428 (87.46%) ... total data used 1428
# 2021-09-01 16:17:24,036 - INFO -   |--    Epoch Losses (10): [1.4102, 0.382, 0.3608, 0.3176, 0.305, 0.2897, 0.2661, 0.2601, 0.258, 0.2405]
# 2021-09-01 16:17:31,328 - INFO -   |-- [Party 2] Average Train Loss:   0.3758 Train Accuracy: global   0.00% local  92.02% ... 1308 forgettables out of 1428 (91.60%) ... total data used 1428
# 2021-09-01 16:17:31,330 - INFO -   |--    Epoch Losses (10): [1.3611, 0.3618, 0.3152, 0.2863, 0.2698, 0.2469, 0.2313, 0.236, 0.2289, 0.2203]
# 2021-09-01 16:17:38,527 - INFO -   |-- [Party 3] Average Train Loss:   0.4265 Train Accuracy: global  80.53% local  82.42% ...  109 forgettables out of 1428 ( 7.63%) ... total data used 1428
# 2021-09-01 16:17:38,530 - INFO -   |--    Epoch Losses (10): [0.4967, 0.4476, 0.4567, 0.4466, 0.4288, 0.3973, 0.4099, 0.4062, 0.3994, 0.376]
# 2021-09-01 16:17:45,173 - INFO -   |-- [Party 4] Average Train Loss:   0.3579 Train Accuracy: global  82.91% local  81.72% ...  111 forgettables out of 1428 ( 7.77%) ... total data used 1428
# 2021-09-01 16:17:45,175 - INFO -   |--    Epoch Losses (10): [0.4013, 0.4063, 0.3874, 0.367, 0.3524, 0.3392, 0.3523, 0.344, 0.333, 0.2963]
# 2021-09-01 16:17:51,793 - INFO -   |-- [Party 5] Average Train Loss:   0.3892 Train Accuracy: global  82.07% local  83.96% ...  101 forgettables out of 1428 ( 7.07%) ... total data used 1428
# 2021-09-01 16:17:51,794 - INFO -   |--    Epoch Losses (10): [0.4489, 0.4123, 0.3871, 0.3881, 0.3708, 0.3832, 0.4012, 0.3627, 0.3648, 0.3731]
# 2021-09-01 16:17:58,396 - INFO -   |-- [Party 6] Average Train Loss:   0.3879 Train Accuracy: global  81.51% local  85.08% ...  108 forgettables out of 1428 ( 7.56%) ... total data used 1428
# 2021-09-01 16:17:58,397 - INFO -   |--    Epoch Losses (10): [0.4505, 0.4247, 0.3912, 0.3976, 0.3787, 0.3729, 0.3533, 0.3731, 0.374, 0.3628]
# 2021-09-01 16:18:05,020 - INFO -   |-- [Party 7] Average Train Loss:   0.3531 Train Accuracy: global  84.94% local  85.43% ...   94 forgettables out of 1428 ( 6.58%) ... total data used 1428
# 2021-09-01 16:18:05,021 - INFO -   |--    Epoch Losses (10): [0.4043, 0.4056, 0.3849, 0.3641, 0.329, 0.3205, 0.3193, 0.3501, 0.3266, 0.3268]
# 2021-09-01 16:18:11,626 - INFO -   |-- [Party 8] Average Train Loss:   0.3683 Train Accuracy: global  82.91% local  87.82% ...   95 forgettables out of 1428 ( 6.65%) ... total data used 1428
# 2021-09-01 16:18:11,628 - INFO -   |--    Epoch Losses (10): [0.4537, 0.4037, 0.3728, 0.3676, 0.3574, 0.3596, 0.3596, 0.3343, 0.347, 0.3275]
# 2021-09-01 16:18:18,437 - INFO -   |-- [Party 9] Average Train Loss:   0.3736 Train Accuracy: global  83.68% local  86.20% ...   87 forgettables out of 1428 ( 6.09%) ... total data used 1428
# 2021-09-01 16:18:18,439 - INFO -   |--    Epoch Losses (10): [0.4306, 0.3956, 0.4145, 0.3571, 0.3625, 0.392, 0.3796, 0.3452, 0.3211, 0.3373]
# 2021-09-01 16:18:22,843 - INFO -     |---- Number of Forgettables: 3262 (25.38%)
# 2021-09-01 16:18:22,846 - INFO -     |---- Train Accuracy: 66.05%
# 2021-09-01 16:18:22,848 - INFO -     |---- Test Accuracy: 42.05%
# 2021-09-01 16:18:22,849 - INFO -     |---- Test Loss: 1.6590
# 2021-09-01 16:18:22,851 - INFO -     |---- Elapsed time: 0:05:36.085767
# 2021-09-01 16:18:22,852 - INFO -
# Test Acc: Max 42.0500% (5 round) | Last 42.0500% | Avg 39.7550% (3 round)
#
# 2021-09-01 16:18:22,856 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 16:18:29,549 - INFO -   |-- [Party 1] Average Train Loss:   0.3904 Train Accuracy: global   0.00% local  91.46% ... 1249 forgettables out of 1428 (87.46%) ... total data used 1428
# 2021-09-01 16:18:29,551 - INFO -   |--    Epoch Losses (10): [1.333, 0.3934, 0.3141, 0.298, 0.284, 0.2738, 0.2748, 0.2579, 0.2339, 0.2412]
# 2021-09-01 16:18:36,146 - INFO -   |-- [Party 2] Average Train Loss:   0.3640 Train Accuracy: global   0.00% local  90.20% ... 1314 forgettables out of 1428 (92.02%) ... total data used 1428
# 2021-09-01 16:18:36,147 - INFO -   |--    Epoch Losses (10): [1.3083, 0.3526, 0.2821, 0.2662, 0.2658, 0.2365, 0.241, 0.222, 0.2362, 0.2292]
# 2021-09-01 16:18:44,024 - INFO -   |-- [Party 3] Average Train Loss:   0.4055 Train Accuracy: global  83.54% local  81.93% ...   85 forgettables out of 1428 ( 5.95%) ... total data used 1428
# 2021-09-01 16:18:44,025 - INFO -   |--    Epoch Losses (10): [0.4495, 0.4063, 0.4112, 0.4257, 0.4364, 0.4281, 0.3786, 0.379, 0.3794, 0.3608]
# 2021-09-01 16:18:51,358 - INFO -   |-- [Party 4] Average Train Loss:   0.3247 Train Accuracy: global  85.29% local  89.08% ...  118 forgettables out of 1428 ( 8.26%) ... total data used 1428
# 2021-09-01 16:18:51,359 - INFO -   |--    Epoch Losses (10): [0.3817, 0.3637, 0.3315, 0.3181, 0.3244, 0.3214, 0.3158, 0.3165, 0.3003, 0.2742]
# 2021-09-01 16:18:58,185 - INFO -   |-- [Party 5] Average Train Loss:   0.3593 Train Accuracy: global  84.59% local  86.90% ...   83 forgettables out of 1428 ( 5.81%) ... total data used 1428
# 2021-09-01 16:18:58,187 - INFO -   |--    Epoch Losses (10): [0.4526, 0.3917, 0.3543, 0.3789, 0.3533, 0.3386, 0.3265, 0.3437, 0.3335, 0.3199]
# 2021-09-01 16:19:04,988 - INFO -   |-- [Party 6] Average Train Loss:   0.3946 Train Accuracy: global  83.26% local  82.84% ...   97 forgettables out of 1428 ( 6.79%) ... total data used 1428
# 2021-09-01 16:19:04,989 - INFO -   |--    Epoch Losses (10): [0.4437, 0.4321, 0.4516, 0.4051, 0.3884, 0.376, 0.3485, 0.3733, 0.3591, 0.3681]
# 2021-09-01 16:19:12,333 - INFO -   |-- [Party 7] Average Train Loss:   0.3289 Train Accuracy: global  85.78% local  88.17% ...   90 forgettables out of 1428 ( 6.30%) ... total data used 1428
# 2021-09-01 16:19:12,336 - INFO -   |--    Epoch Losses (10): [0.3828, 0.3381, 0.3289, 0.3189, 0.3221, 0.3245, 0.3247, 0.3426, 0.3084, 0.2977]
# 2021-09-01 16:19:19,237 - INFO -   |-- [Party 8] Average Train Loss:   0.3510 Train Accuracy: global  85.08% local  88.31% ...   89 forgettables out of 1428 ( 6.23%) ... total data used 1428
# 2021-09-01 16:19:19,239 - INFO -   |--    Epoch Losses (10): [0.4303, 0.3983, 0.379, 0.3574, 0.3652, 0.3361, 0.3302, 0.3121, 0.321, 0.2804]
# 2021-09-01 16:19:26,339 - INFO -   |-- [Party 9] Average Train Loss:   0.3529 Train Accuracy: global  84.45% local  87.46% ...   78 forgettables out of 1428 ( 5.46%) ... total data used 1428
# 2021-09-01 16:19:26,340 - INFO -   |--    Epoch Losses (10): [0.3979, 0.4201, 0.395, 0.3375, 0.3311, 0.3263, 0.3367, 0.3475, 0.3185, 0.3183]
# 2021-09-01 16:19:30,313 - INFO -     |---- Number of Forgettables: 3203 (24.92%)
# 2021-09-01 16:19:30,315 - INFO -     |---- Train Accuracy: 66.38%
# 2021-09-01 16:19:30,316 - INFO -     |---- Test Accuracy: 42.15%
# 2021-09-01 16:19:30,317 - INFO -     |---- Test Loss: 1.6458
# 2021-09-01 16:19:30,317 - INFO -     |---- Elapsed time: 0:06:43.552500
# 2021-09-01 16:19:30,319 - INFO -
# Test Acc: Max 42.1500% (6 round) | Last 42.1500% | Avg 40.1542% (4 round)
#
# 2021-09-01 16:19:30,321 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 16:19:37,092 - INFO -   |-- [Party 1] Average Train Loss:   0.3713 Train Accuracy: global   0.00% local  93.28% ... 1306 forgettables out of 1428 (91.46%) ... total data used 1428
# 2021-09-01 16:19:37,093 - INFO -   |--    Epoch Losses (10): [1.2734, 0.3461, 0.3196, 0.3019, 0.2961, 0.247, 0.2475, 0.2283, 0.2433, 0.21]
# 2021-09-01 16:19:44,626 - INFO -   |-- [Party 2] Average Train Loss:   0.3328 Train Accuracy: global   0.00% local  93.49% ... 1288 forgettables out of 1428 (90.20%) ... total data used 1428
# 2021-09-01 16:19:44,628 - INFO -   |--    Epoch Losses (10): [1.244, 0.3115, 0.2795, 0.2358, 0.2435, 0.2202, 0.2161, 0.1955, 0.1954, 0.1862]
# 2021-09-01 16:19:51,637 - INFO -   |-- [Party 3] Average Train Loss:   0.3702 Train Accuracy: global  83.12% local  80.39% ...  117 forgettables out of 1428 ( 8.19%) ... total data used 1428
# 2021-09-01 16:19:51,639 - INFO -   |--    Epoch Losses (10): [0.4461, 0.3964, 0.3815, 0.358, 0.3545, 0.3601, 0.3403, 0.3548, 0.3449, 0.3653]
# 2021-09-01 16:19:58,422 - INFO -   |-- [Party 4] Average Train Loss:   0.3132 Train Accuracy: global  86.20% local  87.04% ...  106 forgettables out of 1428 ( 7.42%) ... total data used 1428
# 2021-09-01 16:19:58,424 - INFO -   |--    Epoch Losses (10): [0.3828, 0.3431, 0.3085, 0.3144, 0.3274, 0.3232, 0.299, 0.3057, 0.2798, 0.2487]
# 2021-09-01 16:20:05,236 - INFO -   |-- [Party 5] Average Train Loss:   0.3339 Train Accuracy: global  84.80% local  89.01% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:20:05,238 - INFO -   |--    Epoch Losses (10): [0.3822, 0.3647, 0.3339, 0.3323, 0.3417, 0.3386, 0.3053, 0.3077, 0.3033, 0.3296]
# 2021-09-01 16:20:12,124 - INFO -   |-- [Party 6] Average Train Loss:   0.3556 Train Accuracy: global  86.13% local  86.55% ...   78 forgettables out of 1428 ( 5.46%) ... total data used 1428
# 2021-09-01 16:20:12,126 - INFO -   |--    Epoch Losses (10): [0.3962, 0.3606, 0.35, 0.3641, 0.3829, 0.353, 0.3487, 0.328, 0.3493, 0.3233]
# 2021-09-01 16:20:18,898 - INFO -   |-- [Party 7] Average Train Loss:   0.3046 Train Accuracy: global  86.97% local  89.64% ...   88 forgettables out of 1428 ( 6.16%) ... total data used 1428
# 2021-09-01 16:20:18,899 - INFO -   |--    Epoch Losses (10): [0.371, 0.3215, 0.3197, 0.2876, 0.2976, 0.2934, 0.3043, 0.2798, 0.2853, 0.2854]
# 2021-09-01 16:20:26,073 - INFO -   |-- [Party 8] Average Train Loss:   0.3241 Train Accuracy: global  85.99% local  86.83% ...   81 forgettables out of 1428 ( 5.67%) ... total data used 1428
# 2021-09-01 16:20:26,074 - INFO -   |--    Epoch Losses (10): [0.3846, 0.3479, 0.3285, 0.3238, 0.3286, 0.3305, 0.3253, 0.3089, 0.288, 0.2745]
# 2021-09-01 16:20:33,335 - INFO -   |-- [Party 9] Average Train Loss:   0.3343 Train Accuracy: global  86.34% local  84.17% ...   83 forgettables out of 1428 ( 5.81%) ... total data used 1428
# 2021-09-01 16:20:33,336 - INFO -   |--    Epoch Losses (10): [0.3938, 0.3716, 0.3664, 0.3827, 0.3323, 0.3176, 0.3002, 0.2865, 0.2777, 0.3141]
# 2021-09-01 16:20:37,309 - INFO -     |---- Number of Forgettables: 3243 (25.23%)
# 2021-09-01 16:20:37,310 - INFO -     |---- Train Accuracy: 67.73%
# 2021-09-01 16:20:37,312 - INFO -     |---- Test Accuracy: 42.93%
# 2021-09-01 16:20:37,313 - INFO -     |---- Test Loss: 1.5940
# 2021-09-01 16:20:37,315 - INFO -     |---- Elapsed time: 0:07:50.549919
# 2021-09-01 16:20:37,317 - INFO -
# Test Acc: Max 42.9250% (7 round) | Last 42.9250% | Avg 40.5500% (4 round)
#
# 2021-09-01 16:20:37,321 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 16:20:45,032 - INFO -   |-- [Party 1] Average Train Loss:   0.3430 Train Accuracy: global   0.00% local  85.22% ... 1332 forgettables out of 1428 (93.28%) ... total data used 1428
# 2021-09-01 16:20:45,034 - INFO -   |--    Epoch Losses (10): [1.2377, 0.3414, 0.2909, 0.2507, 0.2531, 0.2328, 0.2062, 0.1961, 0.2033, 0.2178]
# 2021-09-01 16:20:52,279 - INFO -   |-- [Party 2] Average Train Loss:   0.3187 Train Accuracy: global   0.00% local  78.36% ... 1335 forgettables out of 1428 (93.49%) ... total data used 1428
# 2021-09-01 16:20:52,280 - INFO -   |--    Epoch Losses (10): [1.2204, 0.3115, 0.2458, 0.2382, 0.2102, 0.22, 0.1901, 0.1811, 0.1919, 0.1774]
# 2021-09-01 16:20:59,530 - INFO -   |-- [Party 3] Average Train Loss:   0.3541 Train Accuracy: global  85.22% local  83.54% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:20:59,533 - INFO -   |--    Epoch Losses (10): [0.4217, 0.4208, 0.349, 0.363, 0.3279, 0.3268, 0.3112, 0.3215, 0.3158, 0.3839]
# 2021-09-01 16:21:06,854 - INFO -   |-- [Party 4] Average Train Loss:   0.2831 Train Accuracy: global  88.10% local  89.08% ...   88 forgettables out of 1428 ( 6.16%) ... total data used 1428
# 2021-09-01 16:21:06,855 - INFO -   |--    Epoch Losses (10): [0.3295, 0.3092, 0.288, 0.2998, 0.2969, 0.2952, 0.2751, 0.2425, 0.2264, 0.2688]
# 2021-09-01 16:21:13,832 - INFO -   |-- [Party 5] Average Train Loss:   0.3220 Train Accuracy: global  86.83% local  87.75% ...   97 forgettables out of 1428 ( 6.79%) ... total data used 1428
# 2021-09-01 16:21:13,833 - INFO -   |--    Epoch Losses (10): [0.3555, 0.3483, 0.3275, 0.3446, 0.3162, 0.3217, 0.302, 0.2913, 0.3057, 0.3078]
# 2021-09-01 16:21:20,614 - INFO -   |-- [Party 6] Average Train Loss:   0.3455 Train Accuracy: global  86.83% local  87.32% ...   85 forgettables out of 1428 ( 5.95%) ... total data used 1428
# 2021-09-01 16:21:20,616 - INFO -   |--    Epoch Losses (10): [0.3978, 0.3879, 0.3543, 0.3666, 0.3841, 0.3341, 0.3336, 0.3049, 0.3029, 0.2884]
# 2021-09-01 16:21:27,395 - INFO -   |-- [Party 7] Average Train Loss:   0.2992 Train Accuracy: global  88.17% local  90.27% ...   78 forgettables out of 1428 ( 5.46%) ... total data used 1428
# 2021-09-01 16:21:27,397 - INFO -   |--    Epoch Losses (10): [0.3434, 0.3094, 0.2866, 0.278, 0.3177, 0.3401, 0.304, 0.2871, 0.2672, 0.2582]
# 2021-09-01 16:21:34,177 - INFO -   |-- [Party 8] Average Train Loss:   0.3114 Train Accuracy: global  87.82% local  90.20% ...   74 forgettables out of 1428 ( 5.18%) ... total data used 1428
# 2021-09-01 16:21:34,179 - INFO -   |--    Epoch Losses (10): [0.36, 0.3293, 0.2963, 0.3096, 0.2888, 0.3388, 0.3356, 0.3378, 0.2715, 0.2467]
# 2021-09-01 16:21:41,098 - INFO -   |-- [Party 9] Average Train Loss:   0.3041 Train Accuracy: global  87.75% local  89.36% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 16:21:41,102 - INFO -   |--    Epoch Losses (10): [0.3507, 0.3418, 0.3149, 0.3033, 0.2966, 0.3065, 0.288, 0.2718, 0.2581, 0.3091]
# 2021-09-01 16:21:45,187 - INFO -     |---- Number of Forgettables: 3260 (25.37%)
# 2021-09-01 16:21:45,188 - INFO -     |---- Train Accuracy: 68.50%
# 2021-09-01 16:21:45,189 - INFO -     |---- Test Accuracy: 43.68%
# 2021-09-01 16:21:45,189 - INFO -     |---- Test Loss: 1.5892
# 2021-09-01 16:21:45,190 - INFO -     |---- Elapsed time: 0:08:58.425270
# 2021-09-01 16:21:45,191 - INFO -
# Test Acc: Max 43.6750% (8 round) | Last 43.6750% | Avg 40.9406% (4 round)
#
# 2021-09-01 16:21:45,193 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 16:21:52,351 - INFO -   |-- [Party 1] Average Train Loss:   0.3362 Train Accuracy: global   0.00% local  89.71% ... 1217 forgettables out of 1428 (85.22%) ... total data used 1428
# 2021-09-01 16:21:52,352 - INFO -   |--    Epoch Losses (10): [1.2367, 0.357, 0.2835, 0.2587, 0.2229, 0.2169, 0.2094, 0.1985, 0.1912, 0.1868]
# 2021-09-01 16:22:00,144 - INFO -   |-- [Party 2] Average Train Loss:   0.3132 Train Accuracy: global   0.07% local  89.29% ... 1118 forgettables out of 1428 (78.29%) ... total data used 1428
# 2021-09-01 16:22:00,145 - INFO -   |--    Epoch Losses (10): [1.1825, 0.321, 0.2652, 0.2211, 0.2004, 0.1935, 0.2071, 0.1781, 0.1747, 0.1883]
# 2021-09-01 16:22:06,891 - INFO -   |-- [Party 3] Average Train Loss:   0.3278 Train Accuracy: global  85.99% local  88.73% ...  101 forgettables out of 1428 ( 7.07%) ... total data used 1428
# 2021-09-01 16:22:06,892 - INFO -   |--    Epoch Losses (10): [0.3915, 0.366, 0.33, 0.3563, 0.312, 0.3074, 0.3027, 0.3154, 0.3078, 0.2885]
# 2021-09-01 16:22:14,528 - INFO -   |-- [Party 4] Average Train Loss:   0.2694 Train Accuracy: global  89.92% local  91.25% ...   61 forgettables out of 1428 ( 4.27%) ... total data used 1428
# 2021-09-01 16:22:14,529 - INFO -   |--    Epoch Losses (10): [0.3229, 0.2852, 0.3191, 0.2835, 0.2571, 0.2569, 0.2505, 0.2395, 0.2476, 0.2317]
# 2021-09-01 16:22:22,160 - INFO -   |-- [Party 5] Average Train Loss:   0.3199 Train Accuracy: global  87.46% local  90.06% ...   92 forgettables out of 1428 ( 6.44%) ... total data used 1428
# 2021-09-01 16:22:22,161 - INFO -   |--    Epoch Losses (10): [0.3496, 0.3552, 0.3274, 0.3369, 0.3549, 0.3312, 0.3004, 0.313, 0.2825, 0.2483]
# 2021-09-01 16:22:29,344 - INFO -   |-- [Party 6] Average Train Loss:   0.3260 Train Accuracy: global  86.90% local  85.43% ...   83 forgettables out of 1428 ( 5.81%) ... total data used 1428
# 2021-09-01 16:22:29,347 - INFO -   |--    Epoch Losses (10): [0.378, 0.3445, 0.3358, 0.3495, 0.3136, 0.3156, 0.3196, 0.2966, 0.3198, 0.2866]
# 2021-09-01 16:22:36,832 - INFO -   |-- [Party 7] Average Train Loss:   0.2722 Train Accuracy: global  88.10% local  90.34% ...   78 forgettables out of 1428 ( 5.46%) ... total data used 1428
# 2021-09-01 16:22:36,834 - INFO -   |--    Epoch Losses (10): [0.3559, 0.3088, 0.2835, 0.2584, 0.2831, 0.2555, 0.2387, 0.243, 0.247, 0.2475]
# 2021-09-01 16:22:44,319 - INFO -   |-- [Party 8] Average Train Loss:   0.2947 Train Accuracy: global  87.61% local  85.64% ...   86 forgettables out of 1428 ( 6.02%) ... total data used 1428
# 2021-09-01 16:22:44,320 - INFO -   |--    Epoch Losses (10): [0.3355, 0.309, 0.3328, 0.331, 0.3052, 0.2624, 0.2738, 0.2682, 0.2683, 0.2607]
# 2021-09-01 16:22:51,724 - INFO -   |-- [Party 9] Average Train Loss:   0.2894 Train Accuracy: global  88.59% local  81.16% ...   72 forgettables out of 1428 ( 5.04%) ... total data used 1428
# 2021-09-01 16:22:51,725 - INFO -   |--    Epoch Losses (10): [0.329, 0.3303, 0.337, 0.2947, 0.2677, 0.262, 0.2705, 0.2522, 0.2712, 0.2794]
# 2021-09-01 16:22:55,753 - INFO -     |---- Number of Forgettables: 2908 (22.63%)
# 2021-09-01 16:22:55,754 - INFO -     |---- Train Accuracy: 68.97%
# 2021-09-01 16:22:55,755 - INFO -     |---- Test Accuracy: 43.80%
# 2021-09-01 16:22:55,756 - INFO -     |---- Test Loss: 1.5525
# 2021-09-01 16:22:55,757 - INFO -     |---- Elapsed time: 0:10:08.991901
# 2021-09-01 16:22:55,758 - INFO -
# Test Acc: Max 43.8000% (9 round) | Last 43.8000% | Avg 41.2583% (5 round)
#
# 2021-09-01 16:22:55,760 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 16:23:03,519 - INFO -   |-- [Party 1] Average Train Loss:   0.3232 Train Accuracy: global   0.07% local  89.22% ... 1280 forgettables out of 1428 (89.64%) ... total data used 1428
# 2021-09-01 16:23:03,520 - INFO -   |--    Epoch Losses (10): [1.2052, 0.3005, 0.2427, 0.2419, 0.2476, 0.2272, 0.2097, 0.1889, 0.1778, 0.1902]
# 2021-09-01 16:23:10,439 - INFO -   |-- [Party 2] Average Train Loss:   0.2996 Train Accuracy: global   0.07% local  93.84% ... 1274 forgettables out of 1428 (89.22%) ... total data used 1428
# 2021-09-01 16:23:10,440 - INFO -   |--    Epoch Losses (10): [1.1567, 0.3273, 0.2501, 0.2049, 0.1869, 0.1674, 0.1872, 0.1707, 0.1799, 0.1645]
# 2021-09-01 16:23:17,811 - INFO -   |-- [Party 3] Average Train Loss:   0.3102 Train Accuracy: global  85.85% local  88.38% ...  113 forgettables out of 1428 ( 7.91%) ... total data used 1428
# 2021-09-01 16:23:17,814 - INFO -   |--    Epoch Losses (10): [0.387, 0.358, 0.3355, 0.3212, 0.3141, 0.2924, 0.2665, 0.2744, 0.2804, 0.2723]
# 2021-09-01 16:23:24,522 - INFO -   |-- [Party 4] Average Train Loss:   0.2482 Train Accuracy: global  89.78% local  92.16% ...   95 forgettables out of 1428 ( 6.65%) ... total data used 1428
# 2021-09-01 16:23:24,524 - INFO -   |--    Epoch Losses (10): [0.297, 0.2814, 0.2526, 0.2484, 0.2201, 0.2148, 0.2314, 0.2565, 0.2361, 0.2435]
# 2021-09-01 16:23:31,314 - INFO -   |-- [Party 5] Average Train Loss:   0.2890 Train Accuracy: global  88.17% local  91.18% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 16:23:31,315 - INFO -   |--    Epoch Losses (10): [0.3549, 0.3568, 0.3091, 0.3208, 0.298, 0.2828, 0.2481, 0.2381, 0.2506, 0.2312]
# 2021-09-01 16:23:38,801 - INFO -   |-- [Party 6] Average Train Loss:   0.3015 Train Accuracy: global  87.96% local  83.12% ...   95 forgettables out of 1428 ( 6.65%) ... total data used 1428
# 2021-09-01 16:23:38,803 - INFO -   |--    Epoch Losses (10): [0.3576, 0.3322, 0.3057, 0.3284, 0.3057, 0.2871, 0.2713, 0.29, 0.2771, 0.2596]
# 2021-09-01 16:23:45,531 - INFO -   |-- [Party 7] Average Train Loss:   0.2464 Train Accuracy: global  89.15% local  91.53% ...   76 forgettables out of 1428 ( 5.32%) ... total data used 1428
# 2021-09-01 16:23:45,533 - INFO -   |--    Epoch Losses (10): [0.3286, 0.2739, 0.2511, 0.2413, 0.2623, 0.2464, 0.2467, 0.207, 0.2103, 0.1962]
# 2021-09-01 16:23:52,971 - INFO -   |-- [Party 8] Average Train Loss:   0.2590 Train Accuracy: global  89.71% local  92.02% ...   74 forgettables out of 1428 ( 5.18%) ... total data used 1428
# 2021-09-01 16:23:52,972 - INFO -   |--    Epoch Losses (10): [0.3386, 0.3015, 0.2761, 0.2615, 0.2568, 0.2545, 0.2522, 0.2357, 0.2158, 0.1976]
# 2021-09-01 16:24:00,565 - INFO -   |-- [Party 9] Average Train Loss:   0.2655 Train Accuracy: global  88.66% local  83.47% ...   66 forgettables out of 1428 ( 4.62%) ... total data used 1428
# 2021-09-01 16:24:00,569 - INFO -   |--    Epoch Losses (10): [0.3487, 0.2993, 0.283, 0.2755, 0.2559, 0.2569, 0.2398, 0.2333, 0.2195, 0.2428]
# 2021-09-01 16:24:04,552 - INFO -     |---- Number of Forgettables: 3148 (24.49%)
# 2021-09-01 16:24:04,553 - INFO -     |---- Train Accuracy: 69.58%
# 2021-09-01 16:24:04,554 - INFO -     |---- Test Accuracy: 44.25%
# 2021-09-01 16:24:04,555 - INFO -     |---- Test Loss: 1.5223
# 2021-09-01 16:24:04,555 - INFO -     |---- Elapsed time: 0:11:17.790558
# 2021-09-01 16:24:04,556 - INFO -
# Test Acc: Max 44.2500% (10 round) | Last 44.2500% | Avg 41.5575% (5 round)
#
# 2021-09-01 16:24:04,559 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 16:24:11,515 - INFO -   |-- [Party 1] Average Train Loss:   0.3088 Train Accuracy: global   0.00% local  93.84% ... 1274 forgettables out of 1428 (89.22%) ... total data used 1428
# 2021-09-01 16:24:11,517 - INFO -   |--    Epoch Losses (10): [1.1739, 0.3121, 0.2391, 0.2446, 0.2095, 0.201, 0.1892, 0.1798, 0.1739, 0.1649]
# 2021-09-01 16:24:18,997 - INFO -   |-- [Party 2] Average Train Loss:   0.2950 Train Accuracy: global   0.00% local  83.68% ... 1340 forgettables out of 1428 (93.84%) ... total data used 1428
# 2021-09-01 16:24:18,999 - INFO -   |--    Epoch Losses (10): [1.1493, 0.3011, 0.2546, 0.2065, 0.1818, 0.1887, 0.1843, 0.157, 0.1548, 0.1721]
# 2021-09-01 16:24:25,924 - INFO -   |-- [Party 3] Average Train Loss:   0.3041 Train Accuracy: global  87.04% local  81.30% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:24:25,925 - INFO -   |--    Epoch Losses (10): [0.3503, 0.3364, 0.3347, 0.3085, 0.2857, 0.274, 0.2651, 0.2838, 0.2874, 0.3147]
# 2021-09-01 16:24:33,385 - INFO -   |-- [Party 4] Average Train Loss:   0.2430 Train Accuracy: global  90.90% local  91.88% ...   74 forgettables out of 1428 ( 5.18%) ... total data used 1428
# 2021-09-01 16:24:33,386 - INFO -   |--    Epoch Losses (10): [0.2691, 0.2883, 0.2525, 0.2672, 0.228, 0.2154, 0.2008, 0.2426, 0.2338, 0.2325]
# 2021-09-01 16:24:40,810 - INFO -   |-- [Party 5] Average Train Loss:   0.2655 Train Accuracy: global  88.73% local  84.59% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:24:40,811 - INFO -   |--    Epoch Losses (10): [0.3034, 0.2899, 0.2708, 0.2705, 0.2641, 0.2507, 0.251, 0.2364, 0.2632, 0.2546]
# 2021-09-01 16:24:48,226 - INFO -   |-- [Party 6] Average Train Loss:   0.2811 Train Accuracy: global  88.80% local  89.92% ...   77 forgettables out of 1428 ( 5.39%) ... total data used 1428
# 2021-09-01 16:24:48,228 - INFO -   |--    Epoch Losses (10): [0.3511, 0.306, 0.2891, 0.3036, 0.2996, 0.2734, 0.2473, 0.2604, 0.2446, 0.2358]
# 2021-09-01 16:24:55,391 - INFO -   |-- [Party 7] Average Train Loss:   0.2353 Train Accuracy: global  90.41% local  90.13% ...   77 forgettables out of 1428 ( 5.39%) ... total data used 1428
# 2021-09-01 16:24:55,394 - INFO -   |--    Epoch Losses (10): [0.3253, 0.2643, 0.2422, 0.2279, 0.2065, 0.2153, 0.2516, 0.2084, 0.2074, 0.2038]
# 2021-09-01 16:25:02,124 - INFO -   |-- [Party 8] Average Train Loss:   0.2512 Train Accuracy: global  90.27% local  89.43% ...   74 forgettables out of 1428 ( 5.18%) ... total data used 1428
# 2021-09-01 16:25:02,125 - INFO -   |--    Epoch Losses (10): [0.2807, 0.2738, 0.2632, 0.2845, 0.2519, 0.2412, 0.2587, 0.2014, 0.2434, 0.2134]
# 2021-09-01 16:25:08,921 - INFO -   |-- [Party 9] Average Train Loss:   0.2611 Train Accuracy: global  90.06% local  91.60% ...   51 forgettables out of 1428 ( 3.57%) ... total data used 1428
# 2021-09-01 16:25:08,922 - INFO -   |--    Epoch Losses (10): [0.3147, 0.3172, 0.258, 0.2586, 0.2623, 0.2564, 0.2245, 0.2194, 0.2309, 0.2691]
# 2021-09-01 16:25:13,014 - INFO -     |---- Number of Forgettables: 3159 (24.58%)
# 2021-09-01 16:25:13,015 - INFO -     |---- Train Accuracy: 69.27%
# 2021-09-01 16:25:13,016 - INFO -     |---- Test Accuracy: 44.67%
# 2021-09-01 16:25:13,017 - INFO -     |---- Test Loss: 1.5072
# 2021-09-01 16:25:13,017 - INFO -     |---- Elapsed time: 0:12:26.252515
# 2021-09-01 16:25:13,018 - INFO -
# Test Acc: Max 44.6750% (11 round) | Last 44.6750% | Avg 41.8409% (5 round)
#
# 2021-09-01 16:25:13,022 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 16:25:19,950 - INFO -   |-- [Party 1] Average Train Loss:   0.3047 Train Accuracy: global   0.14% local  93.14% ... 1338 forgettables out of 1428 (93.70%) ... total data used 1428
# 2021-09-01 16:25:19,952 - INFO -   |--    Epoch Losses (10): [1.1047, 0.3185, 0.2442, 0.2237, 0.204, 0.1968, 0.1742, 0.2448, 0.1781, 0.158]
# 2021-09-01 16:25:27,343 - INFO -   |-- [Party 2] Average Train Loss:   0.2757 Train Accuracy: global   0.28% local  94.19% ... 1191 forgettables out of 1428 (83.40%) ... total data used 1428
# 2021-09-01 16:25:27,345 - INFO -   |--    Epoch Losses (10): [1.0557, 0.2737, 0.2264, 0.1917, 0.1714, 0.1733, 0.1853, 0.1704, 0.153, 0.1561]
# 2021-09-01 16:25:34,937 - INFO -   |-- [Party 3] Average Train Loss:   0.2836 Train Accuracy: global  86.55% local  87.68% ...   71 forgettables out of 1428 ( 4.97%) ... total data used 1428
# 2021-09-01 16:25:34,940 - INFO -   |--    Epoch Losses (10): [0.3299, 0.3062, 0.2937, 0.2611, 0.3086, 0.2923, 0.2876, 0.2464, 0.2617, 0.2489]
# 2021-09-01 16:25:42,200 - INFO -   |-- [Party 4] Average Train Loss:   0.2178 Train Accuracy: global  89.85% local  92.30% ...   94 forgettables out of 1428 ( 6.58%) ... total data used 1428
# 2021-09-01 16:25:42,202 - INFO -   |--    Epoch Losses (10): [0.2662, 0.2541, 0.2293, 0.2099, 0.2183, 0.2193, 0.2003, 0.2164, 0.1903, 0.1742]
# 2021-09-01 16:25:49,539 - INFO -   |-- [Party 5] Average Train Loss:   0.2520 Train Accuracy: global  88.17% local  90.41% ...   67 forgettables out of 1428 ( 4.69%) ... total data used 1428
# 2021-09-01 16:25:49,540 - INFO -   |--    Epoch Losses (10): [0.3041, 0.2985, 0.2462, 0.2693, 0.2534, 0.2572, 0.2296, 0.2196, 0.2166, 0.2258]
# 2021-09-01 16:25:56,278 - INFO -   |-- [Party 6] Average Train Loss:   0.2712 Train Accuracy: global  88.31% local  91.04% ...   98 forgettables out of 1428 ( 6.86%) ... total data used 1428
# 2021-09-01 16:25:56,280 - INFO -   |--    Epoch Losses (10): [0.3147, 0.2983, 0.3082, 0.2723, 0.253, 0.2974, 0.2639, 0.243, 0.244, 0.2177]
# 2021-09-01 16:26:03,356 - INFO -   |-- [Party 7] Average Train Loss:   0.2307 Train Accuracy: global  89.78% local  84.03% ...   88 forgettables out of 1428 ( 6.16%) ... total data used 1428
# 2021-09-01 16:26:03,358 - INFO -   |--    Epoch Losses (10): [0.2967, 0.259, 0.2378, 0.2203, 0.233, 0.2436, 0.2191, 0.2026, 0.2016, 0.1931]
# 2021-09-01 16:26:10,728 - INFO -   |-- [Party 8] Average Train Loss:   0.2507 Train Accuracy: global  90.48% local  92.23% ...   84 forgettables out of 1428 ( 5.88%) ... total data used 1428
# 2021-09-01 16:26:10,730 - INFO -   |--    Epoch Losses (10): [0.2999, 0.2832, 0.2535, 0.2523, 0.2554, 0.2596, 0.2514, 0.2387, 0.2175, 0.1952]
# 2021-09-01 16:26:17,738 - INFO -   |-- [Party 9] Average Train Loss:   0.2418 Train Accuracy: global  89.43% local  91.04% ...   78 forgettables out of 1428 ( 5.46%) ... total data used 1428
# 2021-09-01 16:26:17,741 - INFO -   |--    Epoch Losses (10): [0.2952, 0.2659, 0.25, 0.2791, 0.2506, 0.2233, 0.226, 0.2196, 0.2114, 0.1969]
# 2021-09-01 16:26:21,751 - INFO -     |---- Number of Forgettables: 3109 (24.19%)
# 2021-09-01 16:26:21,752 - INFO -     |---- Train Accuracy: 69.55%
# 2021-09-01 16:26:21,753 - INFO -     |---- Test Accuracy: 44.55%
# 2021-09-01 16:26:21,753 - INFO -     |---- Test Loss: 1.5255
# 2021-09-01 16:26:21,754 - INFO -     |---- Elapsed time: 0:13:34.988969
# 2021-09-01 16:26:21,755 - INFO -
# Test Acc: Max 44.5500% (11 round) | Last 44.5500% | Avg 42.0667% (6 round)
#
# 2021-09-01 16:26:21,757 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 16:26:29,021 - INFO -   |-- [Party 1] Average Train Loss:   0.2928 Train Accuracy: global   0.42% local  91.81% ... 1324 forgettables out of 1428 (92.72%) ... total data used 1428
# 2021-09-01 16:26:29,023 - INFO -   |--    Epoch Losses (10): [1.0815, 0.3204, 0.2396, 0.2185, 0.1932, 0.1914, 0.1788, 0.1607, 0.1712, 0.1728]
# 2021-09-01 16:26:35,695 - INFO -   |-- [Party 2] Average Train Loss:   0.2755 Train Accuracy: global   0.07% local  95.94% ... 1344 forgettables out of 1428 (94.12%) ... total data used 1428
# 2021-09-01 16:26:35,696 - INFO -   |--    Epoch Losses (10): [1.0503, 0.2482, 0.2331, 0.2186, 0.2034, 0.1912, 0.1623, 0.1529, 0.1507, 0.1442]
# 2021-09-01 16:26:43,250 - INFO -   |-- [Party 3] Average Train Loss:   0.2706 Train Accuracy: global  87.82% local  85.71% ...  127 forgettables out of 1428 ( 8.89%) ... total data used 1428
# 2021-09-01 16:26:43,251 - INFO -   |--    Epoch Losses (10): [0.3116, 0.3098, 0.3063, 0.2945, 0.2774, 0.263, 0.2418, 0.228, 0.2421, 0.2318]
# 2021-09-01 16:26:50,737 - INFO -   |-- [Party 4] Average Train Loss:   0.2142 Train Accuracy: global  91.18% local  94.54% ...   82 forgettables out of 1428 ( 5.74%) ... total data used 1428
# 2021-09-01 16:26:50,738 - INFO -   |--    Epoch Losses (10): [0.253, 0.2345, 0.2141, 0.2046, 0.2391, 0.2183, 0.2133, 0.1884, 0.1981, 0.1781]
# 2021-09-01 16:26:57,497 - INFO -   |-- [Party 5] Average Train Loss:   0.2423 Train Accuracy: global  87.82% local  92.93% ...  104 forgettables out of 1428 ( 7.28%) ... total data used 1428
# 2021-09-01 16:26:57,498 - INFO -   |--    Epoch Losses (10): [0.2959, 0.2515, 0.2794, 0.2654, 0.2763, 0.2235, 0.2182, 0.2129, 0.2113, 0.1884]
# 2021-09-01 16:27:04,225 - INFO -   |-- [Party 6] Average Train Loss:   0.2582 Train Accuracy: global  89.01% local  90.27% ...   97 forgettables out of 1428 ( 6.79%) ... total data used 1428
# 2021-09-01 16:27:04,226 - INFO -   |--    Epoch Losses (10): [0.3035, 0.2902, 0.2663, 0.3075, 0.2496, 0.2463, 0.2275, 0.2395, 0.2236, 0.228]
# 2021-09-01 16:27:10,922 - INFO -   |-- [Party 7] Average Train Loss:   0.2287 Train Accuracy: global  89.64% local  89.43% ...   65 forgettables out of 1428 ( 4.55%) ... total data used 1428
# 2021-09-01 16:27:10,925 - INFO -   |--    Epoch Losses (10): [0.2746, 0.258, 0.2436, 0.2081, 0.2288, 0.2326, 0.2239, 0.2165, 0.2018, 0.1992]
# 2021-09-01 16:27:17,610 - INFO -   |-- [Party 8] Average Train Loss:   0.2247 Train Accuracy: global  90.48% local  92.79% ...   73 forgettables out of 1428 ( 5.11%) ... total data used 1428
# 2021-09-01 16:27:17,611 - INFO -   |--    Epoch Losses (10): [0.2598, 0.2477, 0.2431, 0.2545, 0.2501, 0.246, 0.2097, 0.1935, 0.1783, 0.164]
# 2021-09-01 16:27:25,243 - INFO -   |-- [Party 9] Average Train Loss:   0.2559 Train Accuracy: global  89.57% local  92.79% ...  105 forgettables out of 1428 ( 7.35%) ... total data used 1428
# 2021-09-01 16:27:25,245 - INFO -   |--    Epoch Losses (10): [0.3009, 0.2695, 0.2404, 0.2567, 0.2737, 0.2277, 0.267, 0.2619, 0.246, 0.215]
# 2021-09-01 16:27:29,243 - INFO -     |---- Number of Forgettables: 3321 (25.84%)
# 2021-09-01 16:27:29,244 - INFO -     |---- Train Accuracy: 69.76%
# 2021-09-01 16:27:29,245 - INFO -     |---- Test Accuracy: 45.10%
# 2021-09-01 16:27:29,246 - INFO -     |---- Test Loss: 1.4832
# 2021-09-01 16:27:29,247 - INFO -     |---- Elapsed time: 0:14:42.482337
# 2021-09-01 16:27:29,249 - INFO -
# Test Acc: Max 45.1000% (13 round) | Last 45.1000% | Avg 42.3000% (7 round)
#
# 2021-09-01 16:27:29,251 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 16:27:36,788 - INFO -   |-- [Party 1] Average Train Loss:   0.2803 Train Accuracy: global   0.35% local  94.33% ... 1306 forgettables out of 1428 (91.46%) ... total data used 1428
# 2021-09-01 16:27:36,789 - INFO -   |--    Epoch Losses (10): [1.0446, 0.2917, 0.2404, 0.1878, 0.1903, 0.1642, 0.1733, 0.1789, 0.164, 0.1678]
# 2021-09-01 16:27:43,553 - INFO -   |-- [Party 2] Average Train Loss:   0.2703 Train Accuracy: global   0.28% local  95.38% ... 1366 forgettables out of 1428 (95.66%) ... total data used 1428
# 2021-09-01 16:27:43,554 - INFO -   |--    Epoch Losses (10): [1.1058, 0.2697, 0.1999, 0.2074, 0.1609, 0.1543, 0.1584, 0.1634, 0.1412, 0.1422]
# 2021-09-01 16:27:50,282 - INFO -   |-- [Party 3] Average Train Loss:   0.2566 Train Accuracy: global  88.03% local  89.99% ...   71 forgettables out of 1428 ( 4.97%) ... total data used 1428
# 2021-09-01 16:27:50,283 - INFO -   |--    Epoch Losses (10): [0.3136, 0.3037, 0.2507, 0.2777, 0.2596, 0.2719, 0.2239, 0.2211, 0.232, 0.2121]
# 2021-09-01 16:27:56,972 - INFO -   |-- [Party 4] Average Train Loss:   0.2013 Train Accuracy: global  90.06% local  93.98% ...  103 forgettables out of 1428 ( 7.21%) ... total data used 1428
# 2021-09-01 16:27:56,974 - INFO -   |--    Epoch Losses (10): [0.2464, 0.2034, 0.2031, 0.2079, 0.2107, 0.1838, 0.1858, 0.1929, 0.1884, 0.1909]
# 2021-09-01 16:28:03,695 - INFO -   |-- [Party 5] Average Train Loss:   0.2360 Train Accuracy: global  88.66% local  93.56% ...  112 forgettables out of 1428 ( 7.84%) ... total data used 1428
# 2021-09-01 16:28:03,698 - INFO -   |--    Epoch Losses (10): [0.2919, 0.2807, 0.2495, 0.2339, 0.2221, 0.2136, 0.2212, 0.2047, 0.2283, 0.2143]
# 2021-09-01 16:28:10,926 - INFO -   |-- [Party 6] Average Train Loss:   0.2508 Train Accuracy: global  89.01% local  87.46% ...   97 forgettables out of 1428 ( 6.79%) ... total data used 1428
# 2021-09-01 16:28:10,928 - INFO -   |--    Epoch Losses (10): [0.281, 0.2844, 0.2791, 0.2522, 0.2482, 0.2538, 0.2252, 0.2281, 0.2352, 0.2207]
# ...
# 2021-09-01 19:54:47,006 - INFO -   |--    Epoch Losses (10): [0.0042, 0.0044, 0.0026, 0.0026, 0.0055, 0.0033, 0.0122, 0.0225, 0.0178, 0.0272]
# 2021-09-01 19:54:54,040 - INFO -   |-- [Party 6] Average Train Loss:   0.0049 Train Accuracy: global  99.44% local  99.93% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:54:54,042 - INFO -   |--    Epoch Losses (10): [0.0044, 0.0033, 0.0058, 0.0047, 0.003, 0.004, 0.0035, 0.0065, 0.0063, 0.0076]
# 2021-09-01 19:55:01,558 - INFO -   |-- [Party 7] Average Train Loss:   0.0033 Train Accuracy: global  99.30% local 100.00% ...   10 forgettables out of 1428 ( 0.70%) ... total data used 1428
# 2021-09-01 19:55:01,559 - INFO -   |--    Epoch Losses (10): [0.0045, 0.006, 0.0039, 0.0028, 0.0021, 0.0024, 0.0027, 0.0042, 0.003, 0.0018]
# 2021-09-01 19:55:08,444 - INFO -   |-- [Party 8] Average Train Loss:   0.0084 Train Accuracy: global  99.79% local  99.93% ...    3 forgettables out of 1428 ( 0.21%) ... total data used 1428
# 2021-09-01 19:55:08,445 - INFO -   |--    Epoch Losses (10): [0.0041, 0.0039, 0.003, 0.0028, 0.0026, 0.0118, 0.0163, 0.013, 0.0184, 0.0078]
# 2021-09-01 19:55:15,863 - INFO -   |-- [Party 9] Average Train Loss:   0.0036 Train Accuracy: global  99.44% local  99.93% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:55:15,864 - INFO -   |--    Epoch Losses (10): [0.0119, 0.0059, 0.0029, 0.0037, 0.002, 0.0013, 0.0015, 0.0009, 0.0029, 0.0026]
# 2021-09-01 19:55:19,919 - INFO -     |---- Number of Forgettables: 2710 (21.09%)
# 2021-09-01 19:55:19,922 - INFO -     |---- Train Accuracy: 78.76%
# 2021-09-01 19:55:19,923 - INFO -     |---- Test Accuracy: 51.95%
# 2021-09-01 19:55:19,924 - INFO -     |---- Test Loss: 1.8656
# 2021-09-01 19:55:19,925 - INFO -     |---- Elapsed time: 3:42:33.159888
# 2021-09-01 19:55:19,926 - INFO -
# Test Acc: Max 51.9500% (104 round) | Last 51.9500% | Avg 50.7620% (35 round)
#
# 2021-09-01 19:55:19,931 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 19:55:27,391 - INFO -   |-- [Party 1] Average Train Loss:   0.0045 Train Accuracy: global   7.63% local 100.00% ... 1317 forgettables out of 1428 (92.23%) ... total data used 1428
# 2021-09-01 19:55:27,392 - INFO -   |--    Epoch Losses (10): [0.0096, 0.0041, 0.005, 0.0044, 0.0036, 0.006, 0.0053, 0.002, 0.0022, 0.0023]
# 2021-09-01 19:55:34,140 - INFO -   |-- [Party 2] Average Train Loss:   0.0059 Train Accuracy: global   6.86% local 100.00% ... 1330 forgettables out of 1428 (93.14%) ... total data used 1428
# 2021-09-01 19:55:34,141 - INFO -   |--    Epoch Losses (10): [0.0064, 0.0039, 0.0036, 0.0092, 0.0103, 0.0074, 0.0087, 0.0034, 0.0031, 0.0032]
# 2021-09-01 19:55:40,919 - INFO -   |-- [Party 3] Average Train Loss:   0.0068 Train Accuracy: global  98.81% local  99.93% ...   17 forgettables out of 1428 ( 1.19%) ... total data used 1428
# 2021-09-01 19:55:40,921 - INFO -   |--    Epoch Losses (10): [0.0096, 0.0061, 0.0092, 0.008, 0.0127, 0.0043, 0.0053, 0.0048, 0.006, 0.0023]
# 2021-09-01 19:55:47,806 - INFO -   |-- [Party 4] Average Train Loss:   0.0048 Train Accuracy: global  99.09% local 100.00% ...   13 forgettables out of 1428 ( 0.91%) ... total data used 1428
# 2021-09-01 19:55:47,807 - INFO -   |--    Epoch Losses (10): [0.0063, 0.0048, 0.0037, 0.0028, 0.0022, 0.0023, 0.0086, 0.0074, 0.0049, 0.0052]
# 2021-09-01 19:55:54,629 - INFO -   |-- [Party 5] Average Train Loss:   0.0492 Train Accuracy: global  99.37% local  99.37% ...    9 forgettables out of 1428 ( 0.63%) ... total data used 1428
# 2021-09-01 19:55:54,630 - INFO -   |--    Epoch Losses (10): [0.005, 0.0192, 0.0275, 0.0328, 0.1129, 0.1227, 0.0891, 0.0299, 0.0264, 0.0268]
# 2021-09-01 19:56:01,659 - INFO -   |-- [Party 6] Average Train Loss:   0.0209 Train Accuracy: global  99.30% local 100.00% ...   10 forgettables out of 1428 ( 0.70%) ... total data used 1428
# 2021-09-01 19:56:01,661 - INFO -   |--    Epoch Losses (10): [0.0071, 0.0217, 0.0404, 0.0359, 0.0346, 0.0241, 0.0173, 0.0122, 0.0088, 0.007]
# 2021-09-01 19:56:09,436 - INFO -   |-- [Party 7] Average Train Loss:   0.0032 Train Accuracy: global  98.95% local 100.00% ...   15 forgettables out of 1428 ( 1.05%) ... total data used 1428
# 2021-09-01 19:56:09,437 - INFO -   |--    Epoch Losses (10): [0.0044, 0.0032, 0.0023, 0.0035, 0.0021, 0.0024, 0.0012, 0.0031, 0.0011, 0.0081]
# 2021-09-01 19:56:17,204 - INFO -   |-- [Party 8] Average Train Loss:   0.0447 Train Accuracy: global  99.51% local  99.16% ...    7 forgettables out of 1428 ( 0.49%) ... total data used 1428
# 2021-09-01 19:56:17,205 - INFO -   |--    Epoch Losses (10): [0.0422, 0.0844, 0.0838, 0.0492, 0.014, 0.0347, 0.047, 0.0341, 0.0331, 0.0243]
# 2021-09-01 19:56:24,506 - INFO -   |-- [Party 9] Average Train Loss:   0.0057 Train Accuracy: global  98.95% local  99.93% ...   15 forgettables out of 1428 ( 1.05%) ... total data used 1428
# 2021-09-01 19:56:24,509 - INFO -   |--    Epoch Losses (10): [0.0077, 0.0039, 0.0051, 0.0038, 0.0021, 0.0029, 0.0089, 0.0094, 0.0074, 0.0064]
# 2021-09-01 19:56:29,057 - INFO -     |---- Number of Forgettables: 2733 (21.27%)
# 2021-09-01 19:56:29,058 - INFO -     |---- Train Accuracy: 79.17%
# 2021-09-01 19:56:29,058 - INFO -     |---- Test Accuracy: 52.55%
# 2021-09-01 19:56:29,059 - INFO -     |---- Test Loss: 1.8208
# 2021-09-01 19:56:29,059 - INFO -     |---- Elapsed time: 3:43:42.294197
# 2021-09-01 19:56:29,061 - INFO -
# Test Acc: Max 52.5500% (104 round) | Last 52.5500% | Avg 50.7711% (35 round)
#
# 2021-09-01 19:56:29,063 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 19:56:36,736 - INFO -   |-- [Party 1] Average Train Loss:   0.0064 Train Accuracy: global   6.51% local 100.00% ... 1335 forgettables out of 1428 (93.49%) ... total data used 1428
# 2021-09-01 19:56:36,738 - INFO -   |--    Epoch Losses (10): [0.0142, 0.0034, 0.0062, 0.0033, 0.0043, 0.0033, 0.0075, 0.0086, 0.0069, 0.0064]
# 2021-09-01 19:56:43,525 - INFO -   |-- [Party 2] Average Train Loss:   0.0044 Train Accuracy: global   6.16% local 100.00% ... 1340 forgettables out of 1428 (93.84%) ... total data used 1428
# 2021-09-01 19:56:43,526 - INFO -   |--    Epoch Losses (10): [0.0099, 0.0033, 0.0037, 0.0024, 0.0035, 0.0019, 0.002, 0.0024, 0.0031, 0.0115]
# 2021-09-01 19:56:50,252 - INFO -   |-- [Party 3] Average Train Loss:   0.0328 Train Accuracy: global  99.30% local  97.55% ...   10 forgettables out of 1428 ( 0.70%) ... total data used 1428
# 2021-09-01 19:56:50,253 - INFO -   |--    Epoch Losses (10): [0.0066, 0.009, 0.0082, 0.0084, 0.0065, 0.0111, 0.023, 0.0247, 0.1386, 0.092]
# 2021-09-01 19:56:57,061 - INFO -   |-- [Party 4] Average Train Loss:   0.0185 Train Accuracy: global  99.79% local  99.93% ...    3 forgettables out of 1428 ( 0.21%) ... total data used 1428
# 2021-09-01 19:56:57,062 - INFO -   |--    Epoch Losses (10): [0.0044, 0.0059, 0.0144, 0.0241, 0.0384, 0.016, 0.0198, 0.038, 0.0143, 0.0101]
# 2021-09-01 19:57:03,889 - INFO -   |-- [Party 5] Average Train Loss:   0.0046 Train Accuracy: global  99.72% local 100.00% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 19:57:03,891 - INFO -   |--    Epoch Losses (10): [0.0038, 0.0045, 0.0049, 0.0018, 0.0047, 0.0096, 0.0054, 0.0044, 0.0025, 0.0043]
# 2021-09-01 19:57:11,607 - INFO -   |-- [Party 6] Average Train Loss:   0.0050 Train Accuracy: global  99.86% local  99.93% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 19:57:11,608 - INFO -   |--    Epoch Losses (10): [0.0057, 0.0053, 0.003, 0.004, 0.004, 0.0046, 0.0029, 0.0071, 0.0061, 0.0074]
# 2021-09-01 19:57:18,377 - INFO -   |-- [Party 7] Average Train Loss:   0.0148 Train Accuracy: global  99.65% local  99.72% ...    5 forgettables out of 1428 ( 0.35%) ... total data used 1428
# 2021-09-01 19:57:18,379 - INFO -   |--    Epoch Losses (10): [0.005, 0.0031, 0.0048, 0.0016, 0.003, 0.0471, 0.0375, 0.0234, 0.0105, 0.0123]
# 2021-09-01 19:57:25,461 - INFO -   |-- [Party 8] Average Train Loss:   0.0055 Train Accuracy: global  99.93% local 100.00% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:57:25,463 - INFO -   |--    Epoch Losses (10): [0.0018, 0.0062, 0.0036, 0.0038, 0.0043, 0.0066, 0.0057, 0.0078, 0.0045, 0.0105]
# 2021-09-01 19:57:32,375 - INFO -   |-- [Party 9] Average Train Loss:   0.0035 Train Accuracy: global  99.86% local 100.00% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 19:57:32,377 - INFO -   |--    Epoch Losses (10): [0.005, 0.0041, 0.0043, 0.0033, 0.0034, 0.0025, 0.0049, 0.0019, 0.0036, 0.0019]
# 2021-09-01 19:57:36,414 - INFO -     |---- Number of Forgettables: 2702 (21.02%)
# 2021-09-01 19:57:36,416 - INFO -     |---- Train Accuracy: 78.77%
# 2021-09-01 19:57:36,417 - INFO -     |---- Test Accuracy: 51.78%
# 2021-09-01 19:57:36,418 - INFO -     |---- Test Loss: 1.8802
# 2021-09-01 19:57:36,419 - INFO -     |---- Elapsed time: 3:44:49.653825
# 2021-09-01 19:57:36,420 - INFO -
# Test Acc: Max 51.7750% (104 round) | Last 51.7750% | Avg 50.7761% (35 round)
#
# 2021-09-01 19:57:36,422 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 19:57:43,331 - INFO -   |-- [Party 1] Average Train Loss:   0.0486 Train Accuracy: global   6.86% local  99.58% ... 1330 forgettables out of 1428 (93.14%) ... total data used 1428
# 2021-09-01 19:57:43,335 - INFO -   |--    Epoch Losses (10): [0.0097, 0.0192, 0.0353, 0.035, 0.0732, 0.1199, 0.0734, 0.0465, 0.0452, 0.0286]
# 2021-09-01 19:57:50,064 - INFO -   |-- [Party 2] Average Train Loss:   0.0036 Train Accuracy: global   6.65% local 100.00% ... 1333 forgettables out of 1428 (93.35%) ... total data used 1428
# 2021-09-01 19:57:50,065 - INFO -   |--    Epoch Losses (10): [0.0121, 0.0035, 0.0035, 0.0025, 0.0021, 0.0031, 0.0023, 0.0024, 0.0011, 0.0035]
# 2021-09-01 19:57:56,837 - INFO -   |-- [Party 3] Average Train Loss:   0.0477 Train Accuracy: global  98.88% local  98.81% ...   13 forgettables out of 1428 ( 0.91%) ... total data used 1428
# 2021-09-01 19:57:56,839 - INFO -   |--    Epoch Losses (10): [0.0154, 0.0333, 0.0199, 0.0106, 0.0331, 0.0327, 0.0863, 0.1023, 0.065, 0.078]
# 2021-09-01 19:58:04,076 - INFO -   |-- [Party 4] Average Train Loss:   0.0141 Train Accuracy: global  99.09% local  99.79% ...   13 forgettables out of 1428 ( 0.91%) ... total data used 1428
# 2021-09-01 19:58:04,077 - INFO -   |--    Epoch Losses (10): [0.0052, 0.0045, 0.0236, 0.0355, 0.0151, 0.0227, 0.0065, 0.0125, 0.0083, 0.0067]
# 2021-09-01 19:58:10,834 - INFO -   |-- [Party 5] Average Train Loss:   0.0072 Train Accuracy: global  99.37% local  99.93% ...    9 forgettables out of 1428 ( 0.63%) ... total data used 1428
# 2021-09-01 19:58:10,836 - INFO -   |--    Epoch Losses (10): [0.0038, 0.004, 0.0025, 0.0027, 0.0057, 0.0136, 0.0088, 0.0053, 0.0099, 0.0159]
# 2021-09-01 19:58:17,542 - INFO -   |-- [Party 6] Average Train Loss:   0.0050 Train Accuracy: global  99.44% local 100.00% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:58:17,544 - INFO -   |--    Epoch Losses (10): [0.0086, 0.0038, 0.0075, 0.0089, 0.005, 0.0051, 0.0051, 0.0016, 0.0024, 0.0022]
# 2021-09-01 19:58:24,233 - INFO -   |-- [Party 7] Average Train Loss:   0.0039 Train Accuracy: global  99.30% local 100.00% ...    9 forgettables out of 1428 ( 0.63%) ... total data used 1428
# 2021-09-01 19:58:24,234 - INFO -   |--    Epoch Losses (10): [0.0066, 0.0034, 0.006, 0.0031, 0.0052, 0.0031, 0.0033, 0.0023, 0.0035, 0.002]
# 2021-09-01 19:58:30,962 - INFO -   |-- [Party 8] Average Train Loss:   0.0224 Train Accuracy: global  99.65% local  99.93% ...    5 forgettables out of 1428 ( 0.35%) ... total data used 1428
# 2021-09-01 19:58:30,963 - INFO -   |--    Epoch Losses (10): [0.0069, 0.0386, 0.064, 0.0346, 0.0263, 0.0145, 0.0162, 0.0096, 0.0095, 0.0036]
# 2021-09-01 19:58:37,678 - INFO -   |-- [Party 9] Average Train Loss:   0.0050 Train Accuracy: global  99.30% local  98.88% ...   10 forgettables out of 1428 ( 0.70%) ... total data used 1428
# 2021-09-01 19:58:37,680 - INFO -   |--    Epoch Losses (10): [0.0058, 0.0057, 0.0019, 0.0018, 0.0029, 0.0018, 0.0017, 0.0021, 0.0092, 0.0173]
# 2021-09-01 19:58:42,148 - INFO -     |---- Number of Forgettables: 2730 (21.24%)
# 2021-09-01 19:58:42,150 - INFO -     |---- Train Accuracy: 78.92%
# 2021-09-01 19:58:42,151 - INFO -     |---- Test Accuracy: 52.45%
# 2021-09-01 19:58:42,152 - INFO -     |---- Test Loss: 1.7899
# 2021-09-01 19:58:42,152 - INFO -     |---- Elapsed time: 3:45:55.387525
# 2021-09-01 19:58:42,154 - INFO -
# Test Acc: Max 52.4500% (104 round) | Last 52.4500% | Avg 50.7845% (35 round)
#
# 2021-09-01 19:58:42,157 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 19:58:49,732 - INFO -   |-- [Party 1] Average Train Loss:   0.0044 Train Accuracy: global   7.63% local 100.00% ... 1313 forgettables out of 1428 (91.95%) ... total data used 1428
# 2021-09-01 19:58:49,733 - INFO -   |--    Epoch Losses (10): [0.0094, 0.0035, 0.003, 0.0024, 0.005, 0.0041, 0.0045, 0.0024, 0.0066, 0.0036]
# 2021-09-01 19:58:57,549 - INFO -   |-- [Party 2] Average Train Loss:   0.0050 Train Accuracy: global   6.02% local 100.00% ... 1342 forgettables out of 1428 (93.98%) ... total data used 1428
# 2021-09-01 19:58:57,551 - INFO -   |--    Epoch Losses (10): [0.0104, 0.0034, 0.0057, 0.0062, 0.0051, 0.0047, 0.0048, 0.0024, 0.0038, 0.0035]
# 2021-09-01 19:59:04,333 - INFO -   |-- [Party 3] Average Train Loss:   0.0185 Train Accuracy: global  99.37% local  99.72% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:59:04,334 - INFO -   |--    Epoch Losses (10): [0.0273, 0.0353, 0.0306, 0.0281, 0.0178, 0.0098, 0.01, 0.0131, 0.0074, 0.0056]
# 2021-09-01 19:59:11,475 - INFO -   |-- [Party 4] Average Train Loss:   0.0162 Train Accuracy: global  99.16% local  99.79% ...   12 forgettables out of 1428 ( 0.84%) ... total data used 1428
# 2021-09-01 19:59:11,476 - INFO -   |--    Epoch Losses (10): [0.0247, 0.0386, 0.0242, 0.0251, 0.0106, 0.0091, 0.01, 0.0063, 0.0075, 0.0056]
# 2021-09-01 19:59:18,385 - INFO -   |-- [Party 5] Average Train Loss:   0.0259 Train Accuracy: global  99.72% local  99.58% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 19:59:18,386 - INFO -   |--    Epoch Losses (10): [0.0047, 0.0298, 0.0281, 0.0403, 0.0347, 0.0185, 0.0137, 0.0379, 0.0273, 0.0242]
# 2021-09-01 19:59:25,501 - INFO -   |-- [Party 6] Average Train Loss:   0.0032 Train Accuracy: global  99.58% local 100.00% ...    6 forgettables out of 1428 ( 0.42%) ... total data used 1428
# 2021-09-01 19:59:25,503 - INFO -   |--    Epoch Losses (10): [0.0075, 0.0036, 0.0059, 0.0023, 0.0032, 0.002, 0.0025, 0.0021, 0.0019, 0.0011]
# 2021-09-01 19:59:32,786 - INFO -   |-- [Party 7] Average Train Loss:   0.0285 Train Accuracy: global  99.44% local  99.65% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:59:32,788 - INFO -   |--    Epoch Losses (10): [0.0052, 0.0107, 0.0213, 0.0342, 0.0387, 0.0357, 0.0613, 0.0319, 0.02, 0.0263]
# 2021-09-01 19:59:39,640 - INFO -   |-- [Party 8] Average Train Loss:   0.0083 Train Accuracy: global  99.65% local  99.72% ...    5 forgettables out of 1428 ( 0.35%) ... total data used 1428
# 2021-09-01 19:59:39,641 - INFO -   |--    Epoch Losses (10): [0.0048, 0.0032, 0.002, 0.0031, 0.0022, 0.0035, 0.009, 0.0225, 0.0078, 0.0251]
# 2021-09-01 19:59:46,334 - INFO -   |-- [Party 9] Average Train Loss:   0.0173 Train Accuracy: global  99.65% local  99.93% ...    5 forgettables out of 1428 ( 0.35%) ... total data used 1428
# 2021-09-01 19:59:46,335 - INFO -   |--    Epoch Losses (10): [0.0097, 0.0063, 0.0259, 0.0206, 0.0201, 0.0258, 0.0294, 0.0214, 0.0061, 0.0073]
# 2021-09-01 19:59:50,493 - INFO -     |---- Number of Forgettables: 2703 (21.03%)
# 2021-09-01 19:59:50,495 - INFO -     |---- Train Accuracy: 78.98%
# 2021-09-01 19:59:50,496 - INFO -     |---- Test Accuracy: 52.20%
# 2021-09-01 19:59:50,496 - INFO -     |---- Test Loss: 1.8590
# 2021-09-01 19:59:50,497 - INFO -     |---- Elapsed time: 3:47:03.732233
# 2021-09-01 19:59:50,498 - INFO -
# Test Acc: Max 52.2000% (104 round) | Last 52.2000% | Avg 50.7916% (35 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

# %%
# %matplotlib inline

dataset = 'svhn'
clsimb = [2, 7] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_fednova'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 2

# %%
import copy
import json
import logging
import math
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/train_32x32.mat
# Using downloaded and verified file: /home/hgato/projects/benchmark/data/test_32x32.mat

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
# def average_weights(w):
#     w_avg = copy.deepcopy(w[0])
        
#     for key in w_avg.keys():
#         for i in range(1, len(w)):
#             w_avg[key] += w[i][key]
#         w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
#     return w_avg

# %%
# FedNova
def nova_update(w, a_list, d_list, n_list, n_client, device):
    coeff = 0.0
    n_round = sum(n_list)
    d_round = copy.deepcopy(w)
    for k in d_round:
        d_round[k] = 0.0
    for i in range(n_client):
        d_w = d_list[i]
        for k in d_w:
            d_round[k] = d_round[k] + (d_w[k] * n_list[i] / n_round)
        coeff += (a_list[i] * n_list[i] / n_round)
    for k in w:
        w[k] = w[k] - (coeff * d_round[k]).cpu()
    return w

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, global_state, momentum):
    epoch_losses = []
    
    # FedNova
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
    tau = 0
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())
            
            # FedNova
            tau += 1

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    # FedNova
    a_i = (tau - momentum * (1 - math.pow(momentum, tau)) / (1 - momentum)) / (1 - momentum)
    local_weights = model.state_dict()
    norm_grad = copy.deepcopy(global_state)
    for k in norm_grad:
        norm_grad[k] = torch.true_divide(global_state[k] - local_weights[k], a_i)
    
    local_weights = model.state_dict()

    return local_weights, epoch_losses, a_i, norm_grad

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0
momentum = 0

logger.info(f'\nAlgorithm: FedNova\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    # FedNova
    a_list, d_list, n_list = [], [], []
    global_state = fed_model.state_dict()
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls, a_i, norm_grad = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, global_state, momentum)
        
        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
        # FedNova
        a_list.append(a_i)
        d_list.append(norm_grad)
        n_list.append(len(trainloader))
        
    # FedNova
    fed_weights = nova_update(fed_weights, a_list, d_list, n_list, sum(clsimb), device)
    
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 16:21:24,436 - INFO -
# Algorithm: FedNova
# Client Split: [2, 7]
# Dataset: svhn
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 16:21:24,440 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 16:21:37,257 - INFO -   |-- [Party 1] Average Train Loss:   1.0260 Train Accuracy: global   0.00% local  58.59% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:21:37,259 - INFO -   |--    Epoch Losses (10): [2.0453, 1.3754, 1.0881, 0.9514, 0.879, 0.8302, 0.8019, 0.7808, 0.7573, 0.751]
# 2021-09-01 16:21:48,123 - INFO -   |-- [Party 2] Average Train Loss:   1.0292 Train Accuracy: global   0.00% local  59.30% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:21:48,125 - INFO -   |--    Epoch Losses (10): [2.0521, 1.3825, 1.0909, 0.9562, 0.8814, 0.8359, 0.7991, 0.7781, 0.766, 0.7502]
# 2021-09-01 16:21:59,124 - INFO -   |-- [Party 3] Average Train Loss:   1.0095 Train Accuracy: global   0.00% local  62.21% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:21:59,128 - INFO -   |--    Epoch Losses (10): [2.0303, 1.3635, 1.0815, 0.9366, 0.8663, 0.812, 0.781, 0.7586, 0.7387, 0.7264]
# 2021-09-01 16:22:09,444 - INFO -   |-- [Party 4] Average Train Loss:   1.0078 Train Accuracy: global   0.00% local  62.35% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:09,445 - INFO -   |--    Epoch Losses (10): [2.0272, 1.362, 1.0804, 0.9352, 0.8622, 0.8149, 0.7775, 0.7572, 0.7409, 0.7205]
# 2021-09-01 16:22:20,173 - INFO -   |-- [Party 5] Average Train Loss:   1.0112 Train Accuracy: global   0.00% local  62.44% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:20,176 - INFO -   |--    Epoch Losses (10): [2.0283, 1.3673, 1.0804, 0.9412, 0.8625, 0.8155, 0.7839, 0.7607, 0.7442, 0.7282]
# 2021-09-01 16:22:30,530 - INFO -   |-- [Party 6] Average Train Loss:   1.0098 Train Accuracy: global   0.00% local  62.02% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:30,531 - INFO -   |--    Epoch Losses (10): [2.025, 1.3662, 1.0818, 0.9386, 0.8629, 0.8146, 0.7849, 0.7571, 0.7394, 0.7273]
# 2021-09-01 16:22:41,334 - INFO -   |-- [Party 7] Average Train Loss:   1.0121 Train Accuracy: global   0.00% local  62.16% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:41,337 - INFO -   |--    Epoch Losses (10): [2.0319, 1.3674, 1.0813, 0.9437, 0.867, 0.8163, 0.7853, 0.7605, 0.7418, 0.726]
# 2021-09-01 16:22:52,158 - INFO -   |-- [Party 8] Average Train Loss:   1.0094 Train Accuracy: global   0.00% local  62.68% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:22:52,160 - INFO -   |--    Epoch Losses (10): [2.0268, 1.3639, 1.0768, 0.9399, 0.8656, 0.8159, 0.7812, 0.7616, 0.7389, 0.7239]
# 2021-09-01 16:23:02,966 - INFO -   |-- [Party 9] Average Train Loss:   1.0103 Train Accuracy: global   0.00% local  62.07% ...    0 forgettables out of 2130 ( 0.00%) ... total data used 2130
# 2021-09-01 16:23:02,968 - INFO -   |--    Epoch Losses (10): [2.0272, 1.3639, 1.0798, 0.9393, 0.8646, 0.8168, 0.7805, 0.7611, 0.7411, 0.7286]
# 2021-09-01 16:23:11,516 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 16:23:11,521 - INFO -     |---- Train Accuracy: 48.32%
# 2021-09-01 16:23:11,522 - INFO -     |---- Test Accuracy: 34.71%
# 2021-09-01 16:23:11,523 - INFO -     |---- Test Loss: 1.8993
# 2021-09-01 16:23:11,524 - INFO -     |---- Elapsed time: 0:01:47.084677
# 2021-09-01 16:23:11,525 - INFO -
# Test Acc: Max 34.7096% (1 round) | Last 34.7096% | Avg 34.7096% (1 round)
#
# 2021-09-01 16:23:11,528 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 16:23:22,308 - INFO -   |-- [Party 1] Average Train Loss:   1.0343 Train Accuracy: global   0.00% local  59.39% ... 1248 forgettables out of 2130 (58.59%) ... total data used 2130
# 2021-09-01 16:23:22,312 - INFO -   |--    Epoch Losses (10): [2.3587, 1.3625, 1.0416, 0.9149, 0.8411, 0.8059, 0.775, 0.7602, 0.7476, 0.7353]
# 2021-09-01 16:23:32,670 - INFO -   |-- [Party 2] Average Train Loss:   1.0361 Train Accuracy: global   0.00% local  58.54% ... 1263 forgettables out of 2130 (59.30%) ... total data used 2130
# 2021-09-01 16:23:32,671 - INFO -   |--    Epoch Losses (10): [2.3593, 1.3632, 1.0427, 0.9138, 0.8445, 0.8074, 0.7806, 0.7647, 0.7492, 0.7361]
# 2021-09-01 16:23:44,004 - INFO -   |-- [Party 3] Average Train Loss:   0.7327 Train Accuracy: global  62.16% local  63.15% ...   17 forgettables out of 2130 ( 0.80%) ... total data used 2130
# 2021-09-01 16:23:44,008 - INFO -   |--    Epoch Losses (10): [0.8469, 0.8007, 0.7647, 0.742, 0.7287, 0.7112, 0.6986, 0.6878, 0.6781, 0.668]
# 2021-09-01 16:23:54,490 - INFO -   |-- [Party 4] Average Train Loss:   0.7321 Train Accuracy: global  62.44% local  64.93% ...   22 forgettables out of 2130 ( 1.03%) ... total data used 2130
# 2021-09-01 16:23:54,491 - INFO -   |--    Epoch Losses (10): [0.8496, 0.7984, 0.764, 0.7426, 0.7226, 0.7105, 0.6975, 0.6885, 0.677, 0.6702]
# 2021-09-01 16:24:05,055 - INFO -   |-- [Party 5] Average Train Loss:   0.7347 Train Accuracy: global  61.97% local  63.76% ...   23 forgettables out of 2130 ( 1.08%) ... total data used 2130
# 2021-09-01 16:24:05,057 - INFO -   |--    Epoch Losses (10): [0.8478, 0.7978, 0.766, 0.7428, 0.731, 0.7147, 0.7007, 0.694, 0.6796, 0.6728]
# 2021-09-01 16:24:16,010 - INFO -   |-- [Party 6] Average Train Loss:   0.7347 Train Accuracy: global  61.78% local  64.51% ...   22 forgettables out of 2130 ( 1.03%) ... total data used 2130
# 2021-09-01 16:24:16,014 - INFO -   |--    Epoch Losses (10): [0.8498, 0.7992, 0.7681, 0.7488, 0.7233, 0.7139, 0.6983, 0.6909, 0.6826, 0.6719]
# 2021-09-01 16:24:27,038 - INFO -   |-- [Party 7] Average Train Loss:   0.7360 Train Accuracy: global  61.92% local  63.66% ...   22 forgettables out of 2130 ( 1.03%) ... total data used 2130
# 2021-09-01 16:24:27,041 - INFO -   |--    Epoch Losses (10): [0.85, 0.8019, 0.7684, 0.7461, 0.7295, 0.716, 0.7034, 0.6908, 0.6801, 0.6742]
# 2021-09-01 16:24:38,275 - INFO -   |-- [Party 8] Average Train Loss:   0.7338 Train Accuracy: global  62.02% local  63.52% ...   38 forgettables out of 2130 ( 1.78%) ... total data used 2130
# 2021-09-01 16:24:38,278 - INFO -   |--    Epoch Losses (10): [0.8478, 0.8, 0.7659, 0.744, 0.7241, 0.7135, 0.703, 0.6881, 0.6801, 0.6712]
# 2021-09-01 16:24:48,867 - INFO -   |-- [Party 9] Average Train Loss:   0.7355 Train Accuracy: global  62.16% local  64.41% ...   17 forgettables out of 2130 ( 0.80%) ... total data used 2130
# 2021-09-01 16:24:48,870 - INFO -   |--    Epoch Losses (10): [0.8486, 0.7969, 0.7671, 0.745, 0.7274, 0.7128, 0.7027, 0.6923, 0.6862, 0.6761]
# 2021-09-01 16:24:57,298 - INFO -     |---- Number of Forgettables: 2672 (13.94%)
# 2021-09-01 16:24:57,300 - INFO -     |---- Train Accuracy: 49.48%
# 2021-09-01 16:24:57,301 - INFO -     |---- Test Accuracy: 35.11%
# 2021-09-01 16:24:57,302 - INFO -     |---- Test Loss: 1.8552
# 2021-09-01 16:24:57,302 - INFO -     |---- Elapsed time: 0:03:32.863098
# 2021-09-01 16:24:57,304 - INFO -
# Test Acc: Max 35.1123% (2 round) | Last 35.1123% | Avg 34.9109% (2 round)
#
# 2021-09-01 16:24:57,306 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 16:25:07,957 - INFO -   |-- [Party 1] Average Train Loss:   1.0029 Train Accuracy: global   0.00% local  59.86% ... 1265 forgettables out of 2130 (59.39%) ... total data used 2130
# 2021-09-01 16:25:07,958 - INFO -   |--    Epoch Losses (10): [2.3168, 1.2855, 0.9895, 0.8747, 0.8173, 0.7819, 0.7601, 0.7476, 0.7299, 0.7254]
# 2021-09-01 16:25:18,903 - INFO -   |-- [Party 2] Average Train Loss:   1.0049 Train Accuracy: global   0.00% local  59.30% ... 1247 forgettables out of 2130 (58.54%) ... total data used 2130
# 2021-09-01 16:25:18,905 - INFO -   |--    Epoch Losses (10): [2.3218, 1.2908, 0.9907, 0.877, 0.8213, 0.7847, 0.7608, 0.7453, 0.7339, 0.7227]
# 2021-09-01 16:25:29,944 - INFO -   |-- [Party 3] Average Train Loss:   0.6729 Train Accuracy: global  63.57% local  72.68% ...   50 forgettables out of 2130 ( 2.35%) ... total data used 2130
# 2021-09-01 16:25:29,945 - INFO -   |--    Epoch Losses (10): [0.7589, 0.7297, 0.7104, 0.6901, 0.6734, 0.6624, 0.6474, 0.6342, 0.6183, 0.604]
# 2021-09-01 16:25:40,424 - INFO -   |-- [Party 4] Average Train Loss:   0.6720 Train Accuracy: global  63.38% local  71.46% ...   84 forgettables out of 2130 ( 3.94%) ... total data used 2130
# 2021-09-01 16:25:40,426 - INFO -   |--    Epoch Losses (10): [0.7604, 0.7253, 0.7045, 0.6876, 0.672, 0.6586, 0.6454, 0.6343, 0.6195, 0.6123]
# 2021-09-01 16:25:50,933 - INFO -   |-- [Party 5] Average Train Loss:   0.6750 Train Accuracy: global  63.85% local  69.95% ...   58 forgettables out of 2130 ( 2.72%) ... total data used 2130
# 2021-09-01 16:25:50,936 - INFO -   |--    Epoch Losses (10): [0.7603, 0.7274, 0.7076, 0.6894, 0.6791, 0.661, 0.6505, 0.6364, 0.6262, 0.6123]
# 2021-09-01 16:26:02,284 - INFO -   |-- [Party 6] Average Train Loss:   0.6757 Train Accuracy: global  63.57% local  70.75% ...   74 forgettables out of 2130 ( 3.47%) ... total data used 2130
# 2021-09-01 16:26:02,287 - INFO -   |--    Epoch Losses (10): [0.7621, 0.7292, 0.7087, 0.6925, 0.6766, 0.662, 0.6493, 0.6377, 0.6266, 0.612]
# 2021-09-01 16:26:13,471 - INFO -   |-- [Party 7] Average Train Loss:   0.6766 Train Accuracy: global  63.38% local  70.38% ...   60 forgettables out of 2130 ( 2.82%) ... total data used 2130
# 2021-09-01 16:26:13,476 - INFO -   |--    Epoch Losses (10): [0.7607, 0.7338, 0.7127, 0.6924, 0.6771, 0.6576, 0.6515, 0.64, 0.6266, 0.6133]
# 2021-09-01 16:26:24,717 - INFO -   |-- [Party 8] Average Train Loss:   0.6756 Train Accuracy: global  63.15% local  71.60% ...   52 forgettables out of 2130 ( 2.44%) ... total data used 2130
# 2021-09-01 16:26:24,721 - INFO -   |--    Epoch Losses (10): [0.762, 0.7293, 0.7108, 0.6946, 0.6751, 0.6587, 0.6486, 0.6406, 0.6256, 0.6103]
# 2021-09-01 16:26:36,066 - INFO -   |-- [Party 9] Average Train Loss:   0.6761 Train Accuracy: global  63.76% local  71.31% ...   72 forgettables out of 2130 ( 3.38%) ... total data used 2130
# 2021-09-01 16:26:36,067 - INFO -   |--    Epoch Losses (10): [0.7601, 0.7314, 0.7071, 0.6922, 0.6769, 0.6633, 0.6524, 0.639, 0.6256, 0.6136]
# 2021-09-01 16:26:44,461 - INFO -     |---- Number of Forgettables: 2962 (15.45%)
# 2021-09-01 16:26:44,465 - INFO -     |---- Train Accuracy: 53.88%
# 2021-09-01 16:26:44,466 - INFO -     |---- Test Accuracy: 38.05%
# 2021-09-01 16:26:44,467 - INFO -     |---- Test Loss: 1.7767
# 2021-09-01 16:26:44,468 - INFO -     |---- Elapsed time: 0:05:20.029064
# 2021-09-01 16:26:44,470 - INFO -
# Test Acc: Max 38.0536% (3 round) | Last 38.0536% | Avg 35.9585% (3 round)
#
# 2021-09-01 16:26:44,474 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 16:26:55,626 - INFO -   |-- [Party 1] Average Train Loss:   0.9695 Train Accuracy: global   0.00% local  60.28% ... 1275 forgettables out of 2130 (59.86%) ... total data used 2130
# 2021-09-01 16:26:55,630 - INFO -   |--    Epoch Losses (10): [2.2138, 1.2225, 0.9485, 0.8474, 0.7955, 0.7672, 0.7431, 0.7276, 0.7205, 0.7093]
# 2021-09-01 16:27:07,019 - INFO -   |-- [Party 2] Average Train Loss:   0.9707 Train Accuracy: global   0.00% local  60.85% ... 1263 forgettables out of 2130 (59.30%) ... total data used 2130
# 2021-09-01 16:27:07,022 - INFO -   |--    Epoch Losses (10): [2.222, 1.2268, 0.9554, 0.8494, 0.7951, 0.7661, 0.7418, 0.7295, 0.716, 0.7046]
# 2021-09-01 16:27:18,287 - INFO -   |-- [Party 3] Average Train Loss:   0.5884 Train Accuracy: global  69.01% local  80.75% ...  183 forgettables out of 2130 ( 8.59%) ... total data used 2130
# 2021-09-01 16:27:18,289 - INFO -   |--    Epoch Losses (10): [0.697, 0.6659, 0.6342, 0.6179, 0.5899, 0.572, 0.5537, 0.537, 0.5152, 0.5007]
# 2021-09-01 16:27:28,759 - INFO -   |-- [Party 4] Average Train Loss:   0.5931 Train Accuracy: global  70.47% local  78.97% ...  123 forgettables out of 2130 ( 5.77%) ... total data used 2130
# 2021-09-01 16:27:28,763 - INFO -   |--    Epoch Losses (10): [0.6999, 0.662, 0.6383, 0.6119, 0.5924, 0.5805, 0.5562, 0.5453, 0.529, 0.5159]
# 2021-09-01 16:27:39,827 - INFO -   |-- [Party 5] Average Train Loss:   0.5947 Train Accuracy: global  69.25% local  76.06% ...  136 forgettables out of 2130 ( 6.38%) ... total data used 2130
# 2021-09-01 16:27:39,831 - INFO -   |--    Epoch Losses (10): [0.7029, 0.6675, 0.6451, 0.6191, 0.5922, 0.5767, 0.5578, 0.5426, 0.5295, 0.5137]
# 2021-09-01 16:27:51,149 - INFO -   |-- [Party 6] Average Train Loss:   0.5966 Train Accuracy: global  68.87% local  79.30% ...  151 forgettables out of 2130 ( 7.09%) ... total data used 2130
# 2021-09-01 16:27:51,152 - INFO -   |--    Epoch Losses (10): [0.7072, 0.6694, 0.6411, 0.6213, 0.5973, 0.5794, 0.5634, 0.5414, 0.5308, 0.5148]
# 2021-09-01 16:28:01,970 - INFO -   |-- [Party 7] Average Train Loss:   0.5981 Train Accuracy: global  68.97% local  79.77% ...  125 forgettables out of 2130 ( 5.87%) ... total data used 2130
# 2021-09-01 16:28:01,972 - INFO -   |--    Epoch Losses (10): [0.6994, 0.6702, 0.6453, 0.6189, 0.604, 0.5875, 0.5623, 0.5458, 0.5311, 0.5163]
# 2021-09-01 16:28:12,471 - INFO -   |-- [Party 8] Average Train Loss:   0.5944 Train Accuracy: global  70.42% local  78.31% ...  130 forgettables out of 2130 ( 6.10%) ... total data used 2130
# 2021-09-01 16:28:12,474 - INFO -   |--    Epoch Losses (10): [0.7009, 0.6659, 0.6399, 0.6142, 0.5987, 0.5811, 0.5609, 0.5436, 0.5304, 0.5088]
# 2021-09-01 16:28:23,172 - INFO -   |-- [Party 9] Average Train Loss:   0.5977 Train Accuracy: global  69.77% local  79.77% ...  134 forgettables out of 2130 ( 6.29%) ... total data used 2130
# 2021-09-01 16:28:23,176 - INFO -   |--    Epoch Losses (10): [0.7023, 0.6675, 0.6403, 0.6207, 0.6034, 0.5854, 0.5614, 0.5478, 0.5304, 0.518]
# 2021-09-01 16:28:31,390 - INFO -     |---- Number of Forgettables: 3520 (18.36%)
# 2021-09-01 16:28:31,391 - INFO -     |---- Train Accuracy: 60.77%
# 2021-09-01 16:28:31,392 - INFO -     |---- Test Accuracy: 43.19%
# 2021-09-01 16:28:31,393 - INFO -     |---- Test Loss: 1.7038
# 2021-09-01 16:28:31,394 - INFO -     |---- Elapsed time: 0:07:06.954713
# 2021-09-01 16:28:31,395 - INFO -
# Test Acc: Max 43.1925% (4 round) | Last 43.1925% | Avg 37.7670% (3 round)
#
# 2021-09-01 16:28:31,398 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 16:28:42,205 - INFO -   |-- [Party 1] Average Train Loss:   0.9382 Train Accuracy: global   0.00% local  63.19% ... 1284 forgettables out of 2130 (60.28%) ... total data used 2130
# 2021-09-01 16:28:42,209 - INFO -   |--    Epoch Losses (10): [2.1434, 1.1757, 0.9189, 0.826, 0.7719, 0.7405, 0.7224, 0.7054, 0.694, 0.6841]
# 2021-09-01 16:28:52,505 - INFO -   |-- [Party 2] Average Train Loss:   0.9359 Train Accuracy: global   0.00% local  67.65% ... 1296 forgettables out of 2130 (60.85%) ... total data used 2130
# 2021-09-01 16:28:52,507 - INFO -   |--    Epoch Losses (10): [2.1449, 1.1799, 0.9174, 0.8195, 0.7709, 0.7395, 0.7194, 0.7023, 0.6885, 0.6771]
# 2021-09-01 16:29:03,379 - INFO -   |-- [Party 3] Average Train Loss:   0.4964 Train Accuracy: global  78.73% local  81.08% ...  148 forgettables out of 2130 ( 6.95%) ... total data used 2130
# 2021-09-01 16:29:03,381 - INFO -   |--    Epoch Losses (10): [0.601, 0.566, 0.5341, 0.5142, 0.4894, 0.4853, 0.4579, 0.4474, 0.4411, 0.428]
# 2021-09-01 16:29:13,761 - INFO -   |-- [Party 4] Average Train Loss:   0.5069 Train Accuracy: global  78.40% local  81.36% ...  118 forgettables out of 2130 ( 5.54%) ... total data used 2130
# 2021-09-01 16:29:13,762 - INFO -   |--    Epoch Losses (10): [0.6043, 0.5736, 0.5394, 0.524, 0.5105, 0.4816, 0.4678, 0.4649, 0.4529, 0.4501]
# 2021-09-01 16:29:25,152 - INFO -   |-- [Party 5] Average Train Loss:   0.5046 Train Accuracy: global  77.61% local  78.92% ...  209 forgettables out of 2130 ( 9.81%) ... total data used 2130
# 2021-09-01 16:29:25,153 - INFO -   |--    Epoch Losses (10): [0.6095, 0.5665, 0.5413, 0.5246, 0.5077, 0.4831, 0.473, 0.4585, 0.4412, 0.4402]
# 2021-09-01 16:29:35,955 - INFO -   |-- [Party 6] Average Train Loss:   0.5044 Train Accuracy: global  78.73% local  79.72% ...  125 forgettables out of 2130 ( 5.87%) ... total data used 2130
# 2021-09-01 16:29:35,957 - INFO -   |--    Epoch Losses (10): [0.6015, 0.5673, 0.5402, 0.516, 0.5007, 0.4777, 0.4649, 0.4642, 0.4619, 0.4496]
# 2021-09-01 16:29:46,593 - INFO -   |-- [Party 7] Average Train Loss:   0.5087 Train Accuracy: global  78.36% local  80.66% ...  150 forgettables out of 2130 ( 7.04%) ... total data used 2130
# 2021-09-01 16:29:46,597 - INFO -   |--    Epoch Losses (10): [0.6087, 0.5681, 0.5478, 0.5236, 0.5035, 0.4921, 0.4723, 0.4709, 0.4586, 0.4419]
# 2021-09-01 16:29:57,464 - INFO -   |-- [Party 8] Average Train Loss:   0.5051 Train Accuracy: global  79.15% local  82.39% ...  196 forgettables out of 2130 ( 9.20%) ... total data used 2130
# 2021-09-01 16:29:57,465 - INFO -   |--    Epoch Losses (10): [0.6026, 0.5702, 0.5371, 0.5202, 0.501, 0.4907, 0.4717, 0.4661, 0.4496, 0.4422]
# 2021-09-01 16:30:08,890 - INFO -   |-- [Party 9] Average Train Loss:   0.5148 Train Accuracy: global  78.26% local  82.91% ...  145 forgettables out of 2130 ( 6.81%) ... total data used 2130
# 2021-09-01 16:30:08,891 - INFO -   |--    Epoch Losses (10): [0.6015, 0.5724, 0.5483, 0.527, 0.5144, 0.5023, 0.4847, 0.4721, 0.4651, 0.46]
# 2021-09-01 16:30:17,264 - INFO -     |---- Number of Forgettables: 3671 (19.15%)
# 2021-09-01 16:30:17,265 - INFO -     |---- Train Accuracy: 62.68%
# 2021-09-01 16:30:17,266 - INFO -     |---- Test Accuracy: 44.35%
# 2021-09-01 16:30:17,267 - INFO -     |---- Test Loss: 1.6768
# 2021-09-01 16:30:17,267 - INFO -     |---- Elapsed time: 0:08:52.828050
# 2021-09-01 16:30:17,268 - INFO -
# Test Acc: Max 44.3527% (5 round) | Last 44.3527% | Avg 39.0841% (4 round)
#
# 2021-09-01 16:30:17,271 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 16:30:28,223 - INFO -   |-- [Party 1] Average Train Loss:   0.9059 Train Accuracy: global   0.00% local  67.28% ... 1346 forgettables out of 2130 (63.19%) ... total data used 2130
# 2021-09-01 16:30:28,227 - INFO -   |--    Epoch Losses (10): [2.0886, 1.1316, 0.8853, 0.7952, 0.748, 0.7166, 0.6963, 0.6792, 0.6649, 0.6533]
# 2021-09-01 16:30:39,086 - INFO -   |-- [Party 2] Average Train Loss:   0.9026 Train Accuracy: global   0.00% local  68.78% ... 1441 forgettables out of 2130 (67.65%) ... total data used 2130
# 2021-09-01 16:30:39,088 - INFO -   |--    Epoch Losses (10): [2.0915, 1.1319, 0.8868, 0.787, 0.7423, 0.7096, 0.6925, 0.6739, 0.6616, 0.6492]
# 2021-09-01 16:30:49,532 - INFO -   |-- [Party 3] Average Train Loss:   0.4466 Train Accuracy: global  80.80% local  82.72% ...  109 forgettables out of 2130 ( 5.12%) ... total data used 2130
# 2021-09-01 16:30:49,533 - INFO -   |--    Epoch Losses (10): [0.5228, 0.493, 0.4707, 0.4499, 0.4426, 0.4303, 0.4212, 0.4167, 0.4262, 0.3921]
# 2021-09-01 16:31:00,019 - INFO -   |-- [Party 4] Average Train Loss:   0.4580 Train Accuracy: global  80.19% local  83.85% ...  120 forgettables out of 2130 ( 5.63%) ... total data used 2130
# 2021-09-01 16:31:00,023 - INFO -   |--    Epoch Losses (10): [0.5293, 0.503, 0.4805, 0.4709, 0.4476, 0.46, 0.4297, 0.4182, 0.4303, 0.4107]
# 2021-09-01 16:31:10,872 - INFO -   |-- [Party 5] Average Train Loss:   0.4578 Train Accuracy: global  79.81% local  71.08% ...  107 forgettables out of 2130 ( 5.02%) ... total data used 2130
# 2021-09-01 16:31:10,875 - INFO -   |--    Epoch Losses (10): [0.5287, 0.5008, 0.4879, 0.4564, 0.4477, 0.4401, 0.4389, 0.435, 0.4296, 0.4132]
# 2021-09-01 16:31:21,993 - INFO -   |-- [Party 6] Average Train Loss:   0.4605 Train Accuracy: global  79.67% local  84.84% ...  197 forgettables out of 2130 ( 9.25%) ... total data used 2130
# 2021-09-01 16:31:21,994 - INFO -   |--    Epoch Losses (10): [0.5243, 0.5055, 0.4803, 0.4742, 0.4534, 0.4481, 0.4463, 0.442, 0.4204, 0.4105]
# 2021-09-01 16:31:33,086 - INFO -   |-- [Party 7] Average Train Loss:   0.4679 Train Accuracy: global  80.38% local  77.98% ...   99 forgettables out of 2130 ( 4.65%) ... total data used 2130
# 2021-09-01 16:31:33,089 - INFO -   |--    Epoch Losses (10): [0.5353, 0.5108, 0.481, 0.486, 0.4608, 0.4484, 0.432, 0.4369, 0.4448, 0.4427]
# 2021-09-01 16:31:43,529 - INFO -   |-- [Party 8] Average Train Loss:   0.4559 Train Accuracy: global  81.13% local  84.37% ...  101 forgettables out of 2130 ( 4.74%) ... total data used 2130
# 2021-09-01 16:31:43,530 - INFO -   |--    Epoch Losses (10): [0.5234, 0.504, 0.4776, 0.4677, 0.4542, 0.4392, 0.4357, 0.4157, 0.4239, 0.4174]
# 2021-09-01 16:31:54,411 - INFO -   |-- [Party 9] Average Train Loss:   0.4717 Train Accuracy: global  80.52% local  81.08% ...  142 forgettables out of 2130 ( 6.67%) ... total data used 2130
# 2021-09-01 16:31:54,415 - INFO -   |--    Epoch Losses (10): [0.5413, 0.5185, 0.5017, 0.4785, 0.4703, 0.453, 0.4492, 0.4341, 0.4317, 0.4387]
# 2021-09-01 16:32:02,792 - INFO -     |---- Number of Forgettables: 3662 (19.10%)
# 2021-09-01 16:32:02,794 - INFO -     |---- Train Accuracy: 64.33%
# 2021-09-01 16:32:02,795 - INFO -     |---- Test Accuracy: 44.99%
# 2021-09-01 16:32:02,795 - INFO -     |---- Test Loss: 1.6680
# 2021-09-01 16:32:02,796 - INFO -     |---- Elapsed time: 0:10:38.356289
# 2021-09-01 16:32:02,796 - INFO -
# Test Acc: Max 44.9874% (6 round) | Last 44.9874% | Avg 40.0680% (4 round)
#
# 2021-09-01 16:32:02,798 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 16:32:13,313 - INFO -   |-- [Party 1] Average Train Loss:   0.8812 Train Accuracy: global   0.00% local  69.86% ... 1433 forgettables out of 2130 (67.28%) ... total data used 2130
# 2021-09-01 16:32:13,316 - INFO -   |--    Epoch Losses (10): [2.032, 1.0904, 0.8575, 0.773, 0.7254, 0.6972, 0.6751, 0.6659, 0.6572, 0.6383]
# 2021-09-01 16:32:23,720 - INFO -   |-- [Party 2] Average Train Loss:   0.8753 Train Accuracy: global   0.00% local  70.23% ... 1465 forgettables out of 2130 (68.78%) ... total data used 2130
# 2021-09-01 16:32:23,722 - INFO -   |--    Epoch Losses (10): [2.0347, 1.095, 0.8547, 0.7657, 0.7163, 0.6881, 0.6674, 0.6565, 0.6429, 0.6313]
# 2021-09-01 16:32:34,245 - INFO -   |-- [Party 3] Average Train Loss:   0.4156 Train Accuracy: global  83.66% local  87.09% ...  102 forgettables out of 2130 ( 4.79%) ... total data used 2130
# 2021-09-01 16:32:34,246 - INFO -   |--    Epoch Losses (10): [0.4835, 0.4585, 0.4327, 0.4292, 0.4203, 0.4091, 0.389, 0.3944, 0.3749, 0.3647]
# 2021-09-01 16:32:44,872 - INFO -   |-- [Party 4] Average Train Loss:   0.4297 Train Accuracy: global  82.96% local  84.04% ...  125 forgettables out of 2130 ( 5.87%) ... total data used 2130
# 2021-09-01 16:32:44,874 - INFO -   |--    Epoch Losses (10): [0.4997, 0.4675, 0.445, 0.4399, 0.4317, 0.4083, 0.4219, 0.3948, 0.3947, 0.3937]
# 2021-09-01 16:32:55,894 - INFO -   |-- [Party 5] Average Train Loss:   0.4276 Train Accuracy: global  82.02% local  85.49% ...  171 forgettables out of 2130 ( 8.03%) ... total data used 2130
# 2021-09-01 16:32:55,896 - INFO -   |--    Epoch Losses (10): [0.494, 0.4667, 0.4395, 0.4505, 0.4259, 0.4247, 0.4084, 0.3906, 0.3965, 0.3791]
# 2021-09-01 16:33:06,648 - INFO -   |-- [Party 6] Average Train Loss:   0.4316 Train Accuracy: global  82.07% local  82.82% ...  184 forgettables out of 2130 ( 8.64%) ... total data used 2130
# 2021-09-01 16:33:06,650 - INFO -   |--    Epoch Losses (10): [0.4978, 0.4776, 0.4463, 0.4565, 0.4266, 0.4058, 0.4113, 0.4016, 0.4113, 0.3806]
# 2021-09-01 16:33:17,380 - INFO -   |-- [Party 7] Average Train Loss:   0.4379 Train Accuracy: global  83.05% local  85.12% ...   84 forgettables out of 2130 ( 3.94%) ... total data used 2130
# 2021-09-01 16:33:17,382 - INFO -   |--    Epoch Losses (10): [0.5019, 0.469, 0.4674, 0.4404, 0.4395, 0.4255, 0.4287, 0.4178, 0.3993, 0.3896]
# 2021-09-01 16:33:27,826 - INFO -   |-- [Party 8] Average Train Loss:   0.4318 Train Accuracy: global  83.43% local  84.18% ...  122 forgettables out of 2130 ( 5.73%) ... total data used 2130
# 2021-09-01 16:33:27,828 - INFO -   |--    Epoch Losses (10): [0.4989, 0.4743, 0.4465, 0.4328, 0.4332, 0.414, 0.4178, 0.4178, 0.3977, 0.3854]
# 2021-09-01 16:33:39,155 - INFO -   |-- [Party 9] Average Train Loss:   0.4443 Train Accuracy: global  82.21% local  83.24% ...  120 forgettables out of 2130 ( 5.63%) ... total data used 2130
# 2021-09-01 16:33:39,156 - INFO -   |--    Epoch Losses (10): [0.5011, 0.4774, 0.4575, 0.4633, 0.4449, 0.4271, 0.4235, 0.425, 0.417, 0.4065]
# 2021-09-01 16:33:47,467 - INFO -     |---- Number of Forgettables: 3806 (19.85%)
# 2021-09-01 16:33:47,469 - INFO -     |---- Train Accuracy: 64.35%
# 2021-09-01 16:33:47,469 - INFO -     |---- Test Accuracy: 45.74%
# 2021-09-01 16:33:47,470 - INFO -     |---- Test Loss: 1.6190
# 2021-09-01 16:33:47,470 - INFO -     |---- Elapsed time: 0:12:23.030902
# 2021-09-01 16:33:47,471 - INFO -
# Test Acc: Max 45.7449% (7 round) | Last 45.7449% | Avg 40.8790% (4 round)
#
# 2021-09-01 16:33:47,473 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 16:33:57,754 - INFO -   |-- [Party 1] Average Train Loss:   0.8588 Train Accuracy: global   0.00% local  69.20% ... 1488 forgettables out of 2130 (69.86%) ... total data used 2130
# 2021-09-01 16:33:57,756 - INFO -   |--    Epoch Losses (10): [1.9793, 1.0585, 0.8378, 0.7529, 0.707, 0.6787, 0.6606, 0.6504, 0.6382, 0.6246]
# 2021-09-01 16:34:08,578 - INFO -   |-- [Party 2] Average Train Loss:   0.8522 Train Accuracy: global   0.00% local  67.46% ... 1496 forgettables out of 2130 (70.23%) ... total data used 2130
# 2021-09-01 16:34:08,579 - INFO -   |--    Epoch Losses (10): [1.9782, 1.0596, 0.8306, 0.742, 0.6983, 0.6757, 0.6506, 0.6397, 0.6298, 0.6179]
# 2021-09-01 16:34:19,224 - INFO -   |-- [Party 3] Average Train Loss:   0.3954 Train Accuracy: global  83.66% local  86.67% ...  157 forgettables out of 2130 ( 7.37%) ... total data used 2130
# 2021-09-01 16:34:19,226 - INFO -   |--    Epoch Losses (10): [0.4568, 0.4381, 0.4138, 0.41, 0.3839, 0.3739, 0.3757, 0.3768, 0.3718, 0.3529]
# 2021-09-01 16:34:29,654 - INFO -   |-- [Party 4] Average Train Loss:   0.4146 Train Accuracy: global  82.58% local  86.10% ...   90 forgettables out of 2130 ( 4.23%) ... total data used 2130
# 2021-09-01 16:34:29,656 - INFO -   |--    Epoch Losses (10): [0.4833, 0.4515, 0.4283, 0.435, 0.4106, 0.3999, 0.3973, 0.38, 0.3809, 0.3798]
# 2021-09-01 16:34:40,025 - INFO -   |-- [Party 5] Average Train Loss:   0.4081 Train Accuracy: global  82.39% local  86.38% ...  151 forgettables out of 2130 ( 7.09%) ... total data used 2130
# 2021-09-01 16:34:40,027 - INFO -   |--    Epoch Losses (10): [0.4682, 0.4444, 0.4226, 0.4105, 0.4184, 0.3944, 0.4092, 0.382, 0.3799, 0.3517]
# 2021-09-01 16:34:51,304 - INFO -   |-- [Party 6] Average Train Loss:   0.4164 Train Accuracy: global  82.21% local  84.37% ...   93 forgettables out of 2130 ( 4.37%) ... total data used 2130
# 2021-09-01 16:34:51,306 - INFO -   |--    Epoch Losses (10): [0.4701, 0.4625, 0.4374, 0.4267, 0.4197, 0.4069, 0.3912, 0.3878, 0.3872, 0.3742]
# 2021-09-01 16:35:01,651 - INFO -   |-- [Party 7] Average Train Loss:   0.4177 Train Accuracy: global  82.63% local  84.51% ...  133 forgettables out of 2130 ( 6.24%) ... total data used 2130
# 2021-09-01 16:35:01,653 - INFO -   |--    Epoch Losses (10): [0.4752, 0.4552, 0.441, 0.4169, 0.4236, 0.4082, 0.4048, 0.3912, 0.3812, 0.3794]
# 2021-09-01 16:35:12,986 - INFO -   |-- [Party 8] Average Train Loss:   0.4090 Train Accuracy: global  84.27% local  84.55% ...   68 forgettables out of 2130 ( 3.19%) ... total data used 2130
# 2021-09-01 16:35:12,988 - INFO -   |--    Epoch Losses (10): [0.4674, 0.4439, 0.4229, 0.4284, 0.4109, 0.3992, 0.3805, 0.3794, 0.368, 0.3894]
# 2021-09-01 16:35:24,275 - INFO -   |-- [Party 9] Average Train Loss:   0.4263 Train Accuracy: global  81.60% local  82.58% ...   95 forgettables out of 2130 ( 4.46%) ... total data used 2130
# 2021-09-01 16:35:24,276 - INFO -   |--    Epoch Losses (10): [0.4844, 0.4655, 0.4605, 0.4267, 0.4149, 0.4183, 0.4079, 0.4014, 0.3953, 0.388]
# 2021-09-01 16:35:32,876 - INFO -     |---- Number of Forgettables: 3771 (19.67%)
# 2021-09-01 16:35:32,877 - INFO -     |---- Train Accuracy: 65.35%
# 2021-09-01 16:35:32,878 - INFO -     |---- Test Accuracy: 46.31%
# 2021-09-01 16:35:32,879 - INFO -     |---- Test Loss: 1.6020
# 2021-09-01 16:35:32,880 - INFO -     |---- Elapsed time: 0:14:08.440579
# 2021-09-01 16:35:32,881 - INFO -
# Test Acc: Max 46.3113% (8 round) | Last 46.3113% | Avg 41.5580% (4 round)
#
# 2021-09-01 16:35:32,883 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 16:35:43,658 - INFO -   |-- [Party 1] Average Train Loss:   0.8409 Train Accuracy: global   0.00% local  70.70% ... 1474 forgettables out of 2130 (69.20%) ... total data used 2130
# 2021-09-01 16:35:43,662 - INFO -   |--    Epoch Losses (10): [1.94, 1.0342, 0.8187, 0.7327, 0.6929, 0.6635, 0.6499, 0.6338, 0.6274, 0.6157]
# 2021-09-01 16:35:54,870 - INFO -   |-- [Party 2] Average Train Loss:   0.8355 Train Accuracy: global   0.00% local  71.74% ... 1437 forgettables out of 2130 (67.46%) ... total data used 2130
# 2021-09-01 16:35:54,874 - INFO -   |--    Epoch Losses (10): [1.9365, 1.0307, 0.8119, 0.7262, 0.6894, 0.6607, 0.6425, 0.6294, 0.6159, 0.6118]
# 2021-09-01 16:36:05,990 - INFO -   |-- [Party 3] Average Train Loss:   0.3731 Train Accuracy: global  84.88% local  83.24% ...   87 forgettables out of 2130 ( 4.08%) ... total data used 2130
# 2021-09-01 16:36:05,992 - INFO -   |--    Epoch Losses (10): [0.4401, 0.4038, 0.3844, 0.3821, 0.3763, 0.3626, 0.3547, 0.3415, 0.336, 0.3496]
# 2021-09-01 16:36:16,647 - INFO -   |-- [Party 4] Average Train Loss:   0.3913 Train Accuracy: global  84.27% local  85.68% ...  140 forgettables out of 2130 ( 6.57%) ... total data used 2130
# 2021-09-01 16:36:16,649 - INFO -   |--    Epoch Losses (10): [0.4563, 0.4292, 0.4179, 0.3955, 0.3933, 0.3879, 0.376, 0.3551, 0.347, 0.3545]
# 2021-09-01 16:36:27,091 - INFO -   |-- [Party 5] Average Train Loss:   0.3896 Train Accuracy: global  83.71% local  88.22% ...  102 forgettables out of 2130 ( 4.79%) ... total data used 2130
# 2021-09-01 16:36:27,095 - INFO -   |--    Epoch Losses (10): [0.4359, 0.4282, 0.4056, 0.3935, 0.4065, 0.3776, 0.368, 0.3578, 0.3515, 0.3712]
# 2021-09-01 16:36:37,836 - INFO -   |-- [Party 6] Average Train Loss:   0.3936 Train Accuracy: global  83.90% local  84.32% ...  122 forgettables out of 2130 ( 5.73%) ... total data used 2130
# 2021-09-01 16:36:37,837 - INFO -   |--    Epoch Losses (10): [0.4463, 0.4274, 0.4245, 0.3978, 0.4028, 0.3969, 0.3772, 0.3649, 0.354, 0.3441]
# 2021-09-01 16:36:48,839 - INFO -   |-- [Party 7] Average Train Loss:   0.3994 Train Accuracy: global  83.66% local  84.51% ...   80 forgettables out of 2130 ( 3.76%) ... total data used 2130
# 2021-09-01 16:36:48,842 - INFO -   |--    Epoch Losses (10): [0.4593, 0.4348, 0.4223, 0.4119, 0.3886, 0.3942, 0.3715, 0.3612, 0.3807, 0.3691]
# 2021-09-01 16:37:00,133 - INFO -   |-- [Party 8] Average Train Loss:   0.3931 Train Accuracy: global  84.74% local  86.48% ...   71 forgettables out of 2130 ( 3.33%) ... total data used 2130
# 2021-09-01 16:37:00,134 - INFO -   |--    Epoch Losses (10): [0.4513, 0.4285, 0.409, 0.3986, 0.3835, 0.3745, 0.3924, 0.3704, 0.3648, 0.3584]
# 2021-09-01 16:37:11,322 - INFO -   |-- [Party 9] Average Train Loss:   0.4060 Train Accuracy: global  83.24% local  85.49% ...   78 forgettables out of 2130 ( 3.66%) ... total data used 2130
# 2021-09-01 16:37:11,323 - INFO -   |--    Epoch Losses (10): [0.463, 0.4449, 0.4274, 0.4013, 0.4158, 0.395, 0.3964, 0.3764, 0.3765, 0.3629]
# 2021-09-01 16:37:19,756 - INFO -     |---- Number of Forgettables: 3591 (18.73%)
# 2021-09-01 16:37:19,760 - INFO -     |---- Train Accuracy: 66.51%
# 2021-09-01 16:37:19,761 - INFO -     |---- Test Accuracy: 46.78%
# 2021-09-01 16:37:19,762 - INFO -     |---- Test Loss: 1.6066
# 2021-09-01 16:37:19,763 - INFO -     |---- Elapsed time: 0:15:55.323943
# 2021-09-01 16:37:19,765 - INFO -
# Test Acc: Max 46.7754% (9 round) | Last 46.7754% | Avg 42.1377% (4 round)
#
# 2021-09-01 16:37:19,768 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 16:37:30,102 - INFO -   |-- [Party 1] Average Train Loss:   0.8244 Train Accuracy: global   0.00% local  69.95% ... 1506 forgettables out of 2130 (70.70%) ... total data used 2130
# 2021-09-01 16:37:30,106 - INFO -   |--    Epoch Losses (10): [1.9044, 1.0088, 0.7999, 0.7192, 0.6842, 0.6507, 0.6394, 0.6233, 0.6107, 0.6032]
# 2021-09-01 16:37:40,841 - INFO -   |-- [Party 2] Average Train Loss:   0.8199 Train Accuracy: global   0.00% local  72.49% ... 1528 forgettables out of 2130 (71.74%) ... total data used 2130
# 2021-09-01 16:37:40,843 - INFO -   |--    Epoch Losses (10): [1.8989, 1.0071, 0.7963, 0.7147, 0.6742, 0.6512, 0.6327, 0.6173, 0.612, 0.595]
# 2021-09-01 16:37:51,685 - INFO -   |-- [Party 3] Average Train Loss:   0.3611 Train Accuracy: global  86.15% local  88.26% ...  186 forgettables out of 2130 ( 8.73%) ... total data used 2130
# 2021-09-01 16:37:51,689 - INFO -   |--    Epoch Losses (10): [0.4239, 0.3867, 0.3757, 0.3767, 0.3545, 0.3524, 0.3383, 0.324, 0.3538, 0.3247]
# 2021-09-01 16:38:02,300 - INFO -   |-- [Party 4] Average Train Loss:   0.3787 Train Accuracy: global  86.34% local  87.37% ...   60 forgettables out of 2130 ( 2.82%) ... total data used 2130
# 2021-09-01 16:38:02,302 - INFO -   |--    Epoch Losses (10): [0.4281, 0.4169, 0.3876, 0.3822, 0.365, 0.363, 0.3696, 0.3505, 0.3579, 0.3664]
# 2021-09-01 16:38:13,023 - INFO -   |-- [Party 5] Average Train Loss:   0.3692 Train Accuracy: global  85.82% local  86.43% ...  117 forgettables out of 2130 ( 5.49%) ... total data used 2130
# 2021-09-01 16:38:13,024 - INFO -   |--    Epoch Losses (10): [0.437, 0.4091, 0.3897, 0.3647, 0.3795, 0.3518, 0.3567, 0.3486, 0.3306, 0.3238]
# 2021-09-01 16:38:24,223 - INFO -   |-- [Party 6] Average Train Loss:   0.3812 Train Accuracy: global  85.12% local  86.34% ...   89 forgettables out of 2130 ( 4.18%) ... total data used 2130
# 2021-09-01 16:38:24,225 - INFO -   |--    Epoch Losses (10): [0.4398, 0.4182, 0.3943, 0.3985, 0.3773, 0.3795, 0.3618, 0.3553, 0.3418, 0.3452]
# 2021-09-01 16:38:35,204 - INFO -   |-- [Party 7] Average Train Loss:   0.3831 Train Accuracy: global  85.77% local  86.76% ...   64 forgettables out of 2130 ( 3.00%) ... total data used 2130
# 2021-09-01 16:38:35,206 - INFO -   |--    Epoch Losses (10): [0.4411, 0.407, 0.3949, 0.3853, 0.3831, 0.3674, 0.3635, 0.3711, 0.3695, 0.3484]
# 2021-09-01 16:38:45,678 - INFO -   |-- [Party 8] Average Train Loss:   0.3737 Train Accuracy: global  86.01% local  87.79% ...   67 forgettables out of 2130 ( 3.15%) ... total data used 2130
# 2021-09-01 16:38:45,680 - INFO -   |--    Epoch Losses (10): [0.4536, 0.3984, 0.3959, 0.3758, 0.3608, 0.3626, 0.3639, 0.3512, 0.3388, 0.3364]
# 2021-09-01 16:38:56,882 - INFO -   |-- [Party 9] Average Train Loss:   0.3913 Train Accuracy: global  84.55% local  84.93% ...  111 forgettables out of 2130 ( 5.21%) ... total data used 2130
# 2021-09-01 16:38:56,885 - INFO -   |--    Epoch Losses (10): [0.4548, 0.4241, 0.4079, 0.3966, 0.3886, 0.3753, 0.3707, 0.3674, 0.3701, 0.3576]
# 2021-09-01 16:39:05,260 - INFO -     |---- Number of Forgettables: 3728 (19.45%)
# 2021-09-01 16:39:05,264 - INFO -     |---- Train Accuracy: 67.15%
# 2021-09-01 16:39:05,265 - INFO -     |---- Test Accuracy: 47.16%
# 2021-09-01 16:39:05,266 - INFO -     |---- Test Loss: 1.5933
# 2021-09-01 16:39:05,267 - INFO -     |---- Elapsed time: 0:17:40.827821
# 2021-09-01 16:39:05,268 - INFO -
# Test Acc: Max 47.1576% (10 round) | Last 47.1576% | Avg 42.6397% (4 round)
#
# 2021-09-01 16:39:05,271 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 16:39:15,661 - INFO -   |-- [Party 1] Average Train Loss:   0.8103 Train Accuracy: global   0.00% local  69.77% ... 1490 forgettables out of 2130 (69.95%) ... total data used 2130
# 2021-09-01 16:39:15,665 - INFO -   |--    Epoch Losses (10): [1.8695, 0.99, 0.7862, 0.7085, 0.6725, 0.642, 0.6258, 0.6142, 0.602, 0.5922]
# 2021-09-01 16:39:26,878 - INFO -   |-- [Party 2] Average Train Loss:   0.8062 Train Accuracy: global   0.00% local  71.27% ... 1544 forgettables out of 2130 (72.49%) ... total data used 2130
# 2021-09-01 16:39:26,881 - INFO -   |--    Epoch Losses (10): [1.8686, 0.986, 0.7802, 0.7038, 0.6626, 0.6407, 0.62, 0.6113, 0.5951, 0.5938]
# 2021-09-01 16:39:37,315 - INFO -   |-- [Party 3] Average Train Loss:   0.3461 Train Accuracy: global  87.14% local  87.79% ...   92 forgettables out of 2130 ( 4.32%) ... total data used 2130
# 2021-09-01 16:39:37,317 - INFO -   |--    Epoch Losses (10): [0.3973, 0.3781, 0.3761, 0.3584, 0.3416, 0.3399, 0.3256, 0.3191, 0.3134, 0.3115]
# 2021-09-01 16:39:47,700 - INFO -   |-- [Party 4] Average Train Loss:   0.3594 Train Accuracy: global  86.43% local  88.17% ...   72 forgettables out of 2130 ( 3.38%) ... total data used 2130
# 2021-09-01 16:39:47,704 - INFO -   |--    Epoch Losses (10): [0.4127, 0.393, 0.3778, 0.3606, 0.3562, 0.3463, 0.3408, 0.3465, 0.3405, 0.3194]
# 2021-09-01 16:39:58,156 - INFO -   |-- [Party 5] Average Train Loss:   0.3525 Train Accuracy: global  86.81% local  89.25% ...  115 forgettables out of 2130 ( 5.40%) ... total data used 2130
# 2021-09-01 16:39:58,157 - INFO -   |--    Epoch Losses (10): [0.4056, 0.3869, 0.3729, 0.3593, 0.3398, 0.3291, 0.3436, 0.3394, 0.3241, 0.324]
# 2021-09-01 16:40:09,227 - INFO -   |-- [Party 6] Average Train Loss:   0.3625 Train Accuracy: global  85.68% local  88.59% ...   75 forgettables out of 2130 ( 3.52%) ... total data used 2130
# 2021-09-01 16:40:09,231 - INFO -   |--    Epoch Losses (10): [0.4298, 0.3969, 0.3712, 0.3714, 0.3555, 0.3543, 0.3404, 0.327, 0.3335, 0.3454]
# 2021-09-01 16:40:20,504 - INFO -   |-- [Party 7] Average Train Loss:   0.3709 Train Accuracy: global  86.43% local  83.24% ...  105 forgettables out of 2130 ( 4.93%) ... total data used 2130
# 2021-09-01 16:40:20,508 - INFO -   |--    Epoch Losses (10): [0.4238, 0.4007, 0.3815, 0.3893, 0.36, 0.3581, 0.3534, 0.3663, 0.3428, 0.3333]
# 2021-09-01 16:40:31,739 - INFO -   |-- [Party 8] Average Train Loss:   0.3568 Train Accuracy: global  86.95% local  89.01% ...  113 forgettables out of 2130 ( 5.31%) ... total data used 2130
# 2021-09-01 16:40:31,741 - INFO -   |--    Epoch Losses (10): [0.4242, 0.3866, 0.3799, 0.3693, 0.3469, 0.3459, 0.3367, 0.349, 0.3135, 0.3163]
# 2021-09-01 16:40:42,627 - INFO -   |-- [Party 9] Average Train Loss:   0.3783 Train Accuracy: global  85.21% local  86.95% ...   81 forgettables out of 2130 ( 3.80%) ... total data used 2130
# 2021-09-01 16:40:42,629 - INFO -   |--    Epoch Losses (10): [0.4355, 0.4112, 0.3987, 0.3856, 0.3698, 0.363, 0.3769, 0.3547, 0.3445, 0.3428]
# 2021-09-01 16:40:51,015 - INFO -     |---- Number of Forgettables: 3687 (19.23%)
# 2021-09-01 16:40:51,019 - INFO -     |---- Train Accuracy: 67.69%
# 2021-09-01 16:40:51,020 - INFO -     |---- Test Accuracy: 47.36%
# 2021-09-01 16:40:51,022 - INFO -     |---- Test Loss: 1.5846
# 2021-09-01 16:40:51,023 - INFO -     |---- Elapsed time: 0:19:26.583714
# 2021-09-01 16:40:51,025 - INFO -
# Test Acc: Max 47.3623% (11 round) | Last 47.3623% | Avg 43.0691% (4 round)
#
# 2021-09-01 16:40:51,028 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 16:41:02,435 - INFO -   |-- [Party 1] Average Train Loss:   0.7980 Train Accuracy: global   0.00% local  73.05% ... 1486 forgettables out of 2130 (69.77%) ... total data used 2130
# 2021-09-01 16:41:02,439 - INFO -   |--    Epoch Losses (10): [1.8463, 0.9732, 0.7718, 0.698, 0.6595, 0.6285, 0.6169, 0.6056, 0.5936, 0.5867]
# 2021-09-01 16:41:13,617 - INFO -   |-- [Party 2] Average Train Loss:   0.7947 Train Accuracy: global   0.00% local  73.57% ... 1518 forgettables out of 2130 (71.27%) ... total data used 2130
# 2021-09-01 16:41:13,619 - INFO -   |--    Epoch Losses (10): [1.8453, 0.971, 0.7703, 0.6944, 0.6557, 0.6266, 0.6135, 0.6009, 0.5912, 0.5782]
# 2021-09-01 16:41:24,766 - INFO -   |-- [Party 3] Average Train Loss:   0.3330 Train Accuracy: global  87.46% local  88.08% ...  116 forgettables out of 2130 ( 5.45%) ... total data used 2130
# 2021-09-01 16:41:24,767 - INFO -   |--    Epoch Losses (10): [0.3892, 0.3572, 0.3504, 0.3445, 0.3434, 0.3261, 0.3109, 0.2995, 0.3045, 0.3042]
# 2021-09-01 16:41:35,709 - INFO -   |-- [Party 4] Average Train Loss:   0.3477 Train Accuracy: global  87.18% local  85.82% ...   73 forgettables out of 2130 ( 3.43%) ... total data used 2130
# 2021-09-01 16:41:35,713 - INFO -   |--    Epoch Losses (10): [0.4051, 0.3877, 0.3619, 0.3515, 0.3367, 0.34, 0.3218, 0.3218, 0.3254, 0.3253]
# 2021-09-01 16:41:46,783 - INFO -   |-- [Party 5] Average Train Loss:   0.3391 Train Accuracy: global  87.32% local  86.01% ...   69 forgettables out of 2130 ( 3.24%) ... total data used 2130
# 2021-09-01 16:41:46,785 - INFO -   |--    Epoch Losses (10): [0.4044, 0.3683, 0.3483, 0.3558, 0.3495, 0.3197, 0.3186, 0.309, 0.3109, 0.3066]
# 2021-09-01 16:41:57,311 - INFO -   |-- [Party 6] Average Train Loss:   0.3489 Train Accuracy: global  86.90% local  86.34% ...   97 forgettables out of 2130 ( 4.55%) ... total data used 2130
# 2021-09-01 16:41:57,313 - INFO -   |--    Epoch Losses (10): [0.4161, 0.3824, 0.3735, 0.3539, 0.34, 0.3273, 0.3286, 0.3266, 0.3259, 0.3151]
# 2021-09-01 16:42:08,266 - INFO -   |-- [Party 7] Average Train Loss:   0.3597 Train Accuracy: global  87.00% local  88.54% ...  116 forgettables out of 2130 ( 5.45%) ... total data used 2130
# 2021-09-01 16:42:08,267 - INFO -   |--    Epoch Losses (10): [0.4256, 0.3883, 0.3739, 0.3664, 0.3544, 0.3355, 0.3351, 0.3346, 0.3589, 0.3239]
# 2021-09-01 16:42:19,335 - INFO -   |-- [Party 8] Average Train Loss:   0.3455 Train Accuracy: global  87.70% local  89.39% ...   85 forgettables out of 2130 ( 3.99%) ... total data used 2130
# 2021-09-01 16:42:19,337 - INFO -   |--    Epoch Losses (10): [0.4086, 0.3743, 0.3526, 0.356, 0.3531, 0.3246, 0.3224, 0.3206, 0.3331, 0.3095]
# 2021-09-01 16:42:30,068 - INFO -   |-- [Party 9] Average Train Loss:   0.3623 Train Accuracy: global  85.68% local  86.53% ...  106 forgettables out of 2130 ( 4.98%) ... total data used 2130
# 2021-09-01 16:42:30,069 - INFO -   |--    Epoch Losses (10): [0.4277, 0.3978, 0.3706, 0.3722, 0.3679, 0.3626, 0.3395, 0.3275, 0.3306, 0.3263]
# 2021-09-01 16:42:38,497 - INFO -     |---- Number of Forgettables: 3666 (19.12%)
# 2021-09-01 16:42:38,498 - INFO -     |---- Train Accuracy: 68.12%
# 2021-09-01 16:42:38,499 - INFO -     |---- Test Accuracy: 47.72%
# 2021-09-01 16:42:38,500 - INFO -     |---- Test Loss: 1.5641
# 2021-09-01 16:42:38,501 - INFO -     |---- Elapsed time: 0:21:14.061522
# 2021-09-01 16:42:38,502 - INFO -
# Test Acc: Max 47.7172% (12 round) | Last 47.7172% | Avg 43.4564% (5 round)
#
# 2021-09-01 16:42:38,504 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 16:42:49,434 - INFO -   |-- [Party 1] Average Train Loss:   0.7843 Train Accuracy: global   0.00% local  70.75% ... 1556 forgettables out of 2130 (73.05%) ... total data used 2130
# 2021-09-01 16:42:49,437 - INFO -   |--    Epoch Losses (10): [1.8187, 0.9543, 0.7558, 0.6785, 0.6413, 0.6282, 0.609, 0.5966, 0.5828, 0.5782]
# 2021-09-01 16:43:00,569 - INFO -   |-- [Party 2] Average Train Loss:   0.7818 Train Accuracy: global   0.00% local  72.49% ... 1567 forgettables out of 2130 (73.57%) ... total data used 2130
# 2021-09-01 16:43:00,571 - INFO -   |--    Epoch Losses (10): [1.8188, 0.9476, 0.7532, 0.6824, 0.6457, 0.6185, 0.604, 0.5916, 0.5769, 0.579]
# 2021-09-01 16:43:11,750 - INFO -   |-- [Party 3] Average Train Loss:   0.3202 Train Accuracy: global  88.73% local  89.48% ...   85 forgettables out of 2130 ( 3.99%) ... total data used 2130
# 2021-09-01 16:43:11,751 - INFO -   |--    Epoch Losses (10): [0.3734, 0.3463, 0.3322, 0.3288, 0.3175, 0.3184, 0.3117, 0.3079, 0.2821, 0.2836]
# 2021-09-01 16:43:22,433 - INFO -   |-- [Party 4] Average Train Loss:   0.3340 Train Accuracy: global  87.79% local  87.56% ...  133 forgettables out of 2130 ( 6.24%) ... total data used 2130
# 2021-09-01 16:43:22,437 - INFO -   |--    Epoch Losses (10): [0.3917, 0.3735, 0.3451, 0.3404, 0.323, 0.3274, 0.3299, 0.3106, 0.3019, 0.2961]
# 2021-09-01 16:43:32,918 - INFO -   |-- [Party 5] Average Train Loss:   0.3242 Train Accuracy: global  88.17% local  88.17% ...   49 forgettables out of 2130 ( 2.30%) ... total data used 2130
# 2021-09-01 16:43:32,922 - INFO -   |--    Epoch Losses (10): [0.3851, 0.3544, 0.3456, 0.3303, 0.3218, 0.3162, 0.303, 0.3081, 0.2933, 0.2844]
# 2021-09-01 16:43:44,008 - INFO -   |-- [Party 6] Average Train Loss:   0.3342 Train Accuracy: global  87.56% local  88.87% ...   93 forgettables out of 2130 ( 4.37%) ... total data used 2130
# 2021-09-01 16:43:44,010 - INFO -   |--    Epoch Losses (10): [0.3982, 0.3584, 0.3523, 0.3434, 0.328, 0.3204, 0.3129, 0.3094, 0.3099, 0.3095]
# 2021-09-01 16:43:54,430 - INFO -   |-- [Party 7] Average Train Loss:   0.3443 Train Accuracy: global  87.93% local  89.15% ...   77 forgettables out of 2130 ( 3.62%) ... total data used 2130
# 2021-09-01 16:43:54,432 - INFO -   |--    Epoch Losses (10): [0.4053, 0.385, 0.3505, 0.347, 0.3425, 0.3311, 0.3205, 0.317, 0.3344, 0.3093]
# 2021-09-01 16:44:04,750 - INFO -   |-- [Party 8] Average Train Loss:   0.3323 Train Accuracy: global  87.75% local  87.00% ...   85 forgettables out of 2130 ( 3.99%) ... total data used 2130
# 2021-09-01 16:44:04,753 - INFO -   |--    Epoch Losses (10): [0.4021, 0.3616, 0.3527, 0.3354, 0.3289, 0.3286, 0.3172, 0.302, 0.2987, 0.2962]
# 2021-09-01 16:44:15,444 - INFO -   |-- [Party 9] Average Train Loss:   0.3462 Train Accuracy: global  86.29% local  88.69% ...   64 forgettables out of 2130 ( 3.00%) ... total data used 2130
# 2021-09-01 16:44:15,445 - INFO -   |--    Epoch Losses (10): [0.4001, 0.3735, 0.3611, 0.3563, 0.3431, 0.3451, 0.3279, 0.3266, 0.3154, 0.3128]
# 2021-09-01 16:44:23,994 - INFO -     |---- Number of Forgettables: 3709 (19.35%)
# 2021-09-01 16:44:23,997 - INFO -     |---- Train Accuracy: 69.24%
# 2021-09-01 16:44:23,998 - INFO -     |---- Test Accuracy: 47.96%
# 2021-09-01 16:44:23,999 - INFO -     |---- Test Loss: 1.6120
# 2021-09-01 16:44:24,000 - INFO -     |---- Elapsed time: 0:22:59.560458
# 2021-09-01 16:44:24,001 - INFO -
# Test Acc: Max 47.9629% (13 round) | Last 47.9629% | Avg 43.8031% (5 round)
#
# 2021-09-01 16:44:24,003 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 16:44:35,180 - INFO -   |-- [Party 1] Average Train Loss:   0.7730 Train Accuracy: global   0.00% local  70.75% ... 1507 forgettables out of 2130 (70.75%) ... total data used 2130
# 2021-09-01 16:44:35,181 - INFO -   |--    Epoch Losses (10): [1.7906, 0.9362, 0.7524, 0.6814, 0.6396, 0.6118, 0.5968, 0.5829, 0.5765, 0.5621]
# 2021-09-01 16:44:46,111 - INFO -   |-- [Party 2] Average Train Loss:   0.7698 Train Accuracy: global   0.00% local  73.80% ... 1544 forgettables out of 2130 (72.49%) ... total data used 2130
# 2021-09-01 16:44:46,114 - INFO -   |--    Epoch Losses (10): [1.7918, 0.9318, 0.7472, 0.6721, 0.6349, 0.6083, 0.5944, 0.5821, 0.5743, 0.5613]
# 2021-09-01 16:44:57,035 - INFO -   |-- [Party 3] Average Train Loss:   0.3079 Train Accuracy: global  89.48% local  87.61% ...   93 forgettables out of 2130 ( 4.37%) ... total data used 2130
# 2021-09-01 16:44:57,039 - INFO -   |--    Epoch Losses (10): [0.372, 0.3363, 0.323, 0.3094, 0.2997, 0.2968, 0.2978, 0.2849, 0.2759, 0.283]
# 2021-09-01 16:45:07,476 - INFO -   |-- [Party 4] Average Train Loss:   0.3248 Train Accuracy: global  88.73% local  89.72% ...   83 forgettables out of 2130 ( 3.90%) ... total data used 2130
# 2021-09-01 16:45:07,478 - INFO -   |--    Epoch Losses (10): [0.3841, 0.3502, 0.3487, 0.3446, 0.3302, 0.3131, 0.2997, 0.2867, 0.3061, 0.2848]
# 2021-09-01 16:45:18,639 - INFO -   |-- [Party 5] Average Train Loss:   0.3168 Train Accuracy: global  89.48% local  89.15% ...   58 forgettables out of 2130 ( 2.72%) ... total data used 2130
# 2021-09-01 16:45:18,640 - INFO -   |--    Epoch Losses (10): [0.3731, 0.3594, 0.3247, 0.309, 0.3096, 0.3114, 0.3099, 0.2942, 0.2952, 0.2811]
# 2021-09-01 16:45:29,904 - INFO -   |-- [Party 6] Average Train Loss:   0.3246 Train Accuracy: global  88.87% local  84.84% ...   87 forgettables out of 2130 ( 4.08%) ... total data used 2130
# 2021-09-01 16:45:29,906 - INFO -   |--    Epoch Losses (10): [0.3889, 0.3537, 0.3356, 0.329, 0.3188, 0.3046, 0.3156, 0.2958, 0.3014, 0.3027]
# ...
# 2021-09-01 21:58:55,501 - INFO -   |--    Epoch Losses (10): [0.0655, 0.0333, 0.0322, 0.0345, 0.0309, 0.0291, 0.0262, 0.0188, 0.0248, 0.0181]
# 2021-09-01 21:59:05,657 - INFO -   |-- [Party 6] Average Train Loss:   0.0345 Train Accuracy: global  98.50% local  99.62% ...   27 forgettables out of 2130 ( 1.27%) ... total data used 2130
# 2021-09-01 21:59:05,659 - INFO -   |--    Epoch Losses (10): [0.0714, 0.0408, 0.036, 0.0325, 0.0259, 0.0267, 0.0267, 0.0286, 0.029, 0.0278]
# 2021-09-01 21:59:16,399 - INFO -   |-- [Party 7] Average Train Loss:   0.0358 Train Accuracy: global  98.17% local  99.34% ...   35 forgettables out of 2130 ( 1.64%) ... total data used 2130
# 2021-09-01 21:59:16,403 - INFO -   |--    Epoch Losses (10): [0.0644, 0.044, 0.0372, 0.033, 0.0289, 0.0343, 0.0342, 0.0252, 0.0266, 0.0302]
# 2021-09-01 21:59:26,416 - INFO -   |-- [Party 8] Average Train Loss:   0.0340 Train Accuracy: global  97.75% local  99.53% ...   43 forgettables out of 2130 ( 2.02%) ... total data used 2130
# 2021-09-01 21:59:26,419 - INFO -   |--    Epoch Losses (10): [0.0636, 0.0395, 0.0372, 0.0398, 0.0302, 0.0358, 0.0255, 0.0248, 0.0234, 0.0204]
# 2021-09-01 21:59:36,884 - INFO -   |-- [Party 9] Average Train Loss:   0.0294 Train Accuracy: global  98.59% local  99.72% ...   24 forgettables out of 2130 ( 1.13%) ... total data used 2130
# 2021-09-01 21:59:36,885 - INFO -   |--    Epoch Losses (10): [0.045, 0.0367, 0.0278, 0.0267, 0.0277, 0.0312, 0.0282, 0.0228, 0.0239, 0.0235]
# 2021-09-01 21:59:44,667 - INFO -     |---- Number of Forgettables: 4316 (22.51%)
# 2021-09-01 21:59:44,668 - INFO -     |---- Train Accuracy: 76.71%
# 2021-09-01 21:59:44,669 - INFO -     |---- Test Accuracy: 53.37%
# 2021-09-01 21:59:44,670 - INFO -     |---- Test Loss: 1.5284
# 2021-09-01 21:59:44,671 - INFO -     |---- Elapsed time: 5:38:20.232012
# 2021-09-01 21:59:44,673 - INFO -
# Test Acc: Max 53.3747% (189 round) | Last 53.3747% | Avg 52.2030% (65 round)
#
# 2021-09-01 21:59:44,677 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 21:59:54,730 - INFO -   |-- [Party 1] Average Train Loss:   0.0614 Train Accuracy: global   0.09% local  99.25% ... 2111 forgettables out of 2130 (99.11%) ... total data used 2130
# 2021-09-01 21:59:54,733 - INFO -   |--    Epoch Losses (10): [0.2053, 0.0558, 0.05, 0.0485, 0.0445, 0.0427, 0.0407, 0.0401, 0.0412, 0.0456]
# 2021-09-01 22:00:04,509 - INFO -   |-- [Party 2] Average Train Loss:   0.0738 Train Accuracy: global   0.19% local  98.26% ... 2104 forgettables out of 2130 (98.78%) ... total data used 2130
# 2021-09-01 22:00:04,511 - INFO -   |--    Epoch Losses (10): [0.2566, 0.0716, 0.056, 0.0561, 0.0596, 0.0541, 0.0501, 0.0385, 0.0497, 0.0457]
# 2021-09-01 22:00:14,423 - INFO -   |-- [Party 3] Average Train Loss:   0.0285 Train Accuracy: global  98.73% local  99.44% ...   23 forgettables out of 2130 ( 1.08%) ... total data used 2130
# 2021-09-01 22:00:14,425 - INFO -   |--    Epoch Losses (10): [0.0357, 0.0309, 0.0264, 0.0328, 0.0349, 0.0265, 0.0236, 0.0209, 0.0273, 0.0264]
# 2021-09-01 22:00:24,189 - INFO -   |-- [Party 4] Average Train Loss:   0.0321 Train Accuracy: global  98.73% local  99.67% ...   25 forgettables out of 2130 ( 1.17%) ... total data used 2130
# 2021-09-01 22:00:24,191 - INFO -   |--    Epoch Losses (10): [0.0541, 0.0331, 0.0265, 0.0338, 0.0294, 0.0374, 0.0259, 0.0273, 0.0206, 0.033]
# 2021-09-01 22:00:33,919 - INFO -   |-- [Party 5] Average Train Loss:   0.0270 Train Accuracy: global  98.54% local  99.39% ...   25 forgettables out of 2130 ( 1.17%) ... total data used 2130
# 2021-09-01 22:00:33,920 - INFO -   |--    Epoch Losses (10): [0.04, 0.0275, 0.0279, 0.026, 0.0274, 0.0281, 0.0264, 0.0146, 0.0243, 0.0278]
# 2021-09-01 22:00:43,711 - INFO -   |-- [Party 6] Average Train Loss:   0.0328 Train Accuracy: global  98.78% local  99.77% ...   23 forgettables out of 2130 ( 1.08%) ... total data used 2130
# 2021-09-01 22:00:43,715 - INFO -   |--    Epoch Losses (10): [0.0469, 0.037, 0.0381, 0.0374, 0.0341, 0.0287, 0.0258, 0.0303, 0.0272, 0.0222]
# 2021-09-01 22:00:53,477 - INFO -   |-- [Party 7] Average Train Loss:   0.0368 Train Accuracy: global  98.26% local  99.62% ...   32 forgettables out of 2130 ( 1.50%) ... total data used 2130
# 2021-09-01 22:00:53,479 - INFO -   |--    Epoch Losses (10): [0.0591, 0.0411, 0.0476, 0.0419, 0.0365, 0.0306, 0.0339, 0.031, 0.0233, 0.0229]
# 2021-09-01 22:01:03,296 - INFO -   |-- [Party 8] Average Train Loss:   0.0335 Train Accuracy: global  98.22% local  98.69% ...   34 forgettables out of 2130 ( 1.60%) ... total data used 2130
# 2021-09-01 22:01:03,297 - INFO -   |--    Epoch Losses (10): [0.0565, 0.0339, 0.0337, 0.0366, 0.0274, 0.0323, 0.0251, 0.0332, 0.0293, 0.0274]
# 2021-09-01 22:01:14,201 - INFO -   |-- [Party 9] Average Train Loss:   0.0290 Train Accuracy: global  98.92% local  99.67% ...   19 forgettables out of 2130 ( 0.89%) ... total data used 2130
# 2021-09-01 22:01:14,203 - INFO -   |--    Epoch Losses (10): [0.0434, 0.0321, 0.0281, 0.0316, 0.0288, 0.0258, 0.0339, 0.0199, 0.0228, 0.0233]
# 2021-09-01 22:01:22,051 - INFO -     |---- Number of Forgettables: 4396 (22.93%)
# 2021-09-01 22:01:22,052 - INFO -     |---- Train Accuracy: 77.38%
# 2021-09-01 22:01:22,053 - INFO -     |---- Test Accuracy: 56.33%
# 2021-09-01 22:01:22,054 - INFO -     |---- Test Loss: 1.4225
# 2021-09-01 22:01:22,055 - INFO -     |---- Elapsed time: 5:39:57.615636
# 2021-09-01 22:01:22,056 - INFO -
# Test Acc: Max 56.3298% (197 round) | Last 56.3298% | Avg 52.2240% (71 round)
#
# 2021-09-01 22:01:22,060 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 22:01:31,910 - INFO -   |-- [Party 1] Average Train Loss:   0.0507 Train Accuracy: global   3.90% local  99.48% ... 2031 forgettables out of 2130 (95.35%) ... total data used 2130
# 2021-09-01 22:01:31,913 - INFO -   |--    Epoch Losses (10): [0.0916, 0.0555, 0.0511, 0.0514, 0.042, 0.0466, 0.0454, 0.0389, 0.0448, 0.0394]
# 2021-09-01 22:01:43,080 - INFO -   |-- [Party 2] Average Train Loss:   0.0580 Train Accuracy: global   4.46% local  98.83% ... 1998 forgettables out of 2130 (93.80%) ... total data used 2130
# 2021-09-01 22:01:43,081 - INFO -   |--    Epoch Losses (10): [0.1001, 0.0715, 0.0634, 0.0508, 0.0538, 0.0539, 0.0423, 0.0508, 0.047, 0.0461]
# 2021-09-01 22:01:53,609 - INFO -   |-- [Party 3] Average Train Loss:   0.0327 Train Accuracy: global  98.12% local  99.34% ...   38 forgettables out of 2130 ( 1.78%) ... total data used 2130
# 2021-09-01 22:01:53,610 - INFO -   |--    Epoch Losses (10): [0.0634, 0.0309, 0.0375, 0.0306, 0.0344, 0.0239, 0.0236, 0.0218, 0.0293, 0.0318]
# 2021-09-01 22:02:03,372 - INFO -   |-- [Party 4] Average Train Loss:   0.0378 Train Accuracy: global  98.17% local  99.30% ...   37 forgettables out of 2130 ( 1.74%) ... total data used 2130
# 2021-09-01 22:02:03,373 - INFO -   |--    Epoch Losses (10): [0.0746, 0.0292, 0.0366, 0.0343, 0.024, 0.0364, 0.0357, 0.0336, 0.0453, 0.0279]
# 2021-09-01 22:02:13,697 - INFO -   |-- [Party 5] Average Train Loss:   0.0305 Train Accuracy: global  97.93% local  99.86% ...   37 forgettables out of 2130 ( 1.74%) ... total data used 2130
# 2021-09-01 22:02:13,699 - INFO -   |--    Epoch Losses (10): [0.0718, 0.0369, 0.0343, 0.0261, 0.0209, 0.0277, 0.029, 0.0207, 0.0214, 0.0157]
# 2021-09-01 22:02:23,463 - INFO -   |-- [Party 6] Average Train Loss:   0.0358 Train Accuracy: global  98.22% local  99.81% ...   34 forgettables out of 2130 ( 1.60%) ... total data used 2130
# 2021-09-01 22:02:23,464 - INFO -   |--    Epoch Losses (10): [0.0671, 0.0458, 0.0335, 0.0336, 0.0279, 0.0362, 0.0261, 0.0309, 0.0296, 0.0272]
# 2021-09-01 22:02:33,226 - INFO -   |-- [Party 7] Average Train Loss:   0.0361 Train Accuracy: global  97.75% local  99.62% ...   43 forgettables out of 2130 ( 2.02%) ... total data used 2130
# 2021-09-01 22:02:33,229 - INFO -   |--    Epoch Losses (10): [0.0693, 0.0434, 0.0334, 0.0366, 0.0355, 0.0275, 0.0249, 0.0234, 0.0289, 0.038]
# 2021-09-01 22:02:43,009 - INFO -   |-- [Party 8] Average Train Loss:   0.0385 Train Accuracy: global  97.46% local  99.53% ...   51 forgettables out of 2130 ( 2.39%) ... total data used 2130
# 2021-09-01 22:02:43,011 - INFO -   |--    Epoch Losses (10): [0.1017, 0.0417, 0.0378, 0.0368, 0.0296, 0.0269, 0.0266, 0.0289, 0.0306, 0.0242]
# 2021-09-01 22:02:52,738 - INFO -   |-- [Party 9] Average Train Loss:   0.0323 Train Accuracy: global  97.98% local  99.53% ...   41 forgettables out of 2130 ( 1.92%) ... total data used 2130
# 2021-09-01 22:02:52,740 - INFO -   |--    Epoch Losses (10): [0.0655, 0.0324, 0.033, 0.028, 0.0321, 0.0305, 0.0318, 0.0195, 0.0242, 0.0262]
# 2021-09-01 22:03:00,440 - INFO -     |---- Number of Forgettables: 4310 (22.48%)
# 2021-09-01 22:03:00,442 - INFO -     |---- Train Accuracy: 76.58%
# 2021-09-01 22:03:00,443 - INFO -     |---- Test Accuracy: 53.01%
# 2021-09-01 22:03:00,443 - INFO -     |---- Test Loss: 1.5909
# 2021-09-01 22:03:00,444 - INFO -     |---- Elapsed time: 5:41:36.004651
# 2021-09-01 22:03:00,445 - INFO -
# Test Acc: Max 53.0130% (197 round) | Last 53.0130% | Avg 52.2279% (71 round)
#
# 2021-09-01 22:03:00,448 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 22:03:10,295 - INFO -   |-- [Party 1] Average Train Loss:   0.0670 Train Accuracy: global   0.05% local  99.58% ... 2118 forgettables out of 2130 (99.44%) ... total data used 2130
# 2021-09-01 22:03:10,296 - INFO -   |--    Epoch Losses (10): [0.2421, 0.0596, 0.053, 0.0546, 0.0447, 0.0445, 0.0514, 0.0424, 0.0412, 0.037]
# 2021-09-01 22:03:20,179 - INFO -   |-- [Party 2] Average Train Loss:   0.0735 Train Accuracy: global   0.14% local  99.15% ... 2102 forgettables out of 2130 (98.69%) ... total data used 2130
# 2021-09-01 22:03:20,180 - INFO -   |--    Epoch Losses (10): [0.2906, 0.0662, 0.0527, 0.0477, 0.0525, 0.0489, 0.0447, 0.0462, 0.0442, 0.0409]
# 2021-09-01 22:03:31,228 - INFO -   |-- [Party 3] Average Train Loss:   0.0303 Train Accuracy: global  98.92% local  99.72% ...   19 forgettables out of 2130 ( 0.89%) ... total data used 2130
# 2021-09-01 22:03:31,229 - INFO -   |--    Epoch Losses (10): [0.0472, 0.032, 0.0334, 0.0376, 0.0245, 0.024, 0.0304, 0.0216, 0.0295, 0.0227]
# 2021-09-01 22:03:42,334 - INFO -   |-- [Party 4] Average Train Loss:   0.0338 Train Accuracy: global  98.31% local  99.67% ...   30 forgettables out of 2130 ( 1.41%) ... total data used 2130
# 2021-09-01 22:03:42,337 - INFO -   |--    Epoch Losses (10): [0.0601, 0.044, 0.0331, 0.0388, 0.0287, 0.0358, 0.0324, 0.0228, 0.0193, 0.0234]
# 2021-09-01 22:03:52,278 - INFO -   |-- [Party 5] Average Train Loss:   0.0271 Train Accuracy: global  98.45% local  98.73% ...   32 forgettables out of 2130 ( 1.50%) ... total data used 2130
# 2021-09-01 22:03:52,280 - INFO -   |--    Epoch Losses (10): [0.0426, 0.0393, 0.0315, 0.0245, 0.02, 0.0272, 0.0227, 0.0226, 0.0188, 0.0213]
# 2021-09-01 22:04:03,309 - INFO -   |-- [Party 6] Average Train Loss:   0.0346 Train Accuracy: global  98.87% local  99.34% ...   22 forgettables out of 2130 ( 1.03%) ... total data used 2130
# 2021-09-01 22:04:03,313 - INFO -   |--    Epoch Losses (10): [0.0446, 0.043, 0.0459, 0.0295, 0.0326, 0.0413, 0.0304, 0.0258, 0.0297, 0.0235]
# 2021-09-01 22:04:13,094 - INFO -   |-- [Party 7] Average Train Loss:   0.0344 Train Accuracy: global  98.69% local  99.48% ...   25 forgettables out of 2130 ( 1.17%) ... total data used 2130
# 2021-09-01 22:04:13,096 - INFO -   |--    Epoch Losses (10): [0.0453, 0.0448, 0.0339, 0.035, 0.0357, 0.0312, 0.0319, 0.0269, 0.0278, 0.0314]
# 2021-09-01 22:04:22,873 - INFO -   |-- [Party 8] Average Train Loss:   0.0333 Train Accuracy: global  98.12% local  99.53% ...   34 forgettables out of 2130 ( 1.60%) ... total data used 2130
# 2021-09-01 22:04:22,876 - INFO -   |--    Epoch Losses (10): [0.0422, 0.0388, 0.034, 0.0422, 0.033, 0.0284, 0.0351, 0.0254, 0.0323, 0.0214]
# 2021-09-01 22:04:33,377 - INFO -   |-- [Party 9] Average Train Loss:   0.0280 Train Accuracy: global  98.59% local  99.81% ...   25 forgettables out of 2130 ( 1.17%) ... total data used 2130
# 2021-09-01 22:04:33,380 - INFO -   |--    Epoch Losses (10): [0.0417, 0.0303, 0.0302, 0.0311, 0.0227, 0.0257, 0.0271, 0.0216, 0.0221, 0.0279]
# 2021-09-01 22:04:41,361 - INFO -     |---- Number of Forgettables: 4407 (22.99%)
# 2021-09-01 22:04:41,363 - INFO -     |---- Train Accuracy: 77.12%
# 2021-09-01 22:04:41,364 - INFO -     |---- Test Accuracy: 56.32%
# 2021-09-01 22:04:41,365 - INFO -     |---- Test Loss: 1.4299
# 2021-09-01 22:04:41,365 - INFO -     |---- Elapsed time: 5:43:16.926031
# 2021-09-01 22:04:41,367 - INFO -
# Test Acc: Max 56.3161% (197 round) | Last 56.3161% | Avg 52.2485% (71 round)
#
# 2021-09-01 22:04:41,371 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 22:04:51,367 - INFO -   |-- [Party 1] Average Train Loss:   0.0498 Train Accuracy: global   4.23% local  99.11% ... 2032 forgettables out of 2130 (95.40%) ... total data used 2130
# 2021-09-01 22:04:51,369 - INFO -   |--    Epoch Losses (10): [0.0888, 0.0604, 0.0549, 0.0442, 0.0457, 0.0497, 0.0379, 0.0413, 0.0359, 0.039]
# 2021-09-01 22:05:01,199 - INFO -   |-- [Party 2] Average Train Loss:   0.0541 Train Accuracy: global   3.94% local  99.25% ... 2028 forgettables out of 2130 (95.21%) ... total data used 2130
# 2021-09-01 22:05:01,200 - INFO -   |--    Epoch Losses (10): [0.1027, 0.061, 0.0499, 0.0542, 0.0543, 0.0475, 0.0465, 0.0487, 0.0329, 0.0437]
# 2021-09-01 22:05:11,000 - INFO -   |-- [Party 3] Average Train Loss:   0.0310 Train Accuracy: global  98.69% local  99.67% ...   27 forgettables out of 2130 ( 1.27%) ... total data used 2130
# 2021-09-01 22:05:11,003 - INFO -   |--    Epoch Losses (10): [0.0603, 0.0329, 0.0292, 0.0345, 0.0283, 0.0271, 0.0239, 0.0249, 0.028, 0.0207]
# 2021-09-01 22:05:21,342 - INFO -   |-- [Party 4] Average Train Loss:   0.0319 Train Accuracy: global  98.40% local  99.77% ...   30 forgettables out of 2130 ( 1.41%) ... total data used 2130
# 2021-09-01 22:05:21,344 - INFO -   |--    Epoch Losses (10): [0.0645, 0.0374, 0.0261, 0.0262, 0.0288, 0.0298, 0.0258, 0.024, 0.0316, 0.0248]
# 2021-09-01 22:05:31,107 - INFO -   |-- [Party 5] Average Train Loss:   0.0295 Train Accuracy: global  98.31% local  99.67% ...   34 forgettables out of 2130 ( 1.60%) ... total data used 2130
# 2021-09-01 22:05:31,109 - INFO -   |--    Epoch Losses (10): [0.071, 0.0316, 0.0363, 0.0262, 0.0207, 0.0256, 0.0209, 0.0224, 0.0217, 0.0187]
# 2021-09-01 22:05:40,911 - INFO -   |-- [Party 6] Average Train Loss:   0.0333 Train Accuracy: global  98.73% local  99.53% ...   23 forgettables out of 2130 ( 1.08%) ... total data used 2130
# 2021-09-01 22:05:40,915 - INFO -   |--    Epoch Losses (10): [0.0582, 0.0451, 0.0373, 0.0354, 0.0323, 0.0263, 0.0286, 0.0301, 0.0189, 0.0211]
# 2021-09-01 22:05:50,692 - INFO -   |-- [Party 7] Average Train Loss:   0.0350 Train Accuracy: global  97.65% local  99.77% ...   44 forgettables out of 2130 ( 2.07%) ... total data used 2130
# 2021-09-01 22:05:50,694 - INFO -   |--    Epoch Losses (10): [0.0616, 0.0512, 0.0373, 0.0298, 0.0282, 0.0347, 0.0351, 0.024, 0.0261, 0.0222]
# 2021-09-01 22:06:00,545 - INFO -   |-- [Party 8] Average Train Loss:   0.0353 Train Accuracy: global  98.22% local  99.86% ...   35 forgettables out of 2130 ( 1.64%) ... total data used 2130
# 2021-09-01 22:06:00,546 - INFO -   |--    Epoch Losses (10): [0.0793, 0.0322, 0.0286, 0.0332, 0.0292, 0.0382, 0.0296, 0.0318, 0.0289, 0.0218]
# 2021-09-01 22:06:10,482 - INFO -   |-- [Party 9] Average Train Loss:   0.0295 Train Accuracy: global  98.31% local  99.53% ...   35 forgettables out of 2130 ( 1.64%) ... total data used 2130
# 2021-09-01 22:06:10,484 - INFO -   |--    Epoch Losses (10): [0.0513, 0.0329, 0.0285, 0.0247, 0.0241, 0.028, 0.0289, 0.0293, 0.0236, 0.0236]
# 2021-09-01 22:06:18,308 - INFO -     |---- Number of Forgettables: 4288 (22.37%)
# 2021-09-01 22:06:18,310 - INFO -     |---- Train Accuracy: 76.76%
# 2021-09-01 22:06:18,311 - INFO -     |---- Test Accuracy: 53.29%
# 2021-09-01 22:06:18,312 - INFO -     |---- Test Loss: 1.5615
# 2021-09-01 22:06:18,312 - INFO -     |---- Elapsed time: 5:44:53.873163
# 2021-09-01 22:06:18,313 - INFO -
# Test Acc: Max 53.2928% (197 round) | Last 53.2928% | Avg 52.2537% (72 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

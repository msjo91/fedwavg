# %%
# %matplotlib inline

dataset = 'cifar10'
clsimb = [2, 3, 4] # [2, 7], [2, 3, 4], [3, 3, 3]

filename = '{}_clsimb9c{}_42_fednova'.format(dataset, ''.join(str(x) for x in clsimb))

gpu = 1

# %%
import copy
import json
import logging
import math
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Files already downloaded and verified

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4
    
    def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

        self.shortcut = nn.Sequential()
        if (stride != 1) or (in_channel != self.expansion * out_channel):
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
                nn.BatchNorm2d(self.expansion * out_channel)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
        super().__init__()
        self.in_channel = out_channels[0]

        self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels[0])
        
        self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
        self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
        self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
        self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
        self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

    def _make_layer(self, block, out_channel, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channel, out_channel, stride=stride))
            self.in_channel = out_channel * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
# def average_weights(w):
#     w_avg = copy.deepcopy(w[0])
        
#     for key in w_avg.keys():
#         for i in range(1, len(w)):
#             w_avg[key] += w[i][key]
#         w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
#     return w_avg

# %%
# FedNova
def nova_update(w, a_list, d_list, n_list, n_client, device):
    coeff = 0.0
    n_round = sum(n_list)
    d_round = copy.deepcopy(w)
    for k in d_round:
        d_round[k] = 0.0
    for i in range(n_client):
        d_w = d_list[i]
        for k in d_w:
            d_round[k] = d_round[k] + (d_w[k] * n_list[i] / n_round)
        coeff += (a_list[i] * n_list[i] / n_round)
    for k in w:
        w[k] = w[k] - (coeff * d_round[k]).cpu()
    return w

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, global_state, momentum):
    epoch_losses = []
    
    # FedNova
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
    tau = 0
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())
            
            # FedNova
            tau += 1

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    # FedNova
    a_i = (tau - momentum * (1 - math.pow(momentum, tau)) / (1 - momentum)) / (1 - momentum)
    local_weights = model.state_dict()
    norm_grad = copy.deepcopy(global_state)
    for k in norm_grad:
        norm_grad[k] = torch.true_divide(global_state[k] - local_weights[k], a_i)
    
    local_weights = model.state_dict()

    return local_weights, epoch_losses, a_i, norm_grad

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
resnet = resnet9.copy()

out_channels = [64, 128, 256, 512]
strides = [1, 2, 2, 2]
in_channel = 3

num_classes = 10

fed_model = ResNet(resnet['block'], in_channel=in_channel, out_channels=out_channels, num_blocks=resnet['num_blocks'], strides=strides, num_classes=num_classes)
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 200
epochs = 10
lr = 0.001
wdecay = 0
momentum = 0

logger.info(f'\nAlgorithm: FedNova\nClient Split: {clsimb}\nDataset: {dataset}\nModel: ResNet9 | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

st = time.time()
for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    
    # FedNova
    a_list, d_list, n_list = [], [], []
    global_state = fed_model.state_dict()
    
    for i, k in enumerate(indices.keys()):
        match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

        fed_model.train()
        
        sampler_idx = indices[k]['index'].copy()
        sampler = SubsetRandomSampler(sampler_idx)

        trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)
        
        local_model = copy.deepcopy(fed_model)
        w, ls, a_i, norm_grad = train(local_model, trainloader, epochs, lr, wdecay, criterion, device, global_state, momentum)
        
        local_weights.append(copy.deepcopy(w))
        train_losses.append(ls)
        
        match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
        train_accs.append(local_acc)
        
        forget_cnt = len(forgettables)
        round_forget += forget_cnt
        forget_cnt_per_client[int(k)] = forget_cnt
        round_samples += len(indices[k]['index'])
        
        logger.info('  |-- [Party {:>1}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
            i + 1, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
        ))
        logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
        
        # FedNova
        a_list.append(a_i)
        d_list.append(norm_grad)
        n_list.append(len(trainloader))
        
    # FedNova
    fed_weights = nova_update(fed_weights, a_list, d_list, n_list, sum(clsimb), device)
    
    fed_model.load_state_dict(fed_weights)
    train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)
    
    if (r + 1) % 50 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
    logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Max {np.max(test_acc) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Last {test_accs[-1] * 100:.4f}% | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round)\n')
# Out:
# 2021-09-01 16:21:32,236 - INFO -
# Algorithm: FedNova
# Client Split: [2, 3, 4]
# Dataset: cifar10
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 16:21:32,241 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 16:21:41,181 - INFO -   |-- [Party 1] Average Train Loss:   1.0180 Train Accuracy: global   0.00% local  77.45% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:21:41,184 - INFO -   |--    Epoch Losses (10): [2.1306, 1.5274, 1.1841, 0.995, 0.8684, 0.7831, 0.7274, 0.6864, 0.6479, 0.6294]
# 2021-09-01 16:21:48,122 - INFO -   |-- [Party 2] Average Train Loss:   1.0116 Train Accuracy: global   0.00% local  77.45% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:21:48,125 - INFO -   |--    Epoch Losses (10): [2.1264, 1.5287, 1.1764, 0.9865, 0.8548, 0.7799, 0.7262, 0.6755, 0.6478, 0.6137]
# 2021-09-01 16:21:55,274 - INFO -   |-- [Party 3] Average Train Loss:   1.1099 Train Accuracy: global   0.00% local  66.60% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:21:55,278 - INFO -   |--    Epoch Losses (10): [2.1967, 1.6027, 1.2666, 1.0785, 0.9667, 0.8806, 0.8237, 0.7885, 0.7592, 0.7358]
# 2021-09-01 16:22:02,746 - INFO -   |-- [Party 4] Average Train Loss:   1.1128 Train Accuracy: global   0.00% local  70.66% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:22:02,748 - INFO -   |--    Epoch Losses (10): [2.1987, 1.6084, 1.2669, 1.0818, 0.9658, 0.8869, 0.8304, 0.7924, 0.7561, 0.7401]
# 2021-09-01 16:22:09,882 - INFO -   |-- [Party 5] Average Train Loss:   1.1164 Train Accuracy: global   0.00% local  67.65% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:22:09,885 - INFO -   |--    Epoch Losses (10): [2.1945, 1.6072, 1.2728, 1.0773, 0.9709, 0.8899, 0.8427, 0.7942, 0.7703, 0.7446]
# 2021-09-01 16:22:17,174 - INFO -   |-- [Party 6] Average Train Loss:   0.9839 Train Accuracy: global  50.00% local  75.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:22:17,175 - INFO -   |--    Epoch Losses (10): [1.8751, 1.4074, 1.1284, 0.9668, 0.8722, 0.7982, 0.7503, 0.7026, 0.6792, 0.6583]
# 2021-09-01 16:22:24,574 - INFO -   |-- [Party 7] Average Train Loss:   0.9625 Train Accuracy: global  50.00% local  76.75% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:22:24,577 - INFO -   |--    Epoch Losses (10): [1.8761, 1.397, 1.114, 0.9569, 0.8389, 0.7783, 0.7167, 0.6791, 0.6482, 0.6199]
# 2021-09-01 16:22:32,058 - INFO -   |-- [Party 8] Average Train Loss:   0.9776 Train Accuracy: global  50.00% local  75.49% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:22:32,060 - INFO -   |--    Epoch Losses (10): [1.8811, 1.3967, 1.1268, 0.9642, 0.8567, 0.7908, 0.7396, 0.7094, 0.6717, 0.6393]
# 2021-09-01 16:22:39,624 - INFO -   |-- [Party 9] Average Train Loss:   0.9796 Train Accuracy: global  50.00% local  74.58% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 16:22:39,625 - INFO -   |--    Epoch Losses (10): [1.8631, 1.4097, 1.1333, 0.9618, 0.861, 0.7976, 0.7398, 0.7039, 0.6784, 0.6473]
# 2021-09-01 16:22:44,538 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 16:22:44,541 - INFO -     |---- Train Accuracy: 31.51%
# 2021-09-01 16:22:44,542 - INFO -     |---- Test Accuracy: 23.53%
# 2021-09-01 16:22:44,543 - INFO -     |---- Test Loss: 1.9939
# 2021-09-01 16:22:44,544 - INFO -     |---- Elapsed time: 0:01:12.304189
# 2021-09-01 16:22:44,546 - INFO -
# Test Acc: Max 23.5333% (1 round) | Last 23.5333% | Avg 23.5333% (1 round)
#
# 2021-09-01 16:22:44,548 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 16:22:51,910 - INFO -   |-- [Party 1] Average Train Loss:   0.9460 Train Accuracy: global   0.00% local  77.31% ... 1106 forgettables out of 1428 (77.45%) ... total data used 1428
# 2021-09-01 16:22:51,911 - INFO -   |--    Epoch Losses (10): [2.0297, 1.411, 1.0799, 0.8977, 0.8005, 0.7292, 0.6859, 0.6373, 0.603, 0.5858]
# 2021-09-01 16:22:58,865 - INFO -   |-- [Party 2] Average Train Loss:   0.9404 Train Accuracy: global   0.00% local  79.48% ... 1106 forgettables out of 1428 (77.45%) ... total data used 1428
# 2021-09-01 16:22:58,866 - INFO -   |--    Epoch Losses (10): [2.0396, 1.4119, 1.0809, 0.886, 0.7849, 0.7203, 0.6628, 0.6342, 0.6007, 0.583]
# 2021-09-01 16:23:05,980 - INFO -   |-- [Party 3] Average Train Loss:   0.9693 Train Accuracy: global   0.07% local  69.47% ...  950 forgettables out of 1428 (66.53%) ... total data used 1428
# 2021-09-01 16:23:05,982 - INFO -   |--    Epoch Losses (10): [1.764, 1.3084, 1.0724, 0.9456, 0.8652, 0.8144, 0.7707, 0.7341, 0.723, 0.6951]
# 2021-09-01 16:23:13,180 - INFO -   |-- [Party 4] Average Train Loss:   0.9668 Train Accuracy: global   0.07% local  70.80% ... 1008 forgettables out of 1428 (70.59%) ... total data used 1428
# 2021-09-01 16:23:13,182 - INFO -   |--    Epoch Losses (10): [1.7637, 1.3195, 1.0832, 0.9472, 0.8562, 0.8049, 0.7615, 0.7307, 0.7092, 0.6921]
# 2021-09-01 16:23:20,488 - INFO -   |-- [Party 5] Average Train Loss:   0.9764 Train Accuracy: global   0.14% local  69.05% ...  964 forgettables out of 1428 (67.51%) ... total data used 1428
# 2021-09-01 16:23:20,491 - INFO -   |--    Epoch Losses (10): [1.7651, 1.3147, 1.0804, 0.9565, 0.8734, 0.8161, 0.7785, 0.7555, 0.7202, 0.703]
# 2021-09-01 16:23:27,478 - INFO -   |-- [Party 6] Average Train Loss:   0.7949 Train Accuracy: global  69.05% local  76.19% ...  189 forgettables out of 1428 (13.24%) ... total data used 1428
# 2021-09-01 16:23:27,482 - INFO -   |--    Epoch Losses (10): [1.3145, 1.0379, 0.8915, 0.7923, 0.7334, 0.6947, 0.6577, 0.627, 0.6052, 0.595]
# 2021-09-01 16:23:34,464 - INFO -   |-- [Party 7] Average Train Loss:   0.7733 Train Accuracy: global  71.15% local  77.59% ...  180 forgettables out of 1428 (12.61%) ... total data used 1428
# 2021-09-01 16:23:34,466 - INFO -   |--    Epoch Losses (10): [1.3052, 1.0243, 0.8569, 0.7726, 0.7106, 0.6615, 0.6356, 0.5997, 0.5848, 0.5817]
# 2021-09-01 16:23:41,756 - INFO -   |-- [Party 8] Average Train Loss:   0.7925 Train Accuracy: global  71.29% local  77.45% ...  164 forgettables out of 1428 (11.48%) ... total data used 1428
# 2021-09-01 16:23:41,759 - INFO -   |--    Epoch Losses (10): [1.3053, 1.0384, 0.8911, 0.7984, 0.7323, 0.6764, 0.6552, 0.6261, 0.6086, 0.593]
# 2021-09-01 16:23:48,768 - INFO -   |-- [Party 9] Average Train Loss:   0.7967 Train Accuracy: global  68.91% local  75.49% ...  197 forgettables out of 1428 (13.80%) ... total data used 1428
# 2021-09-01 16:23:48,771 - INFO -   |--    Epoch Losses (10): [1.3048, 1.0381, 0.8797, 0.7927, 0.7369, 0.6981, 0.6573, 0.6298, 0.6199, 0.6098]
# 2021-09-01 16:23:53,487 - INFO -     |---- Number of Forgettables: 5864 (45.63%)
# 2021-09-01 16:23:53,488 - INFO -     |---- Train Accuracy: 33.32%
# 2021-09-01 16:23:53,489 - INFO -     |---- Test Accuracy: 23.80%
# 2021-09-01 16:23:53,490 - INFO -     |---- Test Loss: 1.8737
# 2021-09-01 16:23:53,490 - INFO -     |---- Elapsed time: 0:02:21.250467
# 2021-09-01 16:23:53,492 - INFO -
# Test Acc: Max 23.8000% (2 round) | Last 23.8000% | Avg 23.6667% (2 round)
#
# 2021-09-01 16:23:53,494 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 16:24:01,051 - INFO -   |-- [Party 1] Average Train Loss:   0.8970 Train Accuracy: global   0.00% local  79.06% ... 1104 forgettables out of 1428 (77.31%) ... total data used 1428
# 2021-09-01 16:24:01,053 - INFO -   |--    Epoch Losses (10): [1.9712, 1.3291, 1.0063, 0.8424, 0.7465, 0.6938, 0.6385, 0.5925, 0.5889, 0.5612]
# 2021-09-01 16:24:08,463 - INFO -   |-- [Party 2] Average Train Loss:   0.8878 Train Accuracy: global   0.00% local  79.27% ... 1135 forgettables out of 1428 (79.48%) ... total data used 1428
# 2021-09-01 16:24:08,466 - INFO -   |--    Epoch Losses (10): [1.972, 1.3267, 0.9994, 0.8277, 0.7248, 0.6627, 0.6452, 0.5902, 0.5746, 0.5547]
# 2021-09-01 16:24:15,368 - INFO -   |-- [Party 3] Average Train Loss:   0.9024 Train Accuracy: global   0.49% local  69.68% ...  985 forgettables out of 1428 (68.98%) ... total data used 1428
# 2021-09-01 16:24:15,370 - INFO -   |--    Epoch Losses (10): [1.6127, 1.1954, 0.991, 0.8804, 0.8075, 0.7664, 0.7263, 0.6974, 0.6819, 0.6644]
# 2021-09-01 16:24:22,366 - INFO -   |-- [Party 4] Average Train Loss:   0.8977 Train Accuracy: global   0.35% local  71.71% ... 1006 forgettables out of 1428 (70.45%) ... total data used 1428
# 2021-09-01 16:24:22,367 - INFO -   |--    Epoch Losses (10): [1.6117, 1.1971, 0.9906, 0.8799, 0.8109, 0.7629, 0.7242, 0.6835, 0.6652, 0.6512]
# 2021-09-01 16:24:29,693 - INFO -   |-- [Party 5] Average Train Loss:   0.9100 Train Accuracy: global   0.42% local  70.45% ...  980 forgettables out of 1428 (68.63%) ... total data used 1428
# 2021-09-01 16:24:29,694 - INFO -   |--    Epoch Losses (10): [1.6129, 1.2036, 1.0013, 0.884, 0.817, 0.7695, 0.731, 0.7129, 0.6868, 0.6815]
# 2021-09-01 16:24:36,621 - INFO -   |-- [Party 6] Average Train Loss:   0.7312 Train Accuracy: global  74.09% local  77.59% ...  100 forgettables out of 1428 ( 7.00%) ... total data used 1428
# 2021-09-01 16:24:36,625 - INFO -   |--    Epoch Losses (10): [1.1543, 0.9287, 0.8083, 0.7205, 0.6757, 0.6407, 0.621, 0.6206, 0.5773, 0.5653]
# 2021-09-01 16:24:44,079 - INFO -   |-- [Party 7] Average Train Loss:   0.7071 Train Accuracy: global  76.33% local  78.64% ...  107 forgettables out of 1428 ( 7.49%) ... total data used 1428
# 2021-09-01 16:24:44,081 - INFO -   |--    Epoch Losses (10): [1.1454, 0.913, 0.7691, 0.7079, 0.6649, 0.6011, 0.5983, 0.5746, 0.5597, 0.5374]
# 2021-09-01 16:24:51,099 - INFO -   |-- [Party 8] Average Train Loss:   0.7278 Train Accuracy: global  75.91% local  78.99% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:24:51,102 - INFO -   |--    Epoch Losses (10): [1.1633, 0.9219, 0.8019, 0.7246, 0.6741, 0.6449, 0.6304, 0.6012, 0.56, 0.5557]
# 2021-09-01 16:24:58,040 - INFO -   |-- [Party 9] Average Train Loss:   0.7398 Train Accuracy: global  73.88% local  77.17% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:24:58,042 - INFO -   |--    Epoch Losses (10): [1.1551, 0.9364, 0.8201, 0.7207, 0.7102, 0.6506, 0.6289, 0.6046, 0.6033, 0.568]
# 2021-09-01 16:25:02,856 - INFO -     |---- Number of Forgettables: 5609 (43.64%)
# 2021-09-01 16:25:02,860 - INFO -     |---- Train Accuracy: 34.77%
# 2021-09-01 16:25:02,861 - INFO -     |---- Test Accuracy: 25.33%
# 2021-09-01 16:25:02,861 - INFO -     |---- Test Loss: 1.8059
# 2021-09-01 16:25:02,862 - INFO -     |---- Elapsed time: 0:03:30.622225
# 2021-09-01 16:25:02,863 - INFO -
# Test Acc: Max 25.3333% (3 round) | Last 25.3333% | Avg 24.2222% (3 round)
#
# 2021-09-01 16:25:02,866 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 16:25:09,857 - INFO -   |-- [Party 1] Average Train Loss:   0.8548 Train Accuracy: global   0.00% local  80.39% ... 1129 forgettables out of 1428 (79.06%) ... total data used 1428
# 2021-09-01 16:25:09,861 - INFO -   |--    Epoch Losses (10): [1.9026, 1.2608, 0.9391, 0.7918, 0.7077, 0.6515, 0.6113, 0.5737, 0.5557, 0.5542]
# 2021-09-01 16:25:16,867 - INFO -   |-- [Party 2] Average Train Loss:   0.8439 Train Accuracy: global   0.00% local  80.81% ... 1132 forgettables out of 1428 (79.27%) ... total data used 1428
# 2021-09-01 16:25:16,870 - INFO -   |--    Epoch Losses (10): [1.9077, 1.2568, 0.9478, 0.7828, 0.6849, 0.6302, 0.5964, 0.5739, 0.5382, 0.5201]
# 2021-09-01 16:25:24,235 - INFO -   |-- [Party 3] Average Train Loss:   0.8652 Train Accuracy: global   3.15% local  71.50% ...  950 forgettables out of 1428 (66.53%) ... total data used 1428
# 2021-09-01 16:25:24,236 - INFO -   |--    Epoch Losses (10): [1.5246, 1.1266, 0.9435, 0.8372, 0.7816, 0.7388, 0.7047, 0.6736, 0.6756, 0.6453]
# 2021-09-01 16:25:31,417 - INFO -   |-- [Party 4] Average Train Loss:   0.8560 Train Accuracy: global   3.01% local  73.53% ...  983 forgettables out of 1428 (68.84%) ... total data used 1428
# 2021-09-01 16:25:31,419 - INFO -   |--    Epoch Losses (10): [1.53, 1.1297, 0.9446, 0.8262, 0.7631, 0.7328, 0.6804, 0.6696, 0.6422, 0.6414]
# 2021-09-01 16:25:38,793 - INFO -   |-- [Party 5] Average Train Loss:   0.8690 Train Accuracy: global   2.31% local  72.62% ...  973 forgettables out of 1428 (68.14%) ... total data used 1428
# 2021-09-01 16:25:38,795 - INFO -   |--    Epoch Losses (10): [1.5376, 1.1403, 0.9415, 0.8393, 0.777, 0.744, 0.7229, 0.681, 0.6519, 0.6542]
# 2021-09-01 16:25:45,878 - INFO -   |-- [Party 6] Average Train Loss:   0.6914 Train Accuracy: global  75.14% local  78.57% ...  101 forgettables out of 1428 ( 7.07%) ... total data used 1428
# 2021-09-01 16:25:45,879 - INFO -   |--    Epoch Losses (10): [1.1115, 0.8773, 0.7619, 0.689, 0.6354, 0.6087, 0.5796, 0.5629, 0.5491, 0.539]
# 2021-09-01 16:25:53,412 - INFO -   |-- [Party 7] Average Train Loss:   0.6694 Train Accuracy: global  77.24% local  80.39% ...   85 forgettables out of 1428 ( 5.95%) ... total data used 1428
# 2021-09-01 16:25:53,413 - INFO -   |--    Epoch Losses (10): [1.0824, 0.851, 0.7431, 0.6591, 0.6204, 0.5717, 0.5641, 0.5493, 0.5334, 0.5191]
# 2021-09-01 16:26:00,620 - INFO -   |-- [Party 8] Average Train Loss:   0.6900 Train Accuracy: global  77.10% local  79.20% ...  103 forgettables out of 1428 ( 7.21%) ... total data used 1428
# 2021-09-01 16:26:00,622 - INFO -   |--    Epoch Losses (10): [1.0953, 0.8663, 0.7478, 0.6983, 0.6462, 0.6187, 0.5844, 0.5655, 0.5471, 0.5306]
# 2021-09-01 16:26:08,036 - INFO -   |-- [Party 9] Average Train Loss:   0.6951 Train Accuracy: global  74.44% local  78.15% ...  103 forgettables out of 1428 ( 7.21%) ... total data used 1428
# 2021-09-01 16:26:08,038 - INFO -   |--    Epoch Losses (10): [1.104, 0.8726, 0.748, 0.6939, 0.6621, 0.6068, 0.5855, 0.5694, 0.5697, 0.5395]
# 2021-09-01 16:26:12,692 - INFO -     |---- Number of Forgettables: 5559 (43.25%)
# 2021-09-01 16:26:12,693 - INFO -     |---- Train Accuracy: 36.61%
# 2021-09-01 16:26:12,694 - INFO -     |---- Test Accuracy: 27.32%
# 2021-09-01 16:26:12,695 - INFO -     |---- Test Loss: 1.7549
# 2021-09-01 16:26:12,696 - INFO -     |---- Elapsed time: 0:04:40.456084
# 2021-09-01 16:26:12,697 - INFO -
# Test Acc: Max 27.3167% (4 round) | Last 27.3167% | Avg 24.9958% (3 round)
#
# 2021-09-01 16:26:12,701 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 16:26:20,184 - INFO -   |-- [Party 1] Average Train Loss:   0.8251 Train Accuracy: global   0.00% local  80.88% ... 1148 forgettables out of 1428 (80.39%) ... total data used 1428
# 2021-09-01 16:26:20,186 - INFO -   |--    Epoch Losses (10): [1.8468, 1.2011, 0.9146, 0.7642, 0.6783, 0.6178, 0.5803, 0.5675, 0.5527, 0.5274]
# 2021-09-01 16:26:27,278 - INFO -   |-- [Party 2] Average Train Loss:   0.8103 Train Accuracy: global   0.00% local  81.51% ... 1154 forgettables out of 1428 (80.81%) ... total data used 1428
# 2021-09-01 16:26:27,279 - INFO -   |--    Epoch Losses (10): [1.8423, 1.1984, 0.8954, 0.7558, 0.6542, 0.6197, 0.5669, 0.5438, 0.5125, 0.5139]
# 2021-09-01 16:26:34,293 - INFO -   |-- [Party 3] Average Train Loss:   0.8363 Train Accuracy: global   7.70% local  71.78% ...  912 forgettables out of 1428 (63.87%) ... total data used 1428
# 2021-09-01 16:26:34,296 - INFO -   |--    Epoch Losses (10): [1.4746, 1.0833, 0.9062, 0.8037, 0.7514, 0.7108, 0.6933, 0.6591, 0.6511, 0.6295]
# 2021-09-01 16:26:41,858 - INFO -   |-- [Party 4] Average Train Loss:   0.8224 Train Accuracy: global   6.86% local  74.09% ...  952 forgettables out of 1428 (66.67%) ... total data used 1428
# 2021-09-01 16:26:41,862 - INFO -   |--    Epoch Losses (10): [1.4706, 1.0788, 0.8997, 0.7922, 0.7322, 0.698, 0.6768, 0.6439, 0.6303, 0.6019]
# 2021-09-01 16:26:49,231 - INFO -   |-- [Party 5] Average Train Loss:   0.8377 Train Accuracy: global   4.76% local  72.90% ...  969 forgettables out of 1428 (67.86%) ... total data used 1428
# 2021-09-01 16:26:49,235 - INFO -   |--    Epoch Losses (10): [1.4812, 1.0916, 0.8967, 0.8098, 0.7439, 0.7149, 0.6823, 0.6633, 0.6529, 0.6408]
# 2021-09-01 16:26:56,156 - INFO -   |-- [Party 6] Average Train Loss:   0.6672 Train Accuracy: global  76.12% local  79.90% ...  100 forgettables out of 1428 ( 7.00%) ... total data used 1428
# 2021-09-01 16:26:56,160 - INFO -   |--    Epoch Losses (10): [1.0564, 0.8378, 0.7436, 0.6543, 0.6317, 0.5918, 0.565, 0.5499, 0.5166, 0.5252]
# 2021-09-01 16:27:03,403 - INFO -   |-- [Party 7] Average Train Loss:   0.6444 Train Accuracy: global  77.52% local  81.30% ...  104 forgettables out of 1428 ( 7.28%) ... total data used 1428
# 2021-09-01 16:27:03,406 - INFO -   |--    Epoch Losses (10): [1.0408, 0.8213, 0.7077, 0.6305, 0.59, 0.5777, 0.5515, 0.5267, 0.5094, 0.4887]
# 2021-09-01 16:27:10,420 - INFO -   |-- [Party 8] Average Train Loss:   0.6539 Train Accuracy: global  76.89% local  80.25% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:27:10,422 - INFO -   |--    Epoch Losses (10): [1.0585, 0.8288, 0.7168, 0.6461, 0.615, 0.5867, 0.5394, 0.5247, 0.5213, 0.5013]
# 2021-09-01 16:27:17,320 - INFO -   |-- [Party 9] Average Train Loss:   0.6725 Train Accuracy: global  75.91% local  79.27% ...   83 forgettables out of 1428 ( 5.81%) ... total data used 1428
# 2021-09-01 16:27:17,322 - INFO -   |--    Epoch Losses (10): [1.0566, 0.8305, 0.7409, 0.6737, 0.6208, 0.5867, 0.57, 0.5743, 0.532, 0.5393]
# 2021-09-01 16:27:22,007 - INFO -     |---- Number of Forgettables: 5518 (42.93%)
# 2021-09-01 16:27:22,009 - INFO -     |---- Train Accuracy: 37.56%
# 2021-09-01 16:27:22,010 - INFO -     |---- Test Accuracy: 28.20%
# 2021-09-01 16:27:22,011 - INFO -     |---- Test Loss: 1.7210
# 2021-09-01 16:27:22,012 - INFO -     |---- Elapsed time: 0:05:49.771833
# 2021-09-01 16:27:22,013 - INFO -
# Test Acc: Max 28.2000% (5 round) | Last 28.2000% | Avg 25.6367% (4 round)
#
# 2021-09-01 16:27:22,015 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 16:27:29,401 - INFO -   |-- [Party 1] Average Train Loss:   0.8014 Train Accuracy: global   0.00% local  80.74% ... 1155 forgettables out of 1428 (80.88%) ... total data used 1428
# 2021-09-01 16:27:29,402 - INFO -   |--    Epoch Losses (10): [1.7912, 1.168, 0.87, 0.7352, 0.6623, 0.6162, 0.5827, 0.5375, 0.5338, 0.5169]
# 2021-09-01 16:27:36,771 - INFO -   |-- [Party 2] Average Train Loss:   0.7874 Train Accuracy: global   0.00% local  82.56% ... 1164 forgettables out of 1428 (81.51%) ... total data used 1428
# 2021-09-01 16:27:36,772 - INFO -   |--    Epoch Losses (10): [1.7885, 1.1618, 0.8682, 0.7303, 0.6414, 0.5768, 0.5634, 0.5272, 0.5192, 0.4975]
# 2021-09-01 16:27:44,398 - INFO -   |-- [Party 3] Average Train Loss:   0.8181 Train Accuracy: global   9.87% local  72.48% ...  885 forgettables out of 1428 (61.97%) ... total data used 1428
# 2021-09-01 16:27:44,398 - INFO -   |--    Epoch Losses (10): [1.436, 1.0515, 0.8846, 0.7922, 0.7274, 0.7047, 0.6679, 0.6522, 0.6341, 0.63]
# 2021-09-01 16:27:51,396 - INFO -   |-- [Party 4] Average Train Loss:   0.8001 Train Accuracy: global   9.45% local  74.86% ...  925 forgettables out of 1428 (64.78%) ... total data used 1428
# 2021-09-01 16:27:51,400 - INFO -   |--    Epoch Losses (10): [1.4318, 1.0469, 0.8705, 0.7644, 0.7119, 0.675, 0.6535, 0.6369, 0.6052, 0.6048]
# 2021-09-01 16:27:58,910 - INFO -   |-- [Party 5] Average Train Loss:   0.8181 Train Accuracy: global   7.42% local  73.67% ...  935 forgettables out of 1428 (65.48%) ... total data used 1428
# 2021-09-01 16:27:58,913 - INFO -   |--    Epoch Losses (10): [1.451, 1.0572, 0.8787, 0.7862, 0.739, 0.7066, 0.6568, 0.6489, 0.6434, 0.6132]
# 2021-09-01 16:28:06,402 - INFO -   |-- [Party 6] Average Train Loss:   0.6408 Train Accuracy: global  79.34% local  82.00% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 16:28:06,405 - INFO -   |--    Epoch Losses (10): [1.0254, 0.8209, 0.6957, 0.6357, 0.6083, 0.5629, 0.534, 0.5331, 0.5076, 0.4847]
# 2021-09-01 16:28:13,287 - INFO -   |-- [Party 7] Average Train Loss:   0.6145 Train Accuracy: global  80.39% local  82.42% ...   92 forgettables out of 1428 ( 6.44%) ... total data used 1428
# 2021-09-01 16:28:13,289 - INFO -   |--    Epoch Losses (10): [1.0121, 0.7663, 0.6678, 0.6026, 0.5725, 0.5343, 0.5108, 0.5049, 0.4881, 0.4857]
# 2021-09-01 16:28:20,358 - INFO -   |-- [Party 8] Average Train Loss:   0.6272 Train Accuracy: global  77.17% local  81.30% ...  101 forgettables out of 1428 ( 7.07%) ... total data used 1428
# 2021-09-01 16:28:20,362 - INFO -   |--    Epoch Losses (10): [1.0166, 0.7991, 0.6783, 0.6222, 0.577, 0.541, 0.5208, 0.5166, 0.5049, 0.4959]
# 2021-09-01 16:28:27,490 - INFO -   |-- [Party 9] Average Train Loss:   0.6434 Train Accuracy: global  76.89% local  80.25% ...   89 forgettables out of 1428 ( 6.23%) ... total data used 1428
# 2021-09-01 16:28:27,492 - INFO -   |--    Epoch Losses (10): [1.0147, 0.7996, 0.6917, 0.642, 0.5878, 0.5662, 0.5503, 0.5324, 0.54, 0.5093]
# 2021-09-01 16:28:32,085 - INFO -     |---- Number of Forgettables: 5421 (42.18%)
# 2021-09-01 16:28:32,087 - INFO -     |---- Train Accuracy: 38.05%
# 2021-09-01 16:28:32,088 - INFO -     |---- Test Accuracy: 29.12%
# 2021-09-01 16:28:32,089 - INFO -     |---- Test Loss: 1.6954
# 2021-09-01 16:28:32,090 - INFO -     |---- Elapsed time: 0:06:59.849779
# 2021-09-01 16:28:32,091 - INFO -
# Test Acc: Max 29.1167% (6 round) | Last 29.1167% | Avg 26.2167% (4 round)
#
# 2021-09-01 16:28:32,094 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 16:28:39,961 - INFO -   |-- [Party 1] Average Train Loss:   0.7764 Train Accuracy: global   0.00% local  81.93% ... 1153 forgettables out of 1428 (80.74%) ... total data used 1428
# 2021-09-01 16:28:39,963 - INFO -   |--    Epoch Losses (10): [1.749, 1.1238, 0.8516, 0.7034, 0.6479, 0.5783, 0.5633, 0.533, 0.5178, 0.4965]
# 2021-09-01 16:28:46,953 - INFO -   |-- [Party 2] Average Train Loss:   0.7578 Train Accuracy: global   0.00% local  83.12% ... 1179 forgettables out of 1428 (82.56%) ... total data used 1428
# 2021-09-01 16:28:46,957 - INFO -   |--    Epoch Losses (10): [1.7396, 1.1098, 0.833, 0.6844, 0.6325, 0.5741, 0.5275, 0.5043, 0.5007, 0.4717]
# 2021-09-01 16:28:53,868 - INFO -   |-- [Party 3] Average Train Loss:   0.7946 Train Accuracy: global  10.71% local  74.37% ...  884 forgettables out of 1428 (61.90%) ... total data used 1428
# 2021-09-01 16:28:53,872 - INFO -   |--    Epoch Losses (10): [1.406, 1.0129, 0.8512, 0.7652, 0.7152, 0.6712, 0.6566, 0.6384, 0.6172, 0.6121]
# 2021-09-01 16:29:00,893 - INFO -   |-- [Party 4] Average Train Loss:   0.7819 Train Accuracy: global  10.71% local  75.70% ...  918 forgettables out of 1428 (64.29%) ... total data used 1428
# 2021-09-01 16:29:00,896 - INFO -   |--    Epoch Losses (10): [1.4057, 1.0101, 0.8397, 0.7561, 0.6948, 0.6734, 0.6361, 0.6271, 0.6004, 0.5754]
# 2021-09-01 16:29:08,336 - INFO -   |-- [Party 5] Average Train Loss:   0.7945 Train Accuracy: global   9.94% local  74.51% ...  911 forgettables out of 1428 (63.80%) ... total data used 1428
# 2021-09-01 16:29:08,338 - INFO -   |--    Epoch Losses (10): [1.3976, 1.0291, 0.8508, 0.7646, 0.72, 0.6809, 0.6381, 0.6312, 0.6185, 0.6142]
# 2021-09-01 16:29:15,815 - INFO -   |-- [Party 6] Average Train Loss:   0.6134 Train Accuracy: global  77.80% local  81.72% ...  110 forgettables out of 1428 ( 7.70%) ... total data used 1428
# 2021-09-01 16:29:15,816 - INFO -   |--    Epoch Losses (10): [0.9993, 0.7797, 0.6763, 0.6231, 0.5688, 0.5382, 0.5082, 0.4948, 0.4838, 0.4619]
# 2021-09-01 16:29:23,422 - INFO -   |-- [Party 7] Average Train Loss:   0.5974 Train Accuracy: global  78.36% local  82.98% ...  113 forgettables out of 1428 ( 7.91%) ... total data used 1428
# 2021-09-01 16:29:23,423 - INFO -   |--    Epoch Losses (10): [0.9645, 0.7609, 0.6629, 0.5977, 0.5396, 0.5207, 0.498, 0.4955, 0.4662, 0.4684]
# 2021-09-01 16:29:30,878 - INFO -   |-- [Party 8] Average Train Loss:   0.6086 Train Accuracy: global  78.71% local  82.49% ...   97 forgettables out of 1428 ( 6.79%) ... total data used 1428
# 2021-09-01 16:29:30,882 - INFO -   |--    Epoch Losses (10): [0.9928, 0.7859, 0.6666, 0.6038, 0.5658, 0.5372, 0.5034, 0.4914, 0.4735, 0.4658]
# 2021-09-01 16:29:38,044 - INFO -   |-- [Party 9] Average Train Loss:   0.6314 Train Accuracy: global  77.52% local  81.23% ...   91 forgettables out of 1428 ( 6.37%) ... total data used 1428
# 2021-09-01 16:29:38,045 - INFO -   |--    Epoch Losses (10): [1.0178, 0.7895, 0.6913, 0.6319, 0.6027, 0.5459, 0.5272, 0.5242, 0.4918, 0.4921]
# 2021-09-01 16:29:42,697 - INFO -     |---- Number of Forgettables: 5456 (42.45%)
# 2021-09-01 16:29:42,698 - INFO -     |---- Train Accuracy: 39.43%
# 2021-09-01 16:29:42,699 - INFO -     |---- Test Accuracy: 30.03%
# 2021-09-01 16:29:42,700 - INFO -     |---- Test Loss: 1.6687
# 2021-09-01 16:29:42,700 - INFO -     |---- Elapsed time: 0:08:10.460544
# 2021-09-01 16:29:42,701 - INFO -
# Test Acc: Max 30.0333% (7 round) | Last 30.0333% | Avg 26.7619% (4 round)
#
# 2021-09-01 16:29:42,703 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 16:29:49,638 - INFO -   |-- [Party 1] Average Train Loss:   0.7578 Train Accuracy: global   0.00% local  82.14% ... 1170 forgettables out of 1428 (81.93%) ... total data used 1428
# 2021-09-01 16:29:49,640 - INFO -   |--    Epoch Losses (10): [1.7248, 1.1039, 0.8307, 0.6781, 0.6203, 0.575, 0.5345, 0.5119, 0.4968, 0.5018]
# 2021-09-01 16:29:57,203 - INFO -   |-- [Party 2] Average Train Loss:   0.7370 Train Accuracy: global   0.00% local  83.82% ... 1187 forgettables out of 1428 (83.12%) ... total data used 1428
# 2021-09-01 16:29:57,205 - INFO -   |--    Epoch Losses (10): [1.7065, 1.0637, 0.7981, 0.6731, 0.5985, 0.5546, 0.5246, 0.488, 0.497, 0.4661]
# 2021-09-01 16:30:04,822 - INFO -   |-- [Party 3] Average Train Loss:   0.7896 Train Accuracy: global  11.55% local  73.11% ...  898 forgettables out of 1428 (62.89%) ... total data used 1428
# 2021-09-01 16:30:04,824 - INFO -   |--    Epoch Losses (10): [1.3825, 1.0094, 0.8401, 0.777, 0.696, 0.6728, 0.6477, 0.6277, 0.6332, 0.6095]
# 2021-09-01 16:30:12,040 - INFO -   |-- [Party 4] Average Train Loss:   0.7608 Train Accuracy: global  12.54% local  75.28% ...  904 forgettables out of 1428 (63.31%) ... total data used 1428
# 2021-09-01 16:30:12,042 - INFO -   |--    Epoch Losses (10): [1.364, 0.9894, 0.8341, 0.7243, 0.6881, 0.6473, 0.6154, 0.6022, 0.5707, 0.572]
# 2021-09-01 16:30:18,928 - INFO -   |-- [Party 5] Average Train Loss:   0.7821 Train Accuracy: global  11.13% local  76.05% ...  906 forgettables out of 1428 (63.45%) ... total data used 1428
# 2021-09-01 16:30:18,931 - INFO -   |--    Epoch Losses (10): [1.3765, 1.0105, 0.8406, 0.7548, 0.705, 0.6597, 0.6437, 0.6259, 0.6108, 0.5933]
# 2021-09-01 16:30:25,805 - INFO -   |-- [Party 6] Average Train Loss:   0.5991 Train Accuracy: global  78.22% local  83.26% ...  111 forgettables out of 1428 ( 7.77%) ... total data used 1428
# 2021-09-01 16:30:25,808 - INFO -   |--    Epoch Losses (10): [0.9599, 0.7562, 0.6664, 0.5854, 0.5531, 0.5422, 0.5022, 0.4869, 0.4739, 0.465]
# 2021-09-01 16:30:32,860 - INFO -   |-- [Party 7] Average Train Loss:   0.5848 Train Accuracy: global  79.48% local  82.35% ...  102 forgettables out of 1428 ( 7.14%) ... total data used 1428
# 2021-09-01 16:30:32,862 - INFO -   |--    Epoch Losses (10): [0.9627, 0.7269, 0.6448, 0.584, 0.5485, 0.5205, 0.4901, 0.4663, 0.4583, 0.4462]
# 2021-09-01 16:30:39,962 - INFO -   |-- [Party 8] Average Train Loss:   0.5855 Train Accuracy: global  78.57% local  82.42% ...  100 forgettables out of 1428 ( 7.00%) ... total data used 1428
# 2021-09-01 16:30:39,965 - INFO -   |--    Epoch Losses (10): [0.9556, 0.7551, 0.6391, 0.5733, 0.532, 0.5091, 0.489, 0.4771, 0.4674, 0.4575]
# 2021-09-01 16:30:47,019 - INFO -   |-- [Party 9] Average Train Loss:   0.6138 Train Accuracy: global  77.59% local  81.09% ...   98 forgettables out of 1428 ( 6.86%) ... total data used 1428
# 2021-09-01 16:30:47,021 - INFO -   |--    Epoch Losses (10): [0.984, 0.7737, 0.6714, 0.6279, 0.5696, 0.5224, 0.5119, 0.502, 0.486, 0.4887]
# 2021-09-01 16:30:51,721 - INFO -     |---- Number of Forgettables: 5476 (42.61%)
# 2021-09-01 16:30:51,722 - INFO -     |---- Train Accuracy: 39.52%
# 2021-09-01 16:30:51,723 - INFO -     |---- Test Accuracy: 30.20%
# 2021-09-01 16:30:51,724 - INFO -     |---- Test Loss: 1.6503
# 2021-09-01 16:30:51,725 - INFO -     |---- Elapsed time: 0:09:19.484951
# 2021-09-01 16:30:51,726 - INFO -
# Test Acc: Max 30.2000% (8 round) | Last 30.2000% | Avg 27.1917% (4 round)
#
# 2021-09-01 16:30:51,729 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 16:30:58,653 - INFO -   |-- [Party 1] Average Train Loss:   0.7426 Train Accuracy: global   0.00% local  81.37% ... 1173 forgettables out of 1428 (82.14%) ... total data used 1428
# 2021-09-01 16:30:58,654 - INFO -   |--    Epoch Losses (10): [1.7041, 1.0799, 0.8006, 0.667, 0.5912, 0.5626, 0.5261, 0.5062, 0.4901, 0.4979]
# 2021-09-01 16:31:05,847 - INFO -   |-- [Party 2] Average Train Loss:   0.7182 Train Accuracy: global   0.00% local  83.05% ... 1197 forgettables out of 1428 (83.82%) ... total data used 1428
# 2021-09-01 16:31:05,850 - INFO -   |--    Epoch Losses (10): [1.683, 1.0456, 0.7945, 0.6445, 0.5654, 0.5401, 0.5187, 0.4898, 0.4567, 0.4437]
# 2021-09-01 16:31:13,089 - INFO -   |-- [Party 3] Average Train Loss:   0.7703 Train Accuracy: global  12.46% local  74.02% ...  869 forgettables out of 1428 (60.85%) ... total data used 1428
# 2021-09-01 16:31:13,091 - INFO -   |--    Epoch Losses (10): [1.365, 0.9913, 0.8136, 0.747, 0.6852, 0.6687, 0.6256, 0.6168, 0.6022, 0.5871]
# 2021-09-01 16:31:20,250 - INFO -   |-- [Party 4] Average Train Loss:   0.7487 Train Accuracy: global  13.45% local  76.89% ...  888 forgettables out of 1428 (62.18%) ... total data used 1428
# 2021-09-01 16:31:20,253 - INFO -   |--    Epoch Losses (10): [1.3449, 0.9618, 0.8016, 0.7142, 0.6688, 0.6296, 0.6154, 0.5959, 0.5838, 0.5708]
# 2021-09-01 16:31:27,565 - INFO -   |-- [Party 5] Average Train Loss:   0.7707 Train Accuracy: global  13.17% local  75.84% ...  899 forgettables out of 1428 (62.96%) ... total data used 1428
# 2021-09-01 16:31:27,567 - INFO -   |--    Epoch Losses (10): [1.3495, 0.9851, 0.8319, 0.7477, 0.7191, 0.6545, 0.6289, 0.605, 0.6083, 0.5769]
# 2021-09-01 16:31:34,698 - INFO -   |-- [Party 6] Average Train Loss:   0.5815 Train Accuracy: global  79.48% local  83.19% ...  105 forgettables out of 1428 ( 7.35%) ... total data used 1428
# 2021-09-01 16:31:34,702 - INFO -   |--    Epoch Losses (10): [0.9577, 0.7274, 0.6427, 0.5862, 0.5413, 0.5013, 0.4873, 0.4786, 0.4533, 0.4389]
# 2021-09-01 16:31:42,252 - INFO -   |-- [Party 7] Average Train Loss:   0.5654 Train Accuracy: global  80.81% local  83.54% ...   87 forgettables out of 1428 ( 6.09%) ... total data used 1428
# 2021-09-01 16:31:42,253 - INFO -   |--    Epoch Losses (10): [0.9242, 0.7037, 0.6063, 0.5593, 0.5156, 0.4903, 0.4602, 0.4529, 0.4568, 0.4851]
# 2021-09-01 16:31:49,315 - INFO -   |-- [Party 8] Average Train Loss:   0.5704 Train Accuracy: global  79.76% local  83.54% ...  102 forgettables out of 1428 ( 7.14%) ... total data used 1428
# 2021-09-01 16:31:49,318 - INFO -   |--    Epoch Losses (10): [0.9393, 0.7238, 0.6135, 0.5653, 0.522, 0.4909, 0.4942, 0.4537, 0.4524, 0.4493]
# 2021-09-01 16:31:56,333 - INFO -   |-- [Party 9] Average Train Loss:   0.5875 Train Accuracy: global  78.01% local  82.35% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:31:56,336 - INFO -   |--    Epoch Losses (10): [0.9467, 0.745, 0.6389, 0.5892, 0.5447, 0.5279, 0.4827, 0.4755, 0.4709, 0.4538]
# 2021-09-01 16:32:00,908 - INFO -     |---- Number of Forgettables: 5416 (42.14%)
# 2021-09-01 16:32:00,911 - INFO -     |---- Train Accuracy: 39.81%
# 2021-09-01 16:32:00,912 - INFO -     |---- Test Accuracy: 30.63%
# 2021-09-01 16:32:00,913 - INFO -     |---- Test Loss: 1.6368
# 2021-09-01 16:32:00,914 - INFO -     |---- Elapsed time: 0:10:28.673804
# 2021-09-01 16:32:00,915 - INFO -
# Test Acc: Max 30.6333% (9 round) | Last 30.6333% | Avg 27.5741% (5 round)
#
# 2021-09-01 16:32:00,920 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 16:32:07,965 - INFO -   |-- [Party 1] Average Train Loss:   0.7365 Train Accuracy: global   0.00% local  83.96% ... 1162 forgettables out of 1428 (81.37%) ... total data used 1428
# 2021-09-01 16:32:07,968 - INFO -   |--    Epoch Losses (10): [1.681, 1.0359, 0.7872, 0.6874, 0.6056, 0.5609, 0.5204, 0.5097, 0.489, 0.4881]
# 2021-09-01 16:32:15,494 - INFO -   |-- [Party 2] Average Train Loss:   0.7054 Train Accuracy: global   0.00% local  84.10% ... 1186 forgettables out of 1428 (83.05%) ... total data used 1428
# 2021-09-01 16:32:15,496 - INFO -   |--    Epoch Losses (10): [1.6428, 1.046, 0.7675, 0.6439, 0.5594, 0.5269, 0.5071, 0.4712, 0.4593, 0.4301]
# 2021-09-01 16:32:22,781 - INFO -   |-- [Party 3] Average Train Loss:   0.7636 Train Accuracy: global  14.01% local  74.37% ...  859 forgettables out of 1428 (60.15%) ... total data used 1428
# 2021-09-01 16:32:22,783 - INFO -   |--    Epoch Losses (10): [1.354, 0.9732, 0.8268, 0.7281, 0.6811, 0.6542, 0.6158, 0.6195, 0.6028, 0.5806]
# 2021-09-01 16:32:30,218 - INFO -   |-- [Party 4] Average Train Loss:   0.7360 Train Accuracy: global  12.75% local  77.03% ...  917 forgettables out of 1428 (64.22%) ... total data used 1428
# 2021-09-01 16:32:30,220 - INFO -   |--    Epoch Losses (10): [1.3142, 0.9571, 0.7839, 0.7065, 0.6538, 0.6251, 0.5928, 0.5985, 0.5802, 0.5477]
# 2021-09-01 16:32:37,504 - INFO -   |-- [Party 5] Average Train Loss:   0.7533 Train Accuracy: global  12.68% local  75.91% ...  903 forgettables out of 1428 (63.24%) ... total data used 1428
# 2021-09-01 16:32:37,507 - INFO -   |--    Epoch Losses (10): [1.3456, 0.9786, 0.8064, 0.7152, 0.6855, 0.6434, 0.6045, 0.5938, 0.5937, 0.5666]
# 2021-09-01 16:32:44,533 - INFO -   |-- [Party 6] Average Train Loss:   0.5758 Train Accuracy: global  79.41% local  83.96% ...  112 forgettables out of 1428 ( 7.84%) ... total data used 1428
# 2021-09-01 16:32:44,535 - INFO -   |--    Epoch Losses (10): [0.93, 0.7276, 0.6332, 0.5705, 0.5224, 0.5001, 0.4925, 0.4746, 0.4563, 0.4504]
# 2021-09-01 16:32:52,054 - INFO -   |-- [Party 7] Average Train Loss:   0.5522 Train Accuracy: global  80.39% local  84.45% ...  108 forgettables out of 1428 ( 7.56%) ... total data used 1428
# 2021-09-01 16:32:52,058 - INFO -   |--    Epoch Losses (10): [0.9096, 0.6847, 0.5938, 0.5356, 0.519, 0.4919, 0.453, 0.4586, 0.4493, 0.4261]
# 2021-09-01 16:32:59,525 - INFO -   |-- [Party 8] Average Train Loss:   0.5575 Train Accuracy: global  80.74% local  84.24% ...   95 forgettables out of 1428 ( 6.65%) ... total data used 1428
# 2021-09-01 16:32:59,529 - INFO -   |--    Epoch Losses (10): [0.9105, 0.7089, 0.6178, 0.5559, 0.5106, 0.4803, 0.4593, 0.4582, 0.4388, 0.4345]
# 2021-09-01 16:33:06,571 - INFO -   |-- [Party 9] Average Train Loss:   0.5804 Train Accuracy: global  79.41% local  82.49% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 16:33:06,572 - INFO -   |--    Epoch Losses (10): [0.9342, 0.7325, 0.6172, 0.5772, 0.5333, 0.5013, 0.4979, 0.4826, 0.4802, 0.4481]
# 2021-09-01 16:33:11,201 - INFO -     |---- Number of Forgettables: 5438 (42.31%)
# 2021-09-01 16:33:11,203 - INFO -     |---- Train Accuracy: 40.13%
# 2021-09-01 16:33:11,203 - INFO -     |---- Test Accuracy: 31.27%
# 2021-09-01 16:33:11,204 - INFO -     |---- Test Loss: 1.6246
# 2021-09-01 16:33:11,204 - INFO -     |---- Elapsed time: 0:11:38.964477
# 2021-09-01 16:33:11,205 - INFO -
# Test Acc: Max 31.2667% (10 round) | Last 31.2667% | Avg 27.9433% (5 round)
#
# 2021-09-01 16:33:11,207 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 16:33:18,715 - INFO -   |-- [Party 1] Average Train Loss:   0.7173 Train Accuracy: global   0.14% local  83.47% ... 1197 forgettables out of 1428 (83.82%) ... total data used 1428
# 2021-09-01 16:33:18,718 - INFO -   |--    Epoch Losses (10): [1.652, 1.0112, 0.7547, 0.6489, 0.5826, 0.5455, 0.535, 0.498, 0.4825, 0.4626]
# 2021-09-01 16:33:25,614 - INFO -   |-- [Party 2] Average Train Loss:   0.6933 Train Accuracy: global   0.00% local  84.38% ... 1201 forgettables out of 1428 (84.10%) ... total data used 1428
# 2021-09-01 16:33:25,617 - INFO -   |--    Epoch Losses (10): [1.6316, 1.0016, 0.7666, 0.6513, 0.5415, 0.52, 0.4851, 0.4642, 0.4462, 0.4244]
# 2021-09-01 16:33:32,883 - INFO -   |-- [Party 3] Average Train Loss:   0.7586 Train Accuracy: global  13.87% local  75.42% ...  868 forgettables out of 1428 (60.78%) ... total data used 1428
# 2021-09-01 16:33:32,885 - INFO -   |--    Epoch Losses (10): [1.3134, 0.9593, 0.8203, 0.7269, 0.6734, 0.642, 0.627, 0.621, 0.6077, 0.5952]
# 2021-09-01 16:33:40,180 - INFO -   |-- [Party 4] Average Train Loss:   0.7199 Train Accuracy: global  13.52% local  77.31% ...  911 forgettables out of 1428 (63.80%) ... total data used 1428
# 2021-09-01 16:33:40,183 - INFO -   |--    Epoch Losses (10): [1.2852, 0.9486, 0.7637, 0.7153, 0.6374, 0.6, 0.5819, 0.5673, 0.5613, 0.5387]
# 2021-09-01 16:33:47,547 - INFO -   |-- [Party 5] Average Train Loss:   0.7494 Train Accuracy: global  14.08% local  77.17% ...  886 forgettables out of 1428 (62.04%) ... total data used 1428
# 2021-09-01 16:33:47,550 - INFO -   |--    Epoch Losses (10): [1.3188, 0.9568, 0.8019, 0.7287, 0.6697, 0.6395, 0.6139, 0.6026, 0.592, 0.5697]
# 2021-09-01 16:33:54,571 - INFO -   |-- [Party 6] Average Train Loss:   0.5592 Train Accuracy: global  79.55% local  85.36% ...  123 forgettables out of 1428 ( 8.61%) ... total data used 1428
# 2021-09-01 16:33:54,574 - INFO -   |--    Epoch Losses (10): [0.9202, 0.7218, 0.6015, 0.5512, 0.5044, 0.4812, 0.4611, 0.4509, 0.4559, 0.4434]
# 2021-09-01 16:34:01,795 - INFO -   |-- [Party 7] Average Train Loss:   0.5390 Train Accuracy: global  79.55% local  84.87% ...  117 forgettables out of 1428 ( 8.19%) ... total data used 1428
# 2021-09-01 16:34:01,797 - INFO -   |--    Epoch Losses (10): [0.8893, 0.6618, 0.5796, 0.5453, 0.4792, 0.4594, 0.448, 0.4516, 0.4362, 0.4394]
# 2021-09-01 16:34:09,154 - INFO -   |-- [Party 8] Average Train Loss:   0.5431 Train Accuracy: global  80.53% local  84.87% ...   86 forgettables out of 1428 ( 6.02%) ... total data used 1428
# 2021-09-01 16:34:09,157 - INFO -   |--    Epoch Losses (10): [0.8955, 0.7011, 0.5916, 0.5345, 0.4931, 0.4657, 0.457, 0.4434, 0.4284, 0.4206]
# 2021-09-01 16:34:16,435 - INFO -   |-- [Party 9] Average Train Loss:   0.5697 Train Accuracy: global  78.22% local  82.14% ...  107 forgettables out of 1428 ( 7.49%) ... total data used 1428
# 2021-09-01 16:34:16,436 - INFO -   |--    Epoch Losses (10): [0.9139, 0.7186, 0.619, 0.5577, 0.5229, 0.5082, 0.4738, 0.4834, 0.4442, 0.4553]
# 2021-09-01 16:34:21,193 - INFO -     |---- Number of Forgettables: 5496 (42.76%)
# 2021-09-01 16:34:21,195 - INFO -     |---- Train Accuracy: 40.73%
# 2021-09-01 16:34:21,196 - INFO -     |---- Test Accuracy: 31.72%
# 2021-09-01 16:34:21,197 - INFO -     |---- Test Loss: 1.6097
# 2021-09-01 16:34:21,197 - INFO -     |---- Elapsed time: 0:12:48.957522
# 2021-09-01 16:34:21,199 - INFO -
# Test Acc: Max 31.7167% (11 round) | Last 31.7167% | Avg 28.2864% (6 round)
#
# 2021-09-01 16:34:21,201 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 16:34:28,518 - INFO -   |-- [Party 1] Average Train Loss:   0.7100 Train Accuracy: global   0.14% local  83.40% ... 1190 forgettables out of 1428 (83.33%) ... total data used 1428
# 2021-09-01 16:34:28,520 - INFO -   |--    Epoch Losses (10): [1.622, 1.0101, 0.7412, 0.6322, 0.5913, 0.5369, 0.5276, 0.515, 0.4564, 0.4668]
# 2021-09-01 16:34:35,941 - INFO -   |-- [Party 2] Average Train Loss:   0.6779 Train Accuracy: global   0.07% local  84.31% ... 1204 forgettables out of 1428 (84.31%) ... total data used 1428
# 2021-09-01 16:34:35,945 - INFO -   |--    Epoch Losses (10): [1.5969, 0.9855, 0.7445, 0.6114, 0.5605, 0.4999, 0.4821, 0.4546, 0.4227, 0.4209]
# 2021-09-01 16:34:43,246 - INFO -   |-- [Party 3] Average Train Loss:   0.7439 Train Accuracy: global  16.25% local  75.84% ...  854 forgettables out of 1428 (59.80%) ... total data used 1428
# 2021-09-01 16:34:43,250 - INFO -   |--    Epoch Losses (10): [1.3093, 0.9344, 0.7725, 0.7172, 0.6865, 0.6418, 0.6082, 0.5957, 0.5983, 0.5745]
# 2021-09-01 16:34:50,590 - INFO -   |-- [Party 4] Average Train Loss:   0.7072 Train Accuracy: global  14.92% local  79.34% ...  893 forgettables out of 1428 (62.54%) ... total data used 1428
# 2021-09-01 16:34:50,591 - INFO -   |--    Epoch Losses (10): [1.2759, 0.9239, 0.763, 0.6876, 0.6286, 0.5937, 0.5687, 0.5567, 0.5444, 0.5293]
# 2021-09-01 16:34:57,477 - INFO -   |-- [Party 5] Average Train Loss:   0.7347 Train Accuracy: global  16.32% local  77.31% ...  871 forgettables out of 1428 (60.99%) ... total data used 1428
# 2021-09-01 16:34:57,479 - INFO -   |--    Epoch Losses (10): [1.3013, 0.936, 0.7804, 0.7264, 0.6602, 0.6304, 0.5915, 0.5867, 0.5783, 0.5559]
# 2021-09-01 16:35:04,777 - INFO -   |-- [Party 6] Average Train Loss:   0.5447 Train Accuracy: global  79.34% local  85.15% ...  127 forgettables out of 1428 ( 8.89%) ... total data used 1428
# 2021-09-01 16:35:04,778 - INFO -   |--    Epoch Losses (10): [0.8853, 0.6887, 0.6074, 0.5211, 0.4957, 0.5085, 0.4617, 0.4313, 0.4316, 0.4158]
# 2021-09-01 16:35:12,207 - INFO -   |-- [Party 7] Average Train Loss:   0.5267 Train Accuracy: global  80.81% local  84.94% ...  121 forgettables out of 1428 ( 8.47%) ... total data used 1428
# 2021-09-01 16:35:12,210 - INFO -   |--    Epoch Losses (10): [0.8724, 0.6556, 0.5592, 0.5067, 0.4736, 0.4492, 0.4706, 0.4401, 0.4438, 0.3957]
# 2021-09-01 16:35:19,156 - INFO -   |-- [Party 8] Average Train Loss:   0.5306 Train Accuracy: global  82.07% local  85.08% ...  102 forgettables out of 1428 ( 7.14%) ... total data used 1428
# 2021-09-01 16:35:19,157 - INFO -   |--    Epoch Losses (10): [0.8799, 0.6728, 0.5742, 0.5076, 0.476, 0.4531, 0.4517, 0.455, 0.4236, 0.4123]
# 2021-09-01 16:35:26,256 - INFO -   |-- [Party 9] Average Train Loss:   0.5548 Train Accuracy: global  79.06% local  83.96% ...   95 forgettables out of 1428 ( 6.65%) ... total data used 1428
# 2021-09-01 16:35:26,257 - INFO -   |--    Epoch Losses (10): [0.9034, 0.6973, 0.5878, 0.5534, 0.5178, 0.5145, 0.4565, 0.4377, 0.4485, 0.4308]
# 2021-09-01 16:35:30,906 - INFO -     |---- Number of Forgettables: 5457 (42.46%)
# 2021-09-01 16:35:30,909 - INFO -     |---- Train Accuracy: 41.15%
# 2021-09-01 16:35:30,910 - INFO -     |---- Test Accuracy: 32.08%
# 2021-09-01 16:35:30,911 - INFO -     |---- Test Loss: 1.6013
# 2021-09-01 16:35:30,911 - INFO -     |---- Elapsed time: 0:13:58.671342
# 2021-09-01 16:35:30,912 - INFO -
# Test Acc: Max 32.0833% (12 round) | Last 32.0833% | Avg 28.6028% (6 round)
#
# 2021-09-01 16:35:30,915 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 16:35:38,583 - INFO -   |-- [Party 1] Average Train Loss:   0.7019 Train Accuracy: global   0.00% local  83.68% ... 1191 forgettables out of 1428 (83.40%) ... total data used 1428
# 2021-09-01 16:35:38,585 - INFO -   |--    Epoch Losses (10): [1.6018, 0.9926, 0.7296, 0.6446, 0.5774, 0.5304, 0.5107, 0.4831, 0.5036, 0.445]
# 2021-09-01 16:35:46,179 - INFO -   |-- [Party 2] Average Train Loss:   0.6732 Train Accuracy: global   0.14% local  85.57% ... 1202 forgettables out of 1428 (84.17%) ... total data used 1428
# 2021-09-01 16:35:46,183 - INFO -   |--    Epoch Losses (10): [1.5732, 0.9584, 0.7336, 0.6185, 0.5623, 0.5092, 0.4538, 0.4516, 0.4536, 0.4176]
# 2021-09-01 16:35:53,120 - INFO -   |-- [Party 3] Average Train Loss:   0.7345 Train Accuracy: global  16.67% local  73.95% ...  847 forgettables out of 1428 (59.31%) ... total data used 1428
# 2021-09-01 16:35:53,122 - INFO -   |--    Epoch Losses (10): [1.2897, 0.9291, 0.7691, 0.7075, 0.6628, 0.6244, 0.6044, 0.5908, 0.5905, 0.5766]
# 2021-09-01 16:36:00,844 - INFO -   |-- [Party 4] Average Train Loss:   0.6950 Train Accuracy: global  15.76% local  79.06% ...  912 forgettables out of 1428 (63.87%) ... total data used 1428
# 2021-09-01 16:36:00,848 - INFO -   |--    Epoch Losses (10): [1.263, 0.9004, 0.7461, 0.6704, 0.6146, 0.5771, 0.57, 0.5487, 0.5423, 0.5179]
# 2021-09-01 16:36:07,810 - INFO -   |-- [Party 5] Average Train Loss:   0.7201 Train Accuracy: global  17.30% local  76.68% ...  858 forgettables out of 1428 (60.08%) ... total data used 1428
# 2021-09-01 16:36:07,813 - INFO -   |--    Epoch Losses (10): [1.2921, 0.8986, 0.7919, 0.6954, 0.6554, 0.6231, 0.582, 0.5728, 0.554, 0.5356]
# 2021-09-01 16:36:15,155 - INFO -   |-- [Party 6] Average Train Loss:   0.5327 Train Accuracy: global  79.83% local  85.29% ...  118 forgettables out of 1428 ( 8.26%) ... total data used 1428
# 2021-09-01 16:36:15,157 - INFO -   |--    Epoch Losses (10): [0.8715, 0.6666, 0.5776, 0.5368, 0.4837, 0.4719, 0.4359, 0.4542, 0.4197, 0.409]
# 2021-09-01 16:36:22,195 - INFO -   |-- [Party 7] Average Train Loss:   0.5146 Train Accuracy: global  79.90% local  85.43% ...  112 forgettables out of 1428 ( 7.84%) ... total data used 1428
# 2021-09-01 16:36:22,196 - INFO -   |--    Epoch Losses (10): [0.8602, 0.6478, 0.5509, 0.4996, 0.467, 0.4465, 0.4292, 0.4195, 0.4025, 0.4232]
# 2021-09-01 16:36:29,580 - INFO -   |-- [Party 8] Average Train Loss:   0.5193 Train Accuracy: global  81.16% local  84.73% ...  110 forgettables out of 1428 ( 7.70%) ... total data used 1428
# 2021-09-01 16:36:29,583 - INFO -   |--    Epoch Losses (10): [0.8592, 0.6631, 0.5657, 0.4881, 0.4734, 0.4571, 0.4546, 0.427, 0.4123, 0.3923]
# 2021-09-01 16:36:36,789 - INFO -   |-- [Party 9] Average Train Loss:   0.5408 Train Accuracy: global  80.95% local  83.61% ...   93 forgettables out of 1428 ( 6.51%) ... total data used 1428
# 2021-09-01 16:36:36,791 - INFO -   |--    Epoch Losses (10): [0.8934, 0.6802, 0.5736, 0.5392, 0.4971, 0.4828, 0.4714, 0.4364, 0.4196, 0.4144]
# 2021-09-01 16:36:41,571 - INFO -     |---- Number of Forgettables: 5443 (42.35%)
# 2021-09-01 16:36:41,572 - INFO -     |---- Train Accuracy: 41.53%
# 2021-09-01 16:36:41,573 - INFO -     |---- Test Accuracy: 32.90%
# 2021-09-01 16:36:41,574 - INFO -     |---- Test Loss: 1.5828
# 2021-09-01 16:36:41,575 - INFO -     |---- Elapsed time: 0:15:09.334722
# 2021-09-01 16:36:41,576 - INFO -
# Test Acc: Max 32.9000% (13 round) | Last 32.9000% | Avg 28.9333% (6 round)
#
# 2021-09-01 16:36:41,578 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 16:36:48,871 - INFO -   |-- [Party 1] Average Train Loss:   0.6911 Train Accuracy: global   0.28% local  84.10% ... 1191 forgettables out of 1428 (83.40%) ... total data used 1428
# 2021-09-01 16:36:48,872 - INFO -   |--    Epoch Losses (10): [1.5826, 0.9743, 0.7536, 0.6109, 0.5639, 0.5267, 0.5104, 0.4909, 0.4494, 0.448]
# 2021-09-01 16:36:55,770 - INFO -   |-- [Party 2] Average Train Loss:   0.6636 Train Accuracy: global   0.07% local  85.01% ... 1221 forgettables out of 1428 (85.50%) ... total data used 1428
# 2021-09-01 16:36:55,771 - INFO -   |--    Epoch Losses (10): [1.5879, 0.9568, 0.7058, 0.6086, 0.5252, 0.4846, 0.4722, 0.4542, 0.4184, 0.4224]
# 2021-09-01 16:37:02,687 - INFO -   |-- [Party 3] Average Train Loss:   0.7261 Train Accuracy: global  17.02% local  77.10% ...  822 forgettables out of 1428 (57.56%) ... total data used 1428
# 2021-09-01 16:37:02,688 - INFO -   |--    Epoch Losses (10): [1.2613, 0.9439, 0.765, 0.6974, 0.6531, 0.6222, 0.5994, 0.5915, 0.5603, 0.5673]
# 2021-09-01 16:37:09,684 - INFO -   |-- [Party 4] Average Train Loss:   0.6842 Train Accuracy: global  17.93% local  79.83% ...  878 forgettables out of 1428 (61.48%) ... total data used 1428
# 2021-09-01 16:37:09,686 - INFO -   |--    Epoch Losses (10): [1.2304, 0.8722, 0.7355, 0.6628, 0.6107, 0.5743, 0.5711, 0.5207, 0.5368, 0.5275]
# 2021-09-01 16:37:17,253 - INFO -   |-- [Party 5] Average Train Loss:   0.7109 Train Accuracy: global  18.14% local  76.75% ...  839 forgettables out of 1428 (58.75%) ... total data used 1428
# 2021-09-01 16:37:17,255 - INFO -   |--    Epoch Losses (10): [1.2726, 0.9057, 0.7615, 0.6866, 0.6241, 0.6081, 0.5789, 0.5718, 0.5566, 0.5434]
# 2021-09-01 16:37:24,837 - INFO -   |-- [Party 6] Average Train Loss:   0.5216 Train Accuracy: global  80.74% local  86.34% ...  142 forgettables out of 1428 ( 9.94%) ... total data used 1428
# 2021-09-01 16:37:24,839 - INFO -   |--    Epoch Losses (10): [0.8702, 0.6633, 0.57, 0.5351, 0.5075, 0.4436, 0.4386, 0.4138, 0.3841, 0.39]
# ...
# 2021-09-01 20:09:47,279 - INFO -   |--    Epoch Losses (10): [0.1906, 0.1987, 0.2004, 0.1492, 0.1454, 0.1392, 0.1529, 0.1369, 0.1277, 0.1628]
# 2021-09-01 20:09:54,092 - INFO -   |-- [Party 6] Average Train Loss:   0.0679 Train Accuracy: global  79.06% local  95.31% ...  235 forgettables out of 1428 (16.46%) ... total data used 1428
# 2021-09-01 20:09:54,095 - INFO -   |--    Epoch Losses (10): [0.0872, 0.0844, 0.0792, 0.07, 0.0563, 0.0633, 0.0767, 0.047, 0.0486, 0.0665]
# 2021-09-01 20:10:01,217 - INFO -   |-- [Party 7] Average Train Loss:   0.0726 Train Accuracy: global  76.19% local  96.64% ...  117 forgettables out of 1428 ( 8.19%) ... total data used 1428
# 2021-09-01 20:10:01,219 - INFO -   |--    Epoch Losses (10): [0.1108, 0.0863, 0.0812, 0.0742, 0.0633, 0.0803, 0.0553, 0.0576, 0.0654, 0.0513]
# 2021-09-01 20:10:08,184 - INFO -   |-- [Party 8] Average Train Loss:   0.0743 Train Accuracy: global  77.03% local  98.88% ...  325 forgettables out of 1428 (22.76%) ... total data used 1428
# 2021-09-01 20:10:08,185 - INFO -   |--    Epoch Losses (10): [0.0883, 0.0877, 0.1056, 0.1291, 0.0716, 0.0731, 0.0609, 0.0467, 0.0442, 0.0356]
# 2021-09-01 20:10:15,019 - INFO -   |-- [Party 9] Average Train Loss:   0.0732 Train Accuracy: global  76.19% local  82.98% ...  311 forgettables out of 1428 (21.78%) ... total data used 1428
# 2021-09-01 20:10:15,021 - INFO -   |--    Epoch Losses (10): [0.1128, 0.0901, 0.0746, 0.0643, 0.0537, 0.0599, 0.085, 0.0614, 0.0593, 0.071]
# 2021-09-01 20:10:19,553 - INFO -     |---- Number of Forgettables: 6029 (46.91%)
# 2021-09-01 20:10:19,554 - INFO -     |---- Train Accuracy: 52.05%
# 2021-09-01 20:10:19,555 - INFO -     |---- Test Accuracy: 45.28%
# 2021-09-01 20:10:19,556 - INFO -     |---- Test Loss: 1.3672
# 2021-09-01 20:10:19,556 - INFO -     |---- Elapsed time: 3:48:47.316326
# 2021-09-01 20:10:19,558 - INFO -
# Test Acc: Max 45.2833% (155 round) | Last 45.2833% | Avg 39.3452% (37 round)
#
# 2021-09-01 20:10:19,561 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 20:10:26,376 - INFO -   |-- [Party 1] Average Train Loss:   0.0848 Train Accuracy: global  39.71% local  98.04% ...  815 forgettables out of 1428 (57.07%) ... total data used 1428
# 2021-09-01 20:10:26,377 - INFO -   |--    Epoch Losses (10): [0.143, 0.0813, 0.1021, 0.102, 0.0769, 0.0707, 0.0679, 0.0731, 0.0693, 0.0612]
# 2021-09-01 20:10:33,890 - INFO -   |-- [Party 2] Average Train Loss:   0.0836 Train Accuracy: global  38.66% local  97.34% ...  751 forgettables out of 1428 (52.59%) ... total data used 1428
# 2021-09-01 20:10:33,891 - INFO -   |--    Epoch Losses (10): [0.1517, 0.0712, 0.0708, 0.0914, 0.0846, 0.0729, 0.1, 0.0788, 0.0619, 0.0525]
# 2021-09-01 20:10:40,809 - INFO -   |-- [Party 3] Average Train Loss:   0.1832 Train Accuracy: global  21.64% local  73.81% ... 1022 forgettables out of 1428 (71.57%) ... total data used 1428
# 2021-09-01 20:10:40,811 - INFO -   |--    Epoch Losses (10): [0.1947, 0.1962, 0.1971, 0.1861, 0.1795, 0.1571, 0.1683, 0.1646, 0.183, 0.2054]
# 2021-09-01 20:10:47,583 - INFO -   |-- [Party 4] Average Train Loss:   0.1479 Train Accuracy: global  22.27% local  89.99% ...  884 forgettables out of 1428 (61.90%) ... total data used 1428
# 2021-09-01 20:10:47,586 - INFO -   |--    Epoch Losses (10): [0.1517, 0.1541, 0.1572, 0.2036, 0.1629, 0.1212, 0.1339, 0.1383, 0.1233, 0.133]
# 2021-09-01 20:10:54,975 - INFO -   |-- [Party 5] Average Train Loss:   0.1850 Train Accuracy: global  22.41% local  86.62% ...  648 forgettables out of 1428 (45.38%) ... total data used 1428
# 2021-09-01 20:10:54,976 - INFO -   |--    Epoch Losses (10): [0.1695, 0.167, 0.1929, 0.2033, 0.2668, 0.2353, 0.1732, 0.1659, 0.1362, 0.14]
# 2021-09-01 20:11:01,848 - INFO -   |-- [Party 6] Average Train Loss:   0.0562 Train Accuracy: global  82.00% local  95.59% ...  227 forgettables out of 1428 (15.90%) ... total data used 1428
# 2021-09-01 20:11:01,849 - INFO -   |--    Epoch Losses (10): [0.0835, 0.0584, 0.058, 0.0585, 0.0537, 0.067, 0.0464, 0.0471, 0.039, 0.0506]
# 2021-09-01 20:11:09,167 - INFO -   |-- [Party 7] Average Train Loss:   0.0669 Train Accuracy: global  80.46% local  86.62% ...  263 forgettables out of 1428 (18.42%) ... total data used 1428
# 2021-09-01 20:11:09,169 - INFO -   |--    Epoch Losses (10): [0.131, 0.0694, 0.0579, 0.0603, 0.0575, 0.0564, 0.0701, 0.0586, 0.0568, 0.0515]
# 2021-09-01 20:11:16,076 - INFO -   |-- [Party 8] Average Train Loss:   0.0602 Train Accuracy: global  80.53% local  93.42% ...  272 forgettables out of 1428 (19.05%) ... total data used 1428
# 2021-09-01 20:11:16,077 - INFO -   |--    Epoch Losses (10): [0.0716, 0.0545, 0.0503, 0.0679, 0.0544, 0.0579, 0.0553, 0.0676, 0.0684, 0.0537]
# 2021-09-01 20:11:22,953 - INFO -   |-- [Party 9] Average Train Loss:   0.0604 Train Accuracy: global  80.11% local  95.66% ...  248 forgettables out of 1428 (17.37%) ... total data used 1428
# 2021-09-01 20:11:22,957 - INFO -   |--    Epoch Losses (10): [0.0964, 0.0856, 0.0582, 0.0578, 0.0518, 0.0646, 0.0612, 0.0422, 0.0416, 0.0441]
# 2021-09-01 20:11:27,555 - INFO -     |---- Number of Forgettables: 5130 (39.92%)
# 2021-09-01 20:11:27,557 - INFO -     |---- Train Accuracy: 53.21%
# 2021-09-01 20:11:27,559 - INFO -     |---- Test Accuracy: 45.43%
# 2021-09-01 20:11:27,561 - INFO -     |---- Test Loss: 1.3547
# 2021-09-01 20:11:27,562 - INFO -     |---- Elapsed time: 3:49:55.321859
# 2021-09-01 20:11:27,565 - INFO -
# Test Acc: Max 45.4333% (155 round) | Last 45.4333% | Avg 39.3761% (37 round)
#
# 2021-09-01 20:11:27,571 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 20:11:34,453 - INFO -   |-- [Party 1] Average Train Loss:   0.0836 Train Accuracy: global  33.19% local  98.04% ...  929 forgettables out of 1428 (65.06%) ... total data used 1428
# 2021-09-01 20:11:34,456 - INFO -   |--    Epoch Losses (10): [0.1941, 0.0749, 0.0795, 0.0679, 0.072, 0.073, 0.0818, 0.075, 0.0521, 0.0656]
# 2021-09-01 20:11:41,232 - INFO -   |-- [Party 2] Average Train Loss:   0.0798 Train Accuracy: global  32.07% local  71.99% ...  932 forgettables out of 1428 (65.27%) ... total data used 1428
# 2021-09-01 20:11:41,234 - INFO -   |--    Epoch Losses (10): [0.2211, 0.0794, 0.0728, 0.0546, 0.0629, 0.0597, 0.0518, 0.0545, 0.0637, 0.0775]
# 2021-09-01 20:11:48,664 - INFO -   |-- [Party 3] Average Train Loss:   0.1816 Train Accuracy: global  22.13% local  87.75% ...  741 forgettables out of 1428 (51.89%) ... total data used 1428
# 2021-09-01 20:11:48,666 - INFO -   |--    Epoch Losses (10): [0.2098, 0.2237, 0.1596, 0.1875, 0.2184, 0.1917, 0.1677, 0.1444, 0.1633, 0.1503]
# 2021-09-01 20:11:55,737 - INFO -   |-- [Party 4] Average Train Loss:   0.1616 Train Accuracy: global  23.95% local  84.94% ...  961 forgettables out of 1428 (67.30%) ... total data used 1428
# 2021-09-01 20:11:55,740 - INFO -   |--    Epoch Losses (10): [0.1513, 0.1523, 0.1665, 0.184, 0.2041, 0.157, 0.1408, 0.1248, 0.1704, 0.1646]
# 2021-09-01 20:12:02,535 - INFO -   |-- [Party 5] Average Train Loss:   0.1525 Train Accuracy: global  22.55% local  80.25% ...  915 forgettables out of 1428 (64.08%) ... total data used 1428
# 2021-09-01 20:12:02,537 - INFO -   |--    Epoch Losses (10): [0.1773, 0.1765, 0.1481, 0.143, 0.1337, 0.1655, 0.1504, 0.1484, 0.1275, 0.1551]
# 2021-09-01 20:12:09,715 - INFO -   |-- [Party 6] Average Train Loss:   0.0529 Train Accuracy: global  87.82% local  92.79% ...  157 forgettables out of 1428 (10.99%) ... total data used 1428
# 2021-09-01 20:12:09,716 - INFO -   |--    Epoch Losses (10): [0.0834, 0.0597, 0.0495, 0.046, 0.044, 0.0527, 0.0452, 0.0462, 0.0433, 0.0593]
# 2021-09-01 20:12:16,888 - INFO -   |-- [Party 7] Average Train Loss:   0.0764 Train Accuracy: global  85.78% local  69.82% ...  173 forgettables out of 1428 (12.11%) ... total data used 1428
# 2021-09-01 20:12:16,889 - INFO -   |--    Epoch Losses (10): [0.0891, 0.0635, 0.0807, 0.105, 0.0654, 0.0482, 0.0654, 0.0974, 0.0822, 0.0673]
# 2021-09-01 20:12:23,648 - INFO -   |-- [Party 8] Average Train Loss:   0.0683 Train Accuracy: global  86.41% local  98.39% ...  186 forgettables out of 1428 (13.03%) ... total data used 1428
# 2021-09-01 20:12:23,651 - INFO -   |--    Epoch Losses (10): [0.0871, 0.0624, 0.0581, 0.057, 0.1001, 0.0852, 0.0464, 0.0722, 0.0621, 0.0522]
# 2021-09-01 20:12:31,115 - INFO -   |-- [Party 9] Average Train Loss:   0.0752 Train Accuracy: global  86.62% local  98.11% ...  175 forgettables out of 1428 (12.25%) ... total data used 1428
# 2021-09-01 20:12:31,117 - INFO -   |--    Epoch Losses (10): [0.1045, 0.1133, 0.0636, 0.0772, 0.0617, 0.0512, 0.0618, 0.0646, 0.0976, 0.0568]
# 2021-09-01 20:12:35,628 - INFO -     |---- Number of Forgettables: 5169 (40.22%)
# 2021-09-01 20:12:35,629 - INFO -     |---- Train Accuracy: 46.56%
# 2021-09-01 20:12:35,630 - INFO -     |---- Test Accuracy: 39.67%
# 2021-09-01 20:12:35,631 - INFO -     |---- Test Loss: 1.4889
# 2021-09-01 20:12:35,632 - INFO -     |---- Elapsed time: 3:51:03.391980
# 2021-09-01 20:12:35,633 - INFO -
# Test Acc: Max 39.6667% (155 round) | Last 39.6667% | Avg 39.3775% (37 round)
#
# 2021-09-01 20:12:35,636 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 20:12:43,456 - INFO -   |-- [Party 1] Average Train Loss:   0.1061 Train Accuracy: global  32.84% local  99.09% ...  935 forgettables out of 1428 (65.48%) ... total data used 1428
# 2021-09-01 20:12:43,457 - INFO -   |--    Epoch Losses (10): [0.1472, 0.1038, 0.1447, 0.1193, 0.1567, 0.1068, 0.0904, 0.0751, 0.057, 0.0597]
# 2021-09-01 20:12:51,008 - INFO -   |-- [Party 2] Average Train Loss:   0.0745 Train Accuracy: global  32.98% local  98.46% ...  637 forgettables out of 1428 (44.61%) ... total data used 1428
# 2021-09-01 20:12:51,012 - INFO -   |--    Epoch Losses (10): [0.1502, 0.0822, 0.0734, 0.0588, 0.0613, 0.0659, 0.0741, 0.0714, 0.0431, 0.064]
# 2021-09-01 20:12:58,576 - INFO -   |-- [Party 3] Average Train Loss:   0.1842 Train Accuracy: global  14.01% local  58.47% ... 1053 forgettables out of 1428 (73.74%) ... total data used 1428
# 2021-09-01 20:12:58,578 - INFO -   |--    Epoch Losses (10): [0.2221, 0.1816, 0.1782, 0.1891, 0.2103, 0.1763, 0.1605, 0.1895, 0.151, 0.1832]
# 2021-09-01 20:13:05,398 - INFO -   |-- [Party 4] Average Train Loss:   0.1393 Train Accuracy: global  15.20% local  94.75% ... 1013 forgettables out of 1428 (70.94%) ... total data used 1428
# 2021-09-01 20:13:05,399 - INFO -   |--    Epoch Losses (10): [0.1524, 0.1413, 0.1785, 0.1429, 0.1245, 0.1232, 0.1097, 0.1661, 0.1201, 0.1339]
# 2021-09-01 20:13:12,236 - INFO -   |-- [Party 5] Average Train Loss:   0.1461 Train Accuracy: global  14.22% local  77.80% ...  961 forgettables out of 1428 (67.30%) ... total data used 1428
# 2021-09-01 20:13:12,237 - INFO -   |--    Epoch Losses (10): [0.1758, 0.1636, 0.1481, 0.1418, 0.1351, 0.1513, 0.1205, 0.1168, 0.1399, 0.1683]
# 2021-09-01 20:13:19,040 - INFO -   |-- [Party 6] Average Train Loss:   0.0905 Train Accuracy: global  77.59% local  57.77% ...  245 forgettables out of 1428 (17.16%) ... total data used 1428
# 2021-09-01 20:13:19,043 - INFO -   |--    Epoch Losses (10): [0.1083, 0.1124, 0.1452, 0.0686, 0.1115, 0.1323, 0.0539, 0.0442, 0.059, 0.0696]
# 2021-09-01 20:13:25,795 - INFO -   |-- [Party 7] Average Train Loss:   0.0763 Train Accuracy: global  73.32% local  98.81% ...  115 forgettables out of 1428 ( 8.05%) ... total data used 1428
# 2021-09-01 20:13:25,797 - INFO -   |--    Epoch Losses (10): [0.0833, 0.0975, 0.0754, 0.0815, 0.1237, 0.0858, 0.0712, 0.0522, 0.044, 0.0482]
# 2021-09-01 20:13:33,100 - INFO -   |-- [Party 8] Average Train Loss:   0.0685 Train Accuracy: global  76.26% local  98.25% ...  329 forgettables out of 1428 (23.04%) ... total data used 1428
# 2021-09-01 20:13:33,102 - INFO -   |--    Epoch Losses (10): [0.126, 0.0955, 0.085, 0.0702, 0.0577, 0.0568, 0.0423, 0.0454, 0.0469, 0.0592]
# 2021-09-01 20:13:40,499 - INFO -   |-- [Party 9] Average Train Loss:   0.0714 Train Accuracy: global  76.12% local  96.15% ...  319 forgettables out of 1428 (22.34%) ... total data used 1428
# 2021-09-01 20:13:40,501 - INFO -   |--    Epoch Losses (10): [0.0939, 0.0672, 0.062, 0.057, 0.0803, 0.0737, 0.1084, 0.0579, 0.0509, 0.0628]
# 2021-09-01 20:13:45,053 - INFO -     |---- Number of Forgettables: 5607 (43.63%)
# 2021-09-01 20:13:45,054 - INFO -     |---- Train Accuracy: 52.62%
# 2021-09-01 20:13:45,056 - INFO -     |---- Test Accuracy: 44.55%
# 2021-09-01 20:13:45,056 - INFO -     |---- Test Loss: 1.3848
# 2021-09-01 20:13:45,057 - INFO -     |---- Elapsed time: 3:52:12.817235
# 2021-09-01 20:13:45,059 - INFO -
# Test Acc: Max 44.5500% (155 round) | Last 44.5500% | Avg 39.4035% (37 round)
#
# 2021-09-01 20:13:45,061 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 20:13:52,278 - INFO -   |-- [Party 1] Average Train Loss:   0.1002 Train Accuracy: global  35.71% local  96.64% ...  910 forgettables out of 1428 (63.73%) ... total data used 1428
# 2021-09-01 20:13:52,279 - INFO -   |--    Epoch Losses (10): [0.2047, 0.0978, 0.0788, 0.0892, 0.0998, 0.1124, 0.0648, 0.073, 0.1026, 0.0786]
# 2021-09-01 20:13:59,911 - INFO -   |-- [Party 2] Average Train Loss:   0.0876 Train Accuracy: global  32.49% local  77.73% ...  942 forgettables out of 1428 (65.97%) ... total data used 1428
# 2021-09-01 20:13:59,913 - INFO -   |--    Epoch Losses (10): [0.2043, 0.091, 0.0959, 0.0724, 0.0568, 0.0554, 0.0744, 0.0906, 0.0672, 0.0682]
# 2021-09-01 20:14:06,720 - INFO -   |-- [Party 3] Average Train Loss:   0.1805 Train Accuracy: global  19.82% local  69.40% ...  733 forgettables out of 1428 (51.33%) ... total data used 1428
# 2021-09-01 20:14:06,722 - INFO -   |--    Epoch Losses (10): [0.2089, 0.2016, 0.1816, 0.1881, 0.1462, 0.1632, 0.1845, 0.177, 0.1862, 0.1672]
# 2021-09-01 20:14:13,550 - INFO -   |-- [Party 4] Average Train Loss:   0.1380 Train Accuracy: global  20.94% local  62.11% ... 1054 forgettables out of 1428 (73.81%) ... total data used 1428
# 2021-09-01 20:14:13,552 - INFO -   |--    Epoch Losses (10): [0.1596, 0.1552, 0.1878, 0.1239, 0.1225, 0.1392, 0.1176, 0.1094, 0.1368, 0.128]
# 2021-09-01 20:14:20,363 - INFO -   |-- [Party 5] Average Train Loss:   0.1637 Train Accuracy: global  19.40% local  95.10% ...  844 forgettables out of 1428 (59.10%) ... total data used 1428
# 2021-09-01 20:14:20,364 - INFO -   |--    Epoch Losses (10): [0.1824, 0.1753, 0.1924, 0.1429, 0.1402, 0.1211, 0.1327, 0.1647, 0.1951, 0.19]
# 2021-09-01 20:14:27,299 - INFO -   |-- [Party 6] Average Train Loss:   0.0653 Train Accuracy: global  85.99% local  57.35% ...  150 forgettables out of 1428 (10.50%) ... total data used 1428
# 2021-09-01 20:14:27,300 - INFO -   |--    Epoch Losses (10): [0.081, 0.0476, 0.0553, 0.0913, 0.0587, 0.0413, 0.0406, 0.0895, 0.0533, 0.0945]
# 2021-09-01 20:14:34,095 - INFO -   |-- [Party 7] Average Train Loss:   0.0788 Train Accuracy: global  85.85% local  89.36% ...  192 forgettables out of 1428 (13.45%) ... total data used 1428
# 2021-09-01 20:14:34,096 - INFO -   |--    Epoch Losses (10): [0.0827, 0.0617, 0.0673, 0.0776, 0.1006, 0.1547, 0.0645, 0.054, 0.0523, 0.0729]
# 2021-09-01 20:14:40,926 - INFO -   |-- [Party 8] Average Train Loss:   0.0629 Train Accuracy: global  84.73% local  98.53% ...  213 forgettables out of 1428 (14.92%) ... total data used 1428
# 2021-09-01 20:14:40,927 - INFO -   |--    Epoch Losses (10): [0.0979, 0.062, 0.0653, 0.0742, 0.0587, 0.0578, 0.0601, 0.0534, 0.0507, 0.0492]
# 2021-09-01 20:14:48,134 - INFO -   |-- [Party 9] Average Train Loss:   0.0632 Train Accuracy: global  86.34% local  91.74% ...  161 forgettables out of 1428 (11.27%) ... total data used 1428
# 2021-09-01 20:14:48,135 - INFO -   |--    Epoch Losses (10): [0.0858, 0.0795, 0.0791, 0.0742, 0.0565, 0.0416, 0.0445, 0.067, 0.0567, 0.0466]
# 2021-09-01 20:14:52,768 - INFO -     |---- Number of Forgettables: 5199 (40.45%)
# 2021-09-01 20:14:52,769 - INFO -     |---- Train Accuracy: 54.06%
# 2021-09-01 20:14:52,770 - INFO -     |---- Test Accuracy: 47.03%
# 2021-09-01 20:14:52,771 - INFO -     |---- Test Loss: 1.3571
# 2021-09-01 20:14:52,772 - INFO -     |---- Elapsed time: 3:53:20.532111
# 2021-09-01 20:14:52,774 - INFO -
# Test Acc: Max 47.0333% (155 round) | Last 47.0333% | Avg 39.4417% (37 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()

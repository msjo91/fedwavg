# %%
# %matplotlib inline

dataset = 'mnist'
num_clients = 100

filename = '{}_diri{}a01_42_fedprox'.format(dataset, num_clients)

gpu = 0

# %%
import copy
import json
import logging
import os
import random
import time
from datetime import timedelta

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, SubsetRandomSampler
from torchvision import transforms, datasets

# %%
seed = 42

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = True
try:
    torch.use_deterministic_algorithms(False)
except AttributeError:
    torch.set_deterministic(False)

# %%
path_root = os.path.dirname(os.getcwd())
path_data = os.path.join(path_root, 'data')
path_logs = os.path.join(path_root, 'logs')
path_models = os.path.join(path_root, 'models', filename)
path_results = os.path.join(path_root, 'results', filename)

for p in [path_data, path_logs, path_models, path_results]:
    os.makedirs(p, exist_ok=True)

# %%
logger = logging.getLogger(filename)
logger.setLevel(logging.INFO)

streamformatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
streamhandler = logging.StreamHandler()
streamhandler.setFormatter(streamformatter)
logger.addHandler(streamhandler)

fileformatter = logging.Formatter('%(message)s')
filehandler = logging.FileHandler(os.path.join(path_logs, filename + '.log'), mode='w')
filehandler.setFormatter(fileformatter)
logger.addHandler(filehandler)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def __getitem__(self, idx):
        data, target = self.dataset[idx]
        return data, target, idx

    def __len__(self):
        return len(self.dataset)

# %%
if dataset == 'cifar10':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([x / 255 for x in [125.3, 123, 113.9]], [x / 255 for x in [63, 62.1, 66.7]])
    ])

    train_dataset = datasets.CIFAR10(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.CIFAR10(path_data, train=False, transform=test_transform)
    
elif dataset == 'svhn':
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4376821, 0.4437697, 0.47280442), (0.19803012, 0.20101562, 0.19703614))
    ])

    train_dataset = datasets.SVHN(path_data, split='train', transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.SVHN(path_data, split='test', transform=test_transform, download=True)
    
elif dataset == 'fmnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.FashionMNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.FashionMNIST(path_data, train=False, transform=test_transform)

elif dataset == 'mnist':
    train_transform = transforms.Compose([
        transforms.RandomCrop(28, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])

    train_dataset = datasets.MNIST(path_data, train=True, transform=train_transform, download=True)
    custom_dataset = CustomDataset(train_dataset)
    test_dataset = datasets.MNIST(path_data, train=False, transform=test_transform)
# Out:
# Files already downloaded and verified

# %%
with open(os.path.join(path_data, '{}_clsimb9c{}_42.json'.format(dataset, ''.join(str(x) for x in clsimb)))) as f:
    indices = json.load(f)

# %%
batch_size, num_workers = 128, 0

inferloaders, subset_indices = {}, []
for k, v in indices.items():
    infersubset = Subset(custom_dataset, v['index'])
    inferloaders[k] = DataLoader(infersubset, batch_size=batch_size, num_workers=num_workers)
    subset_indices.extend(v['index'])

train_subset = Subset(train_dataset, indices=subset_indices)
fed_trainloader = DataLoader(train_subset, batch_size=batch_size, num_workers=num_workers)
    
try:
    train_labels = np.asarray(custom_dataset.dataset.targets)
    test_labels = test_dataset.targets
except AttributeError:
    train_labels = np.asarray(custom_dataset.dataset.labels)
    test_labels = test_dataset.labels
subset_classes = np.unique(train_labels[subset_indices])
boolarr = [True if y in subset_classes else False for y in test_labels]
subset_indices = np.arange(len(test_dataset))[boolarr]
test_subset = Subset(test_dataset, indices=subset_indices)
testloader = DataLoader(test_subset, batch_size=batch_size, num_workers=num_workers)

# %%
# class ResidualBlock(nn.Module):
#     expansion = 1

#     def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
#         super().__init__()

#         self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
#         self.bn1 = nn.BatchNorm2d(out_channel)
#         self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=1, padding=padding, bias=bias)
#         self.bn2 = nn.BatchNorm2d(out_channel)

#         self.shortcut = nn.Sequential()
#         if (stride != 1) or (in_channel != self.expansion * out_channel):
#             self.shortcut = nn.Sequential(
#                 nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
#                 nn.BatchNorm2d(self.expansion * out_channel)
#             )

#     def forward(self, x):
#         out = F.relu(self.bn1(self.conv1(x)))
#         out = self.bn2(self.conv2(out))
#         out += self.shortcut(x)
#         out = F.relu(out)
#         return out

# %%
# class Bottleneck(nn.Module):
#     expansion = 4
    
#     def __init__(self, in_channel, out_channel, kernel_size=3, stride=1, padding=1, bias=False):
#         super().__init__()

#         self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=1, bias=bias)
#         self.bn1 = nn.BatchNorm2d(out_channel)
#         self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
#         self.bn2 = nn.BatchNorm2d(out_channel)
#         self.conv3 = nn.Conv2d(out_channel, self.expansion * out_channel, kerenel_size=1, bias=bias)
#         self.bn3 = nn.BatchNorm2d(self.expansion * out_channel)

#         self.shortcut = nn.Sequential()
#         if (stride != 1) or (in_channel != self.expansion * out_channel):
#             self.shortcut = nn.Sequential(
#                 nn.Conv2d(in_channel, self.expansion * out_channel, kernel_size=1, stride=stride, bias=bias),
#                 nn.BatchNorm2d(self.expansion * out_channel)
#             )

#     def forward(self, x):
#         out = F.relu(self.bn1(self.conv1(x)))
#         out = F.relu(self.bn2(self.conv2(out)))
#         out = self.bn3(self.conv2(out))
#         out += self.shortcut(x)
#         out = F.relu(out)
#         return out

# %%
# class ResNet(nn.Module):
#     def __init__(self, block, in_channel=3, out_channels=[64, 128, 256, 512], num_blocks=[2, 2, 2, 2], strides=[1, 2, 2, 2], num_classes=10):
#         super().__init__()
#         self.in_channel = out_channels[0]

#         self.conv1 = nn.Conv2d(in_channel, out_channels[0], kernel_size=3, stride=strides[0], padding=1, bias=False)
#         self.bn1 = nn.BatchNorm2d(out_channels[0])
        
#         self.block1 = self._make_layer(block, out_channels[0], num_blocks[0], strides[0])
#         self.block2 = self._make_layer(block, out_channels[1], num_blocks[1], strides[1])
#         self.block3 = self._make_layer(block, out_channels[2], num_blocks[2], strides[2])
#         self.block4 = self._make_layer(block, out_channels[3], num_blocks[3], strides[3])
        
#         self.linear = nn.Linear(out_channels[-1] * block.expansion, num_classes)

#     def _make_layer(self, block, out_channel, num_blocks, stride):
#         strides = [stride] + [1] * (num_blocks - 1)
#         layers = []
#         for stride in strides:
#             layers.append(block(self.in_channel, out_channel, stride=stride))
#             self.in_channel = out_channel * block.expansion
#         return nn.Sequential(*layers)

#     def forward(self, x):
#         out = F.relu(self.bn1(self.conv1(x)))
#         out = self.block1(out)
#         out = self.block2(out)
#         out = self.block3(out)
#         out = self.block4(out)
#         out = F.avg_pool2d(out, 4)
#         out = out.view(out.size(0), -1)
#         out = self.linear(out)
#         return out

# %%
class MLP(nn.Module):
    def __init__(self, in_feature=784, num_classes=10):
        super().__init__()
        self.fc1 = nn.Linear(in_feature, 200)
        self.fc2 = nn.Linear(200, 200)
        self.fc3 = nn.Linear(200, num_classes)
        
    def forward(self, x):
        x = x.view(-1, 784)
        out = F.relu(self.fc1(x))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# %%
# class CNN(nn.Module):
#     def __init__(self, in_channel=3, num_classes=10):
#         super().__init__()
#         self.conv1 = nn.Conv2d(in_channel, 64, 5)
#         self.conv2 = nn.Conv2d(64, 64, 5)
#         self.fc1 = nn.Linear(64 * 5 * 5, 384)
#         self.fc2 = nn.Linear(384, 192)
#         self.fc3 = nn.Linear(192, num_classes)
        
#     def forward(self, x):
#         out = F.max_pool2d(F.relu(self.conv1(x)), 2, 2)
#         out = F.max_pool2d(F.relu(self.conv2(out)), 2, 2)
#         out = out.view(-1, 64 * 5 * 5)
#         out = F.relu(self.fc1(out))
#         out = F.relu(self.fc2(out))
#         out = self.fc3(out)
#         return out

# %%
def average_weights(w):
    w_avg = copy.deepcopy(w[0])
        
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], float(len(w)))
        
    return w_avg

# %%
def train(model, loader, epochs, lr, weight_decay, criterion, device, global_model, mu=0.01):
    epoch_losses = []
    
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    
    global_params = list(global_model.parameters())
    
    model.train()
    
    for ep in range(epochs):
        batch_losses = []
        
        for inputs, labels, _ in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            model.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss = loss.mean()
            
            prox_reg = 0.0
            for i, param in enumerate(model.parameters()):
                prox_reg += ((mu / 2) * torch.norm((param - global_params[i])) ** 2)
            loss += prox_reg
            
            loss.backward()
            optimizer.step()
            
            batch_losses.append(loss.item())

        epoch_losses.append(sum(batch_losses) / len(batch_losses))
        
    local_weights = model.state_dict()

    return local_weights, epoch_losses

# %%
def inference(model, loader, criterion, device):
    avg_loss, correct, num_samples = 0, 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss = loss.mean()
            avg_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            correct += torch.sum(torch.eq(predicted, labels)).item()
            num_samples += len(labels)

    acc = correct / num_samples
    avg_loss /= len(loader)
    
    return acc, avg_loss

# %%
def infer_train(model, loader, device, match_history, flag=False):
    forgettables = []
    correct, total = 0, 0

    model.eval()
    
    with torch.no_grad():
        for inputs, labels, indices in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            match = predicted.eq(labels)
            match = match.type(torch.IntTensor)
            total += len(indices)
            
            for j, idx in enumerate(indices):
                sample_history = match_history.get(idx.item(), [])
                sample_history.append(match[j].item())
                match_history[idx.item()] = sample_history
                correct += match[j].item()
                if flag is True:
                    try:
                        if match[j].item() - sample_history[-2] == -1:
                            forgettables.append(idx.item())
                    except IndexError:
                        continue
            
    acc = correct / total
            
    return match_history, forgettables, acc

# %%
def formatfloats(li):
    new = [float(f'{e:>8.4f}') for e in li]
    return new

# %%
# resnet9 = {'block': ResidualBlock, 'num_blocks': [1, 1, 1, 1]}
# resnet18 = {'block': ResidualBlock, 'num_blocks': [2, 2, 2, 2]}
# resnet34 = {'block': ResidualBlock, 'num_blocks': [3, 4, 6, 3]}
# resnet50 = {'block': Bottleneck, 'num_blocks': [3, 4, 6, 3]}
# resnet101 = {'block': Bottleneck, 'num_blocks': [3, 4, 23, 3]}
# resnet152 = {'block': Bottleneck, 'num_blocks': [3, 8, 36, 3]}

# %%
device = torch.device(f'cuda:{gpu}' if torch.cuda.is_available() else 'cpu')

# %%
num_classes = 10

fed_model = MLP()
fed_weights = fed_model.state_dict()

fed_model.to(device)
criterion = nn.CrossEntropyLoss(reduction='none').to(device)

# %%
rounds = 1000
epochs = 10
lr = 0.01
wdecay = 0.0001

logger.info(f'\nAlgorithm: FedProx\nClients: {num_clients}\nDataset: {dataset}\nModel: MLP | Rounds: {rounds} | Epochs: {epochs} | LR: {lr}\n')

train_accs, train_losses, test_accs, test_losses = [], [], [], []
match_history, round_forget_history = {}, []
forget_cnt_per_client = [0] * len(indices.keys())

st = time.time()
curr_participants = np.random.choice(num_clients, 10)


for r in range(rounds):
    
    round_forget, round_samples = 0, 0
    forget_history, forgettables = {}, {}
    local_weights, local_losses = [], []
    logger.info(f' | Global Training Round : {r + 1} / {rounds} |')
    logger.info(f' | Current Participants : {sorted(curr_participants.tolist())} |')

    next_participants = np.random.choice(num_clients, 10)
    logger.info(f' |    Next Participants : {sorted(next_participants.tolist())} |')
    
    for i, k in enumerate(indices.keys()):
        if int(k) in curr_participants:
            match_history, forgettables, global_acc = infer_train(fed_model, inferloaders[k], device, match_history, flag=True)

            fed_model.train()

            sampler_idx = indices[k]['index'].copy()
            sampler = SubsetRandomSampler(sampler_idx)

            trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)

            local_model = copy.deepcopy(fed_model)
            w, ls = train(local_model, trainloader, epochs, lr, wdecay, criterion, device)

            local_weights.append(copy.deepcopy(w))
            train_losses.append(ls)

            match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)
            train_accs.append(local_acc)

            forget_cnt = len(forgettables)
            round_forget += forget_cnt
            forget_cnt_per_client[int(k)] = forget_cnt
            round_samples += len(indices[k]['index'])

            logger.info('  |-- [Party {:>2}] Average Train Loss: {:>8.4f} Train Accuracy: global {:>6.2f}% local {:>6.2f}% ... {:>4} forgettables out of {:>4} ({:>5.2f}%) ... total data used {:>4}'.format(
                k, sum(ls) / len(ls), 100 * global_acc, 100 * local_acc, forget_cnt, len(indices[k]['index']), 100 * forget_cnt / len(indices[k]['index']), len(sampler_idx)
            ))
            logger.info('  |--    Epoch Losses ({:>2}): {}'.format(epochs, formatfloats(ls)))
            
        elif int(k) in next_participants:
            fed_model.train()

            sampler_idx = indices[k]['index'].copy()
            sampler = SubsetRandomSampler(sampler_idx)

            trainloader = DataLoader(custom_dataset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)

            local_model = copy.deepcopy(fed_model)
            _, _ = train(local_model, trainloader, epochs, lr, wdecay, criterion, device)
            
            match_history, _, local_acc = infer_train(local_model, inferloaders[k], device, match_history, flag=False)

            logger.info('  |-- [Party {:>2}] Training for forgettable counting in the next round'.format(k))
        
    fed_weights = average_weights(local_weights)
    fed_model.load_state_dict(fed_weights)
#     train_acc, _ = inference(fed_model, fed_trainloader, criterion, device)

    curr_participants = next_participants.copy()
    
    if (r + 1) % 100 == 0:
        torch.save(fed_model.state_dict(), os.path.join(path_models, filename + f'_round{r+1}.pth'))
    
    test_acc, test_ls = inference(fed_model, testloader, criterion, device)
    test_accs.append(test_acc)
    test_losses.append(test_ls)
    round_forget_history.append(round_forget)
    logger.info('    |---- Number of Forgettables: {} ({:.2f}%)'.format(round_forget, 100 * round_forget / round_samples))
#     logger.info('    |---- Train Accuracy: {:>.2f}%'.format(100 * train_acc))
    logger.info('    |---- Test Accuracy: {:>.2f}%'.format(100 * test_acc))
    logger.info('    |---- Test Loss: {:.4f}'.format(test_ls))
    logger.info('    |---- Elapsed time: {}'.format(timedelta(seconds=time.time()-st)))
    logger.info(f'\nTest Acc: Highest {np.max(test_accs) * 100:.4f}% ({np.argmax(test_accs)+1} round) | Avg {np.mean(test_accs) * 100:.4f}% ({np.argmax(test_accs > np.mean(test_accs))+1} round) | Curr {test_accs[-1] * 100:.4f}%')
# Out:
# 2021-09-01 13:25:25,738 - INFO -
# Algorithm: FedProx
# Client Split: [2, 7]
# Dataset: cifar10
# Model: ResNet9 | Rounds: 200 | Epochs: 10 | LR: 0.001
#
# 2021-09-01 13:25:25,740 - INFO -  | Global Training Round : 1 / 200 |
# 2021-09-01 13:25:37,674 - INFO -   |-- [Party 1] Average Train Loss:   0.5998 Train Accuracy: global   0.00% local  89.57% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:25:37,679 - INFO -   |--    Epoch Losses (10): [1.0642, 0.8119, 0.7145, 0.611, 0.5631, 0.5047, 0.4621, 0.4205, 0.446, 0.3996]
# 2021-09-01 13:25:48,209 - INFO -   |-- [Party 2] Average Train Loss:   0.5499 Train Accuracy: global   0.00% local  74.09% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:25:48,213 - INFO -   |--    Epoch Losses (10): [1.0521, 0.755, 0.6666, 0.5499, 0.4742, 0.4281, 0.3561, 0.3882, 0.3836, 0.4453]
# 2021-09-01 13:25:58,875 - INFO -   |-- [Party 3] Average Train Loss:   0.7882 Train Accuracy: global   0.00% local  66.53% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:25:58,877 - INFO -   |--    Epoch Losses (10): [1.2581, 0.9891, 0.9084, 0.7804, 0.7139, 0.6885, 0.6602, 0.6309, 0.6347, 0.618]
# 2021-09-01 13:26:09,632 - INFO -   |-- [Party 4] Average Train Loss:   0.7424 Train Accuracy: global   0.00% local  78.57% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:09,636 - INFO -   |--    Epoch Losses (10): [1.1892, 0.9459, 0.8652, 0.765, 0.667, 0.6446, 0.5978, 0.603, 0.5889, 0.5579]
# 2021-09-01 13:26:20,422 - INFO -   |-- [Party 5] Average Train Loss:   0.7771 Train Accuracy: global   0.00% local  60.64% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:20,424 - INFO -   |--    Epoch Losses (10): [1.2501, 0.9436, 0.9098, 0.8047, 0.6812, 0.675, 0.6175, 0.6299, 0.6146, 0.6445]
# 2021-09-01 13:26:31,252 - INFO -   |-- [Party 6] Average Train Loss:   0.7565 Train Accuracy: global   0.00% local  72.41% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:31,255 - INFO -   |--    Epoch Losses (10): [1.2173, 0.9715, 0.8609, 0.7449, 0.7063, 0.6082, 0.6165, 0.6087, 0.6312, 0.5994]
# 2021-09-01 13:26:42,505 - INFO -   |-- [Party 7] Average Train Loss:   0.7079 Train Accuracy: global   0.00% local  64.92% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:42,509 - INFO -   |--    Epoch Losses (10): [1.1764, 0.9272, 0.842, 0.6901, 0.6149, 0.5743, 0.6072, 0.5552, 0.5444, 0.5477]
# 2021-09-01 13:26:52,882 - INFO -   |-- [Party 8] Average Train Loss:   0.7517 Train Accuracy: global   0.00% local  74.09% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:26:52,883 - INFO -   |--    Epoch Losses (10): [1.2974, 0.9193, 0.8821, 0.7697, 0.678, 0.6266, 0.6219, 0.5967, 0.5671, 0.558]
# 2021-09-01 13:27:03,856 - INFO -   |-- [Party 9] Average Train Loss:   0.7040 Train Accuracy: global   0.00% local  76.40% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 13:27:03,860 - INFO -   |--    Epoch Losses (10): [1.162, 0.916, 0.8018, 0.6711, 0.6156, 0.5826, 0.5964, 0.5659, 0.5964, 0.5321]
# 2021-09-01 13:27:10,239 - INFO -     |---- Number of Forgettables: 0 (0.00%)
# 2021-09-01 13:27:10,241 - INFO -     |---- Train Accuracy: 39.27%
# 2021-09-01 13:27:10,242 - INFO -     |---- Test Accuracy: 25.22%
# 2021-09-01 13:27:10,243 - INFO -     |---- Test Loss: 2.6131
# 2021-09-01 13:27:10,244 - INFO -     |---- Elapsed time: 0:01:44.504795
# 2021-09-01 13:27:10,246 - INFO -
# Test Acc: Max 25.2250% (1 round) | Last 25.2250% | Avg 25.2250% (1 round)
#
# 2021-09-01 13:27:10,249 - INFO -  | Global Training Round : 2 / 200 |
# 2021-09-01 13:27:20,571 - INFO -   |-- [Party 1] Average Train Loss:   0.6185 Train Accuracy: global   0.00% local  91.53% ... 1279 forgettables out of 1428 (89.57%) ... total data used 1428
# 2021-09-01 13:27:20,575 - INFO -   |--    Epoch Losses (10): [1.4939, 0.9072, 0.7548, 0.6145, 0.4833, 0.3934, 0.4372, 0.3899, 0.3651, 0.3458]
# 2021-09-01 13:27:31,656 - INFO -   |-- [Party 2] Average Train Loss:   0.5711 Train Accuracy: global   0.00% local  91.95% ... 1058 forgettables out of 1428 (74.09%) ... total data used 1428
# 2021-09-01 13:27:31,660 - INFO -   |--    Epoch Losses (10): [1.3722, 0.8286, 0.7023, 0.5594, 0.4643, 0.4195, 0.3697, 0.343, 0.3395, 0.3127]
# 2021-09-01 13:27:42,310 - INFO -   |-- [Party 3] Average Train Loss:   0.6318 Train Accuracy: global  50.84% local  68.35% ...  293 forgettables out of 1428 (20.52%) ... total data used 1428
# 2021-09-01 13:27:42,314 - INFO -   |--    Epoch Losses (10): [0.8089, 0.8075, 0.7006, 0.649, 0.5724, 0.5957, 0.5767, 0.531, 0.5312, 0.545]
# 2021-09-01 13:27:52,178 - INFO -   |-- [Party 4] Average Train Loss:   0.5628 Train Accuracy: global  50.21% local  77.52% ...  478 forgettables out of 1428 (33.47%) ... total data used 1428
# 2021-09-01 13:27:52,181 - INFO -   |--    Epoch Losses (10): [0.675, 0.697, 0.6225, 0.5285, 0.5027, 0.4887, 0.4979, 0.5262, 0.5291, 0.5603]
# 2021-09-01 13:28:03,098 - INFO -   |-- [Party 5] Average Train Loss:   0.6559 Train Accuracy: global  50.49% local  69.96% ...  164 forgettables out of 1428 (11.48%) ... total data used 1428
# 2021-09-01 13:28:03,103 - INFO -   |--    Epoch Losses (10): [0.8354, 0.8511, 0.7759, 0.6749, 0.5946, 0.6046, 0.576, 0.539, 0.544, 0.5632]
# 2021-09-01 13:28:14,145 - INFO -   |-- [Party 6] Average Train Loss:   0.6163 Train Accuracy: global  50.28% local  77.45% ...  389 forgettables out of 1428 (27.24%) ... total data used 1428
# 2021-09-01 13:28:14,149 - INFO -   |--    Epoch Losses (10): [0.7514, 0.7454, 0.644, 0.5967, 0.5742, 0.5558, 0.5794, 0.5622, 0.5497, 0.6041]
# 2021-09-01 13:28:24,946 - INFO -   |-- [Party 7] Average Train Loss:   0.5577 Train Accuracy: global  50.77% local  81.16% ...  693 forgettables out of 1428 (48.53%) ... total data used 1428
# 2021-09-01 13:28:24,950 - INFO -   |--    Epoch Losses (10): [0.7644, 0.702, 0.6213, 0.5391, 0.4842, 0.5045, 0.5189, 0.5077, 0.4851, 0.4495]
# 2021-09-01 13:28:34,733 - INFO -   |-- [Party 8] Average Train Loss:   0.6107 Train Accuracy: global  50.35% local  84.45% ...  372 forgettables out of 1428 (26.05%) ... total data used 1428
# 2021-09-01 13:28:34,737 - INFO -   |--    Epoch Losses (10): [0.7796, 0.7672, 0.6837, 0.624, 0.5854, 0.5611, 0.5624, 0.5466, 0.5154, 0.4819]
# 2021-09-01 13:28:44,549 - INFO -   |-- [Party 9] Average Train Loss:   0.5976 Train Accuracy: global  50.63% local  73.88% ...  629 forgettables out of 1428 (44.05%) ... total data used 1428
# 2021-09-01 13:28:44,553 - INFO -   |--    Epoch Losses (10): [0.743, 0.7284, 0.6518, 0.6161, 0.56, 0.5136, 0.5379, 0.5534, 0.5359, 0.5363]
# 2021-09-01 13:28:50,515 - INFO -     |---- Number of Forgettables: 5355 (41.67%)
# 2021-09-01 13:28:50,517 - INFO -     |---- Train Accuracy: 50.94%
# 2021-09-01 13:28:50,518 - INFO -     |---- Test Accuracy: 31.82%
# 2021-09-01 13:28:50,518 - INFO -     |---- Test Loss: 2.9469
# 2021-09-01 13:28:50,519 - INFO -     |---- Elapsed time: 0:03:24.779482
# 2021-09-01 13:28:50,520 - INFO -
# Test Acc: Max 31.8250% (2 round) | Last 31.8250% | Avg 28.5250% (2 round)
#
# 2021-09-01 13:28:50,522 - INFO -  | Global Training Round : 3 / 200 |
# 2021-09-01 13:29:00,319 - INFO -   |-- [Party 1] Average Train Loss:   0.5232 Train Accuracy: global   0.00% local  93.14% ... 1307 forgettables out of 1428 (91.53%) ... total data used 1428
# 2021-09-01 13:29:00,321 - INFO -   |--    Epoch Losses (10): [1.3504, 0.7284, 0.5778, 0.4575, 0.3929, 0.3516, 0.3457, 0.3395, 0.3232, 0.3651]
# 2021-09-01 13:29:10,064 - INFO -   |-- [Party 2] Average Train Loss:   0.4896 Train Accuracy: global   0.00% local  84.10% ... 1313 forgettables out of 1428 (91.95%) ... total data used 1428
# 2021-09-01 13:29:10,068 - INFO -   |--    Epoch Losses (10): [1.3218, 0.7071, 0.5736, 0.4239, 0.3522, 0.3202, 0.3068, 0.2955, 0.2841, 0.3102]
# 2021-09-01 13:29:21,153 - INFO -   |-- [Party 3] Average Train Loss:   0.5255 Train Accuracy: global  64.78% local  74.58% ...  438 forgettables out of 1428 (30.67%) ... total data used 1428
# 2021-09-01 13:29:21,155 - INFO -   |--    Epoch Losses (10): [0.6339, 0.5937, 0.5343, 0.5256, 0.5322, 0.5241, 0.4629, 0.4707, 0.4596, 0.5177]
# 2021-09-01 13:29:31,395 - INFO -   |-- [Party 4] Average Train Loss:   0.4820 Train Accuracy: global  65.55% local  77.80% ...  405 forgettables out of 1428 (28.36%) ... total data used 1428
# 2021-09-01 13:29:31,397 - INFO -   |--    Epoch Losses (10): [0.5913, 0.544, 0.4949, 0.4732, 0.4621, 0.4294, 0.4432, 0.4674, 0.4933, 0.4216]
# 2021-09-01 13:29:41,920 - INFO -   |-- [Party 5] Average Train Loss:   0.4946 Train Accuracy: global  64.43% local  83.54% ...  455 forgettables out of 1428 (31.86%) ... total data used 1428
# 2021-09-01 13:29:41,921 - INFO -   |--    Epoch Losses (10): [0.574, 0.6082, 0.5307, 0.4947, 0.4564, 0.4617, 0.4475, 0.4378, 0.4665, 0.4687]
# 2021-09-01 13:29:51,830 - INFO -   |-- [Party 6] Average Train Loss:   0.5059 Train Accuracy: global  65.55% local  80.53% ...  405 forgettables out of 1428 (28.36%) ... total data used 1428
# 2021-09-01 13:29:51,834 - INFO -   |--    Epoch Losses (10): [0.6246, 0.602, 0.5476, 0.5155, 0.4902, 0.4518, 0.4218, 0.4735, 0.4632, 0.469]
# 2021-09-01 13:30:02,773 - INFO -   |-- [Party 7] Average Train Loss:   0.4690 Train Accuracy: global  66.11% local  76.54% ...  263 forgettables out of 1428 (18.42%) ... total data used 1428
# 2021-09-01 13:30:02,776 - INFO -   |--    Epoch Losses (10): [0.545, 0.5229, 0.4637, 0.4379, 0.4266, 0.4652, 0.4264, 0.4459, 0.4629, 0.4933]
# 2021-09-01 13:30:13,207 - INFO -   |-- [Party 8] Average Train Loss:   0.4899 Train Accuracy: global  66.67% local  86.83% ...  400 forgettables out of 1428 (28.01%) ... total data used 1428
# 2021-09-01 13:30:13,210 - INFO -   |--    Epoch Losses (10): [0.5695, 0.5601, 0.4981, 0.5192, 0.4687, 0.4659, 0.4449, 0.4865, 0.4494, 0.437]
# 2021-09-01 13:30:24,318 - INFO -   |-- [Party 9] Average Train Loss:   0.4769 Train Accuracy: global  65.83% local  85.85% ...  452 forgettables out of 1428 (31.65%) ... total data used 1428
# 2021-09-01 13:30:24,323 - INFO -   |--    Epoch Losses (10): [0.5792, 0.5582, 0.5327, 0.4775, 0.4502, 0.4377, 0.4538, 0.4216, 0.4352, 0.4224]
# 2021-09-01 13:30:30,265 - INFO -     |---- Number of Forgettables: 5438 (42.31%)
# 2021-09-01 13:30:30,268 - INFO -     |---- Train Accuracy: 63.44%
# 2021-09-01 13:30:30,269 - INFO -     |---- Test Accuracy: 40.00%
# 2021-09-01 13:30:30,270 - INFO -     |---- Test Loss: 2.9749
# 2021-09-01 13:30:30,271 - INFO -     |---- Elapsed time: 0:05:04.531205
# 2021-09-01 13:30:30,272 - INFO -
# Test Acc: Max 40.0000% (3 round) | Last 40.0000% | Avg 32.3500% (3 round)
#
# 2021-09-01 13:30:30,274 - INFO -  | Global Training Round : 4 / 200 |
# 2021-09-01 13:30:41,723 - INFO -   |-- [Party 1] Average Train Loss:   0.4890 Train Accuracy: global   0.00% local  92.23% ... 1330 forgettables out of 1428 (93.14%) ... total data used 1428
# 2021-09-01 13:30:41,727 - INFO -   |--    Epoch Losses (10): [1.4502, 0.6994, 0.5289, 0.4194, 0.3563, 0.2934, 0.3002, 0.2931, 0.2821, 0.2676]
# 2021-09-01 13:30:52,376 - INFO -   |-- [Party 2] Average Train Loss:   0.4878 Train Accuracy: global   0.00% local  85.36% ... 1201 forgettables out of 1428 (84.10%) ... total data used 1428
# 2021-09-01 13:30:52,381 - INFO -   |--    Epoch Losses (10): [1.3893, 0.6728, 0.5174, 0.449, 0.3482, 0.3032, 0.2999, 0.3247, 0.296, 0.2775]
# 2021-09-01 13:31:03,464 - INFO -   |-- [Party 3] Average Train Loss:   0.4483 Train Accuracy: global  79.48% local  69.33% ...  184 forgettables out of 1428 (12.89%) ... total data used 1428
# 2021-09-01 13:31:03,466 - INFO -   |--    Epoch Losses (10): [0.5091, 0.5229, 0.4719, 0.4514, 0.4715, 0.4349, 0.4201, 0.3904, 0.3888, 0.4226]
# 2021-09-01 13:31:13,759 - INFO -   |-- [Party 4] Average Train Loss:   0.3846 Train Accuracy: global  82.98% local  88.31% ...   71 forgettables out of 1428 ( 4.97%) ... total data used 1428
# 2021-09-01 13:31:13,763 - INFO -   |--    Epoch Losses (10): [0.4384, 0.4598, 0.397, 0.4156, 0.3539, 0.3413, 0.3375, 0.3874, 0.3907, 0.3242]
# 2021-09-01 13:31:23,704 - INFO -   |-- [Party 5] Average Train Loss:   0.4296 Train Accuracy: global  82.28% local  71.99% ...  154 forgettables out of 1428 (10.78%) ... total data used 1428
# 2021-09-01 13:31:23,708 - INFO -   |--    Epoch Losses (10): [0.5044, 0.4829, 0.4334, 0.4619, 0.4535, 0.4268, 0.3819, 0.3862, 0.3872, 0.3775]
# 2021-09-01 13:31:34,964 - INFO -   |-- [Party 6] Average Train Loss:   0.4387 Train Accuracy: global  80.39% local  79.62% ...  123 forgettables out of 1428 ( 8.61%) ... total data used 1428
# 2021-09-01 13:31:34,968 - INFO -   |--    Epoch Losses (10): [0.5401, 0.4816, 0.4653, 0.4446, 0.4225, 0.403, 0.4084, 0.376, 0.4224, 0.4232]
# 2021-09-01 13:31:45,669 - INFO -   |-- [Party 7] Average Train Loss:   0.3997 Train Accuracy: global  83.75% local  87.25% ...  129 forgettables out of 1428 ( 9.03%) ... total data used 1428
# 2021-09-01 13:31:45,673 - INFO -   |--    Epoch Losses (10): [0.4643, 0.4461, 0.3867, 0.4052, 0.3934, 0.3737, 0.3484, 0.3836, 0.393, 0.403]
# 2021-09-01 13:31:56,930 - INFO -   |-- [Party 8] Average Train Loss:   0.4170 Train Accuracy: global  82.35% local  89.78% ...  117 forgettables out of 1428 ( 8.19%) ... total data used 1428
# 2021-09-01 13:31:56,935 - INFO -   |--    Epoch Losses (10): [0.5067, 0.4872, 0.4365, 0.4075, 0.3956, 0.3891, 0.3926, 0.4024, 0.3701, 0.3827]
# 2021-09-01 13:32:06,905 - INFO -   |-- [Party 9] Average Train Loss:   0.4061 Train Accuracy: global  81.93% local  88.59% ...  133 forgettables out of 1428 ( 9.31%) ... total data used 1428
# 2021-09-01 13:32:06,909 - INFO -   |--    Epoch Losses (10): [0.4559, 0.405, 0.3905, 0.426, 0.4631, 0.4048, 0.3837, 0.3884, 0.3791, 0.3647]
# 2021-09-01 13:32:12,942 - INFO -     |---- Number of Forgettables: 3442 (26.78%)
# 2021-09-01 13:32:12,945 - INFO -     |---- Train Accuracy: 66.91%
# 2021-09-01 13:32:12,947 - INFO -     |---- Test Accuracy: 42.18%
# 2021-09-01 13:32:12,947 - INFO -     |---- Test Loss: 3.0059
# 2021-09-01 13:32:12,948 - INFO -     |---- Elapsed time: 0:06:47.207969
# 2021-09-01 13:32:12,949 - INFO -
# Test Acc: Max 42.1750% (4 round) | Last 42.1750% | Avg 34.8062% (3 round)
#
# 2021-09-01 13:32:12,952 - INFO -  | Global Training Round : 5 / 200 |
# 2021-09-01 13:32:23,857 - INFO -   |-- [Party 1] Average Train Loss:   0.4850 Train Accuracy: global   0.00% local  79.55% ... 1317 forgettables out of 1428 (92.23%) ... total data used 1428
# 2021-09-01 13:32:23,860 - INFO -   |--    Epoch Losses (10): [1.4458, 0.7254, 0.5066, 0.3802, 0.2771, 0.3009, 0.3075, 0.3052, 0.3243, 0.277]
# 2021-09-01 13:32:33,750 - INFO -   |-- [Party 2] Average Train Loss:   0.4358 Train Accuracy: global   0.00% local  92.44% ... 1219 forgettables out of 1428 (85.36%) ... total data used 1428
# 2021-09-01 13:32:33,756 - INFO -   |--    Epoch Losses (10): [1.383, 0.6324, 0.498, 0.3831, 0.2759, 0.2527, 0.2222, 0.2331, 0.2264, 0.2516]
# 2021-09-01 13:32:44,399 - INFO -   |-- [Party 3] Average Train Loss:   0.4138 Train Accuracy: global  84.73% local  76.96% ...  121 forgettables out of 1428 ( 8.47%) ... total data used 1428
# 2021-09-01 13:32:44,403 - INFO -   |--    Epoch Losses (10): [0.5096, 0.4724, 0.4091, 0.3932, 0.4057, 0.3889, 0.3783, 0.3754, 0.3846, 0.4207]
# 2021-09-01 13:32:55,404 - INFO -   |-- [Party 4] Average Train Loss:   0.3577 Train Accuracy: global  86.20% local  76.33% ...   82 forgettables out of 1428 ( 5.74%) ... total data used 1428
# 2021-09-01 13:32:55,408 - INFO -   |--    Epoch Losses (10): [0.4568, 0.4089, 0.3551, 0.3315, 0.3562, 0.3727, 0.3457, 0.3206, 0.3182, 0.3113]
# 2021-09-01 13:33:05,218 - INFO -   |-- [Party 5] Average Train Loss:   0.3758 Train Accuracy: global  85.92% local  89.08% ...   92 forgettables out of 1428 ( 6.44%) ... total data used 1428
# 2021-09-01 13:33:05,222 - INFO -   |--    Epoch Losses (10): [0.4448, 0.4011, 0.3648, 0.3854, 0.404, 0.3821, 0.3718, 0.3328, 0.3407, 0.3305]
# 2021-09-01 13:33:16,429 - INFO -   |-- [Party 6] Average Train Loss:   0.3887 Train Accuracy: global  84.59% local  86.34% ...  115 forgettables out of 1428 ( 8.05%) ... total data used 1428
# 2021-09-01 13:33:16,433 - INFO -   |--    Epoch Losses (10): [0.4605, 0.4275, 0.377, 0.3873, 0.3785, 0.3633, 0.3593, 0.3766, 0.366, 0.3909]
# 2021-09-01 13:33:26,250 - INFO -   |-- [Party 7] Average Train Loss:   0.3857 Train Accuracy: global  86.34% local  88.10% ...   72 forgettables out of 1428 ( 5.04%) ... total data used 1428
# 2021-09-01 13:33:26,254 - INFO -   |--    Epoch Losses (10): [0.4231, 0.4201, 0.3963, 0.3696, 0.3324, 0.3936, 0.3425, 0.3669, 0.4242, 0.3882]
# 2021-09-01 13:33:37,672 - INFO -   |-- [Party 8] Average Train Loss:   0.3924 Train Accuracy: global  87.39% local  83.12% ...   93 forgettables out of 1428 ( 6.51%) ... total data used 1428
# 2021-09-01 13:33:37,676 - INFO -   |--    Epoch Losses (10): [0.407, 0.4054, 0.3916, 0.406, 0.4363, 0.437, 0.3887, 0.349, 0.365, 0.3375]
# 2021-09-01 13:33:48,593 - INFO -   |-- [Party 9] Average Train Loss:   0.3617 Train Accuracy: global  86.48% local  62.68% ...  114 forgettables out of 1428 ( 7.98%) ... total data used 1428
# 2021-09-01 13:33:48,594 - INFO -   |--    Epoch Losses (10): [0.398, 0.3889, 0.3457, 0.3658, 0.384, 0.3644, 0.3462, 0.321, 0.3296, 0.3731]
# 2021-09-01 13:33:54,609 - INFO -     |---- Number of Forgettables: 3225 (25.09%)
# 2021-09-01 13:33:54,613 - INFO -     |---- Train Accuracy: 68.08%
# 2021-09-01 13:33:54,614 - INFO -     |---- Test Accuracy: 42.95%
# 2021-09-01 13:33:54,615 - INFO -     |---- Test Loss: 3.0434
# 2021-09-01 13:33:54,615 - INFO -     |---- Elapsed time: 0:08:28.875766
# 2021-09-01 13:33:54,617 - INFO -
# Test Acc: Max 42.9500% (5 round) | Last 42.9500% | Avg 36.4350% (3 round)
#
# 2021-09-01 13:33:54,619 - INFO -  | Global Training Round : 6 / 200 |
# 2021-09-01 13:34:05,121 - INFO -   |-- [Party 1] Average Train Loss:   0.4260 Train Accuracy: global   0.00% local  92.79% ... 1136 forgettables out of 1428 (79.55%) ... total data used 1428
# 2021-09-01 13:34:05,125 - INFO -   |--    Epoch Losses (10): [1.4163, 0.6408, 0.4832, 0.335, 0.2569, 0.2263, 0.2219, 0.2025, 0.2164, 0.2606]
# 2021-09-01 13:34:15,004 - INFO -   |-- [Party 2] Average Train Loss:   0.4376 Train Accuracy: global   0.00% local  91.88% ... 1320 forgettables out of 1428 (92.44%) ... total data used 1428
# 2021-09-01 13:34:15,007 - INFO -   |--    Epoch Losses (10): [1.352, 0.6497, 0.4949, 0.3881, 0.3095, 0.2686, 0.2435, 0.2192, 0.2161, 0.2343]
# 2021-09-01 13:34:25,120 - INFO -   |-- [Party 3] Average Train Loss:   0.3593 Train Accuracy: global  86.41% local  67.72% ...  118 forgettables out of 1428 ( 8.26%) ... total data used 1428
# 2021-09-01 13:34:25,124 - INFO -   |--    Epoch Losses (10): [0.4111, 0.4058, 0.369, 0.3375, 0.342, 0.3576, 0.3794, 0.3361, 0.3249, 0.3299]
# 2021-09-01 13:34:36,051 - INFO -   |-- [Party 4] Average Train Loss:   0.3180 Train Accuracy: global  88.24% local  92.16% ...   68 forgettables out of 1428 ( 4.76%) ... total data used 1428
# 2021-09-01 13:34:36,053 - INFO -   |--    Epoch Losses (10): [0.3662, 0.3851, 0.3384, 0.2869, 0.2862, 0.2682, 0.2782, 0.3248, 0.3353, 0.3103]
# 2021-09-01 13:34:45,836 - INFO -   |-- [Party 5] Average Train Loss:   0.3567 Train Accuracy: global  87.46% local  67.16% ...   93 forgettables out of 1428 ( 6.51%) ... total data used 1428
# 2021-09-01 13:34:45,838 - INFO -   |--    Epoch Losses (10): [0.4007, 0.4111, 0.3707, 0.352, 0.3269, 0.334, 0.3424, 0.3282, 0.3496, 0.3512]
# 2021-09-01 13:34:55,991 - INFO -   |-- [Party 6] Average Train Loss:   0.3899 Train Accuracy: global  86.62% local  88.87% ...  100 forgettables out of 1428 ( 7.00%) ... total data used 1428
# 2021-09-01 13:34:55,994 - INFO -   |--    Epoch Losses (10): [0.4187, 0.4275, 0.4083, 0.3697, 0.3848, 0.3398, 0.3477, 0.395, 0.425, 0.3826]
# 2021-09-01 13:35:06,633 - INFO -   |-- [Party 7] Average Train Loss:   0.3265 Train Accuracy: global  86.62% local  89.08% ...   86 forgettables out of 1428 ( 6.02%) ... total data used 1428
# 2021-09-01 13:35:06,635 - INFO -   |--    Epoch Losses (10): [0.4162, 0.3508, 0.3382, 0.3043, 0.3041, 0.2965, 0.3073, 0.3422, 0.3066, 0.2988]
# 2021-09-01 13:35:16,374 - INFO -   |-- [Party 8] Average Train Loss:   0.3560 Train Accuracy: global  88.38% local  90.34% ...   69 forgettables out of 1428 ( 4.83%) ... total data used 1428
# 2021-09-01 13:35:16,375 - INFO -   |--    Epoch Losses (10): [0.3909, 0.3785, 0.3345, 0.3211, 0.3444, 0.293, 0.3913, 0.3845, 0.3834, 0.3381]
# 2021-09-01 13:35:27,009 - INFO -   |-- [Party 9] Average Train Loss:   0.3267 Train Accuracy: global  88.31% local  92.23% ...  108 forgettables out of 1428 ( 7.56%) ... total data used 1428
# 2021-09-01 13:35:27,011 - INFO -   |--    Epoch Losses (10): [0.3856, 0.3624, 0.3561, 0.3209, 0.3514, 0.3263, 0.3021, 0.2918, 0.2767, 0.2936]
# 2021-09-01 13:35:32,907 - INFO -     |---- Number of Forgettables: 3098 (24.11%)
# 2021-09-01 13:35:32,908 - INFO -     |---- Train Accuracy: 68.98%
# 2021-09-01 13:35:32,909 - INFO -     |---- Test Accuracy: 43.58%
# 2021-09-01 13:35:32,909 - INFO -     |---- Test Loss: 3.0896
# 2021-09-01 13:35:32,910 - INFO -     |---- Elapsed time: 0:10:07.170238
# 2021-09-01 13:35:32,911 - INFO -
# Test Acc: Max 43.5750% (6 round) | Last 43.5750% | Avg 37.6250% (3 round)
#
# 2021-09-01 13:35:32,913 - INFO -  | Global Training Round : 7 / 200 |
# 2021-09-01 13:35:43,864 - INFO -   |-- [Party 1] Average Train Loss:   0.4403 Train Accuracy: global   0.00% local  88.87% ... 1325 forgettables out of 1428 (92.79%) ... total data used 1428
# 2021-09-01 13:35:43,866 - INFO -   |--    Epoch Losses (10): [1.2845, 0.6147, 0.4423, 0.3486, 0.2554, 0.2147, 0.248, 0.3803, 0.34, 0.2745]
# 2021-09-01 13:35:54,937 - INFO -   |-- [Party 2] Average Train Loss:   0.3928 Train Accuracy: global   0.00% local  87.04% ... 1312 forgettables out of 1428 (91.88%) ... total data used 1428
# 2021-09-01 13:35:54,939 - INFO -   |--    Epoch Losses (10): [1.2797, 0.6073, 0.4295, 0.3133, 0.2485, 0.2622, 0.1999, 0.1966, 0.1965, 0.1943]
# 2021-09-01 13:36:05,681 - INFO -   |-- [Party 3] Average Train Loss:   0.3396 Train Accuracy: global  87.25% local  77.03% ...   76 forgettables out of 1428 ( 5.32%) ... total data used 1428
# 2021-09-01 13:36:05,685 - INFO -   |--    Epoch Losses (10): [0.4266, 0.3666, 0.3518, 0.3116, 0.3725, 0.3166, 0.3362, 0.2985, 0.3149, 0.3009]
# 2021-09-01 13:36:16,076 - INFO -   |-- [Party 4] Average Train Loss:   0.2881 Train Accuracy: global  89.64% local  88.94% ...   79 forgettables out of 1428 ( 5.53%) ... total data used 1428
# 2021-09-01 13:36:16,077 - INFO -   |--    Epoch Losses (10): [0.3236, 0.3049, 0.3137, 0.2905, 0.294, 0.3297, 0.2695, 0.2548, 0.2557, 0.2449]
# 2021-09-01 13:36:26,247 - INFO -   |-- [Party 5] Average Train Loss:   0.3396 Train Accuracy: global  89.01% local  89.99% ...   94 forgettables out of 1428 ( 6.58%) ... total data used 1428
# 2021-09-01 13:36:26,249 - INFO -   |--    Epoch Losses (10): [0.4232, 0.3738, 0.3588, 0.3209, 0.2942, 0.2795, 0.3188, 0.3428, 0.3533, 0.3306]
# 2021-09-01 13:36:36,252 - INFO -   |-- [Party 6] Average Train Loss:   0.3504 Train Accuracy: global  87.39% local  87.68% ...   86 forgettables out of 1428 ( 6.02%) ... total data used 1428
# 2021-09-01 13:36:36,253 - INFO -   |--    Epoch Losses (10): [0.3992, 0.3722, 0.3541, 0.3163, 0.3442, 0.3093, 0.3067, 0.3329, 0.4172, 0.3516]
# 2021-09-01 13:36:46,160 - INFO -   |-- [Party 7] Average Train Loss:   0.3235 Train Accuracy: global  88.94% local  89.08% ...   65 forgettables out of 1428 ( 4.55%) ... total data used 1428
# 2021-09-01 13:36:46,164 - INFO -   |--    Epoch Losses (10): [0.3411, 0.3278, 0.3245, 0.3172, 0.3032, 0.3117, 0.3129, 0.3006, 0.3266, 0.3689]
# 2021-09-01 13:36:56,726 - INFO -   |-- [Party 8] Average Train Loss:   0.3007 Train Accuracy: global  89.50% local  93.14% ...   61 forgettables out of 1428 ( 4.27%) ... total data used 1428
# 2021-09-01 13:36:56,729 - INFO -   |--    Epoch Losses (10): [0.3751, 0.3394, 0.3187, 0.3177, 0.2933, 0.2884, 0.2596, 0.2667, 0.2852, 0.2632]
# 2021-09-01 13:37:07,102 - INFO -   |-- [Party 9] Average Train Loss:   0.3155 Train Accuracy: global  88.10% local  80.32% ...   90 forgettables out of 1428 ( 6.30%) ... total data used 1428
# 2021-09-01 13:37:07,104 - INFO -   |--    Epoch Losses (10): [0.3556, 0.3341, 0.3035, 0.2703, 0.2775, 0.3477, 0.3427, 0.2941, 0.3186, 0.3106]
# 2021-09-01 13:37:13,091 - INFO -     |---- Number of Forgettables: 3188 (24.81%)
# 2021-09-01 13:37:13,093 - INFO -     |---- Train Accuracy: 69.83%
# 2021-09-01 13:37:13,094 - INFO -     |---- Test Accuracy: 44.25%
# 2021-09-01 13:37:13,095 - INFO -     |---- Test Loss: 2.9189
# 2021-09-01 13:37:13,096 - INFO -     |---- Elapsed time: 0:11:47.356379
# 2021-09-01 13:37:13,097 - INFO -
# Test Acc: Max 44.2500% (7 round) | Last 44.2500% | Avg 38.5714% (3 round)
#
# 2021-09-01 13:37:13,100 - INFO -  | Global Training Round : 8 / 200 |
# 2021-09-01 13:37:25,154 - INFO -   |-- [Party 1] Average Train Loss:   0.4213 Train Accuracy: global   0.00% local  95.66% ... 1269 forgettables out of 1428 (88.87%) ... total data used 1428
# 2021-09-01 13:37:25,156 - INFO -   |--    Epoch Losses (10): [1.2464, 0.6237, 0.4616, 0.3504, 0.2792, 0.2303, 0.2492, 0.2924, 0.2325, 0.2468]
# 2021-09-01 13:37:36,483 - INFO -   |-- [Party 2] Average Train Loss:   0.3805 Train Accuracy: global   0.00% local  92.58% ... 1243 forgettables out of 1428 (87.04%) ... total data used 1428
# 2021-09-01 13:37:36,486 - INFO -   |--    Epoch Losses (10): [1.2324, 0.6023, 0.4417, 0.2884, 0.2077, 0.1884, 0.1829, 0.1941, 0.2413, 0.2259]
# 2021-09-01 13:37:46,928 - INFO -   |-- [Party 3] Average Train Loss:   0.3443 Train Accuracy: global  88.45% local  87.32% ...   76 forgettables out of 1428 ( 5.32%) ... total data used 1428
# 2021-09-01 13:37:46,930 - INFO -   |--    Epoch Losses (10): [0.3779, 0.3768, 0.3438, 0.3138, 0.3138, 0.3789, 0.3693, 0.3612, 0.3169, 0.291]
# 2021-09-01 13:37:56,728 - INFO -   |-- [Party 4] Average Train Loss:   0.2883 Train Accuracy: global  90.55% local  92.09% ...   68 forgettables out of 1428 ( 4.76%) ... total data used 1428
# 2021-09-01 13:37:56,730 - INFO -   |--    Epoch Losses (10): [0.3318, 0.2959, 0.25, 0.2295, 0.2561, 0.3091, 0.3544, 0.3143, 0.2828, 0.2592]
# 2021-09-01 13:38:06,085 - INFO -   |-- [Party 5] Average Train Loss:   0.3060 Train Accuracy: global  90.69% local  92.58% ...   72 forgettables out of 1428 ( 5.04%) ... total data used 1428
# 2021-09-01 13:38:06,088 - INFO -   |--    Epoch Losses (10): [0.3611, 0.3431, 0.2865, 0.304, 0.3123, 0.2968, 0.2676, 0.3054, 0.2924, 0.2912]
# 2021-09-01 13:38:15,343 - INFO -   |-- [Party 6] Average Train Loss:   0.3221 Train Accuracy: global  88.87% local  89.36% ...   79 forgettables out of 1428 ( 5.53%) ... total data used 1428
# 2021-09-01 13:38:15,345 - INFO -   |--    Epoch Losses (10): [0.3935, 0.3732, 0.3385, 0.3278, 0.2914, 0.3251, 0.2898, 0.2961, 0.2928, 0.2931]
# 2021-09-01 13:38:25,327 - INFO -   |-- [Party 7] Average Train Loss:   0.2957 Train Accuracy: global  89.71% local  91.95% ...   68 forgettables out of 1428 ( 4.76%) ... total data used 1428
# 2021-09-01 13:38:25,329 - INFO -   |--    Epoch Losses (10): [0.3838, 0.3814, 0.2926, 0.2915, 0.2829, 0.2908, 0.2895, 0.2567, 0.2417, 0.2461]
# 2021-09-01 13:38:35,684 - INFO -   |-- [Party 8] Average Train Loss:   0.2997 Train Accuracy: global  90.69% local  93.56% ...   81 forgettables out of 1428 ( 5.67%) ... total data used 1428
# 2021-09-01 13:38:35,686 - INFO -   |--    Epoch Losses (10): [0.3294, 0.2895, 0.2916, 0.3128, 0.288, 0.2905, 0.3174, 0.3026, 0.297, 0.2786]
# 2021-09-01 13:38:45,601 - INFO -   |-- [Party 9] Average Train Loss:   0.2818 Train Accuracy: global  89.50% local  94.47% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 13:38:45,605 - INFO -   |--    Epoch Losses (10): [0.3344, 0.3098, 0.2763, 0.3063, 0.2896, 0.2595, 0.2565, 0.2636, 0.2689, 0.2532]
# 2021-09-01 13:38:51,538 - INFO -     |---- Number of Forgettables: 3031 (23.58%)
# 2021-09-01 13:38:51,540 - INFO -     |---- Train Accuracy: 70.11%
# 2021-09-01 13:38:51,541 - INFO -     |---- Test Accuracy: 44.40%
# 2021-09-01 13:38:51,542 - INFO -     |---- Test Loss: 2.9618
# 2021-09-01 13:38:51,542 - INFO -     |---- Elapsed time: 0:13:25.802710
# 2021-09-01 13:38:51,544 - INFO -
# Test Acc: Max 44.4000% (8 round) | Last 44.4000% | Avg 39.3000% (3 round)
#
# 2021-09-01 13:38:51,546 - INFO -  | Global Training Round : 9 / 200 |
# 2021-09-01 13:39:01,675 - INFO -   |-- [Party 1] Average Train Loss:   0.3816 Train Accuracy: global   0.00% local  96.43% ... 1366 forgettables out of 1428 (95.66%) ... total data used 1428
# 2021-09-01 13:39:01,677 - INFO -   |--    Epoch Losses (10): [1.2261, 0.6176, 0.4331, 0.3203, 0.2444, 0.2065, 0.1794, 0.198, 0.2165, 0.1739]
# 2021-09-01 13:39:12,901 - INFO -   |-- [Party 2] Average Train Loss:   0.3647 Train Accuracy: global   0.00% local  98.46% ... 1322 forgettables out of 1428 (92.58%) ... total data used 1428
# 2021-09-01 13:39:12,903 - INFO -   |--    Epoch Losses (10): [1.196, 0.5925, 0.4455, 0.3111, 0.2499, 0.1938, 0.1793, 0.177, 0.155, 0.1473]
# 2021-09-01 13:39:22,816 - INFO -   |-- [Party 3] Average Train Loss:   0.3125 Train Accuracy: global  88.94% local  91.95% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 13:39:22,818 - INFO -   |--    Epoch Losses (10): [0.3639, 0.3453, 0.3319, 0.3397, 0.3284, 0.2713, 0.2795, 0.2735, 0.3116, 0.2799]
# 2021-09-01 13:39:33,959 - INFO -   |-- [Party 4] Average Train Loss:   0.2768 Train Accuracy: global  91.32% local  91.39% ...   63 forgettables out of 1428 ( 4.41%) ... total data used 1428
# 2021-09-01 13:39:33,961 - INFO -   |--    Epoch Losses (10): [0.3038, 0.3281, 0.2845, 0.2355, 0.2227, 0.2717, 0.2879, 0.2865, 0.3034, 0.2444]
# 2021-09-01 13:39:43,987 - INFO -   |-- [Party 5] Average Train Loss:   0.2811 Train Accuracy: global  91.46% local  79.76% ...   59 forgettables out of 1428 ( 4.13%) ... total data used 1428
# 2021-09-01 13:39:43,989 - INFO -   |--    Epoch Losses (10): [0.3129, 0.3396, 0.336, 0.2921, 0.2709, 0.2864, 0.2898, 0.2345, 0.2216, 0.2276]
# 2021-09-01 13:39:55,353 - INFO -   |-- [Party 6] Average Train Loss:   0.3103 Train Accuracy: global  89.57% local  78.43% ...   82 forgettables out of 1428 ( 5.74%) ... total data used 1428
# 2021-09-01 13:39:55,357 - INFO -   |--    Epoch Losses (10): [0.3802, 0.3429, 0.331, 0.2957, 0.3103, 0.3258, 0.2946, 0.2785, 0.2779, 0.2664]
# 2021-09-01 13:40:06,827 - INFO -   |-- [Party 7] Average Train Loss:   0.2798 Train Accuracy: global  90.76% local  89.43% ...   71 forgettables out of 1428 ( 4.97%) ... total data used 1428
# 2021-09-01 13:40:06,830 - INFO -   |--    Epoch Losses (10): [0.3341, 0.3142, 0.2949, 0.32, 0.2495, 0.252, 0.2782, 0.2584, 0.2449, 0.2519]
# 2021-09-01 13:40:18,030 - INFO -   |-- [Party 8] Average Train Loss:   0.2832 Train Accuracy: global  91.18% local  88.73% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 13:40:18,034 - INFO -   |--    Epoch Losses (10): [0.3355, 0.3181, 0.2969, 0.3335, 0.3035, 0.2729, 0.2692, 0.2402, 0.2385, 0.2234]
# 2021-09-01 13:40:28,788 - INFO -   |-- [Party 9] Average Train Loss:   0.2757 Train Accuracy: global  90.97% local  91.46% ...   89 forgettables out of 1428 ( 6.23%) ... total data used 1428
# 2021-09-01 13:40:28,792 - INFO -   |--    Epoch Losses (10): [0.3137, 0.2938, 0.277, 0.2738, 0.3191, 0.316, 0.2451, 0.2337, 0.2326, 0.2521]
# 2021-09-01 13:40:34,816 - INFO -     |---- Number of Forgettables: 3202 (24.91%)
# 2021-09-01 13:40:34,820 - INFO -     |---- Train Accuracy: 67.69%
# 2021-09-01 13:40:34,821 - INFO -     |---- Test Accuracy: 43.10%
# 2021-09-01 13:40:34,822 - INFO -     |---- Test Loss: 3.1422
# 2021-09-01 13:40:34,823 - INFO -     |---- Elapsed time: 0:15:09.083090
# 2021-09-01 13:40:34,824 - INFO -
# Test Acc: Max 43.1000% (8 round) | Last 43.1000% | Avg 39.7222% (3 round)
#
# 2021-09-01 13:40:34,826 - INFO -  | Global Training Round : 10 / 200 |
# 2021-09-01 13:40:45,534 - INFO -   |-- [Party 1] Average Train Loss:   0.3513 Train Accuracy: global   0.00% local  93.63% ... 1377 forgettables out of 1428 (96.43%) ... total data used 1428
# 2021-09-01 13:40:45,538 - INFO -   |--    Epoch Losses (10): [1.1794, 0.5508, 0.4259, 0.319, 0.2181, 0.1902, 0.1546, 0.1438, 0.151, 0.1801]
# 2021-09-01 13:40:55,321 - INFO -   |-- [Party 2] Average Train Loss:   0.3660 Train Accuracy: global   0.00% local  95.66% ... 1406 forgettables out of 1428 (98.46%) ... total data used 1428
# 2021-09-01 13:40:55,325 - INFO -   |--    Epoch Losses (10): [1.1896, 0.5774, 0.4341, 0.313, 0.2353, 0.1929, 0.1871, 0.1729, 0.1698, 0.1882]
# 2021-09-01 13:41:05,774 - INFO -   |-- [Party 3] Average Train Loss:   0.3004 Train Accuracy: global  85.92% local  90.90% ...  115 forgettables out of 1428 ( 8.05%) ... total data used 1428
# 2021-09-01 13:41:05,775 - INFO -   |--    Epoch Losses (10): [0.36, 0.3521, 0.305, 0.2607, 0.2502, 0.2757, 0.2882, 0.3064, 0.3189, 0.2864]
# 2021-09-01 13:41:14,910 - INFO -   |-- [Party 4] Average Train Loss:   0.2408 Train Accuracy: global  86.27% local  92.23% ...   96 forgettables out of 1428 ( 6.72%) ... total data used 1428
# 2021-09-01 13:41:14,911 - INFO -   |--    Epoch Losses (10): [0.3151, 0.2881, 0.2691, 0.2702, 0.2326, 0.2119, 0.1931, 0.218, 0.1998, 0.2104]
# 2021-09-01 13:41:24,206 - INFO -   |-- [Party 5] Average Train Loss:   0.2785 Train Accuracy: global  87.18% local  93.07% ...  163 forgettables out of 1428 (11.41%) ... total data used 1428
# 2021-09-01 13:41:24,208 - INFO -   |--    Epoch Losses (10): [0.3073, 0.2866, 0.2662, 0.296, 0.3209, 0.2642, 0.2868, 0.2742, 0.2462, 0.2368]
# 2021-09-01 13:41:33,423 - INFO -   |-- [Party 6] Average Train Loss:   0.2901 Train Accuracy: global  85.78% local  94.19% ...   48 forgettables out of 1428 ( 3.36%) ... total data used 1428
# 2021-09-01 13:41:33,425 - INFO -   |--    Epoch Losses (10): [0.3632, 0.347, 0.3057, 0.283, 0.2501, 0.3043, 0.2533, 0.2575, 0.2553, 0.281]
# 2021-09-01 13:41:43,244 - INFO -   |-- [Party 7] Average Train Loss:   0.2630 Train Accuracy: global  87.54% local  86.76% ...   75 forgettables out of 1428 ( 5.25%) ... total data used 1428
# 2021-09-01 13:41:43,248 - INFO -   |--    Epoch Losses (10): [0.3198, 0.302, 0.2919, 0.2609, 0.2154, 0.2413, 0.2529, 0.2483, 0.2361, 0.2612]
# 2021-09-01 13:41:53,840 - INFO -   |-- [Party 8] Average Train Loss:   0.2573 Train Accuracy: global  88.73% local  68.07% ...   64 forgettables out of 1428 ( 4.48%) ... total data used 1428
# 2021-09-01 13:41:53,841 - INFO -   |--    Epoch Losses (10): [0.3261, 0.2722, 0.2752, 0.2908, 0.2544, 0.2337, 0.2313, 0.2044, 0.2626, 0.2218]
# 2021-09-01 13:42:04,597 - INFO -   |-- [Party 9] Average Train Loss:   0.2890 Train Accuracy: global  87.82% local  93.35% ...  147 forgettables out of 1428 (10.29%) ... total data used 1428
# 2021-09-01 13:42:04,598 - INFO -   |--    Epoch Losses (10): [0.3362, 0.3211, 0.2836, 0.2698, 0.2538, 0.2731, 0.2955, 0.325, 0.2991, 0.2324]
# 2021-09-01 13:42:10,579 - INFO -     |---- Number of Forgettables: 3491 (27.16%)
# 2021-09-01 13:42:10,581 - INFO -     |---- Train Accuracy: 70.25%
# 2021-09-01 13:42:10,582 - INFO -     |---- Test Accuracy: 44.52%
# 2021-09-01 13:42:10,582 - INFO -     |---- Test Loss: 2.9393
# 2021-09-01 13:42:10,583 - INFO -     |---- Elapsed time: 0:16:44.843362
# 2021-09-01 13:42:10,584 - INFO -
# Test Acc: Max 44.5250% (10 round) | Last 44.5250% | Avg 40.2025% (4 round)
#
# 2021-09-01 13:42:10,586 - INFO -  | Global Training Round : 11 / 200 |
# 2021-09-01 13:42:20,303 - INFO -   |-- [Party 1] Average Train Loss:   0.3547 Train Accuracy: global   0.00% local  92.09% ... 1337 forgettables out of 1428 (93.63%) ... total data used 1428
# 2021-09-01 13:42:20,306 - INFO -   |--    Epoch Losses (10): [1.1217, 0.5436, 0.4175, 0.2917, 0.2396, 0.2013, 0.2005, 0.2064, 0.1767, 0.1478]
# 2021-09-01 13:42:31,101 - INFO -   |-- [Party 2] Average Train Loss:   0.3515 Train Accuracy: global   0.00% local  94.47% ... 1366 forgettables out of 1428 (95.66%) ... total data used 1428
# 2021-09-01 13:42:31,102 - INFO -   |--    Epoch Losses (10): [1.1204, 0.5535, 0.4019, 0.3081, 0.2204, 0.1706, 0.1516, 0.1717, 0.2181, 0.1989]
# 2021-09-01 13:42:40,949 - INFO -   |-- [Party 3] Average Train Loss:   0.2836 Train Accuracy: global  89.85% local  93.63% ...   87 forgettables out of 1428 ( 6.09%) ... total data used 1428
# 2021-09-01 13:42:40,950 - INFO -   |--    Epoch Losses (10): [0.3444, 0.2902, 0.2705, 0.2882, 0.3182, 0.3155, 0.2844, 0.2417, 0.2394, 0.2433]
# 2021-09-01 13:42:51,875 - INFO -   |-- [Party 4] Average Train Loss:   0.2508 Train Accuracy: global  90.97% local  95.31% ...  108 forgettables out of 1428 ( 7.56%) ... total data used 1428
# 2021-09-01 13:42:51,878 - INFO -   |--    Epoch Losses (10): [0.3007, 0.2566, 0.262, 0.2406, 0.2083, 0.2348, 0.2886, 0.2932, 0.211, 0.2124]
# 2021-09-01 13:43:02,829 - INFO -   |-- [Party 5] Average Train Loss:   0.2647 Train Accuracy: global  90.62% local  91.04% ...   98 forgettables out of 1428 ( 6.86%) ... total data used 1428
# 2021-09-01 13:43:02,832 - INFO -   |--    Epoch Losses (10): [0.3178, 0.2707, 0.2373, 0.2578, 0.2614, 0.2501, 0.2586, 0.2345, 0.2364, 0.3227]
# 2021-09-01 13:43:12,860 - INFO -   |-- [Party 6] Average Train Loss:   0.2907 Train Accuracy: global  89.64% local  92.44% ...   99 forgettables out of 1428 ( 6.93%) ... total data used 1428
# 2021-09-01 13:43:12,861 - INFO -   |--    Epoch Losses (10): [0.3399, 0.3198, 0.2846, 0.3096, 0.2935, 0.2496, 0.2833, 0.2866, 0.2815, 0.2584]
# 2021-09-01 13:43:23,944 - INFO -   |-- [Party 7] Average Train Loss:   0.2660 Train Accuracy: global  90.90% local  82.14% ...   97 forgettables out of 1428 ( 6.79%) ... total data used 1428
# 2021-09-01 13:43:23,946 - INFO -   |--    Epoch Losses (10): [0.2911, 0.2822, 0.2646, 0.2607, 0.3067, 0.264, 0.2446, 0.2505, 0.2517, 0.2434]
# 2021-09-01 13:43:33,869 - INFO -   |-- [Party 8] Average Train Loss:   0.2401 Train Accuracy: global  91.74% local  79.20% ...   39 forgettables out of 1428 ( 2.73%) ... total data used 1428
# 2021-09-01 13:43:33,873 - INFO -   |--    Epoch Losses (10): [0.3018, 0.3127, 0.254, 0.2168, 0.2174, 0.2111, 0.1946, 0.2113, 0.247, 0.2341]
# 2021-09-01 13:43:43,710 - INFO -   |-- [Party 9] Average Train Loss:   0.2569 Train Accuracy: global  91.04% local  93.42% ...   69 forgettables out of 1428 ( 4.83%) ... total data used 1428
# 2021-09-01 13:43:43,711 - INFO -   |--    Epoch Losses (10): [0.3258, 0.2818, 0.2666, 0.263, 0.2279, 0.2427, 0.2184, 0.2411, 0.2497, 0.252]
# 2021-09-01 13:43:49,612 - INFO -     |---- Number of Forgettables: 3300 (25.68%)
# 2021-09-01 13:43:49,614 - INFO -     |---- Train Accuracy: 69.86%
# 2021-09-01 13:43:49,615 - INFO -     |---- Test Accuracy: 44.25%
# 2021-09-01 13:43:49,616 - INFO -     |---- Test Loss: 2.9553
# 2021-09-01 13:43:49,617 - INFO -     |---- Elapsed time: 0:18:23.877439
# 2021-09-01 13:43:49,618 - INFO -
# Test Acc: Max 44.2500% (10 round) | Last 44.2500% | Avg 40.5705% (4 round)
#
# 2021-09-01 13:43:49,620 - INFO -  | Global Training Round : 12 / 200 |
# 2021-09-01 13:44:00,422 - INFO -   |-- [Party 1] Average Train Loss:   0.3284 Train Accuracy: global   0.00% local  88.03% ... 1315 forgettables out of 1428 (92.09%) ... total data used 1428
# 2021-09-01 13:44:00,426 - INFO -   |--    Epoch Losses (10): [1.0678, 0.5451, 0.3807, 0.2543, 0.2148, 0.1899, 0.1925, 0.1574, 0.1363, 0.1454]
# 2021-09-01 13:44:11,193 - INFO -   |-- [Party 2] Average Train Loss:   0.3434 Train Accuracy: global   0.00% local  97.62% ... 1349 forgettables out of 1428 (94.47%) ... total data used 1428
# 2021-09-01 13:44:11,194 - INFO -   |--    Epoch Losses (10): [1.0686, 0.5362, 0.3956, 0.2723, 0.2098, 0.1666, 0.1786, 0.2279, 0.2195, 0.1592]
# 2021-09-01 13:44:22,464 - INFO -   |-- [Party 3] Average Train Loss:   0.2834 Train Accuracy: global  87.89% local  92.65% ...  137 forgettables out of 1428 ( 9.59%) ... total data used 1428
# 2021-09-01 13:44:22,468 - INFO -   |--    Epoch Losses (10): [0.3392, 0.3134, 0.2837, 0.253, 0.3031, 0.3091, 0.2793, 0.2499, 0.2351, 0.2685]
# 2021-09-01 13:44:32,601 - INFO -   |-- [Party 4] Average Train Loss:   0.2362 Train Accuracy: global  89.92% local  91.04% ...  120 forgettables out of 1428 ( 8.40%) ... total data used 1428
# 2021-09-01 13:44:32,602 - INFO -   |--    Epoch Losses (10): [0.3267, 0.2447, 0.2394, 0.2272, 0.2203, 0.2502, 0.2236, 0.2273, 0.228, 0.1743]
# 2021-09-01 13:44:43,608 - INFO -   |-- [Party 5] Average Train Loss:   0.2472 Train Accuracy: global  90.62% local  77.45% ...   71 forgettables out of 1428 ( 4.97%) ... total data used 1428
# 2021-09-01 13:44:43,612 - INFO -   |--    Epoch Losses (10): [0.3258, 0.2498, 0.2354, 0.2378, 0.2724, 0.2546, 0.2274, 0.2338, 0.23, 0.2049]
# 2021-09-01 13:44:53,840 - INFO -   |-- [Party 6] Average Train Loss:   0.2726 Train Accuracy: global  88.52% local  88.66% ...  109 forgettables out of 1428 ( 7.63%) ... total data used 1428
# 2021-09-01 13:44:53,844 - INFO -   |--    Epoch Losses (10): [0.3473, 0.3121, 0.2686, 0.2747, 0.2802, 0.2403, 0.2093, 0.2472, 0.2695, 0.2765]
# 2021-09-01 13:45:03,930 - INFO -   |-- [Party 7] Average Train Loss:   0.2520 Train Accuracy: global  91.25% local  91.88% ...   28 forgettables out of 1428 ( 1.96%) ... total data used 1428
# 2021-09-01 13:45:03,932 - INFO -   |--    Epoch Losses (10): [0.2964, 0.2875, 0.2764, 0.2607, 0.2569, 0.2406, 0.2029, 0.2194, 0.2456, 0.2331]
# 2021-09-01 13:45:14,221 - INFO -   |-- [Party 8] Average Train Loss:   0.2187 Train Accuracy: global  91.39% local  95.59% ...  102 forgettables out of 1428 ( 7.14%) ... total data used 1428
# 2021-09-01 13:45:14,224 - INFO -   |--    Epoch Losses (10): [0.2732, 0.2259, 0.2059, 0.2281, 0.2298, 0.2191, 0.2339, 0.1954, 0.181, 0.195]
# 2021-09-01 13:45:25,083 - INFO -   |-- [Party 9] Average Train Loss:   0.2569 Train Accuracy: global  90.62% local  91.60% ...   87 forgettables out of 1428 ( 6.09%) ... total data used 1428
# 2021-09-01 13:45:25,084 - INFO -   |--    Epoch Losses (10): [0.3368, 0.2874, 0.2496, 0.2336, 0.251, 0.2877, 0.2501, 0.2297, 0.2134, 0.2299]
# 2021-09-01 13:45:31,061 - INFO -     |---- Number of Forgettables: 3318 (25.82%)
# 2021-09-01 13:45:31,063 - INFO -     |---- Train Accuracy: 70.95%
# 2021-09-01 13:45:31,064 - INFO -     |---- Test Accuracy: 44.90%
# 2021-09-01 13:45:31,065 - INFO -     |---- Test Loss: 2.8657
# 2021-09-01 13:45:31,066 - INFO -     |---- Elapsed time: 0:20:05.326151
# 2021-09-01 13:45:31,067 - INFO -
# Test Acc: Max 44.9000% (12 round) | Last 44.9000% | Avg 40.9312% (4 round)
#
# 2021-09-01 13:45:31,069 - INFO -  | Global Training Round : 13 / 200 |
# 2021-09-01 13:45:41,406 - INFO -   |-- [Party 1] Average Train Loss:   0.3183 Train Accuracy: global   0.00% local  93.77% ... 1257 forgettables out of 1428 (88.03%) ... total data used 1428
# 2021-09-01 13:45:41,410 - INFO -   |--    Epoch Losses (10): [1.0143, 0.5243, 0.3751, 0.2537, 0.2213, 0.1711, 0.1867, 0.1479, 0.1462, 0.1424]
# 2021-09-01 13:45:52,344 - INFO -   |-- [Party 2] Average Train Loss:   0.3164 Train Accuracy: global   0.00% local  96.92% ... 1394 forgettables out of 1428 (97.62%) ... total data used 1428
# 2021-09-01 13:45:52,346 - INFO -   |--    Epoch Losses (10): [1.0093, 0.5234, 0.3954, 0.2592, 0.2242, 0.1949, 0.1465, 0.1405, 0.1294, 0.141]
# 2021-09-01 13:46:03,907 - INFO -   |-- [Party 3] Average Train Loss:   0.2992 Train Accuracy: global  89.22% local  92.65% ...  115 forgettables out of 1428 ( 8.05%) ... total data used 1428
# 2021-09-01 13:46:03,910 - INFO -   |--    Epoch Losses (10): [0.3483, 0.3502, 0.2943, 0.3115, 0.2572, 0.2404, 0.3123, 0.2871, 0.3129, 0.2778]
# 2021-09-01 13:46:15,054 - INFO -   |-- [Party 4] Average Train Loss:   0.2202 Train Accuracy: global  91.74% local  90.62% ...   46 forgettables out of 1428 ( 3.22%) ... total data used 1428
# 2021-09-01 13:46:15,057 - INFO -   |--    Epoch Losses (10): [0.2747, 0.2359, 0.2586, 0.2121, 0.1829, 0.1509, 0.1813, 0.2131, 0.2571, 0.2352]
# 2021-09-01 13:46:25,019 - INFO -   |-- [Party 5] Average Train Loss:   0.2262 Train Accuracy: global  91.95% local  86.34% ...   30 forgettables out of 1428 ( 2.10%) ... total data used 1428
# 2021-09-01 13:46:25,021 - INFO -   |--    Epoch Losses (10): [0.305, 0.3153, 0.2281, 0.2182, 0.1849, 0.1942, 0.1973, 0.1908, 0.2023, 0.2257]
# 2021-09-01 13:46:34,804 - INFO -   |-- [Party 6] Average Train Loss:   0.2619 Train Accuracy: global  90.13% local  95.03% ...  101 forgettables out of 1428 ( 7.07%) ... total data used 1428
# 2021-09-01 13:46:34,806 - INFO -   |--    Epoch Losses (10): [0.3541, 0.3304, 0.2528, 0.2377, 0.2726, 0.2727, 0.2525, 0.2266, 0.2182, 0.2018]
# 2021-09-01 13:46:45,023 - INFO -   |-- [Party 7] Average Train Loss:   0.2510 Train Accuracy: global  92.30% local  93.56% ...   46 forgettables out of 1428 ( 3.22%) ... total data used 1428
# 2021-09-01 13:46:45,024 - INFO -   |--    Epoch Losses (10): [0.2921, 0.2769, 0.2297, 0.2196, 0.2176, 0.2535, 0.2555, 0.2702, 0.264, 0.231]
# 2021-09-01 13:46:55,294 - INFO -   |-- [Party 8] Average Train Loss:   0.2247 Train Accuracy: global  92.93% local  83.75% ...   73 forgettables out of 1428 ( 5.11%) ... total data used 1428
# 2021-09-01 13:46:55,297 - INFO -   |--    Epoch Losses (10): [0.2683, 0.2275, 0.203, 0.2371, 0.2842, 0.2223, 0.1823, 0.186, 0.2028, 0.2337]
# 2021-09-01 13:47:05,291 - INFO -   |-- [Party 9] Average Train Loss:   0.2338 Train Accuracy: global  91.39% local  90.20% ...   95 forgettables out of 1428 ( 6.65%) ... total data used 1428
# 2021-09-01 13:47:05,292 - INFO -   |--    Epoch Losses (10): [0.2652, 0.2437, 0.2201, 0.2472, 0.3109, 0.2536, 0.2422, 0.2113, 0.1704, 0.1733]
# 2021-09-01 13:47:11,295 - INFO -     |---- Number of Forgettables: 3157 (24.56%)
# 2021-09-01 13:47:11,299 - INFO -     |---- Train Accuracy: 71.97%
# 2021-09-01 13:47:11,300 - INFO -     |---- Test Accuracy: 45.52%
# 2021-09-01 13:47:11,301 - INFO -     |---- Test Loss: 2.7777
# 2021-09-01 13:47:11,302 - INFO -     |---- Elapsed time: 0:21:45.562392
# 2021-09-01 13:47:11,303 - INFO -
# Test Acc: Max 45.5250% (13 round) | Last 45.5250% | Avg 41.2846% (4 round)
#
# 2021-09-01 13:47:11,306 - INFO -  | Global Training Round : 14 / 200 |
# 2021-09-01 13:47:21,652 - INFO -   |-- [Party 1] Average Train Loss:   0.3340 Train Accuracy: global   0.00% local  96.22% ... 1339 forgettables out of 1428 (93.77%) ... total data used 1428
# 2021-09-01 13:47:21,655 - INFO -   |--    Epoch Losses (10): [1.043, 0.5273, 0.375, 0.263, 0.1988, 0.1941, 0.1915, 0.1767, 0.1802, 0.1899]
# 2021-09-01 13:47:31,753 - INFO -   |-- [Party 2] Average Train Loss:   0.3059 Train Accuracy: global   0.00% local  95.87% ... 1384 forgettables out of 1428 (96.92%) ... total data used 1428
# 2021-09-01 13:47:31,757 - INFO -   |--    Epoch Losses (10): [1.0249, 0.5145, 0.3752, 0.2473, 0.1822, 0.1678, 0.1537, 0.1186, 0.1283, 0.146]
# 2021-09-01 13:47:42,416 - INFO -   |-- [Party 3] Average Train Loss:   0.2649 Train Accuracy: global  90.62% local  94.47% ...   90 forgettables out of 1428 ( 6.30%) ... total data used 1428
# 2021-09-01 13:47:42,420 - INFO -   |--    Epoch Losses (10): [0.3385, 0.264, 0.2884, 0.272, 0.2194, 0.2257, 0.2391, 0.2798, 0.272, 0.2495]
# 2021-09-01 13:47:52,165 - INFO -   |-- [Party 4] Average Train Loss:   0.2052 Train Accuracy: global  92.79% local  80.39% ...   43 forgettables out of 1428 ( 3.01%) ... total data used 1428
# 2021-09-01 13:47:52,167 - INFO -   |--    Epoch Losses (10): [0.2807, 0.2507, 0.2192, 0.1995, 0.2049, 0.1727, 0.1991, 0.1856, 0.155, 0.1849]
# 2021-09-01 13:48:02,303 - INFO -   |-- [Party 5] Average Train Loss:   0.2127 Train Accuracy: global  92.51% local  92.44% ...   49 forgettables out of 1428 ( 3.43%) ... total data used 1428
# 2021-09-01 13:48:02,305 - INFO -   |--    Epoch Losses (10): [0.2767, 0.2385, 0.2168, 0.2045, 0.2373, 0.1761, 0.1936, 0.1889, 0.2049, 0.1897]
# 2021-09-01 13:48:13,255 - INFO -   |-- [Party 6] Average Train Loss:   0.2452 Train Accuracy: global  91.25% local  92.79% ...   87 forgettables out of 1428 ( 6.09%) ... total data used 1428
# 2021-09-01 13:48:13,257 - INFO -   |--    Epoch Losses (10): [0.3207, 0.2847, 0.2594, 0.2154, 0.2077, 0.2426, 0.2439, 0.208, 0.2059, 0.2638]
# ...
# 2021-09-01 18:57:26,979 - INFO -   |--    Epoch Losses (10): [0.0402, 0.0532, 0.0442, 0.0442, 0.0474, 0.0431, 0.0337, 0.0502, 0.1241, 0.1618]
# 2021-09-01 18:57:37,649 - INFO -   |-- [Party 6] Average Train Loss:   0.0692 Train Accuracy: global  99.79% local 100.00% ...    3 forgettables out of 1428 ( 0.21%) ... total data used 1428
# 2021-09-01 18:57:37,653 - INFO -   |--    Epoch Losses (10): [0.0426, 0.0615, 0.0712, 0.0641, 0.06, 0.0548, 0.1092, 0.101, 0.0717, 0.0564]
# 2021-09-01 18:57:47,863 - INFO -   |-- [Party 7] Average Train Loss:   0.0728 Train Accuracy: global  99.86% local  99.44% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 18:57:47,865 - INFO -   |--    Epoch Losses (10): [0.0128, 0.0233, 0.04, 0.0601, 0.104, 0.0976, 0.0837, 0.0873, 0.1205, 0.0988]
# 2021-09-01 18:57:59,024 - INFO -   |-- [Party 8] Average Train Loss:   0.0392 Train Accuracy: global 100.00% local  99.37% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 18:57:59,025 - INFO -   |--    Epoch Losses (10): [0.0303, 0.0437, 0.035, 0.0293, 0.0246, 0.017, 0.0123, 0.0191, 0.0908, 0.0896]
# 2021-09-01 18:58:09,850 - INFO -   |-- [Party 9] Average Train Loss:   0.0764 Train Accuracy: global  99.72% local  98.39% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 18:58:09,851 - INFO -   |--    Epoch Losses (10): [0.0303, 0.0492, 0.0441, 0.0362, 0.0316, 0.0345, 0.0511, 0.1277, 0.1656, 0.1937]
# 2021-09-01 18:58:15,825 - INFO -     |---- Number of Forgettables: 2856 (22.22%)
# 2021-09-01 18:58:15,826 - INFO -     |---- Train Accuracy: 77.65%
# 2021-09-01 18:58:15,827 - INFO -     |---- Test Accuracy: 47.60%
# 2021-09-01 18:58:15,828 - INFO -     |---- Test Loss: 2.9032
# 2021-09-01 18:58:15,829 - INFO -     |---- Elapsed time: 5:32:50.089293
# 2021-09-01 18:58:15,830 - INFO -
# Test Acc: Max 47.6000% (163 round) | Last 47.6000% | Avg 46.2955% (23 round)
#
# 2021-09-01 18:58:15,832 - INFO -  | Global Training Round : 197 / 200 |
# 2021-09-01 18:58:27,070 - INFO -   |-- [Party 1] Average Train Loss:   0.0326 Train Accuracy: global   0.35% local  99.93% ... 1380 forgettables out of 1428 (96.64%) ... total data used 1428
# 2021-09-01 18:58:27,073 - INFO -   |--    Epoch Losses (10): [0.0776, 0.0527, 0.0382, 0.0343, 0.0276, 0.0228, 0.0151, 0.0149, 0.021, 0.0217]
# 2021-09-01 18:58:37,065 - INFO -   |-- [Party 2] Average Train Loss:   0.0468 Train Accuracy: global   0.21% local  99.23% ... 1425 forgettables out of 1428 (99.79%) ... total data used 1428
# 2021-09-01 18:58:37,066 - INFO -   |--    Epoch Losses (10): [0.0713, 0.0581, 0.041, 0.0341, 0.0625, 0.0528, 0.0443, 0.0422, 0.0326, 0.0291]
# 2021-09-01 18:58:48,374 - INFO -   |-- [Party 3] Average Train Loss:   0.1024 Train Accuracy: global  99.44% local  99.93% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 18:58:48,378 - INFO -   |--    Epoch Losses (10): [0.0265, 0.0604, 0.0615, 0.0653, 0.1512, 0.2007, 0.1735, 0.1251, 0.0871, 0.073]
# 2021-09-01 18:58:58,425 - INFO -   |-- [Party 4] Average Train Loss:   0.0527 Train Accuracy: global  99.65% local 100.00% ...    3 forgettables out of 1428 ( 0.21%) ... total data used 1428
# 2021-09-01 18:58:58,426 - INFO -   |--    Epoch Losses (10): [0.0184, 0.0321, 0.0648, 0.0834, 0.0876, 0.0694, 0.0533, 0.0482, 0.0357, 0.0337]
# 2021-09-01 18:59:09,337 - INFO -   |-- [Party 5] Average Train Loss:   0.0384 Train Accuracy: global  99.72% local  99.93% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 18:59:09,339 - INFO -   |--    Epoch Losses (10): [0.0272, 0.0464, 0.0543, 0.0534, 0.0576, 0.0526, 0.0369, 0.0245, 0.0174, 0.0137]
# 2021-09-01 18:59:20,687 - INFO -   |-- [Party 6] Average Train Loss:   0.0561 Train Accuracy: global  99.72% local  99.86% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 18:59:20,689 - INFO -   |--    Epoch Losses (10): [0.0282, 0.0523, 0.0836, 0.0746, 0.0655, 0.0559, 0.0426, 0.041, 0.0611, 0.0558]
# 2021-09-01 18:59:31,660 - INFO -   |-- [Party 7] Average Train Loss:   0.0417 Train Accuracy: global  99.86% local  99.58% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 18:59:31,661 - INFO -   |--    Epoch Losses (10): [0.0277, 0.0465, 0.0517, 0.0445, 0.0438, 0.0401, 0.0387, 0.0348, 0.0341, 0.0552]
# 2021-09-01 18:59:42,712 - INFO -   |-- [Party 8] Average Train Loss:   0.0690 Train Accuracy: global  99.93% local  99.86% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 18:59:42,715 - INFO -   |--    Epoch Losses (10): [0.0214, 0.0229, 0.0325, 0.0787, 0.0945, 0.1038, 0.1105, 0.0902, 0.0793, 0.056]
# 2021-09-01 18:59:54,364 - INFO -   |-- [Party 9] Average Train Loss:   0.0360 Train Accuracy: global  99.93% local 100.00% ...    0 forgettables out of 1428 ( 0.00%) ... total data used 1428
# 2021-09-01 18:59:54,367 - INFO -   |--    Epoch Losses (10): [0.0243, 0.0404, 0.044, 0.0536, 0.0477, 0.0402, 0.0339, 0.0276, 0.026, 0.0225]
# 2021-09-01 19:00:00,348 - INFO -     |---- Number of Forgettables: 2827 (22.00%)
# 2021-09-01 19:00:00,349 - INFO -     |---- Train Accuracy: 77.61%
# 2021-09-01 19:00:00,350 - INFO -     |---- Test Accuracy: 47.30%
# 2021-09-01 19:00:00,350 - INFO -     |---- Test Loss: 3.3846
# 2021-09-01 19:00:00,351 - INFO -     |---- Elapsed time: 5:34:34.611241
# 2021-09-01 19:00:00,352 - INFO -
# Test Acc: Max 47.3000% (163 round) | Last 47.3000% | Avg 46.3006% (23 round)
#
# 2021-09-01 19:00:00,356 - INFO -  | Global Training Round : 198 / 200 |
# 2021-09-01 19:00:12,267 - INFO -   |-- [Party 1] Average Train Loss:   0.0405 Train Accuracy: global   0.21% local 100.00% ... 1424 forgettables out of 1428 (99.72%) ... total data used 1428
# 2021-09-01 19:00:12,269 - INFO -   |--    Epoch Losses (10): [0.1137, 0.081, 0.0488, 0.0373, 0.0347, 0.0282, 0.0203, 0.0177, 0.0129, 0.0101]
# 2021-09-01 19:00:23,497 - INFO -   |-- [Party 2] Average Train Loss:   0.0998 Train Accuracy: global   0.21% local  99.79% ... 1414 forgettables out of 1428 (99.02%) ... total data used 1428
# 2021-09-01 19:00:23,500 - INFO -   |--    Epoch Losses (10): [0.1021, 0.0833, 0.0484, 0.0323, 0.0243, 0.0288, 0.1, 0.232, 0.1874, 0.1598]
# 2021-09-01 19:00:34,957 - INFO -   |-- [Party 3] Average Train Loss:   0.0735 Train Accuracy: global  99.44% local 100.00% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:00:34,958 - INFO -   |--    Epoch Losses (10): [0.0417, 0.0654, 0.0494, 0.0592, 0.0842, 0.0931, 0.0993, 0.0989, 0.0777, 0.066]
# 2021-09-01 19:00:46,238 - INFO -   |-- [Party 4] Average Train Loss:   0.1023 Train Accuracy: global  99.65% local  99.79% ...    5 forgettables out of 1428 ( 0.35%) ... total data used 1428
# 2021-09-01 19:00:46,241 - INFO -   |--    Epoch Losses (10): [0.0314, 0.0395, 0.0292, 0.0232, 0.0389, 0.1265, 0.152, 0.1533, 0.227, 0.2024]
# 2021-09-01 19:00:57,709 - INFO -   |-- [Party 5] Average Train Loss:   0.0872 Train Accuracy: global  99.72% local  97.90% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 19:00:57,713 - INFO -   |--    Epoch Losses (10): [0.0177, 0.0267, 0.0329, 0.0435, 0.045, 0.0569, 0.1738, 0.1794, 0.1581, 0.1376]
# 2021-09-01 19:01:09,296 - INFO -   |-- [Party 6] Average Train Loss:   0.0379 Train Accuracy: global  99.72% local 100.00% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 19:01:09,298 - INFO -   |--    Epoch Losses (10): [0.0439, 0.0689, 0.0606, 0.0555, 0.042, 0.0324, 0.0269, 0.0209, 0.0161, 0.012]
# 2021-09-01 19:01:19,239 - INFO -   |-- [Party 7] Average Train Loss:   0.0468 Train Accuracy: global  99.93% local 100.00% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:01:19,240 - INFO -   |--    Epoch Losses (10): [0.0373, 0.0789, 0.0767, 0.0755, 0.0596, 0.0459, 0.0335, 0.0252, 0.0199, 0.0157]
# 2021-09-01 19:01:29,563 - INFO -   |-- [Party 8] Average Train Loss:   0.0537 Train Accuracy: global  99.79% local  97.90% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 19:01:29,564 - INFO -   |--    Epoch Losses (10): [0.0249, 0.0321, 0.0349, 0.0485, 0.0382, 0.0354, 0.0386, 0.0743, 0.0922, 0.1182]
# 2021-09-01 19:01:40,191 - INFO -   |-- [Party 9] Average Train Loss:   0.0869 Train Accuracy: global  99.93% local 100.00% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:01:40,195 - INFO -   |--    Epoch Losses (10): [0.0243, 0.0334, 0.1763, 0.1711, 0.1527, 0.0933, 0.0661, 0.0499, 0.04, 0.0617]
# 2021-09-01 19:01:46,284 - INFO -     |---- Number of Forgettables: 2863 (22.28%)
# 2021-09-01 19:01:46,285 - INFO -     |---- Train Accuracy: 77.69%
# 2021-09-01 19:01:46,286 - INFO -     |---- Test Accuracy: 47.58%
# 2021-09-01 19:01:46,286 - INFO -     |---- Test Loss: 2.8931
# 2021-09-01 19:01:46,287 - INFO -     |---- Elapsed time: 5:36:20.547538
# 2021-09-01 19:01:46,289 - INFO -
# Test Acc: Max 47.5750% (163 round) | Last 47.5750% | Avg 46.3071% (23 round)
#
# 2021-09-01 19:01:46,291 - INFO -  | Global Training Round : 199 / 200 |
# 2021-09-01 19:01:57,702 - INFO -   |-- [Party 1] Average Train Loss:   0.0509 Train Accuracy: global   0.28% local 100.00% ... 1424 forgettables out of 1428 (99.72%) ... total data used 1428
# 2021-09-01 19:01:57,706 - INFO -   |--    Epoch Losses (10): [0.0973, 0.0893, 0.0551, 0.0368, 0.0267, 0.0275, 0.0379, 0.0493, 0.0461, 0.0435]
# 2021-09-01 19:02:08,053 - INFO -   |-- [Party 2] Average Train Loss:   0.0680 Train Accuracy: global   0.42% local  99.72% ... 1419 forgettables out of 1428 (99.37%) ... total data used 1428
# 2021-09-01 19:02:08,055 - INFO -   |--    Epoch Losses (10): [0.0667, 0.0467, 0.0383, 0.0687, 0.0775, 0.0628, 0.1037, 0.0915, 0.0727, 0.0511]
# 2021-09-01 19:02:17,913 - INFO -   |-- [Party 3] Average Train Loss:   0.0514 Train Accuracy: global  99.72% local 100.00% ...    4 forgettables out of 1428 ( 0.28%) ... total data used 1428
# 2021-09-01 19:02:17,915 - INFO -   |--    Epoch Losses (10): [0.0298, 0.0856, 0.0742, 0.0608, 0.0633, 0.0616, 0.0454, 0.0355, 0.0322, 0.0253]
# 2021-09-01 19:02:28,993 - INFO -   |-- [Party 4] Average Train Loss:   0.0665 Train Accuracy: global  99.79% local  99.79% ...    3 forgettables out of 1428 ( 0.21%) ... total data used 1428
# 2021-09-01 19:02:28,995 - INFO -   |--    Epoch Losses (10): [0.0274, 0.028, 0.028, 0.0268, 0.0436, 0.0947, 0.0953, 0.079, 0.0724, 0.1701]
# 2021-09-01 19:02:39,613 - INFO -   |-- [Party 5] Average Train Loss:   0.0713 Train Accuracy: global  99.86% local  99.09% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 19:02:39,615 - INFO -   |--    Epoch Losses (10): [0.0259, 0.0271, 0.0472, 0.0811, 0.0787, 0.0666, 0.0567, 0.087, 0.1008, 0.1414]
# 2021-09-01 19:02:50,293 - INFO -   |-- [Party 6] Average Train Loss:   0.0925 Train Accuracy: global  99.86% local  79.41% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 19:02:50,296 - INFO -   |--    Epoch Losses (10): [0.0186, 0.0296, 0.0333, 0.0587, 0.0543, 0.0726, 0.107, 0.1419, 0.2064, 0.203]
# 2021-09-01 19:03:01,298 - INFO -   |-- [Party 7] Average Train Loss:   0.0523 Train Accuracy: global  99.86% local  99.72% ...    2 forgettables out of 1428 ( 0.14%) ... total data used 1428
# 2021-09-01 19:03:01,300 - INFO -   |--    Epoch Losses (10): [0.0348, 0.0499, 0.0457, 0.0617, 0.0612, 0.0488, 0.0514, 0.0554, 0.058, 0.0561]
# 2021-09-01 19:03:12,630 - INFO -   |-- [Party 8] Average Train Loss:   0.0625 Train Accuracy: global  99.93% local  99.79% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:03:12,631 - INFO -   |--    Epoch Losses (10): [0.0325, 0.0334, 0.0291, 0.0329, 0.057, 0.0635, 0.0995, 0.1221, 0.0875, 0.0678]
# 2021-09-01 19:03:22,994 - INFO -   |-- [Party 9] Average Train Loss:   0.0733 Train Accuracy: global  99.93% local  99.93% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:03:22,996 - INFO -   |--    Epoch Losses (10): [0.031, 0.0368, 0.0454, 0.0951, 0.1397, 0.1269, 0.0881, 0.0692, 0.0522, 0.0486]
# 2021-09-01 19:03:29,031 - INFO -     |---- Number of Forgettables: 2858 (22.24%)
# 2021-09-01 19:03:29,033 - INFO -     |---- Train Accuracy: 77.74%
# 2021-09-01 19:03:29,034 - INFO -     |---- Test Accuracy: 47.83%
# 2021-09-01 19:03:29,035 - INFO -     |---- Test Loss: 2.7409
# 2021-09-01 19:03:29,035 - INFO -     |---- Elapsed time: 5:38:03.295837
# 2021-09-01 19:03:29,037 - INFO -
# Test Acc: Max 47.8250% (163 round) | Last 47.8250% | Avg 46.3147% (23 round)
#
# 2021-09-01 19:03:29,041 - INFO -  | Global Training Round : 200 / 200 |
# 2021-09-01 19:03:39,512 - INFO -   |-- [Party 1] Average Train Loss:   0.0803 Train Accuracy: global   0.35% local  96.36% ... 1423 forgettables out of 1428 (99.65%) ... total data used 1428
# 2021-09-01 19:03:39,513 - INFO -   |--    Epoch Losses (10): [0.0924, 0.0698, 0.0535, 0.0692, 0.0589, 0.044, 0.0394, 0.0574, 0.1602, 0.1586]
# 2021-09-01 19:03:49,871 - INFO -   |-- [Party 2] Average Train Loss:   0.0725 Train Accuracy: global   0.35% local  99.86% ... 1419 forgettables out of 1428 (99.37%) ... total data used 1428
# 2021-09-01 19:03:49,873 - INFO -   |--    Epoch Losses (10): [0.0725, 0.0648, 0.043, 0.0342, 0.0499, 0.1058, 0.138, 0.0924, 0.0702, 0.0536]
# 2021-09-01 19:03:59,881 - INFO -   |-- [Party 3] Average Train Loss:   0.0330 Train Accuracy: global  99.44% local  99.02% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:03:59,885 - INFO -   |--    Epoch Losses (10): [0.0333, 0.0411, 0.0418, 0.0409, 0.0385, 0.0322, 0.0252, 0.0215, 0.0231, 0.0325]
# 2021-09-01 19:04:09,772 - INFO -   |-- [Party 4] Average Train Loss:   0.0311 Train Accuracy: global  99.44% local  99.93% ...    8 forgettables out of 1428 ( 0.56%) ... total data used 1428
# 2021-09-01 19:04:09,774 - INFO -   |--    Epoch Losses (10): [0.0245, 0.0456, 0.0507, 0.0413, 0.035, 0.0394, 0.0263, 0.0207, 0.0157, 0.0115]
# 2021-09-01 19:04:20,565 - INFO -   |-- [Party 5] Average Train Loss:   0.1012 Train Accuracy: global  99.93% local  99.23% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:04:20,567 - INFO -   |--    Epoch Losses (10): [0.0396, 0.0443, 0.0333, 0.028, 0.034, 0.0974, 0.2319, 0.2313, 0.1673, 0.1048]
# 2021-09-01 19:04:30,543 - INFO -   |-- [Party 6] Average Train Loss:   0.0461 Train Accuracy: global  99.86% local 100.00% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:04:30,545 - INFO -   |--    Epoch Losses (10): [0.0465, 0.0689, 0.0538, 0.0461, 0.0633, 0.0613, 0.0463, 0.0322, 0.0239, 0.0187]
# 2021-09-01 19:04:41,509 - INFO -   |-- [Party 7] Average Train Loss:   0.0422 Train Accuracy: global  99.93% local  93.28% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:04:41,510 - INFO -   |--    Epoch Losses (10): [0.019, 0.0343, 0.0626, 0.0475, 0.0483, 0.0407, 0.0319, 0.0259, 0.0293, 0.0829]
# 2021-09-01 19:04:51,284 - INFO -   |-- [Party 8] Average Train Loss:   0.0361 Train Accuracy: global  99.93% local 100.00% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:04:51,288 - INFO -   |--    Epoch Losses (10): [0.0216, 0.0278, 0.0571, 0.0702, 0.0629, 0.0436, 0.0313, 0.0216, 0.0149, 0.0106]
# 2021-09-01 19:05:02,998 - INFO -   |-- [Party 9] Average Train Loss:   0.0387 Train Accuracy: global  99.93% local  99.93% ...    1 forgettables out of 1428 ( 0.07%) ... total data used 1428
# 2021-09-01 19:05:02,999 - INFO -   |--    Epoch Losses (10): [0.0372, 0.0673, 0.0645, 0.0522, 0.0373, 0.0284, 0.0218, 0.0249, 0.0255, 0.0281]
# 2021-09-01 19:05:08,817 - INFO -     |---- Number of Forgettables: 2863 (22.28%)
# 2021-09-01 19:05:08,818 - INFO -     |---- Train Accuracy: 77.12%
# 2021-09-01 19:05:08,819 - INFO -     |---- Test Accuracy: 46.65%
# 2021-09-01 19:05:08,820 - INFO -     |---- Test Loss: 3.2145
# 2021-09-01 19:05:08,820 - INFO -     |---- Elapsed time: 5:39:43.080573
# 2021-09-01 19:05:08,821 - INFO -
# Test Acc: Max 46.6500% (163 round) | Last 46.6500% | Avg 46.3164% (23 round)

# %%
train_losses = np.asarray(train_losses)
train_accs = np.asarray(train_accs)

with open(os.path.join(path_results, f'{filename}_tr_ls.npy'), 'wb') as f:
    np.save(f, train_losses)
with open(os.path.join(path_results, f'{filename}_tr_acc.npy'), 'wb') as f:
    np.save(f, train_accs)
with open(os.path.join(path_results, f'{filename}_te_ls.npy'), 'wb') as f:
    np.save(f, test_losses)
with open(os.path.join(path_results, f'{filename}_te_acc.npy'), 'wb') as f:
    np.save(f, test_accs)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(50, 30))
axs = axs.ravel()

axs[0].plot(test_accs, c='orange')
axs[0].set_title('Test Accuracies')
axs[0].set_xlabel('Rounds')
axs[0].set_ylabel('Test Accuracy')
axs[1].plot(test_losses, c='blue')
axs[1].set_title('Test Losses')
axs[1].set_xlabel('Rounds')
axs[1].set_ylabel('Test Loss')
axs[2].plot(train_accs, c='red')
axs[2].set_title('Train Average Accuracies by Epochs')
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('Train Average Accuracy')
axs[3].plot(train_losses.mean(axis=1), c='turquoise')
axs[3].set_title('Train Average Losses by Epochs')
axs[3].set_xlabel('Epochs')
axs[3].set_ylabel('Train Average Loss')
axs[4].plot(np.mean(train_accs.reshape(-1, 10), axis=1), c='green')
axs[4].set_title('Train Average Accuracies by Rounds')
axs[4].set_xlabel('Rounds')
axs[4].set_ylabel('Train Average Accuracy')
axs[5].plot(train_losses.mean(axis=1).reshape(-1, 10).mean(axis=1), c='lightpink')
axs[5].set_title('Train Average Losses by Rounds')
axs[5].set_xlabel('Rounds')
axs[5].set_ylabel('Train Average Loss')

plt.show()
